# %% [markdown]
# # Yahoo Finance API

# %%
import csv

import yfinance as yf
import pandas as pd

# Yahoo Finance ticker symbols for the top 20 traded stocks (example list)
import yfinance as yf
import pandas as pd

# Yahoo Finance ticker symbols for the top 20 traded stocks (example list)
top_20_tickers = [
    "AAPL", "MSFT", "AMZN", "GOOGL", "GOOG", "TSLA", "META", "NVDA", "BRK-B", "JPM", 
    "JNJ", "V", "PG", "UNH", "HD", "DIS", "PYPL", "MA", "NFLX", "VZ", "INTC", "KO", 
    "MRK", "BA", "CSCO", "PEP", "CMCSA", "T", "XOM", "PFE", "NKE", "WMT", "ADBE", "CRM", 
    "MCD", "ABT", "CSX", "ORCL", "LLY", "QCOM", "MDT", "RTX", "DHR", "UPS", "LIN", 
    "HON", "AXP", "ANTM", "SBUX", "IBM", "MMM", "AMGN", "CAT", "CVX", "TXN", "GE", "MO", 
    "CL", "AVGO", "SYK", "NEE", "LOW", "SPGI", "CCI", "PLD", "MDLZ", "NOW", "INTU", 
    "LMT", "ISRG", "EL", "BKNG", "TMO", "ZM", "GILD", "VRTX", "FIS", "LRCX", "FDX", "BLK", 
    "ADP", "CI", "APD", "EMR", "ECL", "BAX", "AON", "EOG", "DUK", "USB", "SO", "PNC", 
    "SCHW", "ITW", "GD", "ADM", "ALL", "PSA", "CB", "WM", "APTV", "AIG", "SYY", "TRV"
]

# Columns for the data
columns = ["Ticker", "Price", "Change", "% Change", "Volume", "Avg Vol (3 months)", "Market Cap", "PE Ratio", "52 Week Range"]

# Define a list to hold the stock data
stock_data = []

for ticker in top_20_tickers:
    stock_info = yf.Ticker(ticker).info

    stock_entry = [
        stock_info.get("symbol"),
        stock_info.get("currentPrice"),
        stock_info.get("regularMarketChange"),
        stock_info.get("regularMarketChangePercent"),
        stock_info.get("volume"),
        stock_info.get("averageVolume"),
        stock_info.get("marketCap"),
        stock_info.get("forwardPE", stock_info.get("trailingPE")),
        f'{stock_info.get("fiftyTwoWeekLow")} - {stock_info.get("fiftyTwoWeekHigh")}'
    ]

    stock_data.append(stock_entry)

# Create a DataFrame for better visualization
df = pd.DataFrame(stock_data, columns=columns)
# Columns for the data
columns = ["Ticker", "Price", "Change", "% Change", "Volume", "Avg Vol (3 months)", "Market Cap", "PE Ratio", "52 Week Range"]

# Define a list to hold the stock data
stock_data = []

for ticker in top_20_tickers:
    stock_info = yf.Ticker(ticker).info

    stock_entry = [
        stock_info.get("symbol"),
        stock_info.get("currentPrice"),
        stock_info.get("regularMarketChange"),
        stock_info.get("regularMarketChangePercent"),
        stock_info.get("volume"),
        stock_info.get("averageVolume"),
        stock_info.get("marketCap"),
        stock_info.get("forwardPE", stock_info.get("trailingPE")),
        f'{stock_info.get("fiftyTwoWeekLow")} - {stock_info.get("fiftyTwoWeekHigh")}'
    ]

    stock_data.append(stock_entry)

# Create a DataFrame for better visualization
df = pd.DataFrame(stock_data, columns=columns)

# %%
print(f"df.shape: {df.shape}")
print(f"df.info(): {df.info()}")
print(f"df.head(5): {df.head(5)}")
print(f"df.tail(5): {df.tail(5)}")
# Out:
# df.shape: (104, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Ticker              104 non-null    object
#  1   Price               103 non-null    float64
#  2   Change              0 non-null      object
#  3   % Change            0 non-null      object
#  4   Volume              103 non-null    float64
#  5   Avg Vol (3 months)  103 non-null    float64
#  6   Market Cap          103 non-null    float64
#  7   PE Ratio            103 non-null    float64
#  8   52 Week Range       104 non-null    object
# dtypes: float64(5), object(4)
# memory usage: 7.4+ KB
# df.info(): None
# df.head(5):   Ticker   Price Change % Change      Volume  Avg Vol (3 months)  \
# 0   AAPL  225.89   None     None  40540988.0          65180064.0
# 1   MSFT  421.53   None     None  13998270.0          20303311.0
# 2   AMZN  178.22   None     None  28719266.0          43027953.0
# 3  GOOGL  166.67   None     None  22363188.0          25051003.0
# 4   GOOG  168.40   None     None  12903092.0          17692796.0
#
#      Market Cap   PE Ratio    52 Week Range
# 0  3.434454e+12  30.199198  164.08 - 237.23
# 1  3.133249e+12  27.677610  309.45 - 468.35
# 2  1.870526e+12  30.621992   118.35 - 201.2
# 3  2.061875e+12  19.179518  120.21 - 191.75
# 4  2.060761e+12  19.378597  121.46 - 193.31
# df.tail(5):     Ticker   Price Change % Change     Volume  Avg Vol (3 months)  \
# 99      WM  206.59   None     None  1886697.0           1770383.0
# 100   APTV   70.99   None     None  2657046.0           3409954.0
# 101    AIG   74.43   None     None  2202254.0           4561838.0
# 102    SYY   76.91   None     None  1585297.0           3383690.0
# 103    TRV  218.95   None     None   397707.0           1273495.0
#
#        Market Cap   PE Ratio    52 Week Range
# 99   8.290767e+10  25.791510   149.71 - 225.0
# 100  1.667981e+10   9.043312   65.13 - 104.72
# 101  4.792927e+10  10.572443    57.02 - 80.83
# 102  3.782111e+10  15.537375    62.24 - 82.89
# 103  4.990549e+10  10.638969  157.33 - 232.75

# %%
top_20_tickers = [
    "AAPL", "MSFT", "AMZN", "GOOGL", "GOOG", "TSLA", "META", "NVDA", "BRK-B", "JPM", 
    "JNJ", "V", "PG", "UNH", "HD", "DIS", "PYPL", "MA", "NFLX", "VZ", "INTC", "KO", 
    "MRK", "BA", "CSCO", "PEP", "CMCSA", "T", "XOM", "PFE", "NKE", "WMT", "ADBE", "CRM", 
    "MCD", "ABT", "CSX", "ORCL", "LLY", "QCOM", "MDT", "RTX", "DHR", "UPS", "LIN", 
    "HON", "AXP", "ANTM", "SBUX", "IBM", "MMM", "AMGN", "CAT", "CVX", "TXN", "GE", "MO", 
    "CL", "AVGO", "SYK", "NEE", "LOW", "SPGI", "CCI", "PLD", "MDLZ", "NOW", "INTU", 
    "LMT", "ISRG", "EL", "BKNG", "TMO", "ZM", "GILD", "VRTX", "FIS", "LRCX", "FDX", "BLK", 
    "ADP", "CI", "APD", "EMR", "ECL", "BAX", "AON", "EOG", "DUK", "USB", "SO", "PNC", 
    "SCHW", "ITW", "GD", "ADM", "ALL", "PSA", "CB", "WM", "APTV", "AIG", "SYY", "TRV"
]

input_str = ""
for ticker in top_20_tickers:
    stock_info = yf.Ticker(ticker).info
    row = f'''"{ticker}","{stock_info.get('longName')}"\n'''
    input_str += row

# %%
import csv

csv.Dialect.skipinitialspace = True
rows_in = [row.strip().split(',') for row in input_str.split('\n')]
parsed_rows = []
for row in rows_in:
    new_row = []
    for col in row:
        new_row.append(col.replace('"', ''))
    parsed_rows.append(new_row)

parsed_rows 
# csv.list_dialects()
# Out:
# [['AAPL', 'Apple Inc.'],
#  ['MSFT', 'Microsoft Corporation'],
#  ['AMZN', 'Amazon.com', ' Inc.'],
#  ['GOOGL', 'Alphabet Inc.'],
#  ['GOOG', 'Alphabet Inc.'],
#  ['TSLA', 'Tesla', ' Inc.'],
#  ['META', 'Meta Platforms', ' Inc.'],
#  ['NVDA', 'NVIDIA Corporation'],
#  ['BRK-B', 'Berkshire Hathaway Inc.'],
#  ['JPM', 'JPMorgan Chase & Co.'],
#  ['JNJ', 'Johnson & Johnson'],
#  ['V', 'Visa Inc.'],
#  ['PG', 'The Procter & Gamble Company'],
#  ['UNH', 'UnitedHealth Group Incorporated'],
#  ['HD', 'The Home Depot', ' Inc.'],
#  ['DIS', 'The Walt Disney Company'],
#  ['PYPL', 'PayPal Holdings', ' Inc.'],
#  ['MA', 'Mastercard Incorporated'],
#  ['NFLX', 'Netflix', ' Inc.'],
#  ['VZ', 'Verizon Communications Inc.'],
#  ['INTC', 'Intel Corporation'],
#  ['KO', 'The Coca-Cola Company'],
#  ['MRK', 'Merck & Co.', ' Inc.'],
#  ['BA', 'The Boeing Company'],
#  ['CSCO', 'Cisco Systems', ' Inc.'],
#  ['PEP', 'PepsiCo', ' Inc.'],
#  ['CMCSA', 'Comcast Corporation'],
#  ['T', 'AT&T Inc.'],
#  ['XOM', 'Exxon Mobil Corporation'],
#  ['PFE', 'Pfizer Inc.'],
#  ['NKE', 'NIKE', ' Inc.'],
#  ['WMT', 'Walmart Inc.'],
#  ['ADBE', 'Adobe Inc.'],
#  ['CRM', 'Salesforce', ' Inc.'],
#  ['MCD', "McDonald's Corporation"],
#  ['ABT', 'Abbott Laboratories'],
#  ['CSX', 'CSX Corporation'],
#  ['ORCL', 'Oracle Corporation'],
#  ['LLY', 'Eli Lilly and Company'],
#  ['QCOM', 'QUALCOMM Incorporated'],
#  ['MDT', 'Medtronic plc'],
#  ['RTX', 'RTX Corporation'],
#  ['DHR', 'Danaher Corporation'],
#  ['UPS', 'United Parcel Service', ' Inc.'],
#  ['LIN', 'Linde plc'],
#  ['HON', 'Honeywell International Inc.'],
#  ['AXP', 'American Express Company'],
#  ['ANTM', 'None'],
#  ['SBUX', 'Starbucks Corporation'],
#  ['IBM', 'International Business Machines Corporation'],
#  ['MMM', '3M Company'],
#  ['AMGN', 'Amgen Inc.'],
#  ['CAT', 'Caterpillar Inc.'],
#  ['CVX', 'Chevron Corporation'],
#  ['TXN', 'Texas Instruments Incorporated'],
#  ['GE', 'GE Aerospace'],
#  ['MO', 'Altria Group', ' Inc.'],
#  ['CL', 'Colgate-Palmolive Company'],
#  ['AVGO', 'Broadcom Inc.'],
#  ['SYK', 'Stryker Corporation'],
#  ['NEE', 'NextEra Energy', ' Inc.'],
#  ['LOW', "Lowe's Companies", ' Inc.'],
#  ['SPGI', 'S&P Global Inc.'],
#  ['CCI', 'Crown Castle Inc.'],
#  ['PLD', 'Prologis', ' Inc.'],
#  ['MDLZ', 'Mondelez International', ' Inc.'],
#  ['NOW', 'ServiceNow', ' Inc.'],
#  ['INTU', 'Intuit Inc.'],
#  ['LMT', 'Lockheed Martin Corporation'],
#  ['ISRG', 'Intuitive Surgical', ' Inc.'],
#  ['EL', 'The Estée Lauder Companies Inc.'],
#  ['BKNG', 'Booking Holdings Inc.'],
#  ['TMO', 'Thermo Fisher Scientific Inc.'],
#  ['ZM', 'Zoom Video Communications', ' Inc.'],
#  ['GILD', 'Gilead Sciences', ' Inc.'],
#  ['VRTX', 'Vertex Pharmaceuticals Incorporated'],
#  ['FIS', 'Fidelity National Information Services', ' Inc.'],
#  ['LRCX', 'Lam Research Corporation'],
#  ['FDX', 'FedEx Corporation'],
#  ['BLK', 'BlackRock', ' Inc.'],
#  ['ADP', 'Automatic Data Processing', ' Inc.'],
#  ['CI', 'The Cigna Group'],
#  ['APD', 'Air Products and Chemicals', ' Inc.'],
#  ['EMR', 'Emerson Electric Co.'],
#  ['ECL', 'Ecolab Inc.'],
#  ['BAX', 'Baxter International Inc.'],
#  ['AON', 'Aon plc'],
#  ['EOG', 'EOG Resources', ' Inc.'],
#  ['DUK', 'Duke Energy Corporation'],
#  ['USB', 'U.S. Bancorp'],
#  ['SO', 'The Southern Company'],
#  ['PNC', 'The PNC Financial Services Group', ' Inc.'],
#  ['SCHW', 'The Charles Schwab Corporation'],
#  ['ITW', 'Illinois Tool Works Inc.'],
#  ['GD', 'General Dynamics Corporation'],
#  ['ADM', 'Archer-Daniels-Midland Company'],
#  ['ALL', 'The Allstate Corporation'],
#  ['PSA', 'Public Storage'],
#  ['CB', 'Chubb Limited'],
#  ['WM', 'Waste Management', ' Inc.'],
#  ['APTV', 'Aptiv PLC'],
#  ['AIG', 'American International Group', ' Inc.'],
#  ['SYY', 'Sysco Corporation'],
#  ['TRV', 'The Travelers Companies', ' Inc.'],
#  ['']]

# %%
'''
The following can be used to get 5min bars from the yahoo finance API.
This data can be used to predict a 5min and/or 15min price movement.
  
'''
import pandas as pd
import yfinance as yf
import datetime
import pytz

from pricepredict import PricePredict

def get_price_bars(symbol) -> pd.DataFrame:
    # Get data for today
    eastern = pytz.timezone('US/Eastern')
    now = datetime.datetime.now(eastern)
    start = now.strftime('%Y-%m-%d')
    end = now + datetime.timedelta(days=1)
    end = end.strftime('%Y-%m-%d')

    # Fetch data
    # Interval can be '1m', '5m', '15m', '30m', '1h', '1d'
    # data = yf.download(symbol, start=start, end=end, interval='5m')
    # data = yf.download(symbol, start=start, end=end, interval='1h')
    data = yf.download(symbol, start=start, end=end, interval=PricePredict.Period5min)
    
    return data


bars = get_price_bars('FOLD') 

bars
# Out:
# [*********************100%***********************]  1 of 1 completed
#                               Open     High      Low    Close  Adj Close  \
# Datetime
# 2024-10-21 09:30:00-04:00  11.8500  12.0800  11.7943  12.0800    12.0800
# 2024-10-21 09:35:00-04:00  12.0750  12.0799  11.9500  11.9700    11.9700
# 2024-10-21 09:40:00-04:00  11.9600  11.9700  11.8850  11.9200    11.9200
# 2024-10-21 09:45:00-04:00  11.9250  11.9700  11.9050  11.9650    11.9650
