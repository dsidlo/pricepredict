# %% [markdown]
# # Yahoo Finance API

# %%
import csv

import yfinance as yf
import pandas as pd

# Yahoo Finance ticker symbols for the top 20 traded stocks (example list)
import yfinance as yf
import pandas as pd

# Yahoo Finance ticker symbols for the top 20 traded stocks (example list)
top_20_tickers = [
    "AAPL", "MSFT", "AMZN", "GOOGL", "GOOG", "TSLA", "META", "NVDA", "BRK-B", "JPM", 
    "JNJ", "V", "PG", "UNH", "HD", "DIS", "PYPL", "MA", "NFLX", "VZ", "INTC", "KO", 
    "MRK", "BA", "CSCO", "PEP", "CMCSA", "T", "XOM", "PFE", "NKE", "WMT", "ADBE", "CRM", 
    "MCD", "ABT", "CSX", "ORCL", "LLY", "QCOM", "MDT", "RTX", "DHR", "UPS", "LIN", 
    "HON", "AXP", "ANTM", "SBUX", "IBM", "MMM", "AMGN", "CAT", "CVX", "TXN", "GE", "MO", 
    "CL", "AVGO", "SYK", "NEE", "LOW", "SPGI", "CCI", "PLD", "MDLZ", "NOW", "INTU", 
    "LMT", "ISRG", "EL", "BKNG", "TMO", "ZM", "GILD", "VRTX", "FIS", "LRCX", "FDX", "BLK", 
    "ADP", "CI", "APD", "EMR", "ECL", "BAX", "AON", "EOG", "DUK", "USB", "SO", "PNC", 
    "SCHW", "ITW", "GD", "ADM", "ALL", "PSA", "CB", "WM", "APTV", "AIG", "SYY", "TRV"
]

# Columns for the data
columns = ["Ticker", "Price", "Change", "% Change", "Volume", "Avg Vol (3 months)", "Market Cap", "PE Ratio", "52 Week Range"]

# Define a list to hold the stock data
stock_data = []

for ticker in top_20_tickers:
    stock_info = yf.Ticker(ticker).info

    stock_entry = [
        stock_info.get("symbol"),
        stock_info.get("currentPrice"),
        stock_info.get("regularMarketChange"),
        stock_info.get("regularMarketChangePercent"),
        stock_info.get("volume"),
        stock_info.get("averageVolume"),
        stock_info.get("marketCap"),
        stock_info.get("forwardPE", stock_info.get("trailingPE")),
        f'{stock_info.get("fiftyTwoWeekLow")} - {stock_info.get("fiftyTwoWeekHigh")}'
    ]

    stock_data.append(stock_entry)

# Create a DataFrame for better visualization
df = pd.DataFrame(stock_data, columns=columns)
# Columns for the data
columns = ["Ticker", "Price", "Change", "% Change", "Volume", "Avg Vol (3 months)", "Market Cap", "PE Ratio", "52 Week Range"]

# Define a list to hold the stock data
stock_data = []

for ticker in top_20_tickers:
    stock_info = yf.Ticker(ticker).info

    stock_entry = [
        stock_info.get("symbol"),
        stock_info.get("currentPrice"),
        stock_info.get("regularMarketChange"),
        stock_info.get("regularMarketChangePercent"),
        stock_info.get("volume"),
        stock_info.get("averageVolume"),
        stock_info.get("marketCap"),
        stock_info.get("forwardPE", stock_info.get("trailingPE")),
        f'{stock_info.get("fiftyTwoWeekLow")} - {stock_info.get("fiftyTwoWeekHigh")}'
    ]

    stock_data.append(stock_entry)

# Create a DataFrame for better visualization
df = pd.DataFrame(stock_data, columns=columns)

# %%
print(f"df.shape: {df.shape}")
print(f"df.info(): {df.info()}")
print(f"df.head(5): {df.head(5)}")
print(f"df.tail(5): {df.tail(5)}")
# Out:
# df.shape: (104, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Ticker              104 non-null    object
#  1   Price               103 non-null    float64
#  2   Change              103 non-null    float64
#  3   % Change            103 non-null    float64
#  4   Volume              103 non-null    float64
#  5   Avg Vol (3 months)  103 non-null    float64
#  6   Market Cap          103 non-null    float64
#  7   PE Ratio            103 non-null    float64
#  8   52 Week Range       104 non-null    object
# dtypes: float64(7), object(2)
# memory usage: 7.4+ KB
# df.info(): None
# df.head(5):   Ticker   Price   Change  % Change      Volume  Avg Vol (3 months)  \
# 0   AAPL  252.29  4.84000  1.955950  48839918.0          54379123.0
# 1   MSFT  513.58  1.97003  0.385065  19205931.0          20266984.0
# 2   AMZN  213.04 -1.43001 -0.666764  43119976.0          43823064.0
# 3  GOOGL  253.30  1.84000  0.731725  29564548.0          34807760.0
# 4   GOOG  253.79  1.90999  0.758293  17302137.0          22407254.0
#
#      Market Cap   PE Ratio    52 Week Range
# 0  3.744082e+12  30.359806   169.21 - 260.1
# 1  3.817526e+12  34.353180  344.79 - 555.45
# 2  2.287304e+12  34.640648  161.38 - 242.52
# 3  3.043438e+12  28.270090  140.53 - 256.96
# 4  3.043438e+12  28.356424  142.66 - 257.58
# df.tail(5):     Ticker   Price    Change  % Change     Volume  Avg Vol (3 months)  \
# 99      WM  215.48  2.190000  1.026770  1152428.0           1589182.0
# 100   APTV   82.76 -0.729996 -0.874351  1815382.0           2336803.0
# 101    AIG   77.36  0.340004  0.441449  2768265.0           4519760.0
# 102    SYY   79.91  1.080000  1.370040  1914197.0           3000889.0
# 103    TRV  262.01  0.440002  0.168216  1663587.0           1191325.0
#
#        Market Cap   PE Ratio    52 Week Range
# 99   8.680187e+10  26.701363  199.69 - 242.58
# 100  1.802180e+10  11.856733     47.19 - 88.8
# 101  4.285774e+10  11.529061    69.24 - 88.07
# 102  3.823753e+10  16.241870    67.12 - 83.47
# 103  5.844485e+10  12.329883  230.23 - 287.95

# %%
top_20_tickers = [
    "AAPL", "MSFT", "AMZN", "GOOGL", "GOOG", "TSLA", "META", "NVDA", "BRK-B", "JPM", 
    "JNJ", "V", "PG", "UNH", "HD", "DIS", "PYPL", "MA", "NFLX", "VZ", "INTC", "KO", 
    "MRK", "BA", "CSCO", "PEP", "CMCSA", "T", "XOM", "PFE", "NKE", "WMT", "ADBE", "CRM", 
    "MCD", "ABT", "CSX", "ORCL", "LLY", "QCOM", "MDT", "RTX", "DHR", "UPS", "LIN", 
    "HON", "AXP", "ANTM", "SBUX", "IBM", "MMM", "AMGN", "CAT", "CVX", "TXN", "GE", "MO", 
    "CL", "AVGO", "SYK", "NEE", "LOW", "SPGI", "CCI", "PLD", "MDLZ", "NOW", "INTU", 
    "LMT", "ISRG", "EL", "BKNG", "TMO", "ZM", "GILD", "VRTX", "FIS", "LRCX", "FDX", "BLK", 
    "ADP", "CI", "APD", "EMR", "ECL", "BAX", "AON", "EOG", "DUK", "USB", "SO", "PNC", 
    "SCHW", "ITW", "GD", "ADM", "ALL", "PSA", "CB", "WM", "APTV", "AIG", "SYY", "TRV"
]

input_str = ""
for ticker in top_20_tickers:
    stock_info = yf.Ticker(ticker).info
    row = f'''"{ticker}","{stock_info.get('longName')}"\n'''
    input_str += row

# %%
import csv

csv.Dialect.skipinitialspace = True
rows_in = [row.strip().split(',') for row in input_str.split('\n')]
parsed_rows = []
for row in rows_in:
    new_row = []
    for col in row:
        new_row.append(col.replace('"', ''))
    parsed_rows.append(new_row)

parsed_rows 
# csv.list_dialects()
# Out:
# [['AAPL', 'Apple Inc.'],
#  ['MSFT', 'Microsoft Corporation'],
#  ['AMZN', 'Amazon.com', ' Inc.'],
#  ['GOOGL', 'Alphabet Inc.'],
#  ['GOOG', 'Alphabet Inc.'],
#  ['TSLA', 'Tesla', ' Inc.'],
#  ['META', 'Meta Platforms', ' Inc.'],
#  ['NVDA', 'NVIDIA Corporation'],
#  ['BRK-B', 'Berkshire Hathaway Inc.'],
#  ['JPM', 'JPMorgan Chase & Co.'],
#  ['JNJ', 'Johnson & Johnson'],
#  ['V', 'Visa Inc.'],
#  ['PG', 'The Procter & Gamble Company'],
#  ['UNH', 'UnitedHealth Group Incorporated'],
#  ['HD', 'The Home Depot', ' Inc.'],
#  ['DIS', 'The Walt Disney Company'],
#  ['PYPL', 'PayPal Holdings', ' Inc.'],
#  ['MA', 'Mastercard Incorporated'],
#  ['NFLX', 'Netflix', ' Inc.'],
#  ['VZ', 'Verizon Communications Inc.'],
#  ['INTC', 'Intel Corporation'],
#  ['KO', 'The Coca-Cola Company'],
#  ['MRK', 'Merck & Co.', ' Inc.'],
#  ['BA', 'The Boeing Company'],
#  ['CSCO', 'Cisco Systems', ' Inc.'],
#  ['PEP', 'PepsiCo', ' Inc.'],
#  ['CMCSA', 'Comcast Corporation'],
#  ['T', 'AT&T Inc.'],
#  ['XOM', 'Exxon Mobil Corporation'],
#  ['PFE', 'Pfizer Inc.'],
#  ['NKE', 'NIKE', ' Inc.'],
#  ['WMT', 'Walmart Inc.'],
#  ['ADBE', 'Adobe Inc.'],
#  ['CRM', 'Salesforce', ' Inc.'],
#  ['MCD', "McDonald's Corporation"],
#  ['ABT', 'Abbott Laboratories'],
#  ['CSX', 'CSX Corporation'],
#  ['ORCL', 'Oracle Corporation'],
#  ['LLY', 'Eli Lilly and Company'],
#  ['QCOM', 'QUALCOMM Incorporated'],
#  ['MDT', 'Medtronic plc'],
#  ['RTX', 'RTX Corporation'],
#  ['DHR', 'Danaher Corporation'],
#  ['UPS', 'United Parcel Service', ' Inc.'],
#  ['LIN', 'Linde plc'],
#  ['HON', 'Honeywell International Inc.'],
#  ['AXP', 'American Express Company'],
#  ['ANTM', 'None'],
#  ['SBUX', 'Starbucks Corporation'],
#  ['IBM', 'International Business Machines Corporation'],
#  ['MMM', '3M Company'],
#  ['AMGN', 'Amgen Inc.'],
#  ['CAT', 'Caterpillar Inc.'],
#  ['CVX', 'Chevron Corporation'],
#  ['TXN', 'Texas Instruments Incorporated'],
#  ['GE', 'GE Aerospace'],
#  ['MO', 'Altria Group', ' Inc.'],
#  ['CL', 'Colgate-Palmolive Company'],
#  ['AVGO', 'Broadcom Inc.'],
#  ['SYK', 'Stryker Corporation'],
#  ['NEE', 'NextEra Energy', ' Inc.'],
#  ['LOW', "Lowe's Companies", ' Inc.'],
#  ['SPGI', 'S&P Global Inc.'],
#  ['CCI', 'Crown Castle Inc.'],
#  ['PLD', 'Prologis', ' Inc.'],
#  ['MDLZ', 'Mondelez International', ' Inc.'],
#  ['NOW', 'ServiceNow', ' Inc.'],
#  ['INTU', 'Intuit Inc.'],
#  ['LMT', 'Lockheed Martin Corporation'],
#  ['ISRG', 'Intuitive Surgical', ' Inc.'],
#  ['EL', 'The Estée Lauder Companies Inc.'],
#  ['BKNG', 'Booking Holdings Inc.'],
#  ['TMO', 'Thermo Fisher Scientific Inc.'],
#  ['ZM', 'Zoom Video Communications', ' Inc.'],
#  ['GILD', 'Gilead Sciences', ' Inc.'],
#  ['VRTX', 'Vertex Pharmaceuticals Incorporated'],
#  ['FIS', 'Fidelity National Information Services', ' Inc.'],
#  ['LRCX', 'Lam Research Corporation'],
#  ['FDX', 'FedEx Corporation'],
#  ['BLK', 'BlackRock', ' Inc.'],
#  ['ADP', 'Automatic Data Processing', ' Inc.'],
#  ['CI', 'The Cigna Group'],
#  ['APD', 'Air Products and Chemicals', ' Inc.'],
#  ['EMR', 'Emerson Electric Co.'],
#  ['ECL', 'Ecolab Inc.'],
#  ['BAX', 'Baxter International Inc.'],
#  ['AON', 'Aon plc'],
#  ['EOG', 'EOG Resources', ' Inc.'],
#  ['DUK', 'Duke Energy Corporation'],
#  ['USB', 'U.S. Bancorp'],
#  ['SO', 'The Southern Company'],
#  ['PNC', 'The PNC Financial Services Group', ' Inc.'],
#  ['SCHW', 'The Charles Schwab Corporation'],
#  ['ITW', 'Illinois Tool Works Inc.'],
#  ['GD', 'General Dynamics Corporation'],
#  ['ADM', 'Archer-Daniels-Midland Company'],
#  ['ALL', 'The Allstate Corporation'],
#  ['PSA', 'Public Storage'],
#  ['CB', 'Chubb Limited'],
#  ['WM', 'Waste Management', ' Inc.'],
#  ['APTV', 'Aptiv PLC'],
#  ['AIG', 'American International Group', ' Inc.'],
#  ['SYY', 'Sysco Corporation'],
#  ['TRV', 'The Travelers Companies', ' Inc.'],
#  ['']]

# %%
'''
The following can be used to get 5min bars from the yahoo finance API.
This data can be used to predict a 5min and/or 15min price movement.
  
'''
import pandas as pd
import yfinance as yf
import datetime
import pytz

from pricepredict import PricePredict

def get_price_bars(symbol) -> pd.DataFrame:
    # Get data for today
    eastern = pytz.timezone('US/Eastern')
    now = datetime.datetime.now(eastern)
    end_date = now.strftime('%Y-%m-%d')
    start_date = now - datetime.timedelta(days=2000)
    start_date = start_date.strftime('%Y-%m-%d')
    print("start_date: ", start_date, "   end_date: ", end_date)
    # Fetch data
    # Interval can be '1m', '5m', '15m', '30m', '1h', '1d'
    # data = yf.download(symbol, start_date=end_date, end=end, interval='5m')
    # data = yf.download(symbol, start_date=end_date, end=end, interval='1h')
    # data = yf.download(symbol, start_date=end_date, end=end, interval=PricePredict.Period5min)
    # data = yf.download(symbol, )
    data = yf.Ticker(symbol).history(period='1mo', interval='1d')
    print("Len Data: ", len(data))
    return data


bars = get_price_bars('SRCL') 

bars
# Out:
# start_date:  2020-04-26    end_date:  2025-10-17
# HTTP Error 404:
# $SRCL: possibly delisted; no price data found  (period=1mo) (Yahoo error = "No data found, symbol may be delisted")
# Len Data:  0
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
# Read a test file of S&P 500 stock symbols.
# Validate them against yfinance Tickers function.

import yfinance as yf

# Read the file "SP500-25-01-19.txt". Its format is: <Symbol>: <Company Name>
symbols = []
with open('SP500-25-01-19.txt', 'r') as f:
    lines = f.readlines()
    for l in lines:
        symbol = l.split(':')[0].strip()
        symbols.append(symbol)
        
tickers = yf.Tickers(" ".join(symbols))

valid_symbols = {}
invalid_symbols = {}
for sym in symbols:
    try:
        ticker_info = tickers.tickers[sym].info
        if ticker_info is not None:
            valid_symbols[sym] = ticker_info
    except Exception as e:
        print(f"*** Exception for symbol: {sym}\n->|| {e} ||")    
        invalid_symbols[sym] = e

print("Valid Symbols: ", valid_symbols.keys())
print("Invalid Symbols: ", invalid_symbols.keys())

pass
# Out:
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ABC?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ABC&crumb=bgvhQJdnZhi
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ABMD?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ABMD&crumb=bgvhQJdnZhi
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ATVI?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ATVI&crumb=bgvhQJdnZhi
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/DISH?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=DISH&crumb=bgvhQJdnZhi
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/GPS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=GPS&crumb=bgvhQJdnZhi
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/PXD?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=PXD&crumb=bgvhQJdnZhi
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/RE?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=RE&crumb=bgvhQJdnZhi
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/SIVB?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=SIVB&crumb=bgvhQJdnZhi
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/WRK?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=WRK&crumb=bgvhQJdnZhi
# Valid Symbols:  dict_keys(['A', 'AAL', 'AAP', 'AAPL', 'ABBV', 'ABC', 'ABMD', 'ABT', 'ACN', 'ADBE', 'ADI', 'ADM', 'ADP', 'ADSK', 'AEE', 'AEP', 'AES', 'AFL', 'AIG', 'AIV', 'AIZ', 'AJG', 'AKAM', 'ALB', 'ALGN', 'ALK', 'ALL', 'ALLE', 'AMAT', 'AMCR', 'AMD', 'AME', 'AMGN', 'AMP', 'AMT', 'AMZN', 'ANET', 'ANSS', 'ANTM', 'AON', 'AOS', 'APA', 'APD', 'APH', 'APTV', 'ARE', 'ATO', 'ATVI', 'AVB', 'AVGO', 'AVY', 'AWK', 'AXP', 'AZO', 'BA', 'BAC', 'BAX', 'BBY', 'BDX', 'BEN', 'BIIB', 'BK', 'BKNG', 'BKR', 'BLK', 'BLL', 'BMY', 'BR', 'BRK.B', 'BSX', 'BWA', 'BXP', 'C', 'CAG', 'CAH', 'CARR', 'CAT', 'CB', 'CBOE', 'CBRE', 'CCI', 'CCL', 'CDNS', 'CDW', 'CE', 'CEG', 'CERN', 'CF', 'CFG', 'CHD', 'CHRW', 'CHTR', 'CI', 'CINF', 'CL', 'CLX', 'CMA', 'CMCSA', 'CME', 'CMG', 'CMI', 'CMS', 'CNC', 'CNP', 'COF', 'COG', 'COLM', 'COMP', 'COP', 'COST', 'COTY', 'CPB', 'CPRT', 'CRM', 'CSCO', 'CSX', 'CTAS', 'CTLT', 'CTRA', 'CTSH', 'CTXS', 'CVS', 'CVX', 'CZR', 'D', 'DAL', 'DE', 'DFS', 'DG', 'DGX', 'DHI', 'DHR', 'DIS', 'DISH', 'DLR', 'DLTR', 'DOV', 'DOW', 'DPZ', 'DRE', 'DRI', 'DTE', 'DUK', 'DVA', 'DVN', 'DXC', 'EA', 'EBAY', 'ECL', 'ED', 'EFX', 'EIX', 'EL', 'EMN', 'EMR', 'EOG', 'EPAM', 'EQT', 'ES', 'ESS', 'ETFC', 'ETN', 'ETR', 'EVRG', 'EW', 'EXC', 'EXPD', 'EXPE', 'EXR', 'F', 'FANG', 'FAST', 'FB', 'FBHS', 'FCX', 'FDX', 'FE', 'FFIV', 'FIS', 'FISV', 'FITB', 'FLIR', 'FLS', 'FMC', 'FOX', 'FOXA', 'FRC', 'FRT', 'FTI', 'FTNT', 'FTV', 'GD', 'GE', 'GILD', 'GIS', 'GL', 'GLW', 'GM', 'GNRC', 'GOOGL', 'GOOG', 'GPC', 'GPN', 'GPS', 'GRMN', 'GS', 'GWW', 'HAL', 'HAS', 'HBAN', 'HBI', 'HCA', 'HD', 'HES', 'HIG', 'HII', 'HLT', 'HON', 'HP', 'HPQ', 'HRL', 'HSIC', 'HST', 'HSY', 'HUM', 'HWM', 'IBM', 'ICE', 'IDXX', 'IEX', 'IFF', 'ILMN', 'INCY', 'INFO', 'INTC', 'INTU', 'IP', 'IPG', 'IQV', 'IR', 'IRM', 'ISRG', 'IT', 'ITW', 'IVZ', 'J', 'JBHT', 'JCI', 'JKHY', 'JNJ', 'JNPR', 'JPM', 'K', 'KEY', 'KEYS', 'KHC', 'KIM', 'KLAC', 'KMB', 'KMI', 'KMX', 'KO', 'KR', 'L', 'LB', 'LDOS', 'LEG', 'LEN', 'LH', 'LHX', 'LIN', 'LKQ', 'LLY', 'LMT', 'LNC', 'LNT', 'LOW', 'LRCX', 'LULU', 'LUMN', 'LUV', 'LVS', 'LW', 'LYB', 'LYV', 'MA', 'MAA', 'MAR', 'MAS', 'MCD', 'MCHP', 'MCK', 'MCO', 'MDLZ', 'MDT', 'MET', 'MGM', 'MHK', 'MKC', 'MKTX', 'MLM', 'MMC', 'MMM', 'MNST', 'MO', 'MOH', 'MOS', 'MPC', 'MPWR', 'MRK', 'MRO', 'MS', 'MSCI', 'MSFT', 'MSI', 'MTB', 'MTD', 'MU', 'NBL', 'NCLH', 'NDAQ', 'NEE', 'NEM', 'NFLX', 'NI', 'NKE', 'NLOK', 'NLSN', 'NOC', 'NOW', 'NRG', 'NSC', 'NTAP', 'NTRS', 'NUE', 'NVDA', 'NVR', 'NWL', 'NWS', 'NWSA', 'O', 'ODFL', 'OKE', 'OMC', 'ORCL', 'ORLY', 'OTIS', 'OXY', 'PAYC', 'PAYX', 'PCAR', 'PEG', 'PEP', 'PFE', 'PFG', 'PG', 'PGR', 'PH', 'PHM', 'PKG', 'PKI', 'PLD', 'PM', 'PNC', 'PNR', 'PNW', 'POOL', 'PPG', 'PPL', 'PRGO', 'PRU', 'PSA', 'PSX', 'PVH', 'PWR', 'PXD', 'QCOM', 'QRVO', 'RCL', 'RE', 'REG', 'REGN', 'RF', 'RHI', 'RJF', 'RL', 'RMD', 'ROK', 'ROL', 'ROP', 'ROST', 'RSG', 'RTX', 'SBAC', 'SBNY', 'SBUX', 'SCHW', 'SEE', 'SHW', 'SIVB', 'SJM', 'SLB', 'SLG', 'SNA', 'SNPS', 'SO', 'SPG', 'SPGI', 'SRE', 'STE', 'STT', 'STX', 'STZ', 'SWK', 'SWKS', 'SYF', 'SYK', 'SYY', 'T', 'TAP', 'TDG', 'TDY', 'TECH', 'TEL', 'TER', 'TFC', 'TGT', 'TIF', 'TJX', 'TMO', 'TMUS', 'TPR', 'TRMB', 'TROW', 'TRV', 'TSCO', 'TSN', 'TT', 'TTWO', 'TWTR', 'TXN', 'TXT', 'TYL', 'UA', 'UAA', 'UAL', 'UDR', 'UHS', 'ULTA', 'UNH', 'UNM', 'UNP', 'UPS', 'URI', 'USB', 'V', 'VFC', 'VIAC', 'VICI', 'VLO', 'VMC', 'VNO', 'VNT', 'VNTV', 'VRSK', 'VRSN', 'VRTX', 'VTR', 'VTRS', 'VZ', 'WAB', 'WAT', 'WBA', 'WBD', 'WDC', 'WEC', 'WELL', 'WFC', 'WHR', 'WLTW', 'WM', 'WMB', 'WMT', 'WRB', 'WRK', 'WST', 'WTW', 'WY', 'WYNN', 'XEL', 'XOM', 'XRAY', 'XYL', 'YUM', 'ZBH', 'ZBRA', 'ZION', 'ZTS'])
# Invalid Symbols:  dict_keys([])
