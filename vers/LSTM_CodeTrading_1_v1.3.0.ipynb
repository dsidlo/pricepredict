# %% [markdown]
# # Price ML Predicion
#
# ## Price Prediction's Caveats
#
#   When the characteristics of the instrument are far from stable, price prediction can be quite off.
#   - Examples...
#     - SERV
#     - MEDS
#     - XCUR
#
#   Price Prediction should be combined with Prediction of market highs and lows because if you just entered the market based on predicted price, you could get washed out by manipulative Market Wales hitting your stops.
#
#   Predicting High, Low, Market Open and Market Close Should be done using separate models, using the same model parameters.
#
#   Before trading an instrument, one should review the median market price range, verses median prediction accuracy delta, to verify whether the instrument is worth trading. I have a hunch that the smaller the trading range as compared to the prediction delta, the less likely the instrument is worth engaging with.
# <p>
#
# ## Current Enhancements
#
# From a visual review, although the prediction strays from the price
#    the trend of the prediction seems quite accurate.
#    By pulling the prediction closer to the price, by an average of the delta,
#    between the price and the prediction, the new prediction is quite accurate.
# <p>
#
# ## Enhancements (to add)
#
# We should be able to add prediction targets for high and low for the day by
#    adding the target high-difference and low-difference to the data set,
#    similar to the way we added the target close-difference.
#
# We can also apparently pull minute bars from Yahoo. And with that, we can
#    perform more granular predictions, to the hour, 15min, 5min, and
#    1min period.
#
# ## Version Notes:
#    - Tried smoothing the High & Low prediction by averaging final adjusted predictions.
#    - But, not feeling the results.
#
# ## New Idea...
#    - Make predictions into line segments. Where the first point is aligned to the last close price, and the last point is the predicted close price. The last point is the delta between the prior predicted close (moved up to the last close price) and the predicted close price.
#       1. Generate deltas between each predicted close price.
#       2. Generate line segments from close price to close price + delta.
#       3. Plot the line segments.

# %% [markdown]
# # Choose an existing model -or- Create a New Model

# %%
# Create a list of available .keras models from model_dir...
# Restart the kernel
# %reset -f
# %gui asyncio

import ipywidgets as widgets
from ipywidgets import Output, Checkbox, TwoByTwoLayout
import re
import datetime
import os
import asyncio
import yfinance as yf

# os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'

global Ticker, DataStart, DateEnd, ticker, dateStart, dateEnd, CreateNewModel, model_dir, model_files, Selected_Model

Ticker    = 'AMZN'

DateStart = '2015-06-03'
DateEnd   = '2024-07-30'
CreateNewModel = "Create New Model"

# Get list of file from the model directory...
model_dir = 'models/'
model_files = os.listdir(model_dir)
Selected_Model = None

def wait_for_change(widget, value):
    future = asyncio.Future()
    def getvalue(change):
        # make the new value available
        future.set_result(change.new)
        widget.unobserve(getvalue, value)
    widget.observe(getvalue, value)
    return future

PredsDaily  = 'Daily Predictions'
PredsWeekly = 'Weekly Predictions'

def model_choices():
    global Ticker, DataStart, DateEnd, ticker, dateStart, dateEnd, CreateNewModel, model_dir, model_files, Selected_Model
    
    # Filter the list to only include .keras files...
    models_lst = [file for file in model_files if re.search(r'\.keras$', file)]
    models_lst.sort()
    model_files = [CreateNewModel] + models_lst
    # Display the list of files...
    Selected_Model = widgets.Select ( options=model_files,
                                      value=model_files[0],
                                      description='Model File: ',
                                      disabled=False )
    ticker     = widgets.Text(value=Ticker, description='TICKER: ')
    DateStart = "2015-01-01"
    dateStart = widgets.Text(value=DateStart, description='Start Date: ')
    chk_save_model = widgets.Checkbox(value=True, description='Save Model')
    dd_period = widgets.Dropdown(options=[PredsDaily, PredsWeekly],
                                 value=PredsDaily, description='Periods')
    
    # Set the DateEnd to today's date with the format 'YYYY-MM-DD, determined by the system date.
    if Selected_Model.value == CreateNewModel:
        DateEnd = datetime.datetime.now().strftime('%Y-%m-%d')
    dateEnd   = widgets.Text(value=DateEnd, description='End Date: ')
    out = Output()
    
    async def f0():
        for i in range(10):
            out.append_stdout('did work ' + str(i) + '\n')
            x = await wait_for_change(Selected_Model, 'value')
            if Selected_Model.value != CreateNewModel:
                ticker.value = Selected_Model.value.split('_')[0]
                if '~' in ticker.value:
                    ticker.value = ticker.value.replace('~', '=')
            out.append_stdout('async function continued with value ' + str(x) + '\n')
        asyncio.ensure_future(f0())
    
    async def f1():
        for i in range(10):
            out.append_stdout('did work ' + str(i) + '\n')
            x = await wait_for_change(ticker, 'value')
            tkr = ticker.value
            tkr = re.sub(r'Invalid: ', '', tkr)
            if Selected_Model.value == CreateNewModel:
                # Check yahoo if symbol is valid...
                try:
                    ticker_ = yf.Ticker(tkr).history(period='5d',interval='1d')
                except:
                    ticker_ = []
                if len(ticker_) == 0:
                    ticker.value = 'Invalid: ' + tkr
                else:
                    ticker.value = ticker.upper()
            out.append_stdout('async function continued with value ' + str(x) + '\n')
        asyncio.ensure_future(f1())
    
    asyncio.ensure_future(f0())
    asyncio.ensure_future(f1())
    
    from IPython.display import display, Pretty, Markdown, Latex
    inst0 = """
        +-------------------------------+
        | Choose or Create a New Model  |
        +-------------------------------+
        
    Make you Model Selection and Updates the Start and End Dates.
    Or, Create a New Model by entering by leave the Model File: as
    "Create New Model", and entering the Ticker, Start Date and End Date.
    """
    display(Pretty(inst0))
    
    # print(inst0, inst1)
    display(Selected_Model)
    print()
    display(ticker, dateStart, dateEnd, chk_save_model, dd_period)
    print()
    # display(out)

    # if selected_model.value == CreateNewModel:
    # - Create a new model using the ticker.value, dateStart.value, DateEnd.vale values.
    return(Selected_Model, ticker, dateStart, dateEnd, chk_save_model, dd_period, asyncio)

Selected_Model, ticker, dateStart, dateEnd, chk_save_model, dd_period, asyncio = model_choices()
# Out:
#         +-------------------------------+
#         | Choose or Create a New Model  |
#         +-------------------------------+
#
#     Make you Model Selection and Updates the Start and End Dates.
#     Or, Create a New Model by entering by leave the Model File: as
#     "Create New Model", and entering the Ticker, Start Date and End Date.
# Select(description='Model File: ', options=('Create New Model', 'AAPL_2015-01-01_2024-07-30.keras', 'AAPL_2020…
# Text(value='AMZN', description='TICKER: ')
# Text(value='2015-01-01', description='Start Date: ')
# Text(value='2024-08-14', description='End Date: ')
# Checkbox(value=True, description='Save Model')
# Dropdown(description='Periods', options=('Daily Predictions', 'Weekly Predictions'), value='Daily Predictions'…

# %%
def print_model_choices(Selected_Model, ticker, dateStart, dateEnd, chk_save_model, dd_period):
    print( "Selected_Model:", Selected_Model.value)
    print("Ticker: ", ticker.value)
    print("DateStart: ", dateStart.value)
    print("DateEnd: ", dateEnd.value)
    print("Save Model: ", chk_save_model.value)
    print("Period: ", dd_period.value)

print_model_choices(Selected_Model, ticker, dateStart, dateEnd, chk_save_model, dd_period)
# Out:
# Selected_Model: NVDA_2015-01-01_2024-08-07.keras
# Ticker:  NVDA
# DateStart:  2015-01-01
# DateEnd:  2024-08-14
# Save Model:  True
# Period:  Daily Predictions

# %% [markdown]
# #  Load the latest data for the selected Ticker...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn
import pandas as pd
import yfinance as yf

def load_data():
    global Ticker, DataStart, DateEnd, ticker, dateStart, dateEnd, CreateNewModel, model_dir, model_files, model_path, Selected_Model
    global data_orig, data, feature_cnt, feature_cnt_dl

    model_dir = 'models/'

    if Selected_Model.value == CreateNewModel:
        modelDateStart = DateStart
        modelDateEnd = DateEnd
        if dd_period.value == PredsDaily:
            model_file = ticker.value + "_" + dateStart.value + "_" + dateEnd.value + ".keras"
            model_path = model_dir + model_file
        elif dd_period.value == PredsWeekly:
            model_file = ticker.value + "_w_" + dateStart.value + "_" + dateEnd.value + ".keras"
            model_path = model_dir + model_file
            
    else:
        model_path = model_dir + Selected_Model.value

    # If we are using an existing model, we still have to download the data as we need the
    # actual price data to adjust the prediction.

    # If the predicted value varies/swings-about too much from the price,
    # the days/period training period many be changed to exclude the prior period
    # That does not have present-time characteristics with regard to price movement.
    data_orig = yf.download(tickers = ticker.value, start = dateStart.value, end = dateEnd.value)
    data=data_orig.copy(deep=True)
    offset = pd.Timedelta(days=-30)
    # Resample to 'W'eekly or 'ME'(Month End)
    # logic = {'Open'  : 'first',
    #          'High'  : 'max',
    #          'Low'   : 'min',
    #          'Close' : 'last',
    #          'Adj Close': 'last',
    #          'Volume': 'sum'}
    # data = data.resample('W', offset=offset).apply(logic)
    print("Pulling Data for:", ticker.value, "from", dateStart.value, "to", dateEnd.value)
    print("data.len():", len(data), "data.shape:", data.shape)

    feature_cnt_dl = data.shape[1]
    feature_cnt = feature_cnt_dl + 1  # Actual count vs index count.
    return data_orig, data, feature_cnt

def aggregate_data(data):
    data = data.resample('W').agg({'Open': 'first', 'High': 'max', 'Low': 'min', 'Close': 'last', 'Adj Close': 'last', 'Volume': 'sum'})
    return data

data_orig, data, feature_cnt = load_data()

# Keep a copy of the original data before possible aggregation.
data_original = data_orig

if dd_period.value == PredsWeekly or '_w_' in model_path:
    data = aggregate_data(data)
    data_orig = data.copy(deep=True)

print("data.shape:", data.shape)
print("data:", data.head(5), data.tail(5))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Pulling Data for: NVDA from 2015-01-01 to 2024-08-14
# data.len(): 2419 data.shape: (2419, 6)
# data.shape: (2419, 6)
# data:                Open     High      Low    Close  Adj Close     Volume
# Date
# 2015-01-02  0.50325  0.50700  0.49525  0.50325   0.483218  113680000
# 2015-01-05  0.50325  0.50475  0.49250  0.49475   0.475057  197952000
# 2015-01-06  0.49550  0.49600  0.47925  0.47975   0.460654  197764000
# 2015-01-07  0.48325  0.48750  0.47700  0.47850   0.459453  321808000
# 2015-01-08  0.48400  0.49950  0.48375  0.49650   0.476737  283780000                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-08-07  107.809998  108.800003   98.690002   98.910004   98.910004
# 2024-08-08  102.000000  105.500000   97.519997  104.970001  104.970001
# 2024-08-09  105.639999  106.599998  103.430000  104.750000  104.750000
# 2024-08-12  106.320000  111.070000  106.260002  109.019997  109.019997
# 2024-08-13  112.440002  116.230003  111.580002  116.139999  116.139999
#
#                Volume
# Date
# 2024-08-07  411440400
# 2024-08-08  391910000
# 2024-08-09  290844200
# 2024-08-12  325559900
# 2024-08-13  312646700

# %% [markdown]
# ##  - Add indicators to the data

# %%
# Add indicators to the data...

import pandas_ta as ta

def add_indicators(data, feature_cnt_dl):

    feature_cnt = feature_cnt_dl

    data = data_orig.copy(deep=True)

    # print("= Before Adding Indicators ========================================================")
    # print(data.tail(10))

    data['RSI']=ta.rsi(data.Close, length=3); feature_cnt += 1
    # data['EMAF']=ta.ema(data.Close, length=3); feature_cnt += 1
    # data['EMAM']=ta.ema(data.Close, length=6); feature_cnt += 1
    data['EMAS']=ta.ema(data.Close, length=9); feature_cnt += 1
    data['DPO3']=ta.dpo(data.Close, length=3, centered=True); feature_cnt += 1
    data['DPO6']=ta.dpo(data.Close, length=6, centered=True); feature_cnt += 1
    data['DPO9']=ta.dpo(data.Close, length=9, centered=True); feature_cnt += 1

    # print("= After Adding DPO2 ========================================================")
    # print(data.tail(10))
    #
    # On Balance Volume
    if data['Volume'].iloc[-1] > 0:
        data = data.join(ta.aobv(data.Close, data.Volume, fast=True, min_lookback=3, max_lookback=9))
        feature_cnt += 7 # ta.aobv adds 7 columns

    # print("= After Adding APBV ========================================================")
    # print(data.tail(10))

    # Target is the difference between the adjusted close and the open price.
    data['Target'] = data['Adj Close']-data.Open
    feature_cnt += 1
    data['TargetH'] = data.High - data.Open
    feature_cnt += 1
    data['TargetL'] = data.Low - data.Open
    feature_cnt += 1
    # Shift the target up by one day.Target is the difference between the adjusted close and the open price.
    # That is, the target is the difference between the adjusted close and the open price.
    # Our model will predict the target close for the next day. So we shift the target up by one day.
    data['Target'] = data['Target'].shift(-1)
    data['TargetH'] = data['TargetH'].shift(-1)
    data['TargetL'] = data['TargetL'].shift(-1)

    # 1 if the price goes up, 0 if the price goes down.
    # Not a feature: Needed to test prediction accuracy.
    data['TargetClass'] = [1 if data['Target'].iloc[i]>0 else 0 for i in range(len(data))]
    target_cnt = 1
    # The TargetNextClose is the adjusted close price for the next day.
    # This is the value we want to predict.
    # Not a feature: Needed to test prediction accuracy.
    data['TargetNextClose'] = data['Adj Close'].shift(-1)
    target_cnt += 1
    # TargetNextHigh and TargetNextLow are the high and low prices for the next day.
    data['TargetNextHigh'] = data['High'].shift(-1)
    target_cnt += 1
    # TargetNextLow are the low prices for the next day.
    data['TargetNextLow'] = data['Low'].shift(-1)
    target_cnt += 1

    # Before scaling the data, we need to use the last good value for rows that have NaN values.
    data.ffill(inplace=True)

    # print("= After Adding Targets___ and ForwardFill ========================================================")
    # print(data.tail(10))

    # Reset the index of the dataframe.
    data.reset_index(inplace = True)
    data_date = data['Date'].copy()
    data.drop(['Date'], axis=1, inplace=True);   feature_cnt -= 1
    data.drop(['Close'], axis=1, inplace=True);  feature_cnt -= 1
    # data.drop(['Volume'], axis=1, inplace=True); feature_cnt -= 1

    # Add one more row to the data file, this will be our next day's prediction.
    data = pd.concat([data,data[-1:]])
    # And, reindex the dataframe.
    data.reset_index(inplace=True)

    # print("feature_cnt_d1:", feature_cnt_dl, " feature_cnt:", feature_cnt)
    return data, feature_cnt, data_date

data_aug, feature_cnt, data_date = add_indicators(data, feature_cnt_dl)

data_set = data_aug.copy(deep=True)
print("Len data:", len(data_aug), "Len data_set", len(data_set))
# data_set.tail(10)
# Out:
# Len data: 2420 Len data_set 2420

# %% [markdown]
# ## - Scale the data
#
#   The data is scaled to a range of 0 to 1.
#   This is done to ensure that the data is normalized, so that the model can be trained on it

# %%
# Scale the data for training...

import sklearn
from sklearn.preprocessing import MinMaxScaler


def scale_data(data_set):
    sc = MinMaxScaler(feature_range=(0,1))
    data_set_scaled = sc.fit_transform(data_set)
    return sc, data_set_scaled

sc, data_set_scaled = scale_data(data_set)

print("data_set.shape:", data_set.shape, "data_set_scaled.shape", data_set_scaled.shape)
# print(data_set_scaled)
# Out:
# data_set.shape: (2420, 25) data_set_scaled.shape (2420, 25)

# %%
# Check of nan an/or 0 dataums...
# After scaling the data, we need to check for NaN and 0 values,
# and forward fill the data with the last known value.
# In the case of a series of 0 values, begining at index 0,
# we have to back fill those values with the first non-non/zero value available.
# *** Currently, we are not handling this case. ***
def scaled_data_cleanup(data_set):
    nan_indices = np.argwhere(np.isnan(data_set_scaled))
    zer_indices = np.argwhere(data_set_scaled == 0)

    # print("nan_indices:", nan_indices)
    # print('zer_indices:', zer_indices)

    for i in range(len(nan_indices)):
        j = nan_indices[i][1] - 1
        if j < 0:
            j = nan_indices[i][1] + 1
        data_set_scaled[nan_indices[i][0], nan_indices[i][1]] = data_set_scaled[nan_indices[i][0], j]
    for i in range(len(zer_indices)):
        j = zer_indices[i][1] - 1
        if j < 0:
            j = zer_indices[i][1] + 1
        data_set_scaled[zer_indices[i][0], zer_indices[i][1]] = data_set_scaled[zer_indices[i][0], j]

    nan_indices = np.argwhere(np.isnan(data_set_scaled))
    zer_indices = np.argwhere(data_set_scaled == 0)

    return data_set_scaled, nan_indices, zer_indices

data_set_scaled, nan_indices, zer_indices = scaled_data_cleanup(data_set)
# print("nan_indices:", nan_indices)
# print('zer_indices:', zer_indices)
pass

# %% [markdown]
# ## - Prepare the scaled data for the model
#
#   - The data is prepared for the model by creating a 3D array of the data.
#   - The data is split into training and test data.
#   - The training data is used to train the model.
#   - The test data is used to test the model.
#   - The model is then used to predict the next day's price.

# %%
# LSTM needs a rolling period of data for each feature to make predictions.
# multiple feature from data provided to the model
global X, backcandles, y, yi, data_set
backcandles = 15 # Set the rolling window size.

def prep_model_inputs(data_scaled, backcandles):
    X = []
    # print(data_set_scaled[0].size)
    # data_set_scaled=data_set.values
    # print(data_set_scaled.shape[0])

    # Create a 3D array of the data. X[features][periods][candles]
    # Where candles is the number of candles that rolls by 1 period for each period.
    for j in range(feature_cnt): # data_set_scaled[0].size):# last 2 columns are target not X
        X.append([])
        for i in range(backcandles, data_set_scaled.shape[0]): # backcandles+2
            X[j].append(data_set_scaled[i-backcandles:i, j])

    # print("X.shape:", np.array(X).shape)
    X = np.array(X)
    # Move axis from 0 to position 2
    X=np.moveaxis(X, [0], [2])
    # print("X.shape:", X.shape)

    # Erase first elements of y because of backcandles to match X length
    # del(yi[0:backcandles])
    #X, yi = np.array(X), np.array(yi)
    # Choose -1 for last column, classification else -2...
    # Choose -4 for last 4 columns, classification (up/down), TargetNextClose, TargetNextHigh, and TargetNextLow ...
    X, yi = np.array(X), np.array(data_set_scaled[backcandles:, -4:])
    y = np.reshape(yi,(len(yi),4))
    #y=sc.fit_transform(yi)
    #X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
    
    # print("data_set.shape:",data_set.shape,"X.shape:",X.shape)
    # print(X)
    # print("=========================================================")
    # print(y.shape)
    # print(y)

    return X, y, yi

X, y, yi = prep_model_inputs(data_set_scaled, backcandles)

pass

# %%
# split data into train test sets

global splitlimit
splitlimit = int(len(X)*0.8)

def split_data(X, y, splitlimit):
    # print("lenX:",len(X), "splitLimit:",splitlimit)
    X_train, X_test = X[:splitlimit], X[splitlimit:] # Training data, Test Data
    y_train, y_test = y[:splitlimit], y[splitlimit:] # Training data, Test Data

    # print("X_train.shape:", X_train.shape)
    # print("y_train.shape:", y_train.shape)
    # print("X_test.shape:", X_test.shape)
    # print("y_test.shape:", y_test.shape)
    # print("== X_train ===========================================")
    # print(X_train[-20:-10])
    # print("== _train ===========================================")
    # print(y_train[-20:-10])    

    return X_train, X_test, y_train, y_test

X_train, X_test, y_train, y_test = split_data(X, y, splitlimit)

# %% [markdown]
# # Load an Existing Model -or- Model Training
#  - Using LSTM (Long Short Term Memory) Model
#  - Using Keras (Tensorflow) Library
#  - LSTM --> Dense Layer --> Activation Layer

# %%
import tensorflow as tf
import keras
import numpy as np
import os
from keras import optimizers
from keras.callbacks import History
from keras.models import Model
from keras.layers import Dense, Dropout, LSTM, Input, Activation, concatenate
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import TimeDistributed

def create_fit_model(X_train, y_train, backcandels, model_path):
    # If the Keras model file exists, load it. Otherwise, create a new model.
    
    train_model = True
    if os.path.exists(model_path) and Selected_Model.value != CreateNewModel:
        # Load the model...
        model = keras.models.load_model(model_path)
        model_path = model_path.replace('~', '=')
        print("Model Loaded:", model_path)
        model_outputs = model.layers[3].output.shape[1]
        if model_outputs != 4:
            train_model = True
            print("** Model needs to be retrained.")
        else:
            train_model = False
            
    if train_model:
        # Create a new model...

        #tf.random.set_seed(20)
        np.random.seed(10)

        lstm_input = Input(shape=(backcandles, feature_cnt), name='lstm_input')
        inputs = LSTM(200, name='first_layer')(lstm_input)
        inputs = Dense(4, name='dense_layer')(inputs)
        output = Activation('linear', name='output')(inputs)
        model = Model(inputs=lstm_input, outputs=output)
        adam = optimizers.Adam()
        model.compile(optimizer=adam, loss='mse')
        # model.fit(x=X_train, y=y_train, batch_size=15, epochs=30, shuffle=True, validation_split = 0.1)
        model.fit(x=X_train, y=y_train, batch_size=250, epochs=150, shuffle=True, validation_split = 0.1)

        # Save the model...
        if chk_save_model.value:
            model_path = model_path.replace('=', '~')
            model.save(model_path)
    
    return model

model = create_fit_model(X_train, y_train, backcandles, model_path)
# Out:
# 2024-08-14 16:05:04.908075: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-08-14 16:05:04.918085: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-14 16:05:04.929893: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-14 16:05:04.933215: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-14 16:05:04.941872: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-14 16:05:05.561889: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Model Loaded: models/NVDA_2015-01-01_2024-08-07.keras
# 2024-08-14 16:05:05.947526: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2024-08-14 16:05:05.947545: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:135] retrieving CUDA diagnostic information for host: motoko-7760
# 2024-08-14 16:05:05.947548: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:142] hostname: motoko-7760
# 2024-08-14 16:05:05.947675: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:166] libcuda reported version is: 555.42.6
# 2024-08-14 16:05:05.947687: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:170] kernel reported version is: NOT_FOUND: could not find kernel module information in driver version file contents: "NVRM version: NVIDIA UNIX Open Kernel Module for x86_64  555.42.06  Release Build  (dvs-builder@U16-I3-A13-3-4)  Tue Jun  4 00:45:31 UTC 2024
# GCC version:  gcc version 12.3.0 (Ubuntu 12.3.0-1ubuntu1~22.04)
# "

# %% [markdown]
# # Model Testing

# %%
# Sow some y_pred values. If prediction is no good, we might see NaN values.
y_pred = model.predict(X_test)

# Rescaled the predicted values to dollars...
data_set_scaled_y = data_set_scaled[backcandles + splitlimit:, :].copy()
# Replace the last columns 4 in data_set_scaled_y with the predicted column values...
data_set_scaled_y[:, -4:] = y_pred

y_pred_rs = sc.inverse_transform(data_set_scaled_y)

pass
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %% [markdown]
# ## - Adjust the prediction (Data Alignment with the actual previous prices)
#   - Predictions have a tendency to wander way from the main price action channel.
#       - The ideal for the prediction is for it to be as close to the actual price as possible.
#       - What was observed is that the prediction is often off by a delta.
#       - The delta is the difference between the actual price and the predicted price.
#       - After applying an average of the delta to the prediction, the prediction is closer to the actual price.
#       - Usually within 1% of the actual price, which is an incredible improvement.
#
#
#   - Before we adjust the prediction, the data has to be rescaled to dollars because the each prediction target
#     is scaled independently.
#
#     - The resulting numpy array y_p_adj is the adjusted prediction, which we will use as the prediction for the next day.
#
#  - The in the current implementation, Hign and Low adjusted predictions seem to have different characteristics.
#       - I really want the High to be aligned with the actual high, yet preserving the trend of the prediction.
#         But it seems that the adjusted high tends to wander upward from the prior high.
#       - The Low, on the other hand, is quite close to the actual low, and has required different maths to adjust it.
#       - I have tried getting the high and low maths be the same basic operation, but I haven't yet found the right formula.
#         Thus, the difference in characteristics between the high and low adjusted predictions.
#      - Nevertheless, for now what exists is workable.

# %%
# Calculate the delta between actual price and prediction
# Bring the prediction closer to the price based on the delta
import math

def mov_avg(x, w):
    # return abs(np.convolve(np.flip(x), np.ones(w), 'valid') / w)
    return np.absolute(np.convolve(x, np.ones(w), 'valid') / w)

def apply_deltas(ac,pc,pac,p, t,w):
    """
    Calculate the delta between actual price and prediction
    :param ac:   # Actual close price or high or low
    :param pc:   # Centering close price or high or low
    :param pac:  # Predicted Adj Close price
    :param p:    # Predicted close price or high or low
    :param t:    # Type of prediction ('c'=close, 'h'=high, 'l'=low)
    :param w:    # Window size for moving average
    :return rl:  # Return List of adjusted prediction values 
    """
    al = list(ac)   # Actual
    cc = list(pc)   # Centering or Original Predicted Close
    if pac is None:
        pac = None
    else:
        pac = list(pac) # Predicted Adj Close
    pl = list(p)    # Predicted
    rl = []         # Return List (Adjusted Predictions)
    
    # Calculate the delta between the actual price and the centering value.
    # Get the absolute value of the difference between the actual price and the prediction.
    p_delta = (np.maximum(p, ac[:len(p)]) - np.minimum(p, ac[:len(p)])) # Price - Actual Close or High or Low

    # Shift delta to the left by 1 day so that the adjusted prediction
    # only uses know data, and duplicate the delta for the last day (which we don't know).
    dl = np.append(p_delta[1:], p_delta[-1])
    # Calculate the move average delta for the prediction.
    dl_ma = mov_avg(p_delta, w)

    if len(dl_ma) < len(pl):
        for i in range(len(pl) - len(dl_ma)):
            # Duplicate the first value in the list to make the list the same size as pl.
            dl_ma = np.insert(dl_ma, 0, dl_ma[0], axis=0)
            
    # We don't apply the average to our first predictions
    # fot the size of the moving average window.
    # For this area, we just return the predicted value.
    i = w - 1
    for j in range(0, i):
        rl.append(pl[j]) 

    for delta in dl_ma[:-1]:
        if i >= len(pl):
            break 
        # # print(i,"," ,end="")
        if t == 'c':
            if i >= len(dl_ma):
                break
            if al[i] > pl[i]:
                # If the actual price is greater than the predicted price, add the delta.
                val = pl[i] + delta
            else:
                # If the actual price is less than or equal to the predicted price, subtract the delta.
                val = pl[i] - delta
        elif t == 'h':
            if pac is None:
                # Use delta to adjust the predicted high.
                val = pl[i] + delta
            else:
                # Create a delta value based on the actual high and the predicted high
                # and subtract the delta from the predicted high.
                diff = max(ac[i], cc[i]) - min(ac[i], cc[i])
                if ac[i] < pl[i]:
                    val = pl[i] - diff
                else:
                    val = pl[i] + diff
                if val < pac[i]:
                    # If high is less than the predicted high, set the high to the predicted high.
                    val = pac[i]
        elif t == 'l':
            if pac is None:
                # Use delta to adjust the predicted low.
                val = pl[i] - delta
            else:
                # Create a delta value based on the actual low and the predicted low
                # and subtract the delta from the predicted low.
                val = math.fabs(pl[i] - max(ac[i], cc[i]) - min(ac[i], cc[i]))
                if val > pac[i]:
                    # If low is greater than the predicted low, set the low to the predicted low.
                    val = pac[i]
        else:
            raise ValueError("Invalid type. Must be 'c', 'h', or 'l'.")

        # Append the adjusted value to the return list.
        rl.append(val)
        i += 1
        
    # Return the return list of adjusted values.
    return rl

def adjust_prediction(y_cntr, pc, pac, y_pred, type, avg_win=5):
    """
    Calculate the delta between actual price and prediction
    Bring the prediction closer to the price based on the delta
    """
        
    # print(y_cntr.shape, y_pred.shape, y_p_adj.shape, y_p_delta.shape)
    y_p_adj = apply_deltas(y_cntr, pc, pac, y_pred, type, avg_win)
    y_p_adj = np.array(y_p_adj)

    return y_p_adj


# Gather the target data for the test period.
target_close = np.array(data_set['Adj Close'].iloc[-len(y_pred_rs):])
target_high  = np.array(data_set['High'].iloc[-len(y_pred_rs):])
target_low   = np.array(data_set['Low'].iloc[-len(y_pred_rs):])

# Gather the predicted data for the test period.
pred_close = y_pred_rs[:, -3]
pred_high  = y_pred_rs[:, -2]
pred_low   = y_pred_rs[:, -1]

# Generate the adjusted predictions for Close, High, and Low.

# Adjust the predicted close, centered on the actual close.
pred_adj_close = adjust_prediction(target_close, target_close, None,           pred_close,    'c', avg_win=2)
# Adjust the predicted high, centered on the actual close.
pred_adj_high  = adjust_prediction(target_close, pred_close,   pred_adj_close, pred_high,     'h', avg_win=2)
# Readjust the adjusted predicted low, centered on the actual close.
pred_adj_high  = adjust_prediction(target_high,  target_high,  None,           pred_adj_high, 'h', avg_win=2)
pred_adj_high  = mov_avg(pred_adj_high, 3)
# Adjust the predicted low, centered on the actual high.
pred_adj_low   = adjust_prediction(target_close, pred_close,   pred_adj_close, pred_low,      'l', avg_win=2)
# Readjust the adjusted predicted low, centered on the actual low.
pred_adj_low   = adjust_prediction(target_low,   target_low,   None,           pred_adj_low,  'l', avg_win=2)
pred_adj_low = mov_avg(pred_adj_low, 3)

pass

# %% [markdown]
# # - Plot the Test Results

# %% [markdown]
# ### - Rescaled (Target vs Prediction)

# %%
# %matplotlib notebook

def plot_pred_results(target_close, pred_close, pred_high, pred_low):
    # Plot the scaled test and predicted data.
    y_test_plot = y_test[:-2, 1]
    plt.figure(figsize=(16,8))

    # Original Adj Close
    plt.plot(target_close,   color = 'black',  label = 'Test',       marker='.')

    # Original Prediction
    plt.plot(pred_close[1:], color = 'orange', label = 'Pred Close', marker='1')
    # Original High and Low prediction
    plt.plot(pred_high[1:],  color = 'blue',   label = 'Pred High',  marker='1')
    plt.plot(pred_low[1:],   color = 'red',    label = 'Pred Low',   marker='1')

    title = f"{ticker.value} ({dateStart.value} - {dateEnd.value})" 
    plt.title(title)
    plt.legend()
    plt.grid()
    plt.show()
    
plot_pred_results(target_close[1:-1], pred_close, pred_high, pred_low)

pass
# Out:
# <div id='a195bca3-34d9-420b-9257-aa297b7ab85d'></div>

# %% [markdown]
# ### - Rescaled (Target vs Prediction vs Adjusted Prediction)

# %%
# Use an interactive plot to see the results
# %matplotlib notebook

def plot_adj_pred_results(y_test, y_pred, pred_adj_close, pred_adj_high, pred_adj_low):
    # Plot the scaled test and predicted data.
    y_test_plot = y_test[:]
    plt.figure(figsize=(16,8))

    # Original Adj Close
    plt.plot(y_test_plot, color = 'black', label = 'Test',     marker='.')

    # # Original Prediction
    # plt.plot(y_pred[1:, 1],   color = 'yellow',  label = 'Pred Close', marker='1')
    # # Original High and Low prediction
    # plt.plot(y_pred[1:, 2],   color = 'blue',  label = 'Pred High', marker='1')
    # plt.plot(y_pred[1:, 3],   color = 'red',  label = 'Pred Low', marker='1')

    # Adjusted Predictions
    plt.plot(pred_adj_close,   color = 'yellow',  label = 'Pred Close', marker='1')
    # Original High and Low prediction
    plt.plot(pred_adj_high,   color = 'blue',  label = 'Pred High', marker='1')
    plt.plot(pred_adj_low,   color = 'red',  label = 'Pred Low', marker='1')

    title = f"{ticker.value} ({dateStart.value} - {dateEnd.value})"
    plt.title(title)
    plt.legend()
    plt.grid()
    plt.show()
    return plt

y_p_adj = None
plt = plot_adj_pred_results(target_close[1:-1], pred_close[1:], pred_adj_close[1:], pred_adj_high[1:], pred_adj_low[1:])
# pd.DataFrame(y_test_plot).tail(5)
# Out:
# <div id='f399817e-279c-4945-937e-9d7a6ab3b13a'></div>

# %% [markdown]
# ### - Rescaled Data ($USD) (Prediction vs Target)

# %%
# Plot using candlesticks using matplotlib...

# Use an interactive plot to see the results
# %matplotlib notebook

def plot_candlesticks(plt, prices, title, width=1, width2=.25, clr_up='green', clr_dn='red', clr_wick='black'):
    """
    Plot Candlesticks...
    :param plt:    maplotlib.pyplot handle
    :param prices: The series of OHLC prices to plot
    :param title:  A title for the plot
    :param width:
    :param width2:
    :param clr_up:
    :param clr_dn:
    :param clr_wick:
    :return:
    """
    #define up and down prices
    up = prices[prices.Close>=prices.Open]
    down = prices[prices.Close<prices.Open]

    #plot up prices
    plt.bar(up.index,up.Close-up.Open,width,bottom=up.Open,color=clr_up, alpha=.30)
    # plt.bar(up.index,up.High-up.Close,width2,bottom=up.Close,color=clr_up, alpha=.25)
    # plt.bar(up.index,up.Low-up.Open,width2,bottom=up.Open,color=clr_up, alpha=.25)
    plt.bar(up.index,up.High-up.Low,width2,bottom=up.Low,color=clr_wick, alpha=.30)

    #plot down prices
    plt.bar(down.index,down.Open-down.Close,width,bottom=down.Close,color=clr_dn, alpha=.25)
    # plt.bar(down.index,down.High-down.Open,width2,bottom=down.Open,color=clr_dn, alpha=.25)
    # plt.bar(down.index,down.Low-down.Close,width2,bottom=down.Close,color=clr_dn, alpha=.25)
    plt.bar(down.index,down.High-down.Low,width2,bottom=down.Low,color=clr_wick, alpha=.25)

    #rotate x-axis tick labels
    plt.xticks(rotation=45, ha='right')

import math
import mplfinance as mfp

def plot_pred_results(target_close, pred_close, y_pred_adj_rs, y_high_adj_rs, y_low_adj_rs, data_set, data_date, period):
    # Plot the original Adj Cost data that is in dollars...
    # Remove the last Adj Price, because it just aopy of the last adj
    plt_test_plot = np.array(target_close[:].reshape(-1,1))

    # Calculate the mean of the delta between the prediction and the actual price...
    # Used to create price range circles around the prediction...
    min_len = min(len(target_close), len(y_pred_adj_rs))
    plt_delta = np.array(pd.DataFrame([abs(target_close[i - 1] - y_pred_adj_rs[i - 1]) for i in range(1, min_len)]).rolling(window=6).mean())

    # Dates...
    data_date_str = [str(date) for date in data_date]
    plt_test_dates = np.array((data_date_str[backcandles + splitlimit - 1:]), ).reshape(-1,1)
    plt_pred_dates = np.array((data_date_str[backcandles + splitlimit - 1:]),   ).reshape(-1,1)

    # empty_arr = np.zeros(((len(plt_test_plot)+1, 18)))
    # plt_pred_adj = sc.inverse_transform(np.append(y_p_adj, empty_arr, axis=1))[0:, 1]

    # Plot the data...
    plt.figure(figsize=(16,8))
    plt.autoscale(tight=True)

    plt_test_plot = plt_test_plot.reshape(-1,1)

    # Plot the actual price data ($USD)...
    plt.plot(plt_test_plot, color = 'black', label = 'Actual Adj Close', marker='+')

    # Plot the adj predicted price data ($USD)...
    plt.plot(y_pred_adj_rs, color = 'orange', label = 'Adj Pred Close', marker='.')
    plt.plot(y_high_adj_rs, color = 'Blue', label = 'Adj Pred High', marker='.')
    plt.plot(y_low_adj_rs,  color = 'Red', label = 'Adj Pred Low', marker='.')

    # Plot the candlesticks...
    ds_tmp = data_set[backcandles + splitlimit + 1:-1]
    cs_data = ds_tmp.loc[backcandles + splitlimit:, ['Open','High','Low','Adj Close']].copy().reset_index()
    cs_data.rename(columns={'Adj Close':'Close'}, inplace=True)
    plot_candlesticks (plt, cs_data, 'Candlesticks')

    # Plot the text of the predicted price...
    plt.text(len(y_pred_adj_rs) -1, y_pred_adj_rs[-1], y_pred_adj_rs[-1].round(2), fontsize=8, color='black', ha='left', va='center')

    # plt.xlabel(range(0,len(plt_pred_dates)), plt_pred_dates.tolist(), rotation=45)
    #  .set_major_formatter(matplotlib.dates.DateFormatter('%Y')))

    # Plot a Price Range Circle Arounds the current Prediction...
    Plot_Pred_Circle = True
    if Plot_Pred_Circle:
        import matplotlib.patches as ptch
        lst_pred = len(y_pred_adj_rs) -1
        # ax.set_xlim = ([0, len(plt_pred_adj)])
        # ax.set_ylim = ([plt_pred_adj.min(), plt_pred_adj.max()])
        cpos = np.array([lst_pred, y_pred_adj_rs[-1]])
        circ_pred0 = ptch.Circle(cpos, radius=plt_delta[-1][0]/1,   color='grey',   fill=True, alpha=0.20)
        circ_pred1 = ptch.Circle(cpos, radius=plt_delta[-1][0]/1.5, color='blue',   fill=True, alpha=0.20)
        circ_pred2 = ptch.Circle(cpos, radius=plt_delta[-1][0]/2,   color='yellow', fill=True, alpha=0.20)
        circ_pred3 = ptch.Circle(cpos, radius=plt_delta[-1][0]/3,   color='red',    fill=True, alpha=0.20)
        ax = plt.gca()
        # ax.set_aspect("equal")
        ax.add_patch(circ_pred0)
        ax.add_patch(circ_pred1)
        ax.add_patch(circ_pred2)
        ax.add_patch(circ_pred3)

    title = f"{ticker.value} {period} ({dateStart.value} - {dateEnd.value})" 
    plt.title(title)
    plt.grid(visible=True, which='both')
    plt.legend()
    plt.show()
    return plt

period = PredsDaily
if '_w_' in model_path:
    period = PredsWeekly
data_set_scaled_plus = np.append(data_set_scaled, data_set_scaled[-1].reshape(1, -1), axis=0)
plt = plot_pred_results(target_close[1:-1], pred_close[1:], pred_adj_close[1:], pred_adj_high[1:], pred_adj_low[1:], data_set, data_date, period)
# Out:
# <div id='30a83901-d459-4bc7-b3ca-bcea0ea735d3'></div>

# %% [markdown]
# ### - Plot the Prediction Results (Using mplfinance)

# %%
# %matplotlib notebook
# Plot using mlpfinance...
import mplfinance as mpf
from matplotlib.widgets import MultiCursor

print('Ticker:', ticker.value)
def plot_pred_results(Ticker, data_orig, target_close, pred_close_rs, pred_close_adj_rs, pred_high_ad_rs, pred_low_ad_rs, pred_high_rs, pred_low_rs, data_date, period='Daily'):
    # Createe a dataframe of the data for plt_test_usd, with a datetime index...
    df_plt_test_usd = pd.DataFrame()
    df_plt_test_usd.insert(0, 'Date', data_date[backcandles + splitlimit:])
    df_plt_test_usd.reset_index()
    ohlcv = data_orig.iloc[backcandles + splitlimit:, [0,1,2,3,4,5]].copy()
    ohlcv.reset_index()
    df_plt_test_usd = pd.concat([df_plt_test_usd, ohlcv.set_axis(df_plt_test_usd.index)], axis=1)

    # Add a place holder for the prediction...
    next_date = df_plt_test_usd.iloc[-1, 0] + pd.DateOffset(days=1)
    next_open      = df_plt_test_usd.iloc[-1, 4]
    next_high      = df_plt_test_usd.iloc[-1, 4]
    next_low       = df_plt_test_usd.iloc[-1, 4]
    next_close     = df_plt_test_usd.iloc[-1, 4]
    next_adj_close = df_plt_test_usd.iloc[-1, 4]
    next_volume    = 0
    
    # Prepare the prediction data for the plot...
    c_pred_rs       = pd.DataFrame(pred_close_rs[:]).rename({0:'pred_rs'}, axis=1)
    c_pred_adj_rs   = pd.DataFrame(pred_close_adj_rs[:]).rename({0:'pred_adj_rs'}, axis=1)
    c_pred_h_adj_rs = pd.DataFrame(pred_high_ad_rs[:]).rename({0:'pred_h_adj_rs'}, axis=1)
    c_pred_l_adj_rs = pd.DataFrame(pred_low_ad_rs[:]).rename({0:'pred_l_adj_rs'}, axis=1)
    
    if pred_high_rs is not None and pred_low_rs is not None:
        c_pred_h_rs = pd.DataFrame(pred_high_rs).rename({0:'pred_h_rs'},  axis=1)
        c_pred_l_rs = pd.DataFrame(pred_low_rs).rename({0:'pred_l_rs'}, axis=1)
    
    # Append a new row to the dataframe so it extends out to the prediction...
    new_row = { 'Date': next_date, "Open": next_open, "High": next_high, "Low": next_low, "Close": next_close,
                                   "Adj Close": next_adj_close, "Volume": next_volume,
                                   "pred_rs": c_pred_rs.iloc[-1], "pred_adj_rs": c_pred_adj_rs.iloc[-1],
                                   "pred_h_adj_rs": c_pred_h_adj_rs.iloc[-1], "pred_l_adj_rs": c_pred_l_adj_rs.iloc[-1] }
    if pred_high_rs is not None and pred_low_rs is not None:
        new_row = { 'Date': next_date, "Open": next_open, "High": next_high, "Low": next_low, "Close": next_close,
                        "Adj Close": next_adj_close, "Volume": next_volume,
                        "pred_rs": c_pred_rs.iloc[-1], "pred_adj_rs": c_pred_adj_rs.iloc[-1],
                        "pred_h_adj_rs": c_pred_h_adj_rs.iloc[-1], "pred_l_adj_rs": c_pred_l_adj_rs.iloc[-1],
                        "pred_h_rs": c_pred_h_rs.iloc[-1], "pred_l_rs": c_pred_l_rs.iloc[-1] }
    else:
        new_row = { 'Date': next_date, "Open": next_open, "High": next_high, "Low": next_low, "Close": next_close,
                        "Adj Close": next_adj_close, "Volume": next_volume,
                        "pred_rs": c_pred_rs.iloc[-1], "pred_adj_rs": c_pred_adj_rs.iloc[-1],
                        "pred_h_adj_rs": c_pred_h_adj_rs.iloc[-1], "pred_l_adj_rs": c_pred_l_adj_rs.iloc[-1] }


    new_row = pd.DataFrame(new_row, index=[6])
    df_plt_test_usd = pd.concat([df_plt_test_usd[1:], new_row], axis=0, ignore_index=True)
        
    # # Add the unadjusted prediction data to the OHLCV plot data...
    # df_plt_test_usd = pd.concat([df_plt_test_usd, c_pred_rs[:len(df_plt_test_usd)].set_axis(df_plt_test_usd.index)],     axis=1)
    # if pred_high_rs is not None and pred_low_rs is not None:
    #     df_plt_test_usd = pd.concat([df_plt_test_usd, c_pred_h_rs[:len(df_plt_test_usd)].set_axis(df_plt_test_usd.index)], axis=1)
    #     df_plt_test_usd = pd.concat([df_plt_test_usd, c_pred_l_rs[:len(df_plt_test_usd)].set_axis(df_plt_test_usd.index)], axis=1)
    
    # Add adjusted prediction data to the OHLCV plot data...
    min_len = min(len(df_plt_test_usd), len(c_pred_h_adj_rs))
    df_plt_test_usd = df_plt_test_usd[-min_len:]
    df_plt_test_usd = pd.concat([df_plt_test_usd, c_pred_adj_rs[-min_len:].set_axis(df_plt_test_usd.index)], axis=1)
    df_plt_test_usd = pd.concat([df_plt_test_usd, c_pred_h_adj_rs[-min_len:].set_axis(df_plt_test_usd.index)], axis=1)
    df_plt_test_usd = pd.concat([df_plt_test_usd, c_pred_l_adj_rs[-min_len:].set_axis(df_plt_test_usd.index)], axis=1)
    
    df_plt_test_usd.ffill(inplace=True)
    df_plt_test_usd.set_index('Date', inplace=True, drop=True)
    df_plt_test_usd.ffill(inplace=True)
    df_plt_test_usd.rename(index={6:'pred_rs', 7:'pred_adj_rs'}, inplace=True)
    # Add a day row to df_plt_test_usd as a place holder for the prediction...
    print("df_plt_test_usd:", df_plt_test_usd.shape)
    
    kwargs = dict(type='candle', volume=True, figratio=(11,6), figscale=1.25, warn_too_much_data=10000, title=f'Ticker: {ticker.value} {period} ({df_plt_test_usd.index[-1]})')
    if pred_high_rs is not None and pred_low_rs is not None:
        preds = [ mpf.make_addplot(df_plt_test_usd['pred_adj_rs'],     type='line', panel=0, color='g', secondary_y=False),
                  mpf.make_addplot(df_plt_test_usd['pred_h_adj_rs'],   type='line', panel=0, color='b', secondary_y=False),
                  mpf.make_addplot(df_plt_test_usd['pred_l_adj_rs'],   type='line', panel=0, color='r', secondary_y=False),
                  mpf.make_addplot(df_plt_test_usd['pred_rs'],         type='line', linestyle='-.', panel=0, color='y', secondary_y=False),
                  mpf.make_addplot(df_plt_test_usd['pred_h_rs'],       type='line', linestyle='-.', panel=0, color='b', secondary_y=False),
                  mpf.make_addplot(df_plt_test_usd['pred_l_rs'],       type='line', linestyle='-.', panel=0, color='r', secondary_y=False),
                  ]
    else:
        preds = [ mpf.make_addplot(df_plt_test_usd['pred_adj_rs'],     type='line', panel=0, color='g', secondary_y=False),
                  mpf.make_addplot(df_plt_test_usd['pred_h_adj_rs'],   type='line', panel=0, color='b', secondary_y=False),
                  mpf.make_addplot(df_plt_test_usd['pred_l_adj_rs'],   type='line', panel=0, color='r', secondary_y=False),
                  ]

    fig, axlist = mpf.plot(df_plt_test_usd,**kwargs,style='binance', addplot=preds, returnfig=True)
    multi = MultiCursor(fig.canvas, axlist, color='r', lw=1, horizOn=True, vertOn=True)
    multi.connect()

    # # Given access to the Price chart at axis[0], we can use patches to draw shapes on the chart...
    # # The X axis is the number of periods on the chart (1 - N) and the Y axis is the price.
    # import matplotlib.patches as mptch
    # clipped_circle = mptch.Circle((len(df_plt_test_usd), 200), 5, ec="none", facecolor='C1')
    # axlist[0].add_patch(clipped_circle)

    return mpf

period = PredsDaily
if '_w_' in model_path:
    period = PredsWeekly
mpf = plot_pred_results(Ticker, data_orig, target_close, pred_close[1:], pred_adj_close[1:], pred_adj_high[1:], pred_adj_low[1:], pred_high[1:], pred_low[1:], data_date, period=period)
# Out:
# Ticker: NVDA
# df_plt_test_usd: (478, 15)
# <div id='fc42dadd-31d6-4f9d-a4d5-390fd8cc4116'></div>

# %% [markdown]
# # Analysis of the Prediction
#  - Rescaled data (Prediction vs Target)

# %%
# We convert our data back to dollars...
# predval = y_pred[i] * scalefac

def analyze_pred(target_close, target_high, target_low, pred_close, pred_adj_close):
    # Convert back to dollar $values
    elements = len(target_close)
    print(elements)
    tot_deltas = 0
    tot_adj_deltas = 0
    tot_tradrng = 0
    for i in range(1, -elements, -1):
        actual = target_close[i - 1]
        
        predval = pred_close[i - 1]
        pred_delta = abs(predval - actual)
        tot_deltas += pred_delta

        predval = pred_adj_close[i - 1]
        pred_delta = abs(predval - actual)
        tot_deltas += pred_delta

        trd_rng = abs(target_high[i] - target_low[i])
        tot_tradrng += trd_rng
        print(f"i:{i}", "Close", actual.round(2), "Predicted: $", predval.round(2), "  Delta:$", pred_delta.round(6), "  Trade Rng: $", trd_rng.round(2))

    print("Mean Trading Range: $", round(tot_tradrng / elements, 2))
    print("Mean Delta (Actual vs Prediction): $", round((tot_deltas / elements), 2))
    print("Mean Delta (Actual vs Adj Prediction): $", round((tot_deltas / elements), 2))
    return tot_deltas, tot_tradrng, elements

tot_deltas, tot_tradrng, elements = analyze_pred(target_close, target_high, target_low, pred_close, pred_adj_close)
# Out:
# 481
# i:1 Close 12.92 Predicted: $ 13.86   Delta:$ 0.945574   Trade Rng: $ 0.6
# i:0 Close 116.14 Predicted: $ 113.67   Delta:$ 2.466092   Trade Rng: $ 0.44
# i:-1 Close 116.14 Predicted: $ 107.39   Delta:$ 8.745392   Trade Rng: $ 4.65
# i:-2 Close 109.02 Predicted: $ 104.86   Delta:$ 4.164132   Trade Rng: $ 4.65
# i:-3 Close 104.75 Predicted: $ 106.71   Delta:$ 1.955017   Trade Rng: $ 4.81
# i:-4 Close 104.97 Predicted: $ 107.48   Delta:$ 2.508697   Trade Rng: $ 3.17
# i:-5 Close 98.91 Predicted: $ 100.35   Delta:$ 1.435361   Trade Rng: $ 7.98
# i:-6 Close 104.25 Predicted: $ 100.88   Delta:$ 3.370522   Trade Rng: $ 10.11
# i:-7 Close 100.45 Predicted: $ 105.74   Delta:$ 5.294661   Trade Rng: $ 7.16
# i:-8 Close 107.27 Predicted: $ 105.13   Delta:$ 2.13921   Trade Rng: $ 12.72
# i:-9 Close 109.21 Predicted: $ 115.36   Delta:$ 6.148718   Trade Rng: $ 7.35
# i:-10 Close 117.02 Predicted: $ 114.18   Delta:$ 2.838513   Trade Rng: $ 13.35
# i:-11 Close 103.73 Predicted: $ 110.01   Delta:$ 6.283132   Trade Rng: $ 7.46
# i:-12 Close 111.59 Predicted: $ 112.0   Delta:$ 0.40598   Trade Rng: $ 9.45
# i:-13 Close 113.06 Predicted: $ 113.13   Delta:$ 0.068987   Trade Rng: $ 4.98
# i:-14 Close 112.28 Predicted: $ 108.61   Delta:$ 3.668587   Trade Rng: $ 4.62
# i:-15 Close 114.25 Predicted: $ 122.07   Delta:$ 7.818376   Trade Rng: $ 10.33
# i:-16 Close 122.59 Predicted: $ 119.24   Delta:$ 3.351503   Trade Rng: $ 6.51
# i:-17 Close 123.54 Predicted: $ 118.72   Delta:$ 4.818374   Trade Rng: $ 2.59
# i:-18 Close 117.93 Predicted: $ 118.56   Delta:$ 0.631559   Trade Rng: $ 4.21
# i:-19 Close 121.09 Predicted: $ 122.11   Delta:$ 1.015507   Trade Rng: $ 4.23
# i:-20 Close 117.99 Predicted: $ 127.03   Delta:$ 9.038928   Trade Rng: $ 5.84
# i:-21 Close 126.36 Predicted: $ 128.15   Delta:$ 1.791874   Trade Rng: $ 5.13
# i:-22 Close 128.44 Predicted: $ 128.45   Delta:$ 0.010102   Trade Rng: $ 4.46
# i:-23 Close 129.24 Predicted: $ 132.97   Delta:$ 3.731651   Trade Rng: $ 4.21
# i:-24 Close 127.4 Predicted: $ 133.83   Delta:$ 6.4252   Trade Rng: $ 4.7
# i:-25 Close 134.91 Predicted: $ 130.18   Delta:$ 4.72591   Trade Rng: $ 9.1
# i:-26 Close 131.38 Predicted: $ 127.89   Delta:$ 3.492496   Trade Rng: $ 2.68
# i:-27 Close 128.2 Predicted: $ 127.78   Delta:$ 0.423874   Trade Rng: $ 5.17
# i:-28 Close 125.83 Predicted: $ 124.88   Delta:$ 0.95339   Trade Rng: $ 3.73
# i:-29 Close 128.28 Predicted: $ 123.03   Delta:$ 5.249398   Trade Rng: $ 3.17
# i:-30 Close 122.67 Predicted: $ 123.61   Delta:$ 0.940315   Trade Rng: $ 6.92
# i:-31 Close 124.3 Predicted: $ 123.81   Delta:$ 0.492612   Trade Rng: $ 2.38
# i:-32 Close 123.54 Predicted: $ 125.54   Delta:$ 1.998659   Trade Rng: $ 6.01
# i:-33 Close 123.99 Predicted: $ 125.67   Delta:$ 1.682669   Trade Rng: $ 4.96
# i:-34 Close 126.4 Predicted: $ 120.92   Delta:$ 5.48155   Trade Rng: $ 3.49
# i:-35 Close 126.09 Predicted: $ 123.06   Delta:$ 3.02945   Trade Rng: $ 5.52
# i:-36 Close 118.11 Predicted: $ 129.58   Delta:$ 11.470964   Trade Rng: $ 7.18
# i:-37 Close 126.57 Predicted: $ 133.64   Delta:$ 7.070928   Trade Rng: $ 6.42
# i:-38 Close 130.78 Predicted: $ 133.06   Delta:$ 2.277356   Trade Rng: $ 6.33
# i:-39 Close 135.58 Predicted: $ 133.04   Delta:$ 2.538462   Trade Rng: $ 11.24
# i:-40 Close 130.98 Predicted: $ 132.6   Delta:$ 1.622945   Trade Rng: $ 5.64
# i:-41 Close 131.88 Predicted: $ 128.91   Delta:$ 2.968307   Trade Rng: $ 4.15
# i:-42 Close 129.61 Predicted: $ 124.42   Delta:$ 5.193717   Trade Rng: $ 4.52
# i:-43 Close 125.2 Predicted: $ 122.72   Delta:$ 2.480778   Trade Rng: $ 2.64
# i:-44 Close 120.91 Predicted: $ 122.38   Delta:$ 1.47364   Trade Rng: $ 4.31
# i:-45 Close 121.78 Predicted: $ 122.47   Delta:$ 0.691987   Trade Rng: $ 4.13
# i:-46 Close 120.88 Predicted: $ 123.96   Delta:$ 3.079392   Trade Rng: $ 6.09
# i:-47 Close 120.99 Predicted: $ 120.95   Delta:$ 0.034644   Trade Rng: $ 3.67
# i:-48 Close 122.43 Predicted: $ 117.39   Delta:$ 5.039134   Trade Rng: $ 7.27
# i:-49 Close 116.43 Predicted: $ 113.69   Delta:$ 2.742076   Trade Rng: $ 4.98
# i:-50 Close 114.99 Predicted: $ 112.14   Delta:$ 2.854316   Trade Rng: $ 2.56
# i:-51 Close 109.62 Predicted: $ 115.45   Delta:$ 5.830504   Trade Rng: $ 3.0
# i:-52 Close 110.49 Predicted: $ 116.65   Delta:$ 6.161868   Trade Rng: $ 5.78
# i:-53 Close 114.82 Predicted: $ 112.3   Delta:$ 2.518743   Trade Rng: $ 6.16
# i:-54 Close 113.89 Predicted: $ 107.37   Delta:$ 6.518325   Trade Rng: $ 4.59
# i:-55 Close 106.46 Predicted: $ 101.32   Delta:$ 5.137288   Trade Rng: $ 5.06
# i:-56 Close 103.79 Predicted: $ 96.51   Delta:$ 7.278007   Trade Rng: $ 3.47
# i:-57 Close 94.94 Predicted: $ 95.86   Delta:$ 0.922334   Trade Rng: $ 4.8
# i:-58 Close 95.38 Predicted: $ 94.15   Delta:$ 1.223656   Trade Rng: $ 2.77
# i:-59 Close 94.77 Predicted: $ 94.42   Delta:$ 0.350506   Trade Rng: $ 2.22
# i:-60 Close 92.47 Predicted: $ 95.47   Delta:$ 3.002297   Trade Rng: $ 1.76
# i:-61 Close 94.35 Predicted: $ 93.58   Delta:$ 0.775997   Trade Rng: $ 2.93
# i:-62 Close 94.62 Predicted: $ 91.46   Delta:$ 3.162168   Trade Rng: $ 1.72
# i:-63 Close 91.35 Predicted: $ 90.77   Delta:$ 0.582695   Trade Rng: $ 3.26
# i:-64 Close 90.39 Predicted: $ 90.35   Delta:$ 0.040809   Trade Rng: $ 2.72
# i:-65 Close 89.87 Predicted: $ 90.73   Delta:$ 0.863766   Trade Rng: $ 2.47
# i:-66 Close 88.74 Predicted: $ 87.03   Delta:$ 1.713799   Trade Rng: $ 2.17
# i:-67 Close 90.4 Predicted: $ 92.5   Delta:$ 2.095081   Trade Rng: $ 2.84
# i:-68 Close 90.55 Predicted: $ 91.38   Delta:$ 0.834735   Trade Rng: $ 1.77
# i:-69 Close 92.13 Predicted: $ 88.71   Delta:$ 3.420134   Trade Rng: $ 2.77
# i:-70 Close 88.78 Predicted: $ 88.66   Delta:$ 0.121393   Trade Rng: $ 3.17
# i:-71 Close 85.81 Predicted: $ 84.62   Delta:$ 1.186198   Trade Rng: $ 2.24
# i:-72 Close 83.03 Predicted: $ 84.66   Delta:$ 1.623021   Trade Rng: $ 3.04
# i:-73 Close 86.39 Predicted: $ 88.29   Delta:$ 1.897639   Trade Rng: $ 4.75
# i:-74 Close 87.75 Predicted: $ 88.02   Delta:$ 0.272404   Trade Rng: $ 2.52
# i:-75 Close 87.73 Predicted: $ 89.27   Delta:$ 1.545305   Trade Rng: $ 2.73
# i:-76 Close 82.63 Predicted: $ 81.4   Delta:$ 1.223899   Trade Rng: $ 4.94
# i:-77 Close 79.67 Predicted: $ 79.89   Delta:$ 0.224156   Trade Rng: $ 5.1
# i:-78 Close 82.42 Predicted: $ 76.49   Delta:$ 5.923262   Trade Rng: $ 4.9
# i:-79 Close 79.51 Predicted: $ 79.85   Delta:$ 0.337915   Trade Rng: $ 2.5
# i:-80 Close 76.19 Predicted: $ 83.18   Delta:$ 6.988754   Trade Rng: $ 3.67
# i:-81 Close 84.66 Predicted: $ 85.08   Delta:$ 0.41589   Trade Rng: $ 8.72
# i:-82 Close 84.03 Predicted: $ 85.93   Delta:$ 1.901425   Trade Rng: $ 3.79
# i:-83 Close 87.41 Predicted: $ 87.06   Delta:$ 0.348513   Trade Rng: $ 4.83
# i:-84 Close 85.99 Predicted: $ 87.91   Delta:$ 1.911751   Trade Rng: $ 2.05
# i:-85 Close 88.18 Predicted: $ 86.64   Delta:$ 1.539654   Trade Rng: $ 4.68
# i:-86 Close 90.61 Predicted: $ 92.46   Delta:$ 1.846454   Trade Rng: $ 2.65
# i:-87 Close 87.03 Predicted: $ 85.97   Delta:$ 1.06176   Trade Rng: $ 3.81
# i:-88 Close 85.35 Predicted: $ 87.12   Delta:$ 1.774367   Trade Rng: $ 3.69
# i:-89 Close 87.13 Predicted: $ 86.36   Delta:$ 0.770198   Trade Rng: $ 4.61
# i:-90 Close 88.0 Predicted: $ 87.18   Delta:$ 0.82355   Trade Rng: $ 2.1
# i:-91 Close 85.9 Predicted: $ 88.55   Delta:$ 2.653412   Trade Rng: $ 2.56
# i:-92 Close 88.96 Predicted: $ 89.19   Delta:$ 0.237801   Trade Rng: $ 4.75
# i:-93 Close 89.44 Predicted: $ 89.81   Delta:$ 0.362613   Trade Rng: $ 1.97
# i:-94 Close 90.36 Predicted: $ 89.91   Delta:$ 0.446516   Trade Rng: $ 2.47
# i:-95 Close 90.35 Predicted: $ 90.79   Delta:$ 0.443392   Trade Rng: $ 3.02
# i:-96 Close 90.24 Predicted: $ 89.65   Delta:$ 0.590331   Trade Rng: $ 2.11
# i:-97 Close 92.55 Predicted: $ 95.22   Delta:$ 2.670625   Trade Rng: $ 4.12
# i:-98 Close 94.99 Predicted: $ 93.35   Delta:$ 1.64826   Trade Rng: $ 3.87
# i:-99 Close 94.28 Predicted: $ 91.71   Delta:$ 2.571273   Trade Rng: $ 3.26
# i:-100 Close 91.43 Predicted: $ 90.75   Delta:$ 0.682288   Trade Rng: $ 3.94
# i:-101 Close 90.36 Predicted: $ 90.57   Delta:$ 0.200775   Trade Rng: $ 2.24
# i:-102 Close 89.39 Predicted: $ 88.53   Delta:$ 0.860029   Trade Rng: $ 2.19
# i:-103 Close 88.45 Predicted: $ 88.12   Delta:$ 0.327936   Trade Rng: $ 5.53
# i:-104 Close 87.83 Predicted: $ 87.58   Delta:$ 0.25412   Trade Rng: $ 5.32
# i:-105 Close 87.94 Predicted: $ 85.71   Delta:$ 2.221944   Trade Rng: $ 3.29
# i:-106 Close 90.88 Predicted: $ 91.07   Delta:$ 0.191319   Trade Rng: $ 4.05
# i:-107 Close 91.91 Predicted: $ 90.18   Delta:$ 1.72687   Trade Rng: $ 3.07
# i:-108 Close 85.77 Predicted: $ 83.22   Delta:$ 2.548097   Trade Rng: $ 5.81
# i:-109 Close 87.52 Predicted: $ 92.23   Delta:$ 4.706489   Trade Rng: $ 4.63
# i:-110 Close 92.66 Predicted: $ 89.14   Delta:$ 3.518681   Trade Rng: $ 10.89
# i:-111 Close 88.69 Predicted: $ 87.61   Delta:$ 1.084543   Trade Rng: $ 3.17
# i:-112 Close 85.96 Predicted: $ 85.64   Delta:$ 0.320621   Trade Rng: $ 2.69
# i:-113 Close 85.23 Predicted: $ 82.16   Delta:$ 3.069394   Trade Rng: $ 2.68
# i:-114 Close 82.27 Predicted: $ 80.68   Delta:$ 1.587369   Trade Rng: $ 3.98
# i:-115 Close 79.1 Predicted: $ 78.42   Delta:$ 0.680369   Trade Rng: $ 2.87
# i:-116 Close 77.65 Predicted: $ 77.4   Delta:$ 0.257807   Trade Rng: $ 1.64
# i:-117 Close 78.69 Predicted: $ 80.66   Delta:$ 1.97391   Trade Rng: $ 1.81
# i:-118 Close 79.08 Predicted: $ 80.85   Delta:$ 1.764435   Trade Rng: $ 2.32
# i:-119 Close 78.81 Predicted: $ 81.32   Delta:$ 2.514391   Trade Rng: $ 2.14
# i:-120 Close 78.53 Predicted: $ 80.87   Delta:$ 2.339416   Trade Rng: $ 4.82
# i:-121 Close 67.46 Predicted: $ 71.49   Delta:$ 4.024853   Trade Rng: $ 4.35
# i:-122 Close 69.44 Predicted: $ 73.15   Delta:$ 3.704176   Trade Rng: $ 2.64
# i:-123 Close 72.6 Predicted: $ 73.57   Delta:$ 0.967863   Trade Rng: $ 4.22
# i:-124 Close 72.65 Predicted: $ 73.42   Delta:$ 0.771438   Trade Rng: $ 1.9
# i:-125 Close 73.89 Predicted: $ 74.18   Delta:$ 0.292214   Trade Rng: $ 1.57
# i:-126 Close 72.12 Predicted: $ 72.25   Delta:$ 0.127141   Trade Rng: $ 2.3
# i:-127 Close 72.24 Predicted: $ 72.58   Delta:$ 0.340375   Trade Rng: $ 3.83
# i:-128 Close 72.12 Predicted: $ 71.66   Delta:$ 0.466138   Trade Rng: $ 3.36
# i:-129 Close 69.63 Predicted: $ 69.74   Delta:$ 0.106517   Trade Rng: $ 1.97
# i:-130 Close 70.09 Predicted: $ 70.55   Delta:$ 0.458221   Trade Rng: $ 1.34
# i:-131 Close 68.21 Predicted: $ 69.37   Delta:$ 1.157674   Trade Rng: $ 2.62
# i:-132 Close 69.32 Predicted: $ 68.38   Delta:$ 0.945992   Trade Rng: $ 3.45
# i:-133 Close 66.15 Predicted: $ 63.16   Delta:$ 2.994921   Trade Rng: $ 2.29
# i:-134 Close 63.02 Predicted: $ 62.87   Delta:$ 0.146796   Trade Rng: $ 2.91
# i:-135 Close 61.52 Predicted: $ 63.59   Delta:$ 2.068494   Trade Rng: $ 1.54
# i:-136 Close 62.77 Predicted: $ 62.44   Delta:$ 0.325196   Trade Rng: $ 1.57
# i:-137 Close 62.46 Predicted: $ 62.31   Delta:$ 0.149518   Trade Rng: $ 1.23
# i:-138 Close 61.02 Predicted: $ 62.91   Delta:$ 1.89144   Trade Rng: $ 1.58
# i:-139 Close 61.61 Predicted: $ 61.96   Delta:$ 0.350913   Trade Rng: $ 1.21
# i:-140 Close 61.35 Predicted: $ 61.14   Delta:$ 0.212318   Trade Rng: $ 1.87
# i:-141 Close 59.87 Predicted: $ 60.22   Delta:$ 0.350689   Trade Rng: $ 2.91
# i:-142 Close 59.65 Predicted: $ 60.22   Delta:$ 0.572417   Trade Rng: $ 1.33
# i:-143 Close 59.48 Predicted: $ 59.26   Delta:$ 0.225175   Trade Rng: $ 1.26
# i:-144 Close 57.1 Predicted: $ 57.09   Delta:$ 0.004985   Trade Rng: $ 2.28
# i:-145 Close 56.05 Predicted: $ 56.29   Delta:$ 0.244942   Trade Rng: $ 1.49
# i:-146 Close 56.37 Predicted: $ 56.42   Delta:$ 0.045513   Trade Rng: $ 1.73
# i:-147 Close 54.7 Predicted: $ 53.98   Delta:$ 0.725834   Trade Rng: $ 1.93
# i:-148 Close 54.81 Predicted: $ 55.15   Delta:$ 0.331639   Trade Rng: $ 0.64
# i:-149 Close 54.34 Predicted: $ 54.09   Delta:$ 0.249327   Trade Rng: $ 1.79
# i:-150 Close 53.13 Predicted: $ 53.33   Delta:$ 0.19515   Trade Rng: $ 1.11
# i:-151 Close 52.25 Predicted: $ 53.49   Delta:$ 1.240947   Trade Rng: $ 2.64
# i:-152 Close 49.09 Predicted: $ 47.62   Delta:$ 1.475254   Trade Rng: $ 2.8
# i:-153 Close 47.99 Predicted: $ 47.09   Delta:$ 0.902555   Trade Rng: $ 1.24
# i:-154 Close 47.56 Predicted: $ 48.31   Delta:$ 0.742872   Trade Rng: $ 0.99
# i:-155 Close 48.16 Predicted: $ 49.57   Delta:$ 1.407499   Trade Rng: $ 0.86
# i:-156 Close 49.52 Predicted: $ 49.67   Delta:$ 0.159035   Trade Rng: $ 1.7
# i:-157 Close 49.52 Predicted: $ 49.67   Delta:$ 0.158992   Trade Rng: $ 1.25
# i:-158 Close 49.41 Predicted: $ 49.41   Delta:$ 0.004276   Trade Rng: $ 0.47
# i:-159 Close 49.27 Predicted: $ 49.12   Delta:$ 0.155039   Trade Rng: $ 0.6
# i:-160 Close 48.82 Predicted: $ 48.64   Delta:$ 0.186195   Trade Rng: $ 0.64
# i:-161 Close 48.98 Predicted: $ 48.97   Delta:$ 0.017317   Trade Rng: $ 0.92
# i:-162 Close 48.1 Predicted: $ 50.33   Delta:$ 2.222891   Trade Rng: $ 0.68
# i:-163 Close 49.6 Predicted: $ 50.22   Delta:$ 0.619209   Trade Rng: $ 1.9
# i:-164 Close 50.07 Predicted: $ 49.38   Delta:$ 0.693077   Trade Rng: $ 0.81
# i:-165 Close 48.88 Predicted: $ 48.92   Delta:$ 0.039044   Trade Rng: $ 1.28
# i:-166 Close 48.34 Predicted: $ 48.38   Delta:$ 0.037275   Trade Rng: $ 1.28
# i:-167 Close 48.08 Predicted: $ 47.41   Delta:$ 0.668413   Trade Rng: $ 1.25
# i:-168 Close 47.65 Predicted: $ 47.36   Delta:$ 0.292648   Trade Rng: $ 0.99
# i:-169 Close 46.62 Predicted: $ 47.26   Delta:$ 0.637002   Trade Rng: $ 1.62
# i:-170 Close 47.5 Predicted: $ 46.05   Delta:$ 1.448568   Trade Rng: $ 1.7
# i:-171 Close 46.59 Predicted: $ 45.82   Delta:$ 0.766713   Trade Rng: $ 1.19
# i:-172 Close 45.5 Predicted: $ 45.44   Delta:$ 0.058105   Trade Rng: $ 1.03
# i:-173 Close 46.56 Predicted: $ 45.16   Delta:$ 1.395332   Trade Rng: $ 1.98
# i:-174 Close 45.5 Predicted: $ 45.76   Delta:$ 0.259305   Trade Rng: $ 1.33
# i:-175 Close 46.75 Predicted: $ 46.73   Delta:$ 0.025075   Trade Rng: $ 1.07
# i:-176 Close 46.76 Predicted: $ 47.48   Delta:$ 0.721011   Trade Rng: $ 1.01
# i:-177 Close 48.13 Predicted: $ 47.42   Delta:$ 0.7104   Trade Rng: $ 1.69
# i:-178 Close 47.81 Predicted: $ 47.35   Delta:$ 0.458754   Trade Rng: $ 0.9
# i:-179 Close 48.23 Predicted: $ 47.57   Delta:$ 0.664223   Trade Rng: $ 0.85
# i:-180 Close 47.77 Predicted: $ 49.06   Delta:$ 1.289849   Trade Rng: $ 0.88
# i:-181 Close 48.71 Predicted: $ 50.37   Delta:$ 1.666364   Trade Rng: $ 1.18
# i:-182 Close 49.93 Predicted: $ 50.3   Delta:$ 0.365866   Trade Rng: $ 2.65
# i:-183 Close 50.4 Predicted: $ 49.94   Delta:$ 0.457714   Trade Rng: $ 1.29
# i:-184 Close 49.29 Predicted: $ 49.84   Delta:$ 0.550118   Trade Rng: $ 1.37
# i:-185 Close 49.47 Predicted: $ 50.21   Delta:$ 0.73738   Trade Rng: $ 0.71
# i:-186 Close 48.88 Predicted: $ 50.32   Delta:$ 1.438953   Trade Rng: $ 1.19
# i:-187 Close 49.65 Predicted: $ 49.51   Delta:$ 0.139656   Trade Rng: $ 1.76
# i:-188 Close 48.61 Predicted: $ 48.71   Delta:$ 0.100556   Trade Rng: $ 0.79
# i:-189 Close 48.32 Predicted: $ 48.34   Delta:$ 0.018602   Trade Rng: $ 1.02
# i:-190 Close 46.94 Predicted: $ 46.81   Delta:$ 0.12823   Trade Rng: $ 1.19
# i:-191 Close 46.56 Predicted: $ 47.11   Delta:$ 0.547323   Trade Rng: $ 1.48
# i:-192 Close 45.95 Predicted: $ 46.63   Delta:$ 0.683482   Trade Rng: $ 0.9
# i:-193 Close 45.74 Predicted: $ 45.41   Delta:$ 0.335899   Trade Rng: $ 1.06
# i:-194 Close 45.0 Predicted: $ 44.23   Delta:$ 0.762634   Trade Rng: $ 1.04
# i:-195 Close 43.5 Predicted: $ 44.26   Delta:$ 0.762009   Trade Rng: $ 1.59
# i:-196 Close 42.32 Predicted: $ 40.84   Delta:$ 1.471904   Trade Rng: $ 0.99
# i:-197 Close 40.77 Predicted: $ 40.49   Delta:$ 0.283657   Trade Rng: $ 1.51
# i:-198 Close 41.15 Predicted: $ 39.65   Delta:$ 1.504408   Trade Rng: $ 1.65
# i:-199 Close 40.49 Predicted: $ 40.3   Delta:$ 0.192016   Trade Rng: $ 1.28
# i:-200 Close 40.32 Predicted: $ 42.23   Delta:$ 1.913134   Trade Rng: $ 1.19
# i:-201 Close 41.77 Predicted: $ 43.08   Delta:$ 1.306088   Trade Rng: $ 2.38
# i:-202 Close 43.65 Predicted: $ 41.69   Delta:$ 1.961162   Trade Rng: $ 2.1
# i:-203 Close 42.97 Predicted: $ 40.88   Delta:$ 2.083439   Trade Rng: $ 1.01
# i:-204 Close 41.38 Predicted: $ 41.05   Delta:$ 0.323489   Trade Rng: $ 2.3
# i:-205 Close 42.09 Predicted: $ 41.9   Delta:$ 0.190462   Trade Rng: $ 1.39
# i:-206 Close 42.19 Predicted: $ 44.13   Delta:$ 1.939469   Trade Rng: $ 1.42
# i:-207 Close 43.93 Predicted: $ 45.29   Delta:$ 1.361561   Trade Rng: $ 1.39
# i:-208 Close 46.09 Predicted: $ 46.19   Delta:$ 0.106733   Trade Rng: $ 2.27
# i:-209 Close 45.45 Predicted: $ 47.48   Delta:$ 2.02449   Trade Rng: $ 1.31
# i:-210 Close 46.93 Predicted: $ 47.04   Delta:$ 0.102822   Trade Rng: $ 1.84
# i:-211 Close 46.8 Predicted: $ 46.27   Delta:$ 0.525516   Trade Rng: $ 1.28
# i:-212 Close 45.79 Predicted: $ 46.0   Delta:$ 0.214396   Trade Rng: $ 0.81
# i:-213 Close 45.26 Predicted: $ 45.79   Delta:$ 0.527916   Trade Rng: $ 1.17
# i:-214 Close 45.75 Predicted: $ 46.32   Delta:$ 0.565678   Trade Rng: $ 1.24
# i:-215 Close 44.68 Predicted: $ 44.18   Delta:$ 0.49821   Trade Rng: $ 1.76
# i:-216 Close 44.03 Predicted: $ 44.03   Delta:$ 0.002213   Trade Rng: $ 1.01
# i:-217 Close 43.51 Predicted: $ 44.28   Delta:$ 0.76927   Trade Rng: $ 0.85
# i:-218 Close 44.77 Predicted: $ 44.21   Delta:$ 0.561901   Trade Rng: $ 1.88
# i:-219 Close 43.49 Predicted: $ 43.34   Delta:$ 0.152567   Trade Rng: $ 1.31
# i:-220 Close 43.08 Predicted: $ 42.49   Delta:$ 0.59143   Trade Rng: $ 0.84
# i:-221 Close 42.46 Predicted: $ 42.09   Delta:$ 0.367345   Trade Rng: $ 1.33
# i:-222 Close 41.9 Predicted: $ 41.75   Delta:$ 0.146948   Trade Rng: $ 1.24
# i:-223 Close 42.21 Predicted: $ 40.69   Delta:$ 1.525198   Trade Rng: $ 1.17
# i:-224 Close 41.6 Predicted: $ 40.69   Delta:$ 0.913909   Trade Rng: $ 1.36
# i:-225 Close 41.01 Predicted: $ 41.9   Delta:$ 0.891806   Trade Rng: $ 0.88
# i:-226 Close 42.23 Predicted: $ 42.54   Delta:$ 0.311379   Trade Rng: $ 1.12
# i:-227 Close 43.51 Predicted: $ 42.82   Delta:$ 0.691372   Trade Rng: $ 1.68
# i:-228 Close 43.96 Predicted: $ 44.15   Delta:$ 0.19491   Trade Rng: $ 0.96
# i:-229 Close 43.89 Predicted: $ 45.22   Delta:$ 1.331067   Trade Rng: $ 2.24
# i:-230 Close 45.57 Predicted: $ 44.67   Delta:$ 0.900795   Trade Rng: $ 1.79
# i:-231 Close 45.48 Predicted: $ 44.22   Delta:$ 1.259002   Trade Rng: $ 0.86
# i:-232 Close 44.86 Predicted: $ 44.51   Delta:$ 0.350707   Trade Rng: $ 1.43
# i:-233 Close 45.17 Predicted: $ 44.88   Delta:$ 0.284393   Trade Rng: $ 1.14
# i:-234 Close 45.56 Predicted: $ 45.69   Delta:$ 0.125491   Trade Rng: $ 1.85
# i:-235 Close 46.23 Predicted: $ 47.34   Delta:$ 1.109163   Trade Rng: $ 1.33
# i:-236 Close 47.05 Predicted: $ 48.43   Delta:$ 1.37637   Trade Rng: $ 1.19
# i:-237 Close 48.53 Predicted: $ 49.19   Delta:$ 0.655563   Trade Rng: $ 1.97
# i:-238 Close 48.49 Predicted: $ 49.4   Delta:$ 0.90366   Trade Rng: $ 0.99
# i:-239 Close 49.34 Predicted: $ 49.95   Delta:$ 0.607308   Trade Rng: $ 1.66
# i:-240 Close 49.25 Predicted: $ 49.35   Delta:$ 0.096618   Trade Rng: $ 0.79
# i:-241 Close 48.77 Predicted: $ 49.22   Delta:$ 0.44761   Trade Rng: $ 1.5
# i:-242 Close 46.82 Predicted: $ 46.67   Delta:$ 0.152447   Trade Rng: $ 2.69
# i:-243 Close 46.0 Predicted: $ 46.76   Delta:$ 0.754036   Trade Rng: $ 2.09
# i:-244 Close 47.15 Predicted: $ 47.05   Delta:$ 0.100489   Trade Rng: $ 2.78
# i:-245 Close 47.1 Predicted: $ 47.43   Delta:$ 0.332218   Trade Rng: $ 3.11
# i:-246 Close 45.65 Predicted: $ 47.2   Delta:$ 1.547332   Trade Rng: $ 1.99
# i:-247 Close 46.95 Predicted: $ 46.33   Delta:$ 0.621063   Trade Rng: $ 2.85
# i:-248 Close 43.29 Predicted: $ 43.69   Delta:$ 0.402278   Trade Rng: $ 2.84
# i:-249 Close 43.33 Predicted: $ 43.99   Delta:$ 0.663431   Trade Rng: $ 1.92
# i:-250 Close 43.47 Predicted: $ 44.1   Delta:$ 0.623675   Trade Rng: $ 1.06
# i:-251 Close 43.93 Predicted: $ 41.93   Delta:$ 1.995068   Trade Rng: $ 1.27
# i:-252 Close 43.74 Predicted: $ 40.88   Delta:$ 2.857857   Trade Rng: $ 1.56
# i:-253 Close 40.84 Predicted: $ 41.46   Delta:$ 0.621926   Trade Rng: $ 3.49
# i:-254 Close 42.38 Predicted: $ 42.79   Delta:$ 0.416046   Trade Rng: $ 1.38
# i:-255 Close 42.54 Predicted: $ 44.5   Delta:$ 1.956298   Trade Rng: $ 1.74
# i:-256 Close 44.65 Predicted: $ 44.7   Delta:$ 0.05415   Trade Rng: $ 2.18
# i:-257 Close 45.4 Predicted: $ 43.93   Delta:$ 1.473908   Trade Rng: $ 1.19
# i:-258 Close 44.67 Predicted: $ 43.48   Delta:$ 1.188343   Trade Rng: $ 0.98
# i:-259 Close 44.5 Predicted: $ 44.73   Delta:$ 0.233227   Trade Rng: $ 1.25
# i:-260 Close 44.26 Predicted: $ 46.51   Delta:$ 2.252425   Trade Rng: $ 1.32
# i:-261 Close 46.49 Predicted: $ 47.02   Delta:$ 0.525314   Trade Rng: $ 2.45
# i:-262 Close 46.72 Predicted: $ 46.76   Delta:$ 0.043508   Trade Rng: $ 0.87
# i:-263 Close 46.74 Predicted: $ 46.09   Delta:$ 0.648951   Trade Rng: $ 0.62
# i:-264 Close 45.89 Predicted: $ 45.83   Delta:$ 0.055627   Trade Rng: $ 0.65
# i:-265 Close 45.44 Predicted: $ 45.14   Delta:$ 0.302035   Trade Rng: $ 1.65
# i:-266 Close 45.67 Predicted: $ 44.1   Delta:$ 1.56058   Trade Rng: $ 1.42
# i:-267 Close 44.6 Predicted: $ 44.57   Delta:$ 0.03054   Trade Rng: $ 1.26
# i:-268 Close 44.3 Predicted: $ 46.21   Delta:$ 1.914949   Trade Rng: $ 1.07
# i:-269 Close 45.51 Predicted: $ 47.37   Delta:$ 1.866608   Trade Rng: $ 1.77
# i:-270 Close 47.06 Predicted: $ 47.31   Delta:$ 0.247819   Trade Rng: $ 2.03
# i:-271 Close 47.48 Predicted: $ 47.24   Delta:$ 0.239455   Trade Rng: $ 1.08
# i:-272 Close 46.45 Predicted: $ 45.94   Delta:$ 0.503414   Trade Rng: $ 2.16
# i:-273 Close 45.46 Predicted: $ 44.9   Delta:$ 0.555623   Trade Rng: $ 1.23
# i:-274 Close 45.96 Predicted: $ 45.86   Delta:$ 0.102322   Trade Rng: $ 3.03
# i:-275 Close 43.89 Predicted: $ 42.65   Delta:$ 1.234746   Trade Rng: $ 1.66
# i:-276 Close 42.39 Predicted: $ 42.44   Delta:$ 0.043161   Trade Rng: $ 1.16
# i:-277 Close 42.17 Predicted: $ 42.44   Delta:$ 0.271052   Trade Rng: $ 0.69
# i:-278 Close 42.49 Predicted: $ 42.19   Delta:$ 0.300168   Trade Rng: $ 1.16
# i:-279 Close 42.09 Predicted: $ 42.64   Delta:$ 0.549766   Trade Rng: $ 1.03
# i:-280 Close 42.3 Predicted: $ 42.71   Delta:$ 0.408575   Trade Rng: $ 0.83
# i:-281 Close 42.4 Predicted: $ 41.74   Delta:$ 0.660547   Trade Rng: $ 1.09
# i:-282 Close 42.29 Predicted: $ 40.8   Delta:$ 1.490126   Trade Rng: $ 0.7
# i:-283 Close 40.81 Predicted: $ 41.27   Delta:$ 0.456267   Trade Rng: $ 1.05
# i:-284 Close 41.1 Predicted: $ 40.99   Delta:$ 0.119448   Trade Rng: $ 1.0
# i:-285 Close 41.86 Predicted: $ 41.0   Delta:$ 0.858895   Trade Rng: $ 1.33
# i:-286 Close 40.62 Predicted: $ 42.28   Delta:$ 1.65735   Trade Rng: $ 1.49
# i:-287 Close 42.2 Predicted: $ 43.09   Delta:$ 0.89129   Trade Rng: $ 2.66
# i:-288 Close 43.01 Predicted: $ 43.52   Delta:$ 0.506182   Trade Rng: $ 0.79
# i:-289 Close 43.03 Predicted: $ 43.65   Delta:$ 0.614271   Trade Rng: $ 1.19
# i:-290 Close 43.79 Predicted: $ 43.76   Delta:$ 0.031359   Trade Rng: $ 1.53
# i:-291 Close 42.68 Predicted: $ 41.87   Delta:$ 0.810485   Trade Rng: $ 1.32
# i:-292 Close 42.64 Predicted: $ 42.94   Delta:$ 0.302424   Trade Rng: $ 1.06
# i:-293 Close 42.98 Predicted: $ 42.08   Delta:$ 0.906751   Trade Rng: $ 1.14
# i:-294 Close 41.01 Predicted: $ 41.73   Delta:$ 0.719337   Trade Rng: $ 2.45
# i:-295 Close 39.47 Predicted: $ 39.21   Delta:$ 0.258629   Trade Rng: $ 1.36
# i:-296 Close 38.76 Predicted: $ 38.21   Delta:$ 0.54534   Trade Rng: $ 0.91
# i:-297 Close 38.5 Predicted: $ 38.17   Delta:$ 0.326628   Trade Rng: $ 1.14
# i:-298 Close 37.46 Predicted: $ 39.07   Delta:$ 1.606246   Trade Rng: $ 1.36
# i:-299 Close 38.64 Predicted: $ 38.89   Delta:$ 0.247634   Trade Rng: $ 2.14
# i:-300 Close 39.16 Predicted: $ 40.38   Delta:$ 1.220085   Trade Rng: $ 1.01
# i:-301 Close 39.31 Predicted: $ 39.65   Delta:$ 0.337794   Trade Rng: $ 0.86
# i:-302 Close 39.75 Predicted: $ 40.5   Delta:$ 0.7489   Trade Rng: $ 1.44
# i:-303 Close 37.82 Predicted: $ 41.53   Delta:$ 3.7067   Trade Rng: $ 1.71
# i:-304 Close 40.09 Predicted: $ 40.64   Delta:$ 0.54268   Trade Rng: $ 2.47
# i:-305 Close 38.93 Predicted: $ 37.95   Delta:$ 0.9847   Trade Rng: $ 1.99
# i:-306 Close 37.96 Predicted: $ 34.32   Delta:$ 3.645885   Trade Rng: $ 1.62
# i:-307 Close 30.53 Predicted: $ 31.48   Delta:$ 0.952302   Trade Rng: $ 2.85
# i:-308 Close 30.68 Predicted: $ 31.71   Delta:$ 1.036548   Trade Rng: $ 0.8
# i:-309 Close 31.16 Predicted: $ 31.23   Delta:$ 0.063706   Trade Rng: $ 0.66
# i:-310 Close 31.25 Predicted: $ 30.79   Delta:$ 0.46035   Trade Rng: $ 0.84
# i:-311 Close 31.67 Predicted: $ 31.15   Delta:$ 0.519999   Trade Rng: $ 0.66
# i:-312 Close 30.17 Predicted: $ 29.73   Delta:$ 0.439233   Trade Rng: $ 1.51
# i:-313 Close 29.2 Predicted: $ 28.96   Delta:$ 0.24392   Trade Rng: $ 0.77
# i:-314 Close 28.94 Predicted: $ 28.38   Delta:$ 0.562114   Trade Rng: $ 1.04
# i:-315 Close 28.33 Predicted: $ 28.74   Delta:$ 0.410581   Trade Rng: $ 0.82
# i:-316 Close 28.57 Predicted: $ 28.84   Delta:$ 0.269192   Trade Rng: $ 0.73
# i:-317 Close 28.87 Predicted: $ 28.94   Delta:$ 0.065365   Trade Rng: $ 0.7
# i:-318 Close 28.56 Predicted: $ 29.31   Delta:$ 0.748097   Trade Rng: $ 0.65
# i:-319 Close 29.14 Predicted: $ 29.63   Delta:$ 0.495009   Trade Rng: $ 0.52
# i:-320 Close 28.67 Predicted: $ 27.6   Delta:$ 1.072744   Trade Rng: $ 0.87
# i:-321 Close 27.55 Predicted: $ 27.97   Delta:$ 0.418784   Trade Rng: $ 1.02
# i:-322 Close 27.79 Predicted: $ 28.26   Delta:$ 0.466422   Trade Rng: $ 0.62
# i:-323 Close 28.2 Predicted: $ 28.33   Delta:$ 0.132962   Trade Rng: $ 0.9
# i:-324 Close 28.9 Predicted: $ 28.55   Delta:$ 0.350193   Trade Rng: $ 0.75
# i:-325 Close 27.74 Predicted: $ 27.58   Delta:$ 0.157039   Trade Rng: $ 1.28
# i:-326 Close 27.22 Predicted: $ 26.7   Delta:$ 0.519328   Trade Rng: $ 0.69
# i:-327 Close 26.95 Predicted: $ 26.19   Delta:$ 0.751388   Trade Rng: $ 0.87
# i:-328 Close 26.23 Predicted: $ 26.71   Delta:$ 0.475132   Trade Rng: $ 0.62
# i:-329 Close 27.03 Predicted: $ 26.7   Delta:$ 0.326866   Trade Rng: $ 1.02
# i:-330 Close 27.11 Predicted: $ 27.37   Delta:$ 0.262683   Trade Rng: $ 0.69
# i:-331 Close 27.09 Predicted: $ 28.25   Delta:$ 1.155475   Trade Rng: $ 0.46
# i:-332 Close 27.92 Predicted: $ 27.88   Delta:$ 0.043964   Trade Rng: $ 1.03
# i:-333 Close 27.66 Predicted: $ 28.17   Delta:$ 0.512107   Trade Rng: $ 0.77
# i:-334 Close 26.99 Predicted: $ 26.57   Delta:$ 0.423424   Trade Rng: $ 0.75
# i:-335 Close 26.75 Predicted: $ 26.05   Delta:$ 0.695383   Trade Rng: $ 0.57
# i:-336 Close 26.45 Predicted: $ 26.41   Delta:$ 0.039019   Trade Rng: $ 0.66
# i:-337 Close 26.48 Predicted: $ 27.23   Delta:$ 0.743972   Trade Rng: $ 0.56
# i:-338 Close 27.16 Predicted: $ 27.27   Delta:$ 0.108684   Trade Rng: $ 1.02
# i:-339 Close 27.57 Predicted: $ 26.55   Delta:$ 1.01842   Trade Rng: $ 0.66
# i:-340 Close 27.03 Predicted: $ 26.64   Delta:$ 0.389862   Trade Rng: $ 0.95
# i:-341 Close 26.87 Predicted: $ 27.61   Delta:$ 0.735273   Trade Rng: $ 0.65
# i:-342 Close 27.44 Predicted: $ 28.26   Delta:$ 0.821234   Trade Rng: $ 0.6
# i:-343 Close 27.95 Predicted: $ 28.12   Delta:$ 0.163211   Trade Rng: $ 0.69
# i:-344 Close 27.77 Predicted: $ 27.79   Delta:$ 0.025393   Trade Rng: $ 0.66
# i:-345 Close 27.37 Predicted: $ 27.05   Delta:$ 0.323829   Trade Rng: $ 0.73
# i:-346 Close 26.97 Predicted: $ 26.44   Delta:$ 0.53716   Trade Rng: $ 0.4
# i:-347 Close 26.4 Predicted: $ 26.66   Delta:$ 0.255837   Trade Rng: $ 0.48
# i:-348 Close 26.52 Predicted: $ 27.09   Delta:$ 0.571867   Trade Rng: $ 0.66
# i:-349 Close 26.77 Predicted: $ 27.32   Delta:$ 0.551265   Trade Rng: $ 0.64
# i:-350 Close 27.18 Predicted: $ 27.15   Delta:$ 0.030184   Trade Rng: $ 0.81
# i:-351 Close 26.46 Predicted: $ 26.47   Delta:$ 0.011401   Trade Rng: $ 0.81
# i:-352 Close 26.19 Predicted: $ 26.52   Delta:$ 0.327303   Trade Rng: $ 1.35
# i:-353 Close 25.89 Predicted: $ 26.44   Delta:$ 0.550985   Trade Rng: $ 1.01
# i:-354 Close 25.71 Predicted: $ 25.55   Delta:$ 0.165998   Trade Rng: $ 0.89
# i:-355 Close 25.53 Predicted: $ 24.85   Delta:$ 0.678468   Trade Rng: $ 0.73
# i:-356 Close 24.22 Predicted: $ 23.65   Delta:$ 0.573229   Trade Rng: $ 1.69
# i:-357 Close 24.05 Predicted: $ 24.84   Delta:$ 0.788391   Trade Rng: $ 0.93
# i:-358 Close 22.96 Predicted: $ 22.97   Delta:$ 0.016499   Trade Rng: $ 0.76
# i:-359 Close 22.96 Predicted: $ 23.62   Delta:$ 0.66614   Trade Rng: $ 1.0
# i:-360 Close 23.43 Predicted: $ 23.72   Delta:$ 0.298324   Trade Rng: $ 0.9
# i:-361 Close 24.17 Predicted: $ 24.45   Delta:$ 0.274685   Trade Rng: $ 1.07
# i:-362 Close 23.28 Predicted: $ 23.66   Delta:$ 0.38031   Trade Rng: $ 0.78
# i:-363 Close 23.54 Predicted: $ 23.63   Delta:$ 0.084794   Trade Rng: $ 0.88
# i:-364 Close 23.88 Predicted: $ 23.97   Delta:$ 0.096685   Trade Rng: $ 0.76
# i:-365 Close 23.3 Predicted: $ 22.98   Delta:$ 0.316702   Trade Rng: $ 0.77
# i:-366 Close 22.69 Predicted: $ 23.1   Delta:$ 0.418201   Trade Rng: $ 0.95
# i:-367 Close 23.2 Predicted: $ 22.6   Delta:$ 0.601559   Trade Rng: $ 0.75
# i:-368 Close 23.49 Predicted: $ 24.28   Delta:$ 0.797398   Trade Rng: $ 0.62
# i:-369 Close 23.27 Predicted: $ 23.97   Delta:$ 0.701712   Trade Rng: $ 0.43
# i:-370 Close 23.65 Predicted: $ 23.0   Delta:$ 0.653488   Trade Rng: $ 0.53
# i:-371 Close 20.74 Predicted: $ 20.6   Delta:$ 0.145756   Trade Rng: $ 0.86
# i:-372 Close 20.64 Predicted: $ 21.22   Delta:$ 0.578236   Trade Rng: $ 0.68
# i:-373 Close 21.38 Predicted: $ 21.99   Delta:$ 0.610693   Trade Rng: $ 0.88
# i:-374 Close 21.99 Predicted: $ 22.22   Delta:$ 0.229051   Trade Rng: $ 0.76
# i:-375 Close 22.75 Predicted: $ 23.07   Delta:$ 0.322091   Trade Rng: $ 0.62
# i:-376 Close 22.96 Predicted: $ 23.12   Delta:$ 0.157329   Trade Rng: $ 0.75
# i:-377 Close 21.78 Predicted: $ 21.48   Delta:$ 0.292252   Trade Rng: $ 1.68
# i:-378 Close 21.25 Predicted: $ 22.11   Delta:$ 0.860048   Trade Rng: $ 1.09
# i:-379 Close 22.32 Predicted: $ 22.76   Delta:$ 0.438246   Trade Rng: $ 1.27
# i:-380 Close 22.19 Predicted: $ 22.14   Delta:$ 0.053317   Trade Rng: $ 0.9
# i:-381 Close 22.16 Predicted: $ 21.46   Delta:$ 0.696238   Trade Rng: $ 0.87
# i:-382 Close 21.08 Predicted: $ 20.35   Delta:$ 0.725955   Trade Rng: $ 1.11
# i:-383 Close 21.09 Predicted: $ 21.98   Delta:$ 0.889117   Trade Rng: $ 0.78
# i:-384 Close 21.7 Predicted: $ 21.06   Delta:$ 0.640675   Trade Rng: $ 0.96
# i:-385 Close 20.93 Predicted: $ 20.63   Delta:$ 0.303688   Trade Rng: $ 1.25
# i:-386 Close 19.53 Predicted: $ 19.14   Delta:$ 0.384581   Trade Rng: $ 1.58
# i:-387 Close 19.15 Predicted: $ 19.38   Delta:$ 0.228798   Trade Rng: $ 0.74
# i:-388 Close 20.35 Predicted: $ 20.19   Delta:$ 0.160339   Trade Rng: $ 0.99
# i:-389 Close 19.79 Predicted: $ 19.95   Delta:$ 0.158305   Trade Rng: $ 1.22
# i:-390 Close 19.31 Predicted: $ 20.0   Delta:$ 0.68346   Trade Rng: $ 0.89
# i:-391 Close 19.25 Predicted: $ 19.19   Delta:$ 0.062492   Trade Rng: $ 0.79
# i:-392 Close 19.18 Predicted: $ 18.36   Delta:$ 0.818963   Trade Rng: $ 0.68
# i:-393 Close 17.83 Predicted: $ 17.83   Delta:$ 0.001257   Trade Rng: $ 1.43
# i:-394 Close 16.76 Predicted: $ 17.07   Delta:$ 0.310315   Trade Rng: $ 1.03
# i:-395 Close 17.37 Predicted: $ 17.79   Delta:$ 0.420395   Trade Rng: $ 0.47
# i:-396 Close 17.69 Predicted: $ 17.23   Delta:$ 0.462811   Trade Rng: $ 0.59
# i:-397 Close 16.89 Predicted: $ 16.78   Delta:$ 0.111549   Trade Rng: $ 0.83
# i:-398 Close 16.5 Predicted: $ 16.45   Delta:$ 0.046718   Trade Rng: $ 0.76
# i:-399 Close 15.99 Predicted: $ 16.31   Delta:$ 0.319152   Trade Rng: $ 1.14
# i:-400 Close 15.9 Predicted: $ 15.83   Delta:$ 0.066071   Trade Rng: $ 0.47
# i:-401 Close 15.62 Predicted: $ 15.63   Delta:$ 0.008546   Trade Rng: $ 0.49
# i:-402 Close 14.85 Predicted: $ 14.42   Delta:$ 0.42945   Trade Rng: $ 0.91
# i:-403 Close 14.26 Predicted: $ 14.59   Delta:$ 0.337005   Trade Rng: $ 0.98
# i:-404 Close 14.74 Predicted: $ 14.26   Delta:$ 0.480881   Trade Rng: $ 0.42
# i:-405 Close 14.31 Predicted: $ 14.63   Delta:$ 0.323634   Trade Rng: $ 0.61
# i:-406 Close 14.61 Predicted: $ 14.24   Delta:$ 0.360725   Trade Rng: $ 0.9
# i:-407 Close 14.59 Predicted: $ 13.49   Delta:$ 1.10589   Trade Rng: $ 0.4
# i:-408 Close 14.03 Predicted: $ 14.08   Delta:$ 0.048106   Trade Rng: $ 0.46
# i:-409 Close 14.11 Predicted: $ 14.67   Delta:$ 0.553309   Trade Rng: $ 0.38
# i:-410 Close 15.2 Predicted: $ 15.58   Delta:$ 0.384963   Trade Rng: $ 1.04
# i:-411 Close 15.33 Predicted: $ 16.19   Delta:$ 0.857186   Trade Rng: $ 0.46
# i:-412 Close 16.49 Predicted: $ 15.68   Delta:$ 0.80779   Trade Rng: $ 1.26
# i:-413 Close 16.08 Predicted: $ 15.91   Delta:$ 0.168203   Trade Rng: $ 0.53
# i:-414 Close 16.24 Predicted: $ 16.2   Delta:$ 0.047142   Trade Rng: $ 0.46
# i:-415 Close 16.56 Predicted: $ 16.89   Delta:$ 0.328583   Trade Rng: $ 0.46
# i:-416 Close 16.94 Predicted: $ 17.49   Delta:$ 0.552528   Trade Rng: $ 0.63
# i:-417 Close 17.66 Predicted: $ 17.56   Delta:$ 0.104741   Trade Rng: $ 0.62
# i:-418 Close 18.06 Predicted: $ 17.7   Delta:$ 0.364371   Trade Rng: $ 0.83
# i:-419 Close 17.52 Predicted: $ 17.58   Delta:$ 0.058544   Trade Rng: $ 1.08
# i:-420 Close 16.99 Predicted: $ 17.52   Delta:$ 0.528388   Trade Rng: $ 0.74
# i:-421 Close 17.16 Predicted: $ 17.31   Delta:$ 0.153122   Trade Rng: $ 0.61
# i:-422 Close 16.11 Predicted: $ 15.94   Delta:$ 0.169576   Trade Rng: $ 1.22
# i:-423 Close 15.98 Predicted: $ 16.57   Delta:$ 0.593098   Trade Rng: $ 0.52
# i:-424 Close 16.6 Predicted: $ 16.78   Delta:$ 0.181603   Trade Rng: $ 0.75
# i:-425 Close 16.87 Predicted: $ 16.63   Delta:$ 0.233359   Trade Rng: $ 0.52
# i:-426 Close 17.13 Predicted: $ 17.45   Delta:$ 0.320453   Trade Rng: $ 0.49
# i:-427 Close 16.91 Predicted: $ 17.29   Delta:$ 0.376802   Trade Rng: $ 0.63
# i:-428 Close 15.63 Predicted: $ 15.89   Delta:$ 0.264152   Trade Rng: $ 1.33
# i:-429 Close 15.81 Predicted: $ 16.39   Delta:$ 0.580351   Trade Rng: $ 0.41
# i:-430 Close 16.26 Predicted: $ 16.47   Delta:$ 0.214082   Trade Rng: $ 0.63
# i:-431 Close 16.51 Predicted: $ 16.69   Delta:$ 0.181651   Trade Rng: $ 0.31
# i:-432 Close 16.02 Predicted: $ 16.66   Delta:$ 0.631779   Trade Rng: $ 0.48
# i:-433 Close 15.3 Predicted: $ 15.33   Delta:$ 0.025082   Trade Rng: $ 0.94
# i:-434 Close 15.4 Predicted: $ 15.52   Delta:$ 0.123334   Trade Rng: $ 0.4
# i:-435 Close 15.66 Predicted: $ 15.78   Delta:$ 0.115816   Trade Rng: $ 0.88
# i:-436 Close 15.9 Predicted: $ 16.02   Delta:$ 0.124001   Trade Rng: $ 0.73
# i:-437 Close 16.65 Predicted: $ 16.9   Delta:$ 0.250136   Trade Rng: $ 0.49
# i:-438 Close 16.28 Predicted: $ 16.67   Delta:$ 0.392661   Trade Rng: $ 0.62
# i:-439 Close 16.31 Predicted: $ 16.43   Delta:$ 0.115791   Trade Rng: $ 0.62
# i:-440 Close 15.74 Predicted: $ 15.75   Delta:$ 0.014659   Trade Rng: $ 0.91
# i:-441 Close 13.76 Predicted: $ 14.97   Delta:$ 1.209623   Trade Rng: $ 1.23
# i:-442 Close 14.59 Predicted: $ 14.62   Delta:$ 0.033598   Trade Rng: $ 0.45
# i:-443 Close 14.29 Predicted: $ 14.14   Delta:$ 0.151549   Trade Rng: $ 0.68
# i:-444 Close 14.14 Predicted: $ 14.65   Delta:$ 0.50739   Trade Rng: $ 0.46
# i:-445 Close 13.41 Predicted: $ 13.35   Delta:$ 0.056485   Trade Rng: $ 0.53
# i:-446 Close 13.21 Predicted: $ 13.59   Delta:$ 0.377371   Trade Rng: $ 0.82
# i:-447 Close 13.53 Predicted: $ 13.62   Delta:$ 0.091781   Trade Rng: $ 1.0
# i:-448 Close 13.49 Predicted: $ 13.67   Delta:$ 0.188508   Trade Rng: $ 0.41
# i:-449 Close 13.82 Predicted: $ 14.09   Delta:$ 0.267745   Trade Rng: $ 0.54
# i:-450 Close 13.17 Predicted: $ 13.11   Delta:$ 0.05589   Trade Rng: $ 0.79
# i:-451 Close 12.89 Predicted: $ 13.27   Delta:$ 0.380291   Trade Rng: $ 0.72
# i:-452 Close 13.25 Predicted: $ 13.58   Delta:$ 0.327545   Trade Rng: $ 0.68
# i:-453 Close 12.59 Predicted: $ 12.63   Delta:$ 0.038772   Trade Rng: $ 0.64
# i:-454 Close 12.46 Predicted: $ 12.36   Delta:$ 0.096911   Trade Rng: $ 0.65
# i:-455 Close 12.18 Predicted: $ 12.22   Delta:$ 0.033252   Trade Rng: $ 0.61
# i:-456 Close 12.04 Predicted: $ 12.22   Delta:$ 0.174725   Trade Rng: $ 0.66
# i:-457 Close 11.96 Predicted: $ 11.68   Delta:$ 0.279199   Trade Rng: $ 0.52
# i:-458 Close 11.88 Predicted: $ 11.6   Delta:$ 0.27581   Trade Rng: $ 0.87
# i:-459 Close 11.22 Predicted: $ 11.84   Delta:$ 0.626839   Trade Rng: $ 0.43
# i:-460 Close 11.95 Predicted: $ 12.7   Delta:$ 0.750166   Trade Rng: $ 0.91
# i:-461 Close 11.49 Predicted: $ 11.08   Delta:$ 0.409746   Trade Rng: $ 1.27
# i:-462 Close 11.58 Predicted: $ 11.14   Delta:$ 0.441314   Trade Rng: $ 0.39
# i:-463 Close 11.66 Predicted: $ 12.04   Delta:$ 0.377807   Trade Rng: $ 0.56
# i:-464 Close 12.07 Predicted: $ 13.27   Delta:$ 1.206139   Trade Rng: $ 0.72
# i:-465 Close 13.12 Predicted: $ 13.26   Delta:$ 0.142114   Trade Rng: $ 0.65
# i:-466 Close 13.2 Predicted: $ 13.06   Delta:$ 0.13535   Trade Rng: $ 0.55
# i:-467 Close 13.16 Predicted: $ 13.17   Delta:$ 0.010257   Trade Rng: $ 0.7
# i:-468 Close 12.5 Predicted: $ 11.94   Delta:$ 0.566113   Trade Rng: $ 0.34
# i:-469 Close 12.13 Predicted: $ 12.32   Delta:$ 0.195422   Trade Rng: $ 0.57
# i:-470 Close 12.21 Predicted: $ 12.78   Delta:$ 0.569656   Trade Rng: $ 0.56
# i:-471 Close 12.73 Predicted: $ 12.96   Delta:$ 0.238272   Trade Rng: $ 0.55
# i:-472 Close 12.4 Predicted: $ 11.94   Delta:$ 0.458315   Trade Rng: $ 0.47
# i:-473 Close 12.22 Predicted: $ 11.99   Delta:$ 0.223455   Trade Rng: $ 0.48
# i:-474 Close 12.51 Predicted: $ 12.5   Delta:$ 0.005488   Trade Rng: $ 0.45
# i:-475 Close 12.55 Predicted: $ 13.1   Delta:$ 0.553072   Trade Rng: $ 0.35
# i:-476 Close 13.25 Predicted: $ 13.19   Delta:$ 0.063977   Trade Rng: $ 0.72
# i:-477 Close 13.17 Predicted: $ 13.38   Delta:$ 0.210999   Trade Rng: $ 0.92
# i:-478 Close 13.37 Predicted: $ 12.91   Delta:$ 0.463567   Trade Rng: $ 0.43
# i:-479 Close 13.19 Predicted: $ 12.9   Delta:$ 0.28446   Trade Rng: $ 0.45
# i:-480 Close 12.92 Predicted: $ 13.86   Delta:$ 0.945574   Trade Rng: $ 0.6
# Mean Trading Range: $ 2.0
# Mean Delta (Actual vs Prediction): $ 3.35
# Mean Delta (Actual vs Adj Prediction): $ 3.35

# %% [markdown]
# ## - Rescaled data (0..1) (Adjusted Prediction vs Target)

# %%
def analyze_pred(target_close, target_high, target_low, pred_close):
    # Convert back to dollar $values
    elements = len(target_close)
    print(elements)
    tot_deltas = 0
    tot_tradrng = 0
    for i in range(1, -elements, -1):
        actual = target_close[i - 1]
        scalefac = target_close[i - 1] / target_close[i - 1]
        # print("Scaling Factor", scalefac)
        predval = pred_close[i] * scalefac
        predval = pred_close[i - 1] if np.isinf(predval) else predval
        pred_delta = abs(predval - actual)
        tot_deltas += pred_delta
        trd_rng = abs(target_high[i] - target_low[i])
        tot_tradrng += trd_rng
        print(f"i:{i}", "Close", actual.round(2), "Predicted: $", predval.round(2), "  Delta:$", pred_delta.round(6), "  Trade Rng: $", trd_rng.round(2))

    print("Mean Trading Range: $", round(tot_tradrng / elements, 2))
    print("Mean Delta (Actual vs Prediction): $", round((tot_deltas / elements), 2))
    return tot_deltas, tot_tradrng, elements

tot_deltas, tot_tradrng, elements = analyze_pred(target_close, target_high, target_low, pred_adj_close)

print("Mean Trading Range: $", round(tot_tradrng / elements, 2))
print("Mean Delta (Actual vs Prediction): $", round((tot_deltas[0] / elements), 2))
# Out:
# 481
# i:1 Close 12.92 Predicted: $ 12.9   Delta:$ 0.015684   Trade Rng: $ 0.6
# i:0 Close 116.14 Predicted: $ 13.86   Delta:$ 102.276131   Trade Rng: $ 0.44
# i:-1 Close 116.14 Predicted: $ 113.67   Delta:$ 2.466092   Trade Rng: $ 4.65
# i:-2 Close 109.02 Predicted: $ 107.39   Delta:$ 1.625389   Trade Rng: $ 4.65
# i:-3 Close 104.75 Predicted: $ 104.86   Delta:$ 0.105865   Trade Rng: $ 4.81
# i:-4 Close 104.97 Predicted: $ 106.71   Delta:$ 1.735015   Trade Rng: $ 3.17
# i:-5 Close 98.91 Predicted: $ 107.48   Delta:$ 8.568695   Trade Rng: $ 7.98
# i:-6 Close 104.25 Predicted: $ 100.35   Delta:$ 3.904636   Trade Rng: $ 10.11
# i:-7 Close 100.45 Predicted: $ 100.88   Delta:$ 0.429481   Trade Rng: $ 7.16
# i:-8 Close 107.27 Predicted: $ 105.74   Delta:$ 1.525338   Trade Rng: $ 12.72
# i:-9 Close 109.21 Predicted: $ 105.13   Delta:$ 4.079213   Trade Rng: $ 7.35
# i:-10 Close 117.02 Predicted: $ 115.36   Delta:$ 1.66128   Trade Rng: $ 13.35
# i:-11 Close 103.73 Predicted: $ 114.18   Delta:$ 10.45148   Trade Rng: $ 7.46
# i:-12 Close 111.59 Predicted: $ 110.01   Delta:$ 1.576861   Trade Rng: $ 9.45
# i:-13 Close 113.06 Predicted: $ 112.0   Delta:$ 1.064021   Trade Rng: $ 4.98
# i:-14 Close 112.28 Predicted: $ 113.13   Delta:$ 0.848986   Trade Rng: $ 4.62
# i:-15 Close 114.25 Predicted: $ 108.61   Delta:$ 5.638588   Trade Rng: $ 10.33
# i:-16 Close 122.59 Predicted: $ 122.07   Delta:$ 0.521621   Trade Rng: $ 6.51
# i:-17 Close 123.54 Predicted: $ 119.24   Delta:$ 4.301507   Trade Rng: $ 2.59
# i:-18 Close 117.93 Predicted: $ 118.72   Delta:$ 0.791626   Trade Rng: $ 4.21
# i:-19 Close 121.09 Predicted: $ 118.56   Delta:$ 2.528437   Trade Rng: $ 4.23
# i:-20 Close 117.99 Predicted: $ 122.11   Delta:$ 4.115505   Trade Rng: $ 5.84
# i:-21 Close 126.36 Predicted: $ 127.03   Delta:$ 0.668926   Trade Rng: $ 5.13
# i:-22 Close 128.44 Predicted: $ 128.15   Delta:$ 0.288128   Trade Rng: $ 4.46
# i:-23 Close 129.24 Predicted: $ 128.45   Delta:$ 0.789901   Trade Rng: $ 4.21
# i:-24 Close 127.4 Predicted: $ 132.97   Delta:$ 5.571655   Trade Rng: $ 4.7
# i:-25 Close 134.91 Predicted: $ 133.83   Delta:$ 1.084803   Trade Rng: $ 9.1
# i:-26 Close 131.38 Predicted: $ 130.18   Delta:$ 1.195911   Trade Rng: $ 2.68
# i:-27 Close 128.2 Predicted: $ 127.89   Delta:$ 0.312488   Trade Rng: $ 5.17
# i:-28 Close 125.83 Predicted: $ 127.78   Delta:$ 1.946121   Trade Rng: $ 3.73
# i:-29 Close 128.28 Predicted: $ 124.88   Delta:$ 3.403386   Trade Rng: $ 3.17
# i:-30 Close 122.67 Predicted: $ 123.03   Delta:$ 0.360602   Trade Rng: $ 6.92
# i:-31 Close 124.3 Predicted: $ 123.61   Delta:$ 0.68969   Trade Rng: $ 2.38
# i:-32 Close 123.54 Predicted: $ 123.81   Delta:$ 0.26739   Trade Rng: $ 6.01
# i:-33 Close 123.99 Predicted: $ 125.54   Delta:$ 1.548662   Trade Rng: $ 4.96
# i:-34 Close 126.4 Predicted: $ 125.67   Delta:$ 0.727335   Trade Rng: $ 3.49
# i:-35 Close 126.09 Predicted: $ 120.92   Delta:$ 5.171544   Trade Rng: $ 5.52
# i:-36 Close 118.11 Predicted: $ 123.06   Delta:$ 4.950546   Trade Rng: $ 7.18
# i:-37 Close 126.57 Predicted: $ 129.58   Delta:$ 3.010965   Trade Rng: $ 6.42
# i:-38 Close 130.78 Predicted: $ 133.64   Delta:$ 2.860929   Trade Rng: $ 6.33
# i:-39 Close 135.58 Predicted: $ 133.06   Delta:$ 2.522647   Trade Rng: $ 11.24
# i:-40 Close 130.98 Predicted: $ 133.04   Delta:$ 2.061544   Trade Rng: $ 5.64
# i:-41 Close 131.88 Predicted: $ 132.6   Delta:$ 0.722936   Trade Rng: $ 4.15
# i:-42 Close 129.61 Predicted: $ 128.91   Delta:$ 0.698303   Trade Rng: $ 4.52
# i:-43 Close 125.2 Predicted: $ 124.42   Delta:$ 0.783713   Trade Rng: $ 2.64
# i:-44 Close 120.91 Predicted: $ 122.72   Delta:$ 1.809216   Trade Rng: $ 4.31
# i:-45 Close 121.78 Predicted: $ 122.38   Delta:$ 0.603644   Trade Rng: $ 4.13
# i:-46 Close 120.88 Predicted: $ 122.47   Delta:$ 1.593911   Trade Rng: $ 6.09
# i:-47 Close 120.99 Predicted: $ 123.96   Delta:$ 2.969407   Trade Rng: $ 3.67
# i:-48 Close 122.43 Predicted: $ 120.95   Delta:$ 1.476531   Trade Rng: $ 7.27
# i:-49 Close 116.43 Predicted: $ 117.39   Delta:$ 0.963384   Trade Rng: $ 4.98
# i:-50 Close 114.99 Predicted: $ 113.69   Delta:$ 1.305201   Trade Rng: $ 2.56
# i:-51 Close 109.62 Predicted: $ 112.14   Delta:$ 2.512238   Trade Rng: $ 3.0
# i:-52 Close 110.49 Predicted: $ 115.45   Delta:$ 4.963584   Trade Rng: $ 5.78
# i:-53 Close 114.82 Predicted: $ 116.65   Delta:$ 1.837222   Trade Rng: $ 6.16
# i:-54 Close 113.89 Predicted: $ 112.3   Delta:$ 1.594824   Trade Rng: $ 4.59
# i:-55 Close 106.46 Predicted: $ 107.37   Delta:$ 0.913063   Trade Rng: $ 5.06
# i:-56 Close 103.79 Predicted: $ 101.32   Delta:$ 2.467512   Trade Rng: $ 3.47
# i:-57 Close 94.94 Predicted: $ 96.51   Delta:$ 1.570275   Trade Rng: $ 4.8
# i:-58 Close 95.38 Predicted: $ 95.86   Delta:$ 0.486367   Trade Rng: $ 2.77
# i:-59 Close 94.77 Predicted: $ 94.15   Delta:$ 0.617706   Trade Rng: $ 2.22
# i:-60 Close 92.47 Predicted: $ 94.42   Delta:$ 1.950313   Trade Rng: $ 1.76
# i:-61 Close 94.35 Predicted: $ 95.47   Delta:$ 1.122445   Trade Rng: $ 2.93
# i:-62 Close 94.62 Predicted: $ 93.58   Delta:$ 1.04697   Trade Rng: $ 1.72
# i:-63 Close 91.35 Predicted: $ 91.46   Delta:$ 0.11156   Trade Rng: $ 3.26
# i:-64 Close 90.39 Predicted: $ 90.77   Delta:$ 0.374222   Trade Rng: $ 2.72
# i:-65 Close 89.87 Predicted: $ 90.35   Delta:$ 0.480156   Trade Rng: $ 2.47
# i:-66 Close 88.74 Predicted: $ 90.73   Delta:$ 1.994664   Trade Rng: $ 2.17
# i:-67 Close 90.4 Predicted: $ 87.03   Delta:$ 3.378662   Trade Rng: $ 2.84
# i:-68 Close 90.55 Predicted: $ 92.5   Delta:$ 1.953098   Trade Rng: $ 1.77
# i:-69 Close 92.13 Predicted: $ 91.38   Delta:$ 0.751134   Trade Rng: $ 2.77
# i:-70 Close 88.78 Predicted: $ 88.71   Delta:$ 0.069411   Trade Rng: $ 3.17
# i:-71 Close 85.81 Predicted: $ 88.66   Delta:$ 2.850363   Trade Rng: $ 2.24
# i:-72 Close 83.03 Predicted: $ 84.62   Delta:$ 1.589574   Trade Rng: $ 3.04
# i:-73 Close 86.39 Predicted: $ 84.66   Delta:$ 1.737705   Trade Rng: $ 4.75
# i:-74 Close 87.75 Predicted: $ 88.29   Delta:$ 0.54275   Trade Rng: $ 2.52
# i:-75 Close 87.73 Predicted: $ 88.02   Delta:$ 0.294407   Trade Rng: $ 2.73
# i:-76 Close 82.63 Predicted: $ 89.27   Delta:$ 6.647882   Trade Rng: $ 4.94
# i:-77 Close 79.67 Predicted: $ 81.4   Delta:$ 1.730858   Trade Rng: $ 5.1
# i:-78 Close 82.42 Predicted: $ 79.89   Delta:$ 2.521617   Trade Rng: $ 4.9
# i:-79 Close 79.51 Predicted: $ 76.49   Delta:$ 3.0185   Trade Rng: $ 2.5
# i:-80 Close 76.19 Predicted: $ 79.85   Delta:$ 3.655641   Trade Rng: $ 3.67
# i:-81 Close 84.66 Predicted: $ 83.18   Delta:$ 1.481545   Trade Rng: $ 8.72
# i:-82 Close 84.03 Predicted: $ 85.08   Delta:$ 1.05183   Trade Rng: $ 3.79
# i:-83 Close 87.41 Predicted: $ 85.93   Delta:$ 1.478297   Trade Rng: $ 4.83
# i:-84 Close 85.99 Predicted: $ 87.06   Delta:$ 1.065374   Trade Rng: $ 2.05
# i:-85 Close 88.18 Predicted: $ 87.91   Delta:$ 0.273071   Trade Rng: $ 4.68
# i:-86 Close 90.61 Predicted: $ 86.64   Delta:$ 3.969448   Trade Rng: $ 2.65
# i:-87 Close 87.03 Predicted: $ 92.46   Delta:$ 5.423153   Trade Rng: $ 3.81
# i:-88 Close 85.35 Predicted: $ 85.97   Delta:$ 0.623108   Trade Rng: $ 3.69
# i:-89 Close 87.13 Predicted: $ 87.12   Delta:$ 0.004495   Trade Rng: $ 4.61
# i:-90 Close 88.0 Predicted: $ 86.36   Delta:$ 1.645129   Trade Rng: $ 2.1
# i:-91 Close 85.9 Predicted: $ 87.18   Delta:$ 1.279286   Trade Rng: $ 2.56
# i:-92 Close 88.96 Predicted: $ 88.55   Delta:$ 0.405334   Trade Rng: $ 4.75
# i:-93 Close 89.44 Predicted: $ 89.19   Delta:$ 0.250167   Trade Rng: $ 1.97
# i:-94 Close 90.36 Predicted: $ 89.81   Delta:$ 0.548306   Trade Rng: $ 2.47
# i:-95 Close 90.35 Predicted: $ 89.91   Delta:$ 0.43952   Trade Rng: $ 3.02
# i:-96 Close 90.24 Predicted: $ 90.79   Delta:$ 0.549387   Trade Rng: $ 2.11
# i:-97 Close 92.55 Predicted: $ 89.65   Delta:$ 2.901145   Trade Rng: $ 4.12
# i:-98 Close 94.99 Predicted: $ 95.22   Delta:$ 0.229829   Trade Rng: $ 3.87
# i:-99 Close 94.28 Predicted: $ 93.35   Delta:$ 0.935323   Trade Rng: $ 3.26
# i:-100 Close 91.43 Predicted: $ 91.71   Delta:$ 0.282494   Trade Rng: $ 3.94
# i:-101 Close 90.36 Predicted: $ 90.75   Delta:$ 0.380624   Trade Rng: $ 2.24
# i:-102 Close 89.39 Predicted: $ 90.57   Delta:$ 1.17469   Trade Rng: $ 2.19
# i:-103 Close 88.45 Predicted: $ 88.53   Delta:$ 0.082895   Trade Rng: $ 5.53
# i:-104 Close 87.83 Predicted: $ 88.12   Delta:$ 0.290022   Trade Rng: $ 5.32
# i:-105 Close 87.94 Predicted: $ 87.58   Delta:$ 0.361114   Trade Rng: $ 3.29
# i:-106 Close 90.88 Predicted: $ 85.71   Delta:$ 5.165708   Trade Rng: $ 4.05
# i:-107 Close 91.91 Predicted: $ 91.07   Delta:$ 0.833591   Trade Rng: $ 3.07
# i:-108 Close 85.77 Predicted: $ 90.18   Delta:$ 4.411619   Trade Rng: $ 5.81
# i:-109 Close 87.52 Predicted: $ 83.22   Delta:$ 4.30195   Trade Rng: $ 4.63
# i:-110 Close 92.66 Predicted: $ 92.23   Delta:$ 0.434083   Trade Rng: $ 10.89
# i:-111 Close 88.69 Predicted: $ 89.14   Delta:$ 0.449993   Trade Rng: $ 3.17
# i:-112 Close 85.96 Predicted: $ 87.61   Delta:$ 1.651228   Trade Rng: $ 2.69
# i:-113 Close 85.23 Predicted: $ 85.64   Delta:$ 0.410321   Trade Rng: $ 2.68
# i:-114 Close 82.27 Predicted: $ 82.16   Delta:$ 0.111776   Trade Rng: $ 3.98
# i:-115 Close 79.1 Predicted: $ 80.68   Delta:$ 1.579219   Trade Rng: $ 2.87
# i:-116 Close 77.65 Predicted: $ 78.42   Delta:$ 0.768445   Trade Rng: $ 1.64
# i:-117 Close 78.69 Predicted: $ 77.4   Delta:$ 1.295671   Trade Rng: $ 1.81
# i:-118 Close 79.08 Predicted: $ 80.66   Delta:$ 1.58295   Trade Rng: $ 2.32
# i:-119 Close 78.81 Predicted: $ 80.85   Delta:$ 2.039406   Trade Rng: $ 2.14
# i:-120 Close 78.53 Predicted: $ 81.32   Delta:$ 2.793352   Trade Rng: $ 4.82
# i:-121 Close 67.46 Predicted: $ 80.87   Delta:$ 13.403992   Trade Rng: $ 4.35
# i:-122 Close 69.44 Predicted: $ 71.49   Delta:$ 2.045109   Trade Rng: $ 2.64
# i:-123 Close 72.6 Predicted: $ 73.15   Delta:$ 0.543585   Trade Rng: $ 4.22
# i:-124 Close 72.65 Predicted: $ 73.57   Delta:$ 0.922872   Trade Rng: $ 1.9
# i:-125 Close 73.89 Predicted: $ 73.42   Delta:$ 0.470407   Trade Rng: $ 1.57
# i:-126 Close 72.12 Predicted: $ 74.18   Delta:$ 2.063981   Trade Rng: $ 2.3
# i:-127 Close 72.24 Predicted: $ 72.25   Delta:$ 0.007161   Trade Rng: $ 3.83
# i:-128 Close 72.12 Predicted: $ 72.58   Delta:$ 0.455365   Trade Rng: $ 3.36
# i:-129 Close 69.63 Predicted: $ 71.66   Delta:$ 2.025538   Trade Rng: $ 1.97
# i:-130 Close 70.09 Predicted: $ 69.74   Delta:$ 0.351422   Trade Rng: $ 1.34
# i:-131 Close 68.21 Predicted: $ 70.55   Delta:$ 2.333968   Trade Rng: $ 2.62
# i:-132 Close 69.32 Predicted: $ 69.37   Delta:$ 0.048818   Trade Rng: $ 3.45
# i:-133 Close 66.15 Predicted: $ 68.38   Delta:$ 2.225601   Trade Rng: $ 2.29
# i:-134 Close 63.02 Predicted: $ 63.16   Delta:$ 0.137678   Trade Rng: $ 2.91
# i:-135 Close 61.52 Predicted: $ 62.87   Delta:$ 1.353014   Trade Rng: $ 1.54
# i:-136 Close 62.77 Predicted: $ 63.59   Delta:$ 0.821656   Trade Rng: $ 1.57
# i:-137 Close 62.46 Predicted: $ 62.44   Delta:$ 0.01624   Trade Rng: $ 1.23
# i:-138 Close 61.02 Predicted: $ 62.31   Delta:$ 1.284297   Trade Rng: $ 1.58
# i:-139 Close 61.61 Predicted: $ 62.91   Delta:$ 1.305517   Trade Rng: $ 1.21
# i:-140 Close 61.35 Predicted: $ 61.96   Delta:$ 0.60588   Trade Rng: $ 1.87
# i:-141 Close 59.87 Predicted: $ 61.14   Delta:$ 1.276485   Trade Rng: $ 2.91
# i:-142 Close 59.65 Predicted: $ 60.22   Delta:$ 0.569664   Trade Rng: $ 1.33
# i:-143 Close 59.48 Predicted: $ 60.22   Delta:$ 0.735396   Trade Rng: $ 1.26
# i:-144 Close 57.1 Predicted: $ 59.26   Delta:$ 2.158519   Trade Rng: $ 2.28
# i:-145 Close 56.05 Predicted: $ 57.09   Delta:$ 1.048875   Trade Rng: $ 1.49
# i:-146 Close 56.37 Predicted: $ 56.29   Delta:$ 0.084015   Trade Rng: $ 1.73
# i:-147 Close 54.7 Predicted: $ 56.42   Delta:$ 1.7173   Trade Rng: $ 1.93
# i:-148 Close 54.81 Predicted: $ 53.98   Delta:$ 0.837822   Trade Rng: $ 0.64
# i:-149 Close 54.34 Predicted: $ 55.15   Delta:$ 0.803578   Trade Rng: $ 1.79
# i:-150 Close 53.13 Predicted: $ 54.09   Delta:$ 0.960515   Trade Rng: $ 1.11
# i:-151 Close 52.25 Predicted: $ 53.33   Delta:$ 1.08204   Trade Rng: $ 2.64
# i:-152 Close 49.09 Predicted: $ 53.49   Delta:$ 4.396537   Trade Rng: $ 2.8
# i:-153 Close 47.99 Predicted: $ 47.62   Delta:$ 0.3764   Trade Rng: $ 1.24
# i:-154 Close 47.56 Predicted: $ 47.09   Delta:$ 0.473608   Trade Rng: $ 0.99
# i:-155 Close 48.16 Predicted: $ 48.31   Delta:$ 0.143949   Trade Rng: $ 0.86
# i:-156 Close 49.52 Predicted: $ 49.57   Delta:$ 0.053675   Trade Rng: $ 1.7
# i:-157 Close 49.52 Predicted: $ 49.67   Delta:$ 0.159035   Trade Rng: $ 1.25
# i:-158 Close 49.41 Predicted: $ 49.67   Delta:$ 0.26398   Trade Rng: $ 0.47
# i:-159 Close 49.27 Predicted: $ 49.41   Delta:$ 0.133705   Trade Rng: $ 0.6
# i:-160 Close 48.82 Predicted: $ 49.12   Delta:$ 0.293898   Trade Rng: $ 0.64
# i:-161 Close 48.98 Predicted: $ 48.64   Delta:$ 0.346172   Trade Rng: $ 0.92
# i:-162 Close 48.1 Predicted: $ 48.97   Delta:$ 0.861574   Trade Rng: $ 0.68
# i:-163 Close 49.6 Predicted: $ 50.33   Delta:$ 0.730081   Trade Rng: $ 1.9
# i:-164 Close 50.07 Predicted: $ 50.22   Delta:$ 0.14627   Trade Rng: $ 0.81
# i:-165 Close 48.88 Predicted: $ 49.38   Delta:$ 0.493771   Trade Rng: $ 1.28
# i:-166 Close 48.34 Predicted: $ 48.92   Delta:$ 0.578976   Trade Rng: $ 1.28
# i:-167 Close 48.08 Predicted: $ 48.38   Delta:$ 0.299234   Trade Rng: $ 1.25
# i:-168 Close 47.65 Predicted: $ 47.41   Delta:$ 0.237467   Trade Rng: $ 0.99
# i:-169 Close 46.62 Predicted: $ 47.36   Delta:$ 0.737221   Trade Rng: $ 1.62
# i:-170 Close 47.5 Predicted: $ 47.26   Delta:$ 0.241885   Trade Rng: $ 1.7
# i:-171 Close 46.59 Predicted: $ 46.05   Delta:$ 0.538687   Trade Rng: $ 1.19
# i:-172 Close 45.5 Predicted: $ 45.82   Delta:$ 0.326151   Trade Rng: $ 1.03
# i:-173 Close 46.56 Predicted: $ 45.44   Delta:$ 1.120971   Trade Rng: $ 1.98
# i:-174 Close 45.5 Predicted: $ 45.16   Delta:$ 0.335464   Trade Rng: $ 1.33
# i:-175 Close 46.75 Predicted: $ 45.76   Delta:$ 0.995425   Trade Rng: $ 1.07
# i:-176 Close 46.76 Predicted: $ 46.73   Delta:$ 0.030076   Trade Rng: $ 1.01
# i:-177 Close 48.13 Predicted: $ 47.48   Delta:$ 0.648695   Trade Rng: $ 1.69
# i:-178 Close 47.81 Predicted: $ 47.42   Delta:$ 0.391465   Trade Rng: $ 0.9
# i:-179 Close 48.23 Predicted: $ 47.35   Delta:$ 0.879663   Trade Rng: $ 0.85
# i:-180 Close 47.77 Predicted: $ 47.57   Delta:$ 0.198326   Trade Rng: $ 0.88
# i:-181 Close 48.71 Predicted: $ 49.06   Delta:$ 0.350056   Trade Rng: $ 1.18
# i:-182 Close 49.93 Predicted: $ 50.37   Delta:$ 0.438626   Trade Rng: $ 2.65
# i:-183 Close 50.4 Predicted: $ 50.3   Delta:$ 0.099031   Trade Rng: $ 1.29
# i:-184 Close 49.29 Predicted: $ 49.94   Delta:$ 0.653042   Trade Rng: $ 1.37
# i:-185 Close 49.47 Predicted: $ 49.84   Delta:$ 0.368157   Trade Rng: $ 0.71
# i:-186 Close 48.88 Predicted: $ 50.21   Delta:$ 1.329253   Trade Rng: $ 1.19
# i:-187 Close 49.65 Predicted: $ 50.32   Delta:$ 0.671123   Trade Rng: $ 1.76
# i:-188 Close 48.61 Predicted: $ 49.51   Delta:$ 0.896122   Trade Rng: $ 0.79
# i:-189 Close 48.32 Predicted: $ 48.71   Delta:$ 0.385491   Trade Rng: $ 1.02
# i:-190 Close 46.94 Predicted: $ 48.34   Delta:$ 1.403299   Trade Rng: $ 1.19
# i:-191 Close 46.56 Predicted: $ 46.81   Delta:$ 0.247689   Trade Rng: $ 1.48
# i:-192 Close 45.95 Predicted: $ 47.11   Delta:$ 1.166185   Trade Rng: $ 0.9
# i:-193 Close 45.74 Predicted: $ 46.63   Delta:$ 0.887442   Trade Rng: $ 1.06
# i:-194 Close 45.0 Predicted: $ 45.41   Delta:$ 0.409936   Trade Rng: $ 1.04
# i:-195 Close 43.5 Predicted: $ 44.23   Delta:$ 0.736046   Trade Rng: $ 1.59
# i:-196 Close 42.32 Predicted: $ 44.26   Delta:$ 1.942745   Trade Rng: $ 0.99
# i:-197 Close 40.77 Predicted: $ 40.84   Delta:$ 0.072766   Trade Rng: $ 1.51
# i:-198 Close 41.15 Predicted: $ 40.49   Delta:$ 0.664574   Trade Rng: $ 1.65
# i:-199 Close 40.49 Predicted: $ 39.65   Delta:$ 0.843554   Trade Rng: $ 1.28
# i:-200 Close 40.32 Predicted: $ 40.3   Delta:$ 0.018055   Trade Rng: $ 1.19
# i:-201 Close 41.77 Predicted: $ 42.23   Delta:$ 0.460451   Trade Rng: $ 2.38
# i:-202 Close 43.65 Predicted: $ 43.08   Delta:$ 0.577502   Trade Rng: $ 2.1
# i:-203 Close 42.97 Predicted: $ 41.69   Delta:$ 1.273315   Trade Rng: $ 1.01
# i:-204 Close 41.38 Predicted: $ 40.88   Delta:$ 0.495781   Trade Rng: $ 2.3
# i:-205 Close 42.09 Predicted: $ 41.05   Delta:$ 1.037337   Trade Rng: $ 1.39
# i:-206 Close 42.19 Predicted: $ 41.9   Delta:$ 0.28544   Trade Rng: $ 1.42
# i:-207 Close 43.93 Predicted: $ 44.13   Delta:$ 0.197849   Trade Rng: $ 1.39
# i:-208 Close 46.09 Predicted: $ 45.29   Delta:$ 0.794975   Trade Rng: $ 2.27
# i:-209 Close 45.45 Predicted: $ 46.19   Delta:$ 0.740602   Trade Rng: $ 1.31
# i:-210 Close 46.93 Predicted: $ 47.48   Delta:$ 0.540809   Trade Rng: $ 1.84
# i:-211 Close 46.8 Predicted: $ 47.04   Delta:$ 0.241795   Trade Rng: $ 1.28
# i:-212 Close 45.79 Predicted: $ 46.27   Delta:$ 0.482262   Trade Rng: $ 0.81
# i:-213 Close 45.26 Predicted: $ 46.0   Delta:$ 0.739283   Trade Rng: $ 1.17
# i:-214 Close 45.75 Predicted: $ 45.79   Delta:$ 0.03902   Trade Rng: $ 1.24
# i:-215 Close 44.68 Predicted: $ 46.32   Delta:$ 1.639442   Trade Rng: $ 1.76
# i:-216 Close 44.03 Predicted: $ 44.18   Delta:$ 0.148652   Trade Rng: $ 1.01
# i:-217 Close 43.51 Predicted: $ 44.03   Delta:$ 0.521675   Trade Rng: $ 0.85
# i:-218 Close 44.77 Predicted: $ 44.28   Delta:$ 0.495458   Trade Rng: $ 1.88
# i:-219 Close 43.49 Predicted: $ 44.21   Delta:$ 0.720821   Trade Rng: $ 1.31
# i:-220 Close 43.08 Predicted: $ 43.34   Delta:$ 0.257345   Trade Rng: $ 0.84
# i:-221 Close 42.46 Predicted: $ 42.49   Delta:$ 0.029435   Trade Rng: $ 1.33
# i:-222 Close 41.9 Predicted: $ 42.09   Delta:$ 0.189532   Trade Rng: $ 1.24
# i:-223 Close 42.21 Predicted: $ 41.75   Delta:$ 0.45788   Trade Rng: $ 1.17
# i:-224 Close 41.6 Predicted: $ 40.69   Delta:$ 0.913328   Trade Rng: $ 1.36
# i:-225 Close 41.01 Predicted: $ 40.69   Delta:$ 0.32104   Trade Rng: $ 0.88
# i:-226 Close 42.23 Predicted: $ 41.9   Delta:$ 0.329931   Trade Rng: $ 1.12
# i:-227 Close 43.51 Predicted: $ 42.54   Delta:$ 0.96934   Trade Rng: $ 1.68
# i:-228 Close 43.96 Predicted: $ 42.82   Delta:$ 1.137272   Trade Rng: $ 0.96
# i:-229 Close 43.89 Predicted: $ 44.15   Delta:$ 0.260893   Trade Rng: $ 2.24
# i:-230 Close 45.57 Predicted: $ 45.22   Delta:$ 0.349574   Trade Rng: $ 1.79
# i:-231 Close 45.48 Predicted: $ 44.67   Delta:$ 0.804813   Trade Rng: $ 0.86
# i:-232 Close 44.86 Predicted: $ 44.22   Delta:$ 0.64413   Trade Rng: $ 1.43
# i:-233 Close 45.17 Predicted: $ 44.51   Delta:$ 0.658644   Trade Rng: $ 1.14
# i:-234 Close 45.56 Predicted: $ 44.88   Delta:$ 0.678306   Trade Rng: $ 1.85
# i:-235 Close 46.23 Predicted: $ 45.69   Delta:$ 0.543363   Trade Rng: $ 1.33
# i:-236 Close 47.05 Predicted: $ 47.34   Delta:$ 0.289343   Trade Rng: $ 1.19
# i:-237 Close 48.53 Predicted: $ 48.43   Delta:$ 0.106311   Trade Rng: $ 1.97
# i:-238 Close 48.49 Predicted: $ 49.19   Delta:$ 0.694549   Trade Rng: $ 0.99
# i:-239 Close 49.34 Predicted: $ 49.4   Delta:$ 0.057919   Trade Rng: $ 1.66
# i:-240 Close 49.25 Predicted: $ 49.95   Delta:$ 0.698281   Trade Rng: $ 0.79
# i:-241 Close 48.77 Predicted: $ 49.35   Delta:$ 0.576469   Trade Rng: $ 1.5
# i:-242 Close 46.82 Predicted: $ 49.22   Delta:$ 2.396028   Trade Rng: $ 2.69
# i:-243 Close 46.0 Predicted: $ 46.67   Delta:$ 0.66431   Trade Rng: $ 2.09
# i:-244 Close 47.15 Predicted: $ 46.76   Delta:$ 0.390621   Trade Rng: $ 2.78
# i:-245 Close 47.1 Predicted: $ 47.05   Delta:$ 0.053507   Trade Rng: $ 3.11
# i:-246 Close 45.65 Predicted: $ 47.43   Delta:$ 1.779793   Trade Rng: $ 1.99
# i:-247 Close 46.95 Predicted: $ 47.2   Delta:$ 0.248714   Trade Rng: $ 2.85
# i:-248 Close 43.29 Predicted: $ 46.33   Delta:$ 3.045842   Trade Rng: $ 2.84
# i:-249 Close 43.33 Predicted: $ 43.69   Delta:$ 0.357291   Trade Rng: $ 1.92
# i:-250 Close 43.47 Predicted: $ 43.99   Delta:$ 0.521475   Trade Rng: $ 1.06
# i:-251 Close 43.93 Predicted: $ 44.1   Delta:$ 0.169814   Trade Rng: $ 1.27
# i:-252 Close 43.74 Predicted: $ 41.93   Delta:$ 1.808125   Trade Rng: $ 1.56
# i:-253 Close 40.84 Predicted: $ 40.88   Delta:$ 0.039276   Trade Rng: $ 3.49
# i:-254 Close 42.38 Predicted: $ 41.46   Delta:$ 0.910617   Trade Rng: $ 1.38
# i:-255 Close 42.54 Predicted: $ 42.79   Delta:$ 0.250096   Trade Rng: $ 1.74
# i:-256 Close 44.65 Predicted: $ 44.5   Delta:$ 0.153073   Trade Rng: $ 2.18
# i:-257 Close 45.4 Predicted: $ 44.7   Delta:$ 0.69862   Trade Rng: $ 1.19
# i:-258 Close 44.67 Predicted: $ 43.93   Delta:$ 0.73713   Trade Rng: $ 0.98
# i:-259 Close 44.5 Predicted: $ 43.48   Delta:$ 1.023395   Trade Rng: $ 1.25
# i:-260 Close 44.26 Predicted: $ 44.73   Delta:$ 0.479153   Trade Rng: $ 1.32
# i:-261 Close 46.49 Predicted: $ 46.51   Delta:$ 0.015097   Trade Rng: $ 2.45
# i:-262 Close 46.72 Predicted: $ 47.02   Delta:$ 0.303383   Trade Rng: $ 0.87
# i:-263 Close 46.74 Predicted: $ 46.76   Delta:$ 0.022508   Trade Rng: $ 0.62
# i:-264 Close 45.89 Predicted: $ 46.09   Delta:$ 0.200796   Trade Rng: $ 0.65
# i:-265 Close 45.44 Predicted: $ 45.83   Delta:$ 0.392245   Trade Rng: $ 1.65
# i:-266 Close 45.67 Predicted: $ 45.14   Delta:$ 0.528971   Trade Rng: $ 1.42
# i:-267 Close 44.6 Predicted: $ 44.1   Delta:$ 0.493899   Trade Rng: $ 1.26
# i:-268 Close 44.3 Predicted: $ 44.57   Delta:$ 0.272373   Trade Rng: $ 1.07
# i:-269 Close 45.51 Predicted: $ 46.21   Delta:$ 0.704309   Trade Rng: $ 1.77
# i:-270 Close 47.06 Predicted: $ 47.37   Delta:$ 0.31007   Trade Rng: $ 2.03
# i:-271 Close 47.48 Predicted: $ 47.31   Delta:$ 0.169055   Trade Rng: $ 1.08
# i:-272 Close 46.45 Predicted: $ 47.24   Delta:$ 0.793237   Trade Rng: $ 2.16
# i:-273 Close 45.46 Predicted: $ 45.94   Delta:$ 0.488289   Trade Rng: $ 1.23
# i:-274 Close 45.96 Predicted: $ 44.9   Delta:$ 1.06347   Trade Rng: $ 3.03
# i:-275 Close 43.89 Predicted: $ 45.86   Delta:$ 1.972057   Trade Rng: $ 1.66
# i:-276 Close 42.39 Predicted: $ 42.65   Delta:$ 0.261802   Trade Rng: $ 1.16
# i:-277 Close 42.17 Predicted: $ 42.44   Delta:$ 0.268098   Trade Rng: $ 0.69
# i:-278 Close 42.49 Predicted: $ 42.44   Delta:$ 0.051846   Trade Rng: $ 1.16
# i:-279 Close 42.09 Predicted: $ 42.19   Delta:$ 0.099703   Trade Rng: $ 1.03
# i:-280 Close 42.3 Predicted: $ 42.64   Delta:$ 0.33583   Trade Rng: $ 0.83
# i:-281 Close 42.4 Predicted: $ 42.71   Delta:$ 0.312609   Trade Rng: $ 1.09
# i:-282 Close 42.29 Predicted: $ 41.74   Delta:$ 0.549582   Trade Rng: $ 0.7
# i:-283 Close 40.81 Predicted: $ 40.8   Delta:$ 0.010569   Trade Rng: $ 1.05
# i:-284 Close 41.1 Predicted: $ 41.27   Delta:$ 0.161356   Trade Rng: $ 1.0
# i:-285 Close 41.86 Predicted: $ 40.99   Delta:$ 0.878222   Trade Rng: $ 1.33
# i:-286 Close 40.62 Predicted: $ 41.0   Delta:$ 0.384731   Trade Rng: $ 1.49
# i:-287 Close 42.2 Predicted: $ 42.28   Delta:$ 0.080824   Trade Rng: $ 2.66
# i:-288 Close 43.01 Predicted: $ 43.09   Delta:$ 0.075532   Trade Rng: $ 0.79
# i:-289 Close 43.03 Predicted: $ 43.52   Delta:$ 0.48619   Trade Rng: $ 1.19
# i:-290 Close 43.79 Predicted: $ 43.65   Delta:$ 0.148496   Trade Rng: $ 1.53
# i:-291 Close 42.68 Predicted: $ 43.76   Delta:$ 1.084303   Trade Rng: $ 1.32
# i:-292 Close 42.64 Predicted: $ 41.87   Delta:$ 0.771499   Trade Rng: $ 1.06
# i:-293 Close 42.98 Predicted: $ 42.94   Delta:$ 0.041471   Trade Rng: $ 1.14
# i:-294 Close 41.01 Predicted: $ 42.08   Delta:$ 1.067656   Trade Rng: $ 2.45
# i:-295 Close 39.47 Predicted: $ 41.73   Delta:$ 2.258877   Trade Rng: $ 1.36
# i:-296 Close 38.76 Predicted: $ 39.21   Delta:$ 0.453163   Trade Rng: $ 0.91
# i:-297 Close 38.5 Predicted: $ 38.21   Delta:$ 0.285418   Trade Rng: $ 1.14
# i:-298 Close 37.46 Predicted: $ 38.17   Delta:$ 0.708063   Trade Rng: $ 1.36
# i:-299 Close 38.64 Predicted: $ 39.07   Delta:$ 0.431594   Trade Rng: $ 2.14
# i:-300 Close 39.16 Predicted: $ 38.89   Delta:$ 0.269158   Trade Rng: $ 1.01
# i:-301 Close 39.31 Predicted: $ 40.38   Delta:$ 1.064148   Trade Rng: $ 0.86
# i:-302 Close 39.75 Predicted: $ 39.65   Delta:$ 0.105028   Trade Rng: $ 1.44
# i:-303 Close 37.82 Predicted: $ 40.5   Delta:$ 2.684123   Trade Rng: $ 1.71
# i:-304 Close 40.09 Predicted: $ 41.53   Delta:$ 1.430615   Trade Rng: $ 2.47
# i:-305 Close 38.93 Predicted: $ 40.64   Delta:$ 1.707212   Trade Rng: $ 1.99
# i:-306 Close 37.96 Predicted: $ 37.95   Delta:$ 0.01909   Trade Rng: $ 1.62
# i:-307 Close 30.53 Predicted: $ 34.32   Delta:$ 3.793118   Trade Rng: $ 2.85
# i:-308 Close 30.68 Predicted: $ 31.48   Delta:$ 0.802362   Trade Rng: $ 0.8
# i:-309 Close 31.16 Predicted: $ 31.71   Delta:$ 0.548743   Trade Rng: $ 0.66
# i:-310 Close 31.25 Predicted: $ 31.23   Delta:$ 0.024257   Trade Rng: $ 0.84
# i:-311 Close 31.67 Predicted: $ 30.79   Delta:$ 0.874184   Trade Rng: $ 0.66
# i:-312 Close 30.17 Predicted: $ 31.15   Delta:$ 0.979396   Trade Rng: $ 1.51
# i:-313 Close 29.2 Predicted: $ 29.73   Delta:$ 0.525378   Trade Rng: $ 0.77
# i:-314 Close 28.94 Predicted: $ 28.96   Delta:$ 0.015977   Trade Rng: $ 1.04
# i:-315 Close 28.33 Predicted: $ 28.38   Delta:$ 0.050637   Trade Rng: $ 0.82
# i:-316 Close 28.57 Predicted: $ 28.74   Delta:$ 0.172677   Trade Rng: $ 0.73
# i:-317 Close 28.87 Predicted: $ 28.84   Delta:$ 0.037685   Trade Rng: $ 0.7
# i:-318 Close 28.56 Predicted: $ 28.94   Delta:$ 0.379242   Trade Rng: $ 0.65
# i:-319 Close 29.14 Predicted: $ 29.31   Delta:$ 0.16833   Trade Rng: $ 0.52
# i:-320 Close 28.67 Predicted: $ 29.63   Delta:$ 0.965815   Trade Rng: $ 0.87
# i:-321 Close 27.55 Predicted: $ 27.6   Delta:$ 0.044808   Trade Rng: $ 1.02
# i:-322 Close 27.79 Predicted: $ 27.97   Delta:$ 0.178879   Trade Rng: $ 0.62
# i:-323 Close 28.2 Predicted: $ 28.26   Delta:$ 0.058589   Trade Rng: $ 0.9
# i:-324 Close 28.9 Predicted: $ 28.33   Delta:$ 0.566757   Trade Rng: $ 0.75
# i:-325 Close 27.74 Predicted: $ 28.55   Delta:$ 0.810337   Trade Rng: $ 1.28
# i:-326 Close 27.22 Predicted: $ 27.58   Delta:$ 0.365754   Trade Rng: $ 0.69
# i:-327 Close 26.95 Predicted: $ 26.7   Delta:$ 0.249436   Trade Rng: $ 0.87
# i:-328 Close 26.23 Predicted: $ 26.19   Delta:$ 0.036678   Trade Rng: $ 0.62
# i:-329 Close 27.03 Predicted: $ 26.71   Delta:$ 0.325547   Trade Rng: $ 1.02
# i:-330 Close 27.11 Predicted: $ 26.7   Delta:$ 0.403833   Trade Rng: $ 0.69
# i:-331 Close 27.09 Predicted: $ 27.37   Delta:$ 0.277675   Trade Rng: $ 0.46
# i:-332 Close 27.92 Predicted: $ 28.25   Delta:$ 0.328809   Trade Rng: $ 1.03
# i:-333 Close 27.66 Predicted: $ 27.88   Delta:$ 0.219927   Trade Rng: $ 0.77
# i:-334 Close 26.99 Predicted: $ 28.17   Delta:$ 1.176841   Trade Rng: $ 0.75
# i:-335 Close 26.75 Predicted: $ 26.57   Delta:$ 0.179523   Trade Rng: $ 0.57
# i:-336 Close 26.45 Predicted: $ 26.05   Delta:$ 0.4005   Trade Rng: $ 0.66
# i:-337 Close 26.48 Predicted: $ 26.41   Delta:$ 0.071007   Trade Rng: $ 0.56
# i:-338 Close 27.16 Predicted: $ 27.23   Delta:$ 0.070241   Trade Rng: $ 1.02
# i:-339 Close 27.57 Predicted: $ 27.27   Delta:$ 0.301149   Trade Rng: $ 0.66
# i:-340 Close 27.03 Predicted: $ 26.55   Delta:$ 0.476639   Trade Rng: $ 0.95
# i:-341 Close 26.87 Predicted: $ 26.64   Delta:$ 0.233923   Trade Rng: $ 0.65
# i:-342 Close 27.44 Predicted: $ 27.61   Delta:$ 0.163503   Trade Rng: $ 0.6
# i:-343 Close 27.95 Predicted: $ 28.26   Delta:$ 0.309441   Trade Rng: $ 0.69
# i:-344 Close 27.77 Predicted: $ 28.12   Delta:$ 0.351133   Trade Rng: $ 0.66
# i:-345 Close 27.37 Predicted: $ 27.79   Delta:$ 0.419236   Trade Rng: $ 0.73
# i:-346 Close 26.97 Predicted: $ 27.05   Delta:$ 0.075013   Trade Rng: $ 0.4
# i:-347 Close 26.4 Predicted: $ 26.44   Delta:$ 0.036605   Trade Rng: $ 0.48
# i:-348 Close 26.52 Predicted: $ 26.66   Delta:$ 0.134888   Trade Rng: $ 0.66
# i:-349 Close 26.77 Predicted: $ 27.09   Delta:$ 0.323967   Trade Rng: $ 0.64
# i:-350 Close 27.18 Predicted: $ 27.32   Delta:$ 0.139432   Trade Rng: $ 0.81
# i:-351 Close 26.46 Predicted: $ 27.15   Delta:$ 0.692524   Trade Rng: $ 0.81
# i:-352 Close 26.19 Predicted: $ 26.47   Delta:$ 0.280293   Trade Rng: $ 1.35
# i:-353 Close 25.89 Predicted: $ 26.52   Delta:$ 0.626183   Trade Rng: $ 1.01
# i:-354 Close 25.71 Predicted: $ 26.44   Delta:$ 0.725916   Trade Rng: $ 0.89
# i:-355 Close 25.53 Predicted: $ 25.55   Delta:$ 0.017926   Trade Rng: $ 0.73
# i:-356 Close 24.22 Predicted: $ 24.85   Delta:$ 0.634003   Trade Rng: $ 1.69
# i:-357 Close 24.05 Predicted: $ 23.65   Delta:$ 0.408295   Trade Rng: $ 0.93
# i:-358 Close 22.96 Predicted: $ 24.84   Delta:$ 1.884952   Trade Rng: $ 0.76
# i:-359 Close 22.96 Predicted: $ 22.97   Delta:$ 0.017497   Trade Rng: $ 1.0
# i:-360 Close 23.43 Predicted: $ 23.62   Delta:$ 0.195326   Trade Rng: $ 0.9
# i:-361 Close 24.17 Predicted: $ 23.72   Delta:$ 0.446374   Trade Rng: $ 1.07
# i:-362 Close 23.28 Predicted: $ 24.45   Delta:$ 1.167326   Trade Rng: $ 0.78
# i:-363 Close 23.54 Predicted: $ 23.66   Delta:$ 0.118414   Trade Rng: $ 0.88
# i:-364 Close 23.88 Predicted: $ 23.63   Delta:$ 0.251015   Trade Rng: $ 0.76
# i:-365 Close 23.3 Predicted: $ 23.97   Delta:$ 0.672357   Trade Rng: $ 0.77
# i:-366 Close 22.69 Predicted: $ 22.98   Delta:$ 0.298946   Trade Rng: $ 0.95
# i:-367 Close 23.2 Predicted: $ 23.1   Delta:$ 0.099503   Trade Rng: $ 0.75
# i:-368 Close 23.49 Predicted: $ 22.6   Delta:$ 0.886395   Trade Rng: $ 0.62
# i:-369 Close 23.27 Predicted: $ 24.28   Delta:$ 1.012274   Trade Rng: $ 0.43
# i:-370 Close 23.65 Predicted: $ 23.97   Delta:$ 0.323931   Trade Rng: $ 0.53
# i:-371 Close 20.74 Predicted: $ 23.0   Delta:$ 2.254843   Trade Rng: $ 0.86
# i:-372 Close 20.64 Predicted: $ 20.6   Delta:$ 0.046812   Trade Rng: $ 0.68
# i:-373 Close 21.38 Predicted: $ 21.22   Delta:$ 0.154345   Trade Rng: $ 0.88
# i:-374 Close 21.99 Predicted: $ 21.99   Delta:$ 0.002957   Trade Rng: $ 0.76
# i:-375 Close 22.75 Predicted: $ 22.22   Delta:$ 0.532512   Trade Rng: $ 0.62
# i:-376 Close 22.96 Predicted: $ 23.07   Delta:$ 0.115211   Trade Rng: $ 0.75
# i:-377 Close 21.78 Predicted: $ 23.12   Delta:$ 1.339651   Trade Rng: $ 1.68
# i:-378 Close 21.25 Predicted: $ 21.48   Delta:$ 0.230447   Trade Rng: $ 1.09
# i:-379 Close 22.32 Predicted: $ 22.11   Delta:$ 0.211337   Trade Rng: $ 1.27
# i:-380 Close 22.19 Predicted: $ 22.76   Delta:$ 0.570171   Trade Rng: $ 0.9
# i:-381 Close 22.16 Predicted: $ 22.14   Delta:$ 0.021338   Trade Rng: $ 0.87
# i:-382 Close 21.08 Predicted: $ 21.46   Delta:$ 0.387142   Trade Rng: $ 1.11
# i:-383 Close 21.09 Predicted: $ 20.35   Delta:$ 0.736949   Trade Rng: $ 0.78
# i:-384 Close 21.7 Predicted: $ 21.98   Delta:$ 0.280468   Trade Rng: $ 0.96
# i:-385 Close 20.93 Predicted: $ 21.06   Delta:$ 0.124883   Trade Rng: $ 1.25
# i:-386 Close 19.53 Predicted: $ 20.63   Delta:$ 1.101505   Trade Rng: $ 1.58
# i:-387 Close 19.15 Predicted: $ 19.14   Delta:$ 0.009795   Trade Rng: $ 0.74
# i:-388 Close 20.35 Predicted: $ 19.38   Delta:$ 0.973511   Trade Rng: $ 0.99
# i:-389 Close 19.79 Predicted: $ 20.19   Delta:$ 0.402339   Trade Rng: $ 1.22
# i:-390 Close 19.31 Predicted: $ 19.95   Delta:$ 0.63703   Trade Rng: $ 0.89
# i:-391 Close 19.25 Predicted: $ 20.0   Delta:$ 0.741428   Trade Rng: $ 0.79
# i:-392 Close 19.18 Predicted: $ 19.19   Delta:$ 0.009466   Trade Rng: $ 0.68
# i:-393 Close 17.83 Predicted: $ 18.36   Delta:$ 0.534259   Trade Rng: $ 1.43
# i:-394 Close 16.76 Predicted: $ 17.83   Delta:$ 1.074644   Trade Rng: $ 1.03
# i:-395 Close 17.37 Predicted: $ 17.07   Delta:$ 0.301337   Trade Rng: $ 0.47
# i:-396 Close 17.69 Predicted: $ 17.79   Delta:$ 0.095583   Trade Rng: $ 0.59
# i:-397 Close 16.89 Predicted: $ 17.23   Delta:$ 0.339729   Trade Rng: $ 0.83
# i:-398 Close 16.5 Predicted: $ 16.78   Delta:$ 0.27623   Trade Rng: $ 0.76
# i:-399 Close 15.99 Predicted: $ 16.45   Delta:$ 0.46299   Trade Rng: $ 1.14
# i:-400 Close 15.9 Predicted: $ 16.31   Delta:$ 0.411099   Trade Rng: $ 0.47
# i:-401 Close 15.62 Predicted: $ 15.83   Delta:$ 0.214769   Trade Rng: $ 0.49
# i:-402 Close 14.85 Predicted: $ 15.63   Delta:$ 0.777104   Trade Rng: $ 0.91
# i:-403 Close 14.26 Predicted: $ 14.42   Delta:$ 0.16421   Trade Rng: $ 0.98
# i:-404 Close 14.74 Predicted: $ 14.59   Delta:$ 0.146717   Trade Rng: $ 0.42
# i:-405 Close 14.31 Predicted: $ 14.26   Delta:$ 0.047129   Trade Rng: $ 0.61
# i:-406 Close 14.61 Predicted: $ 14.63   Delta:$ 0.024803   Trade Rng: $ 0.9
# i:-407 Close 14.59 Predicted: $ 14.24   Delta:$ 0.349731   Trade Rng: $ 0.4
# i:-408 Close 14.03 Predicted: $ 13.49   Delta:$ 0.539215   Trade Rng: $ 0.46
# i:-409 Close 14.11 Predicted: $ 14.08   Delta:$ 0.036846   Trade Rng: $ 0.38
# i:-410 Close 15.2 Predicted: $ 14.67   Delta:$ 0.531069   Trade Rng: $ 1.04
# i:-411 Close 15.33 Predicted: $ 15.58   Delta:$ 0.25204   Trade Rng: $ 0.46
# i:-412 Close 16.49 Predicted: $ 16.19   Delta:$ 0.304148   Trade Rng: $ 1.26
# i:-413 Close 16.08 Predicted: $ 15.68   Delta:$ 0.392032   Trade Rng: $ 0.53
# i:-414 Close 16.24 Predicted: $ 15.91   Delta:$ 0.337102   Trade Rng: $ 0.46
# i:-415 Close 16.56 Predicted: $ 16.2   Delta:$ 0.363962   Trade Rng: $ 0.46
# i:-416 Close 16.94 Predicted: $ 16.89   Delta:$ 0.052198   Trade Rng: $ 0.63
# i:-417 Close 17.66 Predicted: $ 17.49   Delta:$ 0.169058   Trade Rng: $ 0.62
# i:-418 Close 18.06 Predicted: $ 17.56   Delta:$ 0.502515   Trade Rng: $ 0.83
# i:-419 Close 17.52 Predicted: $ 17.7   Delta:$ 0.172323   Trade Rng: $ 1.08
# i:-420 Close 16.99 Predicted: $ 17.58   Delta:$ 0.592239   Trade Rng: $ 0.74
# i:-421 Close 17.16 Predicted: $ 17.52   Delta:$ 0.36048   Trade Rng: $ 0.61
# i:-422 Close 16.11 Predicted: $ 17.31   Delta:$ 1.201523   Trade Rng: $ 1.22
# i:-423 Close 15.98 Predicted: $ 15.94   Delta:$ 0.036652   Trade Rng: $ 0.52
# i:-424 Close 16.6 Predicted: $ 16.57   Delta:$ 0.029543   Trade Rng: $ 0.75
# i:-425 Close 16.87 Predicted: $ 16.78   Delta:$ 0.084243   Trade Rng: $ 0.52
# i:-426 Close 17.13 Predicted: $ 16.63   Delta:$ 0.492213   Trade Rng: $ 0.49
# i:-427 Close 16.91 Predicted: $ 17.45   Delta:$ 0.532335   Trade Rng: $ 0.63
# i:-428 Close 15.63 Predicted: $ 17.29   Delta:$ 1.664061   Trade Rng: $ 1.33
# i:-429 Close 15.81 Predicted: $ 15.89   Delta:$ 0.076308   Trade Rng: $ 0.41
# i:-430 Close 16.26 Predicted: $ 16.39   Delta:$ 0.137714   Trade Rng: $ 0.63
# i:-431 Close 16.51 Predicted: $ 16.47   Delta:$ 0.034707   Trade Rng: $ 0.31
# i:-432 Close 16.02 Predicted: $ 16.69   Delta:$ 0.662249   Trade Rng: $ 0.48
# i:-433 Close 15.3 Predicted: $ 16.66   Delta:$ 1.352182   Trade Rng: $ 0.94
# i:-434 Close 15.4 Predicted: $ 15.33   Delta:$ 0.06684   Trade Rng: $ 0.4
# i:-435 Close 15.66 Predicted: $ 15.52   Delta:$ 0.144444   Trade Rng: $ 0.88
# i:-436 Close 15.9 Predicted: $ 15.78   Delta:$ 0.116991   Trade Rng: $ 0.73
# i:-437 Close 16.65 Predicted: $ 16.02   Delta:$ 0.631373   Trade Rng: $ 0.49
# i:-438 Close 16.28 Predicted: $ 16.9   Delta:$ 0.62083   Trade Rng: $ 0.62
# i:-439 Close 16.31 Predicted: $ 16.67   Delta:$ 0.360686   Trade Rng: $ 0.62
# i:-440 Close 15.74 Predicted: $ 16.43   Delta:$ 0.692315   Trade Rng: $ 0.91
# i:-441 Close 13.76 Predicted: $ 15.75   Delta:$ 1.987023   Trade Rng: $ 1.23
# i:-442 Close 14.59 Predicted: $ 14.97   Delta:$ 0.384308   Trade Rng: $ 0.45
# i:-443 Close 14.29 Predicted: $ 14.62   Delta:$ 0.334348   Trade Rng: $ 0.68
# i:-444 Close 14.14 Predicted: $ 14.14   Delta:$ 0.006669   Trade Rng: $ 0.46
# i:-445 Close 13.41 Predicted: $ 14.65   Delta:$ 1.241783   Trade Rng: $ 0.53
# i:-446 Close 13.21 Predicted: $ 13.35   Delta:$ 0.145347   Trade Rng: $ 0.82
# i:-447 Close 13.53 Predicted: $ 13.59   Delta:$ 0.053638   Trade Rng: $ 1.0
# i:-448 Close 13.49 Predicted: $ 13.62   Delta:$ 0.137745   Trade Rng: $ 0.41
# i:-449 Close 13.82 Predicted: $ 13.67   Delta:$ 0.148214   Trade Rng: $ 0.54
# i:-450 Close 13.17 Predicted: $ 14.09   Delta:$ 0.925203   Trade Rng: $ 0.79
# i:-451 Close 12.89 Predicted: $ 13.11   Delta:$ 0.223877   Trade Rng: $ 0.72
# i:-452 Close 13.25 Predicted: $ 13.27   Delta:$ 0.015592   Trade Rng: $ 0.68
# i:-453 Close 12.59 Predicted: $ 13.58   Delta:$ 0.988997   Trade Rng: $ 0.64
# i:-454 Close 12.46 Predicted: $ 12.63   Delta:$ 0.171661   Trade Rng: $ 0.65
# i:-455 Close 12.18 Predicted: $ 12.36   Delta:$ 0.174864   Trade Rng: $ 0.61
# i:-456 Close 12.04 Predicted: $ 12.22   Delta:$ 0.176136   Trade Rng: $ 0.66
# i:-457 Close 11.96 Predicted: $ 12.22   Delta:$ 0.258653   Trade Rng: $ 0.52
# i:-458 Close 11.88 Predicted: $ 11.68   Delta:$ 0.200263   Trade Rng: $ 0.87
# i:-459 Close 11.22 Predicted: $ 11.6   Delta:$ 0.384641   Trade Rng: $ 0.43
# i:-460 Close 11.95 Predicted: $ 11.84   Delta:$ 0.105553   Trade Rng: $ 0.91
# i:-461 Close 11.49 Predicted: $ 12.7   Delta:$ 1.209785   Trade Rng: $ 1.27
# i:-462 Close 11.58 Predicted: $ 11.08   Delta:$ 0.495676   Trade Rng: $ 0.39
# i:-463 Close 11.66 Predicted: $ 11.14   Delta:$ 0.525242   Trade Rng: $ 0.56
# i:-464 Close 12.07 Predicted: $ 12.04   Delta:$ 0.027858   Trade Rng: $ 0.72
# i:-465 Close 13.12 Predicted: $ 13.27   Delta:$ 0.153011   Trade Rng: $ 0.65
# i:-466 Close 13.2 Predicted: $ 13.26   Delta:$ 0.06318   Trade Rng: $ 0.55
# i:-467 Close 13.16 Predicted: $ 13.06   Delta:$ 0.093386   Trade Rng: $ 0.7
# i:-468 Close 12.5 Predicted: $ 13.17   Delta:$ 0.664714   Trade Rng: $ 0.34
# i:-469 Close 12.13 Predicted: $ 11.94   Delta:$ 0.193422   Trade Rng: $ 0.57
# i:-470 Close 12.21 Predicted: $ 12.32   Delta:$ 0.11449   Trade Rng: $ 0.56
# i:-471 Close 12.73 Predicted: $ 12.78   Delta:$ 0.054084   Trade Rng: $ 0.55
# i:-472 Close 12.4 Predicted: $ 12.96   Delta:$ 0.561003   Trade Rng: $ 0.47
# i:-473 Close 12.22 Predicted: $ 11.94   Delta:$ 0.273467   Trade Rng: $ 0.48
# i:-474 Close 12.51 Predicted: $ 11.99   Delta:$ 0.511217   Trade Rng: $ 0.45
# i:-475 Close 12.55 Predicted: $ 12.5   Delta:$ 0.050451   Trade Rng: $ 0.35
# i:-476 Close 13.25 Predicted: $ 13.1   Delta:$ 0.146349   Trade Rng: $ 0.72
# i:-477 Close 13.17 Predicted: $ 13.19   Delta:$ 0.020954   Trade Rng: $ 0.92
# i:-478 Close 13.37 Predicted: $ 13.38   Delta:$ 0.005169   Trade Rng: $ 0.43
# i:-479 Close 13.19 Predicted: $ 12.91   Delta:$ 0.279719   Trade Rng: $ 0.45
# i:-480 Close 12.92 Predicted: $ 12.9   Delta:$ 0.015684   Trade Rng: $ 0.6
# Mean Trading Range: $ 2.0
# Mean Delta (Actual vs Prediction): $ 1.11
# Mean Trading Range: $ 2.0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[52], line 26
#      23 tot_deltas, tot_tradrng, elements = analyze_pred(target_close, target_high, target_low, pred_adj_close)
#      25 print("Mean Trading Range: $", round(tot_tradrng / elements, 2))
# ---> 26 print("Mean Delta (Actual vs Prediction): $", round((tot_deltas[0] / elements), 2))
#
# IndexError: invalid index to scalar variable.

# %% [markdown]
# ### - Deltas between predicted price and actual price

# %%
# Calculate an array of deltas between predicted price and actual price
print("Std Dev -     Pred: ", pred_delta.std())
y_pa_delta = abs(y_test - y_p_adj)
print("Std Dev - Pred Adj: ", y_pa_delta.std())
print("Better by", (y_p_delta.std() / y_pa_delta.std()), "Standard Deviations")

# %% [markdown]
# ### - Deltas between predicted price and actual price

# %%
# Calculate an array of deltas between predicted price and actual price
print("Std Dev -     Pred: ", pred_delta.std())
y_pa_delta = abs(y_test - y_p_adj)
print("Std Dev - Pred Adj: ", y_pa_delta.std())
print("Better by", (y_p_delta.std() / y_pa_delta.std()), "Standard Deviations")

# %% [markdown]
# ## - Trend Prediction Stats using Unscaled (v < 1) Adjusted
# ** The stats are not entirely accurate a the adjusted prediction will change when the new close actually occurs
#    and the adjusting process includes the new close in the calculation

# %%
# How often is the prediction within 1% of the actual price?
pct = 0.05
pct_delta = abs(y_test * pct)
delta = abs(y_test - y_p_adj)
within_range = delta[delta < pct_delta]
# Get average price range for the instrument
avg_price_rng = data_set['High'] - data_set['Low']
# Get pct of average price range
pcnt_avg_price_rng = avg_price_rng.mean() * pct

print("Within",pct * 100,"% of Acutal Adj Close","[ Trading Range:$", round(tot_tradrng / elements, 2), 
      " Within Avg Price:", avg_price_rng.mean().round(2), " Average Difference to Actual: $", pcnt_avg_price_rng.round(2),"]", 
      " Pct within Range:", round((len(within_range) / len(y_test)),2) * 100,"%")

# How often is the predicted trend the same as the actual trend?
test_trend = y_test[1:] - y_test[:-1]
pred_trend = y_p_adj[1:] - y_p_adj[:-1]
delta = [1 if (test_trend < 0) and (pred_trend < 0) or (test_trend > 0) and (pred_trend > 0) else 0 for test_trend, pred_trend in zip(test_trend, pred_trend)]
# Print the number of elements in delta and the percent of delta that are 1.
print("Same Trend:", len(delta), "Wrong:", len(delta) - len(within_range)+1, "Right", np.count_nonzero(within_range+1), "%Right", round((len(within_range)-1) / len(delta) * 100,2))

# %% [markdown]
# # Model Details...

# %%
# Review feature importance
# importance = model.coef_

import shap
import pydot

print(X_train.shape)

print(model.summary())
print("model.outputs", model.layers[3].output.shape[1])
from keras.utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
from IPython.display import Image

pass

# %% [markdown]
# ## - Model Plot
# <img src="model_plot.png" alt="Drawing" style="width: 200px;"/>
