# %% [markdown]
# # Price ML Predicion
#
# ## Price Prediction's Caveats
#
#   When the characteristics of the instrument are far from stable, price prediction can be quite off.
#   - Examples...
#     - SERV
#     - MEDS
#     - XCUR
#
#   Price Prediction should be combined with Prediction of market highs and lows because if you just entered the market based on predicted price, you could get washed out by manipulative Market Wales hitting your stops.
#
#   Predicting High, Low, Market Open and Market Close Should be done using separate models, using the same model parameters.
#
#   Before trading an instrument, one should review the median market price range, verses median prediction accuracy delta, to verify whether the instrument is worth trading. I have a hunch that the smaller the trading range as compared to the prediction delta, the less likely the instrument is worth engaging with.
# <p>
#
# ## Current Enhancements
#
# From a visual review, although the prediction strays from the price
#    the trend of the prediction seems quite accurate.
#    By pulling the prediction closer to the price, by an average of the delta,
#    between the price and the prediction, the new prediction is quite accurate.
# <p>
#
# ## Enhancements (to add)
#
# We should be able to add prediction targets for high and low for the day by
#    adding the target high-difference and low-difference to the data set,
#    similar to the way we added the target close-difference.
#
# We can also apparently pull minute bars from Yahoo. And with that, we can
#    perform more granular predictions, to the hour, 15min, 5min, and
#    1min period.

# %% [markdown]
# # Choose an existing model -or- Create a New Model

# %%
# Create a list of available .keras models from model_dir...
# Restart the kernel
# %reset -f
# %gui asyncio

import ipywidgets as widgets
from ipywidgets import Output  
import re
import datetime
import os
import asyncio
import yfinance as yf

global Ticker, DataStart, DateEnd, ticker, dateStart, dateEnd, CreateNewModel, model_dir, model_files, Selected_Model

Ticker    = 'AMZN'

DateStart = '2015-06-03'
DateEnd   = '2024-07-30'
CreateNewModel = "Create New Model"

# Get list of file from the model directory...
model_dir = 'models/'
model_files = os.listdir(model_dir)
Selected_Model = None

def wait_for_change(widget, value):
    future = asyncio.Future()
    def getvalue(change):
        # make the new value available
        future.set_result(change.new)
        widget.unobserve(getvalue, value)
    widget.observe(getvalue, value)
    return future

def model_choices():
    global Ticker, DataStart, DateEnd, ticker, dateStart, dateEnd, CreateNewModel, model_dir, model_files, Selected_Model
    
    # Filter the list to only include .keras files...
    models_lst = [file for file in model_files if re.search(r'\.keras$', file)]
    models_lst.sort()
    model_files = [CreateNewModel] + models_lst
    # Display the list of files...
    Selected_Model = widgets.Select ( options=model_files,
                                      value=model_files[0],
                                      description='Model File: ',
                                      disabled=False )
    ticker     = widgets.Text(value=Ticker, description='TICKER: ')
    DateStart = "2015-01-01"
    dateStart = widgets.Text(value=DateStart, description='Start Date: ')
    # Set the DateEnd to today's date with the format 'YYYY-MM-DD, determined by the system date.
    if Selected_Model.value == CreateNewModel:
        DateEnd = datetime.datetime.now().strftime('%Y-%m-%d')
    dateEnd   = widgets.Text(value=DateEnd, description='End Date: ')
    out = Output()
    
    async def f0():
        for i in range(10):
            out.append_stdout('did work ' + str(i) + '\n')
            x = await wait_for_change(Selected_Model, 'value')
            if Selected_Model.value != CreateNewModel:
                ticker.value = Selected_Model.value.split('_')[0]
            out.append_stdout('async function continued with value ' + str(x) + '\n')
        asyncio.ensure_future(f0())
    
    async def f1():
        for i in range(10):
            out.append_stdout('did work ' + str(i) + '\n')
            x = await wait_for_change(ticker, 'value')
            tkr = ticker.value
            tkr = re.sub(r'Invalid: ', '', tkr)
            if Selected_Model.value == CreateNewModel:
                # Check yahoo if symbol is valid...
                try:
                    ticker_ = yf.Ticker(tkr).history(period='5d',interval='1d')
                except:
                    ticker_ = []
                if len(ticker_) == 0:
                    ticker.value = 'Invalid: ' + tkr
                else:
                    ticker.value = ticker.upper()
            out.append_stdout('async function continued with value ' + str(x) + '\n')
        asyncio.ensure_future(f1())
    
    asyncio.ensure_future(f0())
    asyncio.ensure_future(f1())
    
    inst0 = """
        +-------------------------------+" +
        | Choose or Create a New Model  |
        +-------------------------------+
    """
    inst1 = """Make you Model Selection and Updates the Start and End Dates.
    Or, Create a New Model by entering by leave the Model File: as
    "Create New Model", and entering the Ticker, Start Date and End Date.
    """
    print(inst0, inst1)
    display(Selected_Model)
    print()
    display(ticker, dateStart, dateEnd)
    print()
    # display(out)

    # if selected_model.value == CreateNewModel:
    # - Create a new model using the ticker.value, dateStart.value, DateEnd.vale values.
    return(Selected_Model, ticker, dateStart, dateEnd)

Selected_Model, ticker, dateStart, dateEnd = model_choices()
# Out:
#         +-------------------------------+" +
#         | Choose or Create a New Model  |
#         +-------------------------------+
#      Make you Model Selection and Updates the Start and End Dates.
#     Or, Create a New Model by entering by leave the Model File: as
#     "Create New Model", and entering the Ticker, Start Date and End Date.
# Select(description='Model File: ', options=('Create New Model', 'AAPL_2015-01-01_2024-07-30.keras', 'AMZN_2015…
# Text(value='AMZN', description='TICKER: ')
# Text(value='2015-01-01', description='Start Date: ')
# Text(value='2024-08-07', description='End Date: ')

# %%
def print_model_choices(Selected_Model, ticker, dateStart, dateEnd):
    print( "Selected_Model:", Selected_Model.value)
    print("Ticker: ", ticker.value)
    print("DateStart: ", dateStart.value)
    print("DateEnd: ", dateEnd.value)

print_model_choices(Selected_Model, ticker, dateStart, dateEnd)
# Out:
# Selected_Model: ^N225_2015-01-01_2024-07-30.keras
# Ticker:  ^N225
# DateStart:  2015-01-01
# DateEnd:  2024-08-07

# %% [markdown]
# #  Load the latest data for the selected Ticker...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn
import pandas as pd
import yfinance as yf

global data, feature_cnt, feature_cnt_dl, model_path

def load_data():
    global Ticker, DataStart, DateEnd, ticker, dateStart, dateEnd, CreateNewModel, model_dir, model_files, model_path, Selected_Model
    global data_orig, data, feature_cnt, feature_cnt_dl

    model_dir = 'models/'

    if Selected_Model.value == CreateNewModel:
        modelDateStart = DateStart
        modelDateEnd = DateEnd
        model_file = ticker.value + "_" + dateStart.value + "_" + dateEnd.value + ".keras"
        model_path = model_dir + model_file
    else:
        model_path = model_dir + Selected_Model.value

    # If we are using an existing model, we still have to download the data as we need the
    # actual price data to adjust the prediction.

    # If the predicted value varies/swings-about too much from the price,
    # the days/period training period many be changed to exclude the prior period
    # That does not have present-time characteristics with regard to price movement.
    data_orig = yf.download(tickers = ticker.value, start = dateStart.value, end = dateEnd.value)
    data=data_orig.copy(deep=True)
    offset = pd.Timedelta(days=-30)
    # Resample to 'W'eekly or 'ME'(Month End)
    # logic = {'Open'  : 'first',
    #          'High'  : 'max',
    #          'Low'   : 'min',
    #          'Close' : 'last',
    #          'Adj Close': 'last',
    #          'Volume': 'sum'}
    # data = data.resample('W', offset=offset).apply(logic)
    print("Pulling Data for:", ticker.value, "from", dateStart.value, "to", dateEnd.value)
    print("data.len():", len(data), "data.shape:", data.shape)

    feature_cnt_dl = data.shape[1]
    feature_cnt = feature_cnt_dl + 1  # Actual count vs index count.

load_data()
# data.tail(10)
data.head(5), data.tail(5)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Pulling Data for: ^N225 from 2015-01-01 to 2024-08-07
# data.len(): 2346 data.shape: (2346, 6)
# (                    Open          High           Low         Close  \
#  Date
#  2015-01-05  17325.679688  17540.919922  17219.220703  17408.710938
#  2015-01-06  17101.580078  17111.359375  16881.730469  16883.189453
#  2015-01-07  16808.259766  16974.609375  16808.259766  16885.330078
#  2015-01-08  17067.400391  17243.710938  17016.089844  17167.099609
#  2015-01-09  17318.740234  17342.650391  17129.529297  17197.730469
#
#                 Adj Close     Volume
#  Date
#  2015-01-05  17408.710938  116500000
#  2015-01-06  16883.189453  166000000
#  2015-01-07  16885.330078  138600000
#  2015-01-08  17167.099609  140600000
#  2015-01-09  17197.730469  155200000  ,
#                      Open          High           Low         Close  \
#  Date
#  2024-07-31  38140.769531  39188.371094  37954.378906  39101.820312
#  2024-08-01  38781.558594  38781.558594  37737.878906  38126.328125
#  2024-08-02  37444.171875  37471.519531  35880.148438  35909.699219
#  2024-08-05  35249.359375  35301.179688  31156.119141  31458.419922
#  2024-08-06  32077.330078  34911.800781  32077.330078  34675.460938
#
#                 Adj Close     Volume
#  Date
#  2024-07-31  39101.820312  146400000
#  2024-08-01  38126.328125  178800000
#  2024-08-02  35909.699219  204300000
#  2024-08-05  31458.419922  285600000
#  2024-08-06  34675.460938  251200000  )

# %% [markdown]
# ##  - Add indicators to the data

# %%
# Add indicators to the data...

import pandas_ta as ta

def add_indicators(data, feature_cnt_dl):

    feature_cnt = feature_cnt_dl

    data = data_orig.copy(deep=True)

    # print("= Before Adding Indicators ========================================================")
    # print(data.tail(10))

    data['RSI']=ta.rsi(data.Close, length=3); feature_cnt += 1
    # data['EMAF']=ta.ema(data.Close, length=3); feature_cnt += 1
    # data['EMAM']=ta.ema(data.Close, length=6); feature_cnt += 1
    data['EMAS']=ta.ema(data.Close, length=9); feature_cnt += 1
    data['DPO3']=ta.dpo(data.Close, length=3, centered=True); feature_cnt += 1
    data['DPO6']=ta.dpo(data.Close, length=6, centered=True); feature_cnt += 1
    data['DPO9']=ta.dpo(data.Close, length=9, centered=True); feature_cnt += 1

    # print("= After Adding DPO2 ========================================================")
    # print(data.tail(10))
    #
    # On Balance Volume
    if data['Volume'].iloc[-1] > 0:
        data = data.join(ta.aobv(data.Close, data.Volume, fast=True, min_lookback=3, max_lookback=9))
        feature_cnt += 7 # ta.aobv adds 7 columns

    # print("= After Adding APBV ========================================================")
    # print(data.tail(10))

    # Target is the difference between the adjusted close and the open price.
    data['Target'] = data['Adj Close']-data.Open
    # Shift the target up by one day.Target is the difference between the adjusted close and the open price.
    # That is, the target is the difference between the adjusted close and the open price.
    # Our model will predict the target close for the next day. So we shift the target up by one day.
    data['Target'] = data['Target'].shift(-1)
    feature_cnt += 1

    # 1 if the price goes up, 0 if the price goes down.
    # Not a feature: Needed to test prediction accuracy.
    data['TargetClass'] = [1 if data['Target'].iloc[i]>0 else 0 for i in range(len(data))]

    # The TargetNextClose is the adjusted close price for the next day.
    # This is the value we want to predict.
    # Not a feature: Needed to test prediction accuracy.
    data['TargetNextClose'] = data['Adj Close'].shift(-1)

    # Before scaling the data, we need to use the last good value for rows that have NaN values.
    data.ffill(inplace=True)

    # print("= After Adding Targets___ and ForwardFill ========================================================")
    # print(data.tail(10))

    # Reset the index of the dataframe.
    data.reset_index(inplace = True)
    data_date = data['Date'].copy()
    data.drop(['Date'], axis=1, inplace=True);   feature_cnt -= 1
    data.drop(['Close'], axis=1, inplace=True);  feature_cnt -= 1
    # data.drop(['Volume'], axis=1, inplace=True); feature_cnt -= 1

    # Add one more row to the data file, this will be our next day's prediction.
    data = pd.concat([data,data[-1:]])
    # And, reindex the dataframe.
    data.reset_index(inplace=True)

    # print("feature_cnt_d1:", feature_cnt_dl, " feature_cnt:", feature_cnt)
    return data, feature_cnt, data_date

data, feature_cnt, data_date = add_indicators(data, feature_cnt_dl)

data_set = data.copy(deep=True)
print("Len data:", len(data), "Len data_set", len(data_set))
# data_set.tail(10)
# Out:
# Len data: 2347 Len data_set 2347

# %% [markdown]
# ## - Scale the data
#
#   The data is scaled to a range of 0 to 1.
#   This is done to ensure that the data is normalized, so that the model can be trained on it

# %%
# Scale the data for training...

import sklearn
from sklearn.preprocessing import MinMaxScaler


def scale_data(data_set):
    sc = MinMaxScaler(feature_range=(0,1))
    data_set_scaled = sc.fit_transform(data_set)
    return sc, data_set_scaled

sc, data_set_scaled = scale_data(data_set)

print("data_set.shape:", data_set.shape, "data_set_scaled.shape", data_set_scaled.shape)
# print(data_set_scaled)
# Out:
# data_set.shape: (2347, 21) data_set_scaled.shape (2347, 21)

# %%
# Check of nan an/or 0 dataums...
# After scaling the data, we need to check for NaN and 0 values,
# and forward fill the data with the last known value.
# In the case of a series of 0 values, begining at index 0,
# we have to back fill those values with the first non-non/zero value available.
# *** Currently, we are not handling this case. ***
def scaled_data_cleanup(data_set):
    nan_indices = np.argwhere(np.isnan(data_set_scaled))
    zer_indices = np.argwhere(data_set_scaled == 0)

    # print("nan_indices:", nan_indices)
    # print('zer_indices:', zer_indices)

    for i in range(len(nan_indices)):
        j = nan_indices[i][1] - 1
        if j < 0:
            j = nan_indices[i][1] + 1
        data_set_scaled[nan_indices[i][0], nan_indices[i][1]] = data_set_scaled[nan_indices[i][0], j]
    for i in range(len(zer_indices)):
        j = zer_indices[i][1] - 1
        if j < 0:
            j = zer_indices[i][1] + 1
        data_set_scaled[zer_indices[i][0], zer_indices[i][1]] = data_set_scaled[zer_indices[i][0], j]

    nan_indices = np.argwhere(np.isnan(data_set_scaled))
    zer_indices = np.argwhere(data_set_scaled == 0)

    return data_set_scaled, nan_indices, zer_indices

data_set_scaled, nan_indices, zer_indices = scaled_data_cleanup(data_set)
# print("nan_indices:", nan_indices)
# print('zer_indices:', zer_indices)

# %% [markdown]
# ## - Prepare the scaled data for the model
#
#   - The data is prepared for the model by creating a 3D array of the data.
#   - The data is split into training and test data.
#   - The training data is used to train the model.
#   - The test data is used to test the model.
#   - The model is then used to predict the next day's price.

# %%
# LSTM needs a rolling period of data for each feature to make predictions.
# multiple feature from data provided to the model
global X, backcandles, y, yi, data_set
backcandles = 15 # Set the rolling window size.

def prep_model_inputs(data_scaled, backcandles):
    X = []
    # print(data_set_scaled[0].size)
    # data_set_scaled=data_set.values
    # print(data_set_scaled.shape[0])

    # Create a 3D array of the data. X[features][periods][candles]
    # Where candles is the number of candles that rolls by 1 period for each period.
    for j in range(feature_cnt): # data_set_scaled[0].size):# last 2 columns are target not X
        X.append([])
        for i in range(backcandles, data_set_scaled.shape[0]): # backcandles+2
            X[j].append(data_set_scaled[i-backcandles:i, j])

    # print("X.shape:", np.array(X).shape)
    X = np.array(X)
    # Move axis from 0 to position 2
    X=np.moveaxis(X, [0], [2])
    # print("X.shape:", X.shape)

    # Erase first elements of y because of backcandles to match X length
    # del(yi[0:backcandles])
    #X, yi = np.array(X), np.array(yi)
    # Choose -1 for last column, classification else -2...
    X, yi = np.array(X), np.array(data_set_scaled[backcandles:,-1])
    y = np.reshape(yi,(len(yi),1))
    #y=sc.fit_transform(yi)
    #X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
    
    # print("data_set.shape:",data_set.shape,"X.shape:",X.shape)
    # print(X)
    # print("=========================================================")
    # print(y.shape)
    # print(y)

    return X, y, yi

X, y, yi = prep_model_inputs(data_set_scaled, backcandles)

# %%
# split data into train test sets

global splitlimit
splitlimit = int(len(X)*0.8)

def split_data(X, y, splitlimit):
    # print("lenX:",len(X), "splitLimit:",splitlimit)
    X_train, X_test = X[:splitlimit], X[splitlimit:] # Training data, Test Data
    y_train, y_test = y[:splitlimit], y[splitlimit:] # Training data, Test Data

    adj_close_train, adj_close_test = data_set.loc[:splitlimit, 'Adj Close':'Adj Close'], data_set.loc[splitlimit:, 'Adj Close':'Adj Close'] # Training data, Test Data
    
    # print("X_train.shape:", X_train.shape)
    # print("y_train.shape:", y_train.shape)
    # print("X_test.shape:", X_test.shape)
    # print("y_test.shape:", y_test.shape)
    # print("adj_close_test.shape:", adj_close_test.shape)
    # print("== X_train ===========================================")
    # print(X_train[-20:-10])
    # print("== _train ===========================================")
    # print(y_train[-20:-10])    

    return X_train, X_test, y_train, y_test, adj_close_test

X_train, X_test, y_train, y_test, adj_close_test = split_data(X, y, splitlimit)

# %% [markdown]
# # Load an Existing Model -or- Model Training
#  - Using LSTM (Long Short Term Memory) Model
#  - Using Keras (Tensorflow) Library
#  - LSTM --> Dense Layer --> Activation Layer

# %%
import tensorflow as tf
import keras
import numpy as np
import os
from keras import optimizers
from keras.callbacks import History
from keras.models import Model
from keras.layers import Dense, Dropout, LSTM, Input, Activation, concatenate
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import TimeDistributed

def create_fit_model(X_train, y_train, backcandels, model_path):
    # If the Keras model file exists, load it. Otherwise, create a new model.
    if os.path.exists(model_path) and Selected_Model.value != CreateNewModel:
        # Load the model...
        model = keras.models.load_model(model_path)
        print("Model Loaded:", model_path)
    else:
        # Create a new model...

        #tf.random.set_seed(20)
        np.random.seed(10)

        lstm_input = Input(shape=(backcandles, feature_cnt), name='lstm_input')
        inputs = LSTM(200, name='first_layer')(lstm_input)
        inputs = Dense(1, name='dense_layer')(inputs)
        output = Activation('linear', name='output')(inputs)
        model = Model(inputs=lstm_input, outputs=output)
        adam = optimizers.Adam()
        model.compile(optimizer=adam, loss='mse')
        # model.fit(x=X_train, y=y_train, batch_size=15, epochs=30, shuffle=True, validation_split = 0.1)
        model.fit(x=X_train, y=y_train, batch_size=30, epochs=50, shuffle=True, validation_split = 0.1)
        print("adj_close_test.shape:", adj_close_test.shape)

        # Save the model...
        model.save(model_path)
    
    return model

model = create_fit_model(X_train, y_train, backcandles, model_path)
# Out:
# 2024-08-07 14:31:59.611389: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model Loaded: models/^N225_2015-01-01_2024-07-30.keras
# 2024-08-07 14:32:00.867040: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %% [markdown]
# # Model Testing

# %%
# Sow some y_pred values. If prediction is no good, we might see NaN values.
y_pred = model.predict(X_test)
# for i in range(10):
#     print(y_pred[i], y_test[i], )
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step

# %% [markdown]
# ## - Adjust the prediction
#   The ideal for the prediction is for it to be as close to the actual price as possible.
#   What was observed is that the prediction is often off by a delta.
#   The delta is the difference between the actual price and the predicted price.
#   After applying an average of the delta to the prediction, the prediction is closer to the actual price.
#   Usually within 1% of the actual price, which is an incredible improvement.
#
#   The resulting numpy array y_p_adj is the adjusted prediction, which we will use as the prediction for the next day.

# %%
# Calculate the delta between actual price and prediction
# Bring the prediction closer to the price based on the delta
def mov_avg(x, w):
    return abs(np.convolve(x, np.ones(w), 'valid') / w)

def apply_deltas(a,p,d, w):
    al = list(a) # Actual
    pl = list(p) # Predicted
    dl = list(d) # Delta
    rl = [] # Return List
    if len(dl) < len(pl):
        for i in range(len(pl) - len(dl)):
            # Duplidate the first value in the list to make the list the same size as pl.
            dl.insert(0, dl[0])
    # We don't apply the average to our first predictions
    # fot the size of the moving average window.
    # For this area, we just return the predicted value.
    i = w - 1
    for j in range(0, i):
        rl.append(pl[j]) 
    # print("al.len", len(al), "pl.len", len(pl), "dl.len", len(dl))
    # Beyond the window, we apply the average delta to the prediction.
    delta_factor = 1
    for delta in dl[:-1]:
        if i >= len(dl):
            break
        # print("i:", i, "dl:", len(dl), "al:", len(al), "pl:", len(pl))
        if al[i] > pl[i]:
            # If the actual price is greater than the predicted price, add the delta.
            val = pl[i] + (delta * delta_factor)
        else:
            # If the actual price is less than or equal to the predicted price, subtract the delta.
            val = pl[i] - (delta * delta_factor)
        rl.append(val)
        i += 1
    return rl

def adjust_prediction(y_test, y_pred, avg_win=5):
    """
    Calculate the delta between actual price and prediction
    Bring the prediction closer to the price based on the delta
    """

    y_p_delta = y_pred - y_test
    # Shift delta to the left by 1 day so that the adjusted prediction
    # only uses know data, and duplidate the delta for the last day (which we don't know).
    y_p_delta = np.append(y_p_delta[1:], y_p_delta[-1])
    # Calculate the average delta for the prediction.
    y_p_davg = mov_avg(y_p_delta, avg_win)

    # print(y_test.shape, y_pred.shape, y_p_adj.shape, y_p_delta.shape)
    y_p_adj = apply_deltas(y_test, y_pred, y_p_davg, avg_win)
    # We don't know the actual price for today, so we don't know the delta and average,
    # so for today, we will use the last known average delta (yesterday's) to adjust todays prediction.
    if y_test[-2] > y_pred[-1]:
        y_p_adj[-1] = y_pred[-1] + y_p_davg[-2]
    else:
        y_p_adj[-1] = y_pred[-1] - y_p_davg[-2]
    # Convert y_p_adj to a numpy array for plotting.
    y_p_adj = np.array(y_p_adj)

    return y_p_adj, y_p_delta

y_p_adj, y_p_delta = adjust_prediction(y_test, y_pred, avg_win=3)
# print("adj_close_test.shape:", adj_close_test.shape)
# print("y_pred:", y_pred.shape[0])

# %% [markdown]
# # - Plot the Test Results

# %% [markdown]
# ### - Unscaled Data (0..1) (Prediction vs Target)

# %%
# Use an interactive plot to see the results
# %matplotlib notebook

def plot_pred_results(y_test, y_pred, y_p_adj):
    # Plot the scaled test and predicted data.
    y_test_plot = y_test[:-2]
    plt.figure(figsize=(16,8))
    # Acj Close
    plt.plot(y_test_plot, color = 'black', label = 'Test',     marker='.')
    # Original Prediction
    plt.plot(y_pred[1:],      color = 'red',   label = 'Pred',     marker='1')
    # Adjusted Prediction
    plt.plot(y_p_adj[1:],     color = 'orange', label = 'Adj Pred', marker='1')
    plt.legend()
    plt.grid()
    plt.show()
    return plt

plt = plot_pred_results(y_test, y_pred, y_p_adj)
# pd.DataFrame(y_test_plot).tail(5)
# Out:
# <div id='3c56a5fd-da15-4384-ba4e-47f35a7a826c'></div>

# %% [markdown]
# ### - Rescaled Data ($USD) (Prediction vs Target)

# %%
# Plot using candlesticks using matplotlib...

# Use an interactive plot to see the results
# %matplotlib notebook

def plot_candlesticks(plt, prices, title, width=1, width2=.25, clr_up='green', clr_dn='red', clr_wick='black'):
    """
    Plot Candlesticks...
    :param plt:    maplotlib.pyplot handle
    :param prices: The series of OHLC prices to plot
    :param title:  A title for the plot
    :param width:
    :param width2:
    :param clr_up:
    :param clr_dn:
    :param clr_wick:
    :return:
    """
    #define up and down prices
    up = prices[prices.Close>=prices.Open]
    down = prices[prices.Close<prices.Open]

    #plot up prices
    plt.bar(up.index,up.Close-up.Open,width,bottom=up.Open,color=clr_up, alpha=.30)
    # plt.bar(up.index,up.High-up.Close,width2,bottom=up.Close,color=clr_up, alpha=.25)
    # plt.bar(up.index,up.Low-up.Open,width2,bottom=up.Open,color=clr_up, alpha=.25)
    plt.bar(up.index,up.High-up.Low,width2,bottom=up.Low,color=clr_wick, alpha=.30)

    #plot down prices
    plt.bar(down.index,down.Open-down.Close,width,bottom=down.Close,color=clr_dn, alpha=.25)
    # plt.bar(down.index,down.High-down.Open,width2,bottom=down.Open,color=clr_dn, alpha=.25)
    # plt.bar(down.index,down.Low-down.Close,width2,bottom=down.Close,color=clr_dn, alpha=.25)
    plt.bar(down.index,down.High-down.Low,width2,bottom=down.Low,color=clr_wick, alpha=.25)

    #rotate x-axis tick labels
    plt.xticks(rotation=45, ha='right')

import math
import mplfinance as mfp


def plot_pred_results(y_test, y_pred, y_p_adj, data_set, data_set_scaled, data_date):
    # Plot the original Adj Cost data that is in dollars...
    # Remove the last Adj Price, because it just aopy of the last adj
    plt_test_usd = np.array(data_set[backcandles + splitlimit:]['Adj Close'])
    plt_test_plot =np.array(plt_test_usd[:-1].reshape(-1,1))

    # Using Inverse_Transform to Rescale the predicted data to dollars...
    # To rescale the data, we need to use .inverse_transform with a similar tructure
    # to the original data_set_scaled returned by the .fit_transform function that did
    # the original scaling.
    # So we feed om the "test" portion of the data_set_scaled and replace the "TargetNextClose"
    # Column, which is the last column, with the predicted values (which we wan to rescale).
    # This is then fed to the .inverse_transform function to get the rescaled values, and we
    # will get accurate rescaled predicted values.
    data_set_scaled_y = data_set_scaled[backcandles + splitlimit:, :].copy()
    # Replace the last column in data_set_scaled_y with the predicted values...
    data_set_scaled_y[:, -1] = y_p_adj.reshape(-1)
    # Get the rescaled values for the adjusted prediction...
    y_pred_adj_rs = sc.inverse_transform(data_set_scaled_y)[:, -1]
    # Replace the last column in data_set_scaled_y with the predicted values...
    data_set_scaled_y[:, -1] = y_pred.reshape(-1)
    # Get the rescaled values for the adjusted prediction...
    y_pred_rs = sc.inverse_transform(data_set_scaled_y)[:, -1]

    # Calculate the mean of the delta between the prediction and the actual price...
    # Used to create price range circles around the prediction...
    plt_delta = np.array(pd.DataFrame([abs(plt_test_usd[i] - y_pred_adj_rs[i]) for i in range(len(y_p_adj)) ]).rolling(window=6).mean())

    # Dates...
    data_date_str = [str(date) for date in data_date]
    plt_test_dates = np.array((data_date_str[backcandles + splitlimit - 1:-1]), ).reshape(-1,1)
    plt_pred_dates = np.array((data_date_str[backcandles + splitlimit - 1:]),   ).reshape(-1,1)

    # empty_arr = np.zeros(((len(plt_test_plot)+1, 18)))
    # plt_pred_adj = sc.inverse_transform(np.append(y_p_adj, empty_arr, axis=1))[0:, 1]

    # Plot the data...
    plt.figure(figsize=(16,8))
    plt.autoscale(tight=True)

    plt_test_plot = plt_test_plot.reshape(-1,1)

    # Plot the actual price data ($USD)...
    plt.plot(plt_test_plot, color = 'black', label = 'Test', marker='+')
    # Plot the rescaled price data ($USD)...
    # plt.plot(plt_test_rescaled, color = 'purple', label = 'Test', marker='+')
    # Plot the adj predicted price data ($USD)...
    # plt.plot(plt_pred_adj, color = 'green', label = 'Test', marker='.')
    # Plot the adj predicted price data ($USD)...
    plt.plot(y_pred_rs, color = 'green', label = 'Test', marker='.')
    # Plot the adj predicted price data ($USD)...
    plt.plot(y_pred_adj_rs, color = 'orange', label = 'Test', marker='.')

    # Plot the candlesticks...
    ds_tmp = data_set[backcandles + splitlimit:-1]
    cs_data = ds_tmp.loc[backcandles + splitlimit:, ['Open','High','Low','Adj Close']].copy().reset_index()
    cs_data.rename(columns={'Adj Close':'Close'}, inplace=True)
    plot_candlesticks (plt, cs_data, 'Candlesticks')

    # Plot the text of the predicted price...
    plt.text(len(y_pred_adj_rs) -1, y_pred_adj_rs[-1], y_pred_adj_rs[-1].round(2), fontsize=8, color='black', ha='left', va='center')

    # plt.xlabel(range(0,len(plt_pred_dates)), plt_pred_dates.tolist(), rotation=45)
    #  .set_major_formatter(matplotlib.dates.DateFormatter('%Y')))

    # Plot a Price Range Circle Arounds the current Prediction...
    Plot_Pred_Circle = True
    if Plot_Pred_Circle:
        import matplotlib.patches as ptch
        lst_pred = len(y_pred_adj_rs) -1
        # ax.set_xlim = ([0, len(plt_pred_adj)])
        # ax.set_ylim = ([plt_pred_adj.min(), plt_pred_adj.max()])
        cpos = np.array([lst_pred, y_pred_adj_rs[-1]])
        circ_pred0 = ptch.Circle(cpos, radius=plt_delta[-1][0]/1,   color='grey',   fill=True, alpha=0.20)
        circ_pred1 = ptch.Circle(cpos, radius=plt_delta[-1][0]/1.5, color='blue',   fill=True, alpha=0.20)
        circ_pred2 = ptch.Circle(cpos, radius=plt_delta[-1][0]/2,   color='yellow', fill=True, alpha=0.20)
        circ_pred3 = ptch.Circle(cpos, radius=plt_delta[-1][0]/3,   color='red',    fill=True, alpha=0.20)
        ax = plt.gca()
        # ax.set_aspect("equal")
        ax.add_patch(circ_pred0)
        ax.add_patch(circ_pred1)
        ax.add_patch(circ_pred2)
        ax.add_patch(circ_pred3)

    plt.grid(visible=True, which='both')
    plt.legend()
    plt.show()
    return plt, y_pred_rs, y_pred_adj_rs

plt, y_pred_rs, y_pred_adj_rs = plot_pred_results(y_test, y_pred, y_p_adj, data_set, data_set_scaled, data_date)
# Out:
# <div id='7e70e300-d394-4b27-a688-0c9fe3cadd31'></div>

# %% [markdown]
# ### - Plot the Prediction Results (Using mplfinance)

# %%
# Plot using mlpfinance...
import mplfinance as mpf
print('Ticker:', ticker.value)
def plot_pred_results(Ticker, y_test, y_pred, y_p_adj, y_pred_adj_rs, data_set, data_set_scaled, data_date):
    # Createe a dataframe of the data for plt_test_usd, with a datetime index...
    df_plt_test_usd = pd.DataFrame()
    df_plt_test_usd.insert(0, 'Date', data_date[backcandles + splitlimit + 4:])
    df_plt_test_usd.reset_index()
    ohlcv = data_orig.iloc[backcandles + splitlimit + 4:, [0,1,2,3,4,5]].copy()
    ohlcv.reset_index()
    df_plt_test_usd = pd.concat([df_plt_test_usd, ohlcv.set_axis(df_plt_test_usd.index)], axis=1)
    
    # Add a place holder for the prediction...
    next_date = df_plt_test_usd.iloc[-1, 0] + pd.DateOffset(days=1)
    next_open      = df_plt_test_usd.iloc[-1, 4]
    next_high      = df_plt_test_usd.iloc[-1, 4]
    next_low       = df_plt_test_usd.iloc[-1, 4]
    next_close     = df_plt_test_usd.iloc[-1, 4]
    next_adj_close = df_plt_test_usd.iloc[-1, 4]
    next_volume    = 0
    
    # Prepare the prediction data for the plot...
    c_pred_rs     = pd.DataFrame(y_pred_rs[4:]).rename({0:'pred_rs'}, axis=1)
    c_pred_adj_rs = pd.DataFrame(y_pred_adj_rs[4:]).rename({0:'pred_adj_rs'}, axis=1)
    
    # Append a new row to the dataframe so it extends out to the prediction...
    new_row = { 'Date': next_date, "Open": next_open, "High": next_high, "Low": next_low, "Close": next_close,
                                   "Adj Close": next_adj_close, "Volume": next_volume,
                                   "pred_rs": c_pred_rs.iloc[-1], "pred_adj_rs": c_pred_adj_rs.iloc[-1] }
    new_row = pd.DataFrame(new_row, index=[6])
    df_plt_test_usd = pd.concat([df_plt_test_usd, new_row], axis=0, ignore_index=True)
    
    # Add the prediction data to the OHLCV plot data...
    df_plt_test_usd = pd.concat([df_plt_test_usd, c_pred_rs.set_axis(df_plt_test_usd.index)],     axis=1)
    df_plt_test_usd = pd.concat([df_plt_test_usd, c_pred_adj_rs.set_axis(df_plt_test_usd.index)], axis=1)
    
    df_plt_test_usd.ffill(inplace=True)
    df_plt_test_usd.set_index('Date', inplace=True, drop=True)
    df_plt_test_usd.ffill(inplace=True)
    df_plt_test_usd.rename(index={6:'pred_rs', 7:'pred_adj_rs'}, inplace=True)
    # Add a day row to df_plt_test_usd as a place holder for the prediction...
    print("df_plt_test_usd:", df_plt_test_usd.shape)
    
    kwargs = dict(type='candle', volume=True, figratio=(11,6), figscale=1.25, warn_too_much_data=10000, title='Ticker: '+ticker.value)
    preds = [ mpf.make_addplot(df_plt_test_usd['pred_rs'],     type='line', panel=0, color='g', secondary_y=False),
              mpf.make_addplot(df_plt_test_usd['pred_adj_rs'], type='line', panel=0, color='r', secondary_y=False)  ]
    mpf.plot(df_plt_test_usd,**kwargs,style='binance', addplot=preds)
    return mpf

mpf = plot_pred_results(Ticker, y_test, y_pred, y_p_adj, y_pred_adj_rs, data_set, data_set_scaled, data_date)
# Out:
# Ticker: ^N225
# df_plt_test_usd: (463, 10)
# <div id='b1810fa0-d39e-473d-9142-e5e4614655e2'></div>

# %% [markdown]
# # Analysis of the Prediction
#  - Rescaled data (0..1) (Prediction vs Target)

# %%
# We convert our data back to dollars...
# predval = y_pred[i] * scalefac

def analyze_pred(y_test, y_pred, y_p_adj, data_set, data_set_scaled, data_date):
    # Convert back to dollar $values
    elements = len(y_pred)
    print(elements)
    tot_deltas = 0
    tot_tradrng = 0
    for i in range(-1, -elements, -1):
        actual = data_set['Adj Close'].iloc[i - 1]
        scalefac = data_set['Adj Close'].iloc[i - 1] / y_test[i - 1]
        # print("Scaling Factor", scalefac)
        predval = y_pred[i] * scalefac
        predval = y_pred[i - 1] if np.isinf(predval) else predval
        pred_delta = abs(predval - actual)
        tot_deltas += pred_delta
        trd_rng = abs(data_set['High'].iloc[i] - data_set['Low'].iloc[i])
        tot_tradrng += trd_rng
        print("Close", actual.round(2), "Predicted: $", predval.round(2), "  Actual: $", actual.round(2), "  Delta:$", pred_delta.round(6), "  Trade Rng: $", trd_rng.round(2))

    print("Mean Trading Range: $", round(tot_tradrng / elements, 2))
    print("Mean Delta (Actual vs Prediction): $", round((tot_deltas[0] / elements), 2))
    return tot_deltas, tot_tradrng, elements

tot_deltas, tot_tradrng, elements = analyze_pred(y_test, y_pred, y_p_adj, data_set, data_set_scaled, data_date)
# Out:
# 467
# Close 34675.46 Predicted: $ [6033.81]   Actual: $ 34675.46   Delta:$ [28641.646682]   Trade Rng: $ 2834.47
# Close 31458.42 Predicted: $ [5627.38]   Actual: $ 31458.42   Delta:$ [25831.035403]   Trade Rng: $ 2834.47
# Close 35909.7 Predicted: $ [8959.46]   Actual: $ 35909.7   Delta:$ [26950.237142]   Trade Rng: $ 4145.06
# Close 38126.33 Predicted: $ [8490.14]   Actual: $ 38126.33   Delta:$ [29636.187105]   Trade Rng: $ 1591.37
# Close 39101.82 Predicted: $ [10041.71]   Actual: $ 39101.82   Delta:$ [29060.107424]   Trade Rng: $ 1043.68
# Close 38525.95 Predicted: $ [10533.39]   Actual: $ 38525.95   Delta:$ [27992.559652]   Trade Rng: $ 1233.99
# Close 38468.63 Predicted: $ [11078.25]   Actual: $ 38468.63   Delta:$ [27390.378605]   Trade Rng: $ 454.46
# Close 37667.41 Predicted: $ [10807.99]   Actual: $ 37667.41   Delta:$ [26859.416216]   Trade Rng: $ 709.69
# Close 37869.51 Predicted: $ [10921.73]   Actual: $ 37869.51   Delta:$ [26947.779692]   Trade Rng: $ 494.77
# Close 39154.85 Predicted: $ [10638.95]   Actual: $ 39154.85   Delta:$ [28515.902231]   Trade Rng: $ 732.21
# Close 39594.39 Predicted: $ [10833.01]   Actual: $ 39594.39   Delta:$ [28761.384192]   Trade Rng: $ 546.77
# Close 39599.0 Predicted: $ [11460.8]   Actual: $ 39599.0   Delta:$ [28138.201993]   Trade Rng: $ 407.98
# Close 40063.79 Predicted: $ [11992.19]   Actual: $ 40063.79   Delta:$ [28071.596515]   Trade Rng: $ 453.81
# Close 40126.35 Predicted: $ [12390.11]   Actual: $ 40126.35   Delta:$ [27736.241692]   Trade Rng: $ 388.32
# Close 41097.69 Predicted: $ [12974.89]   Actual: $ 41097.69   Delta:$ [28122.799829]   Trade Rng: $ 483.41
# Close 41275.08 Predicted: $ [13300.73]   Actual: $ 41275.08   Delta:$ [27974.347746]   Trade Rng: $ 411.73
# Close 41190.68 Predicted: $ [13924.46]   Actual: $ 41190.68   Delta:$ [27266.219203]   Trade Rng: $ 299.42
# Close 42224.02 Predicted: $ [14653.14]   Actual: $ 42224.02   Delta:$ [27570.880466]   Trade Rng: $ 566.47
# Close 41831.99 Predicted: $ [14588.92]   Actual: $ 41831.99   Delta:$ [27243.063867]   Trade Rng: $ 324.31
# Close 41580.17 Predicted: $ [14951.9]   Actual: $ 41580.17   Delta:$ [26628.276699]   Trade Rng: $ 458.78
# Close 40780.7 Predicted: $ [14853.29]   Actual: $ 40780.7   Delta:$ [25927.410599]   Trade Rng: $ 826.91
# Close 40912.37 Predicted: $ [15083.08]   Actual: $ 40912.37   Delta:$ [25829.288201]   Trade Rng: $ 331.54
# Close 40913.65 Predicted: $ [14680.26]   Actual: $ 40913.65   Delta:$ [26233.386781]   Trade Rng: $ 353.24
# Close 40580.76 Predicted: $ [14518.45]   Actual: $ 40580.76   Delta:$ [26062.310064]   Trade Rng: $ 367.08
# Close 40074.69 Predicted: $ [14372.11]   Actual: $ 40074.69   Delta:$ [25702.585513]   Trade Rng: $ 521.36
# Close 39631.06 Predicted: $ [14148.78]   Actual: $ 39631.06   Delta:$ [25482.283458]   Trade Rng: $ 655.86
# Close 39583.08 Predicted: $ [13957.47]   Actual: $ 39583.08   Delta:$ [25625.609999]   Trade Rng: $ 405.59
# Close 39341.54 Predicted: $ [13670.01]   Actual: $ 39341.54   Delta:$ [25671.527194]   Trade Rng: $ 297.97
# Close 39667.07 Predicted: $ [13820.79]   Actual: $ 39667.07   Delta:$ [25846.282396]   Trade Rng: $ 245.73
# Close 39173.15 Predicted: $ [13361.92]   Actual: $ 39173.15   Delta:$ [25811.223997]   Trade Rng: $ 555.07
# Close 38804.65 Predicted: $ [13128.84]   Actual: $ 38804.65   Delta:$ [25675.806419]   Trade Rng: $ 457.0
# Close 38596.47 Predicted: $ [12774.1]   Actual: $ 38596.47   Delta:$ [25822.368196]   Trade Rng: $ 489.4
# Close 38633.02 Predicted: $ [12663.87]   Actual: $ 38633.02   Delta:$ [25969.152464]   Trade Rng: $ 263.55
# Close 38570.76 Predicted: $ [12376.4]   Actual: $ 38570.76   Delta:$ [26194.365713]   Trade Rng: $ 374.54
# Close 38482.11 Predicted: $ [12210.66]   Actual: $ 38482.11   Delta:$ [26271.451178]   Trade Rng: $ 344.56
# Close 38102.44 Predicted: $ [12118.24]   Actual: $ 38102.44   Delta:$ [25984.198702]   Trade Rng: $ 186.13
# Close 38814.56 Predicted: $ [12481.88]   Actual: $ 38814.56   Delta:$ [26332.675643]   Trade Rng: $ 492.5
# Close 38720.47 Predicted: $ [12239.23]   Actual: $ 38720.47   Delta:$ [26481.236123]   Trade Rng: $ 470.95
# Close 38876.71 Predicted: $ [12687.59]   Actual: $ 38876.71   Delta:$ [26189.120745]   Trade Rng: $ 562.65
# Close 39134.79 Predicted: $ [12910.46]   Actual: $ 39134.79   Delta:$ [26224.32525]   Trade Rng: $ 136.63
# Close 39038.16 Predicted: $ [12710.94]   Actual: $ 39038.16   Delta:$ [26327.220045]   Trade Rng: $ 261.78
# Close 38683.93 Predicted: $ [12573.06]   Actual: $ 38683.93   Delta:$ [26110.872346]   Trade Rng: $ 391.76
# Close 38703.51 Predicted: $ [12560.15]   Actual: $ 38703.51   Delta:$ [26143.35739]   Trade Rng: $ 186.42
# Close 38490.17 Predicted: $ [12402.95]   Actual: $ 38490.17   Delta:$ [26087.222619]   Trade Rng: $ 318.43
# Close 38837.46 Predicted: $ [12620.74]   Actual: $ 38837.46   Delta:$ [26216.720432]   Trade Rng: $ 312.43
# Close 38923.03 Predicted: $ [12488.51]   Actual: $ 38923.03   Delta:$ [26434.519821]   Trade Rng: $ 303.27
# Close 38487.9 Predicted: $ [12315.37]   Actual: $ 38487.9   Delta:$ [26172.523761]   Trade Rng: $ 297.55
# Close 38054.13 Predicted: $ [12214.28]   Actual: $ 38054.13   Delta:$ [25839.848009]   Trade Rng: $ 439.32
# Close 38556.87 Predicted: $ [12461.81]   Actual: $ 38556.87   Delta:$ [26095.063734]   Trade Rng: $ 521.03
# Close 38855.37 Predicted: $ [12519.65]   Actual: $ 38855.37   Delta:$ [26335.720142]   Trade Rng: $ 617.75
# Close 38900.02 Predicted: $ [12676.96]   Actual: $ 38900.02   Delta:$ [26223.05563]   Trade Rng: $ 225.84
# Close 38646.11 Predicted: $ [12804.99]   Actual: $ 38646.11   Delta:$ [25841.121402]   Trade Rng: $ 232.09
# Close 39103.22 Predicted: $ [13163.51]   Actual: $ 39103.22   Delta:$ [25939.713399]   Trade Rng: $ 373.12
# Close 38617.1 Predicted: $ [12888.49]   Actual: $ 38617.1   Delta:$ [25728.611322]   Trade Rng: $ 512.04
# Close 38946.93 Predicted: $ [13486.11]   Actual: $ 38946.93   Delta:$ [25460.8219]   Trade Rng: $ 262.05
# Close 39069.68 Predicted: $ [13379.66]   Actual: $ 39069.68   Delta:$ [25690.019775]   Trade Rng: $ 403.87
# Close 38787.38 Predicted: $ [13332.07]   Actual: $ 38787.38   Delta:$ [25455.307805]   Trade Rng: $ 733.46
# Close 38920.26 Predicted: $ [13405.06]   Actual: $ 38920.26   Delta:$ [25515.204843]   Trade Rng: $ 302.93
# Close 38385.73 Predicted: $ [12961.16]   Actual: $ 38385.73   Delta:$ [25424.57271]   Trade Rng: $ 436.05
# Close 38356.06 Predicted: $ [12887.77]   Actual: $ 38356.06   Delta:$ [25468.292815]   Trade Rng: $ 480.99
# Close 38179.46 Predicted: $ [12524.62]   Actual: $ 38179.46   Delta:$ [25654.845315]   Trade Rng: $ 392.97
# Close 38229.11 Predicted: $ [12499.55]   Actual: $ 38229.11   Delta:$ [25729.561226]   Trade Rng: $ 303.82
# Close 38073.98 Predicted: $ [12295.83]   Actual: $ 38073.98   Delta:$ [25778.154165]   Trade Rng: $ 614.97
# Close 38202.37 Predicted: $ [12449.49]   Actual: $ 38202.37   Delta:$ [25752.882535]   Trade Rng: $ 357.57
# Close 38835.1 Predicted: $ [12626.87]   Actual: $ 38835.1   Delta:$ [26208.233835]   Trade Rng: $ 589.5
# Close 38236.07 Predicted: $ [12276.72]   Actual: $ 38236.07   Delta:$ [25959.354126]   Trade Rng: $ 321.17
# Close 38274.05 Predicted: $ [12528.35]   Actual: $ 38274.05   Delta:$ [25745.700112]   Trade Rng: $ 397.41
# Close 38405.66 Predicted: $ [12321.06]   Actual: $ 38405.66   Delta:$ [26084.603233]   Trade Rng: $ 397.1
# Close 37934.76 Predicted: $ [12047.89]   Actual: $ 37934.76   Delta:$ [25886.873551]   Trade Rng: $ 426.06
# Close 37628.48 Predicted: $ [11889.1]   Actual: $ 37628.48   Delta:$ [25739.380548]   Trade Rng: $ 546.84
# Close 38460.08 Predicted: $ [11752.27]   Actual: $ 38460.08   Delta:$ [26707.811453]   Trade Rng: $ 525.3
# Close 37552.16 Predicted: $ [11068.29]   Actual: $ 37552.16   Delta:$ [26483.871946]   Trade Rng: $ 602.61
# Close 37438.61 Predicted: $ [11084.26]   Actual: $ 37438.61   Delta:$ [26354.352402]   Trade Rng: $ 420.51
# Close 37068.35 Predicted: $ [10650.37]   Actual: $ 37068.35   Delta:$ [26417.984692]   Trade Rng: $ 459.17
# Close 38079.7 Predicted: $ [10628.84]   Actual: $ 38079.7   Delta:$ [27450.857321]   Trade Rng: $ 1016.42
# Close 37961.8 Predicted: $ [10461.44]   Actual: $ 37961.8   Delta:$ [27500.365164]   Trade Rng: $ 571.84
# Close 38471.2 Predicted: $ [10919.33]   Actual: $ 38471.2   Delta:$ [27551.870508]   Trade Rng: $ 625.81
# Close 39232.8 Predicted: $ [11212.25]   Actual: $ 39232.8   Delta:$ [28020.546924]   Trade Rng: $ 442.5
# Close 39523.55 Predicted: $ [11558.05]   Actual: $ 39523.55   Delta:$ [27965.502514]   Trade Rng: $ 411.85
# Close 39442.63 Predicted: $ [11765.04]   Actual: $ 39442.63   Delta:$ [27677.584416]   Trade Rng: $ 317.09
# Close 39581.81 Predicted: $ [12053.49]   Actual: $ 39581.81   Delta:$ [27528.318773]   Trade Rng: $ 408.17
# Close 39773.13 Predicted: $ [12082.]   Actual: $ 39773.13   Delta:$ [27691.132979]   Trade Rng: $ 198.22
# Close 39347.04 Predicted: $ [11891.11]   Actual: $ 39347.04   Delta:$ [27455.931584]   Trade Rng: $ 297.0
# Close 38992.08 Predicted: $ [11893.82]   Actual: $ 38992.08   Delta:$ [27098.25873]   Trade Rng: $ 420.36
# Close 39773.14 Predicted: $ [11935.09]   Actual: $ 39773.14   Delta:$ [27838.053547]   Trade Rng: $ 500.52
# Close 39451.85 Predicted: $ [11581.32]   Actual: $ 39451.85   Delta:$ [27870.53293]   Trade Rng: $ 469.88
# Close 39838.91 Predicted: $ [12016.7]   Actual: $ 39838.91   Delta:$ [27822.213443]   Trade Rng: $ 408.86
# Close 39803.09 Predicted: $ [12080.35]   Actual: $ 39803.09   Delta:$ [27722.743955]   Trade Rng: $ 443.18
# Close 40369.44 Predicted: $ [12476.09]   Actual: $ 40369.44   Delta:$ [27893.347062]   Trade Rng: $ 990.77
# Close 40168.07 Predicted: $ [12504.82]   Actual: $ 40168.07   Delta:$ [27663.248561]   Trade Rng: $ 253.6
# Close 40762.73 Predicted: $ [13088.08]   Actual: $ 40762.73   Delta:$ [27674.654435]   Trade Rng: $ 427.96
# Close 40398.03 Predicted: $ [12891.02]   Actual: $ 40398.03   Delta:$ [27507.012776]   Trade Rng: $ 527.15
# Close 40414.12 Predicted: $ [13276.55]   Actual: $ 40414.12   Delta:$ [27137.571244]   Trade Rng: $ 248.68
# Close 40888.43 Predicted: $ [13447.17]   Actual: $ 40888.43   Delta:$ [27441.260468]   Trade Rng: $ 423.06
# Close 40815.66 Predicted: $ [13204.]   Actual: $ 40815.66   Delta:$ [27611.659126]   Trade Rng: $ 373.61
# Close 40003.6 Predicted: $ [13091.34]   Actual: $ 40003.6   Delta:$ [26912.259204]   Trade Rng: $ 371.13
# Close 39740.44 Predicted: $ [12848.38]   Actual: $ 39740.44   Delta:$ [26892.066372]   Trade Rng: $ 596.1
# Close 38707.64 Predicted: $ [12149.17]   Actual: $ 38707.64   Delta:$ [26558.465821]   Trade Rng: $ 833.64
# Close 38807.38 Predicted: $ [12322.85]   Actual: $ 38807.38   Delta:$ [26484.52533]   Trade Rng: $ 288.74
# Close 38695.97 Predicted: $ [11949.8]   Actual: $ 38695.97   Delta:$ [26746.167875]   Trade Rng: $ 440.16
# Close 38797.51 Predicted: $ [12255.12]   Actual: $ 38797.51   Delta:$ [26542.393478]   Trade Rng: $ 695.23
# Close 38820.49 Predicted: $ [12600.64]   Actual: $ 38820.49   Delta:$ [26219.853131]   Trade Rng: $ 570.42
# Close 39688.94 Predicted: $ [13132.14]   Actual: $ 39688.94   Delta:$ [26556.805694]   Trade Rng: $ 744.62
# Close 39598.71 Predicted: $ [13327.58]   Actual: $ 39598.71   Delta:$ [26271.13399]   Trade Rng: $ 437.73
# Close 40090.78 Predicted: $ [14338.59]   Actual: $ 40090.78   Delta:$ [25752.192411]   Trade Rng: $ 953.71
# Close 40097.63 Predicted: $ [14348.27]   Actual: $ 40097.63   Delta:$ [25749.362125]   Trade Rng: $ 378.73
# Close 40109.23 Predicted: $ [14510.88]   Actual: $ 40109.23   Delta:$ [25598.349269]   Trade Rng: $ 386.65
# Close 39910.82 Predicted: $ [14502.99]   Actual: $ 39910.82   Delta:$ [25407.827476]   Trade Rng: $ 313.09
# Close 39166.19 Predicted: $ [14428.84]   Actual: $ 39166.19   Delta:$ [24737.346959]   Trade Rng: $ 765.59
# Close 39208.03 Predicted: $ [14619.66]   Actual: $ 39208.03   Delta:$ [24588.369866]   Trade Rng: $ 373.31
# Close 39239.52 Predicted: $ [14412.53]   Actual: $ 39239.52   Delta:$ [24826.985627]   Trade Rng: $ 208.48
# Close 39233.71 Predicted: $ [14254.81]   Actual: $ 39233.71   Delta:$ [24978.89713]   Trade Rng: $ 313.26
# Close 39098.68 Predicted: $ [14128.7]   Actual: $ 39098.68   Delta:$ [24969.978915]   Trade Rng: $ 207.05
# Close 38262.16 Predicted: $ [13930.25]   Actual: $ 38262.16   Delta:$ [24331.913752]   Trade Rng: $ 648.9
# Close 38363.61 Predicted: $ [14275.91]   Actual: $ 38363.61   Delta:$ [24087.69814]   Trade Rng: $ 244.55
# Close 38470.38 Predicted: $ [14148.24]   Actual: $ 38470.38   Delta:$ [24322.136458]   Trade Rng: $ 454.29
# Close 38487.24 Predicted: $ [14016.96]   Actual: $ 38487.24   Delta:$ [24470.273751]   Trade Rng: $ 274.14
# Close 38157.94 Predicted: $ [13909.2]   Actual: $ 38157.94   Delta:$ [24248.745305]   Trade Rng: $ 503.51
# Close 37703.32 Predicted: $ [13897.79]   Actual: $ 37703.32   Delta:$ [23805.531448]   Trade Rng: $ 253.38
# Close 37963.97 Predicted: $ [14001.82]   Actual: $ 37963.97   Delta:$ [23962.149598]   Trade Rng: $ 231.38
# Close 36897.42 Predicted: $ [13548.56]   Actual: $ 36897.42   Delta:$ [23348.866694]   Trade Rng: $ 826.59
# Close 36863.28 Predicted: $ [13524.06]   Actual: $ 36863.28   Delta:$ [23339.223819]   Trade Rng: $ 480.23
# Close 36119.92 Predicted: $ [12716.9]   Actual: $ 36119.92   Delta:$ [23403.018699]   Trade Rng: $ 750.77
# Close 36160.66 Predicted: $ [12912.44]   Actual: $ 36160.66   Delta:$ [23248.218103]   Trade Rng: $ 340.87
# Close 36354.16 Predicted: $ [12845.73]   Actual: $ 36354.16   Delta:$ [23508.42842]   Trade Rng: $ 228.5
# Close 36158.02 Predicted: $ [12530.35]   Actual: $ 36158.02   Delta:$ [23627.667062]   Trade Rng: $ 239.62
# Close 36011.46 Predicted: $ [12596.88]   Actual: $ 36011.46   Delta:$ [23414.584909]   Trade Rng: $ 357.48
# Close 36286.71 Predicted: $ [12933.7]   Actual: $ 36286.71   Delta:$ [23353.011479]   Trade Rng: $ 221.76
# Close 36065.86 Predicted: $ [12642.55]   Actual: $ 36065.86   Delta:$ [23423.31146]   Trade Rng: $ 587.95
# Close 36026.94 Predicted: $ [12739.18]   Actual: $ 36026.94   Delta:$ [23287.76451]   Trade Rng: $ 209.72
# Close 35751.07 Predicted: $ [12734.51]   Actual: $ 35751.07   Delta:$ [23016.560558]   Trade Rng: $ 373.1
# Close 36236.47 Predicted: $ [13317.36]   Actual: $ 36236.47   Delta:$ [22919.10458]   Trade Rng: $ 372.82
# Close 36226.48 Predicted: $ [13323.78]   Actual: $ 36226.48   Delta:$ [22902.696182]   Trade Rng: $ 399.82
# Close 36517.57 Predicted: $ [13849.61]   Actual: $ 36517.57   Delta:$ [22667.956645]   Trade Rng: $ 366.5
# Close 36546.95 Predicted: $ [13865.63]   Actual: $ 36546.95   Delta:$ [22681.32152]   Trade Rng: $ 548.44
# Close 35963.27 Predicted: $ [13831.08]   Actual: $ 35963.27   Delta:$ [22132.192207]   Trade Rng: $ 345.89
# Close 35466.17 Predicted: $ [13796.93]   Actual: $ 35466.17   Delta:$ [21669.243024]   Trade Rng: $ 286.16
# Close 35477.75 Predicted: $ [13938.08]   Actual: $ 35477.75   Delta:$ [21539.672777]   Trade Rng: $ 356.84
# Close 35619.18 Predicted: $ [14014.73]   Actual: $ 35619.18   Delta:$ [21604.454009]   Trade Rng: $ 762.7
# Close 35901.79 Predicted: $ [14149.73]   Actual: $ 35901.79   Delta:$ [21752.058915]   Trade Rng: $ 368.15
# Close 35577.11 Predicted: $ [14002.59]   Actual: $ 35577.11   Delta:$ [21574.522093]   Trade Rng: $ 463.91
# Close 35049.86 Predicted: $ [14010.16]   Actual: $ 35049.86   Delta:$ [21039.700863]   Trade Rng: $ 477.41
# Close 34441.72 Predicted: $ [13825.71]   Actual: $ 34441.72   Delta:$ [20616.010425]   Trade Rng: $ 307.99
# Close 33763.18 Predicted: $ [13368.43]   Actual: $ 33763.18   Delta:$ [20394.753562]   Trade Rng: $ 653.28
# Close 33377.42 Predicted: $ [12784.99]   Actual: $ 33377.42   Delta:$ [20592.432081]   Trade Rng: $ 389.96
# Close 33288.29 Predicted: $ [12588.83]   Actual: $ 33288.29   Delta:$ [20699.460891]   Trade Rng: $ 310.61
# Close 33464.17 Predicted: $ [12740.98]   Actual: $ 33464.17   Delta:$ [20723.193927]   Trade Rng: $ 606.21
# Close 33539.62 Predicted: $ [12781.3]   Actual: $ 33539.62   Delta:$ [20758.32049]   Trade Rng: $ 347.54
# Close 33681.24 Predicted: $ [12811.79]   Actual: $ 33681.24   Delta:$ [20869.449809]   Trade Rng: $ 160.49
# Close 33305.85 Predicted: $ [12444.97]   Actual: $ 33305.85   Delta:$ [20860.883814]   Trade Rng: $ 234.23
# Close 33254.03 Predicted: $ [12425.65]   Actual: $ 33254.03   Delta:$ [20828.382581]   Trade Rng: $ 130.9
# Close 33169.05 Predicted: $ [12183.48]   Actual: $ 33169.05   Delta:$ [20985.567069]   Trade Rng: $ 192.94
# Close 33140.47 Predicted: $ [12302.54]   Actual: $ 33140.47   Delta:$ [20837.931338]   Trade Rng: $ 223.49
# Close 33675.94 Predicted: $ [12466.49]   Actual: $ 33675.94   Delta:$ [21209.451696]   Trade Rng: $ 240.05
# Close 33219.39 Predicted: $ [11939.71]   Actual: $ 33219.39   Delta:$ [21279.680875]   Trade Rng: $ 356.74
# Close 32758.98 Predicted: $ [11939.99]   Actual: $ 32758.98   Delta:$ [20818.992453]   Trade Rng: $ 564.96
# Close 32970.55 Predicted: $ [11978.88]   Actual: $ 32970.55   Delta:$ [20991.668756]   Trade Rng: $ 249.35
# Close 32686.25 Predicted: $ [11454.55]   Actual: $ 32686.25   Delta:$ [21231.701254]   Trade Rng: $ 389.67
# Close 32926.35 Predicted: $ [11725.31]   Actual: $ 32926.35   Delta:$ [21201.045574]   Trade Rng: $ 605.51
# Close 32843.7 Predicted: $ [11353.72]   Actual: $ 32843.7   Delta:$ [21489.976892]   Trade Rng: $ 240.09
# Close 32791.8 Predicted: $ [11218.53]   Actual: $ 32791.8   Delta:$ [21573.274014]   Trade Rng: $ 371.89
# Close 32307.86 Predicted: $ [11061.75]   Actual: $ 32307.86   Delta:$ [21246.110758]   Trade Rng: $ 282.98
# Close 32858.31 Predicted: $ [11393.42]   Actual: $ 32858.31   Delta:$ [21464.891736]   Trade Rng: $ 398.97
# Close 33445.9 Predicted: $ [11412.32]   Actual: $ 33445.9   Delta:$ [22033.581537]   Trade Rng: $ 381.18
# Close 32775.82 Predicted: $ [11013.31]   Actual: $ 32775.82   Delta:$ [21762.509624]   Trade Rng: $ 538.04
# Close 33231.27 Predicted: $ [11869.66]   Actual: $ 33231.27   Delta:$ [21361.612309]   Trade Rng: $ 363.14
# Close 33431.51 Predicted: $ [12182.43]   Actual: $ 33431.51   Delta:$ [21249.082754]   Trade Rng: $ 301.34
# Close 33486.89 Predicted: $ [12369.16]   Actual: $ 33486.89   Delta:$ [21117.730243]   Trade Rng: $ 154.15
# Close 33321.22 Predicted: $ [12178.13]   Actual: $ 33321.22   Delta:$ [21143.087823]   Trade Rng: $ 325.82
# Close 33408.39 Predicted: $ [12669.52]   Actual: $ 33408.39   Delta:$ [20738.867335]   Trade Rng: $ 337.16
# Close 33447.67 Predicted: $ [12937.78]   Actual: $ 33447.67   Delta:$ [20509.88719]   Trade Rng: $ 247.81
# Close 33625.53 Predicted: $ [13362.18]   Actual: $ 33625.53   Delta:$ [20263.348736]   Trade Rng: $ 414.37
# Close 33451.83 Predicted: $ [13103.36]   Actual: $ 33451.83   Delta:$ [20348.469794]   Trade Rng: $ 195.29
# Close 33354.14 Predicted: $ [13226.75]   Actual: $ 33354.14   Delta:$ [20127.389742]   Trade Rng: $ 410.51
# Close 33388.03 Predicted: $ [13434.5]   Actual: $ 33388.03   Delta:$ [19953.529692]   Trade Rng: $ 205.59
# Close 33585.2 Predicted: $ [13714.1]   Actual: $ 33585.2   Delta:$ [19871.094671]   Trade Rng: $ 500.77
# Close 33424.41 Predicted: $ [13628.8]   Actual: $ 33424.41   Delta:$ [19795.610446]   Trade Rng: $ 335.96
# Close 33519.7 Predicted: $ [13689.91]   Actual: $ 33519.7   Delta:$ [19829.789148]   Trade Rng: $ 380.29
# Close 32695.93 Predicted: $ [13260.19]   Actual: $ 32695.93   Delta:$ [19435.738241]   Trade Rng: $ 459.59
# Close 32585.11 Predicted: $ [13245.22]   Actual: $ 32585.11   Delta:$ [19339.885275]   Trade Rng: $ 168.87
# Close 32568.11 Predicted: $ [12987.9]   Actual: $ 32568.11   Delta:$ [19580.204439]   Trade Rng: $ 414.03
# Close 32646.46 Predicted: $ [12777.44]   Actual: $ 32646.46   Delta:$ [19869.017287]   Trade Rng: $ 350.69
# Close 32166.48 Predicted: $ [12562.75]   Actual: $ 32166.48   Delta:$ [19603.72609]   Trade Rng: $ 530.51
# Close 32271.82 Predicted: $ [12884.34]   Actual: $ 32271.82   Delta:$ [19387.483931]   Trade Rng: $ 462.83
# Close 32708.48 Predicted: $ [12811.33]   Actual: $ 32708.48   Delta:$ [19897.1487]   Trade Rng: $ 340.18
# Close 31949.89 Predicted: $ [12361.74]   Actual: $ 31949.89   Delta:$ [19588.154361]   Trade Rng: $ 371.04
# Close 31601.65 Predicted: $ [12280.49]   Actual: $ 31601.65   Delta:$ [19321.158328]   Trade Rng: $ 208.77
# Close 30858.85 Predicted: $ [11565.48]   Actual: $ 30858.85   Delta:$ [19293.372763]   Trade Rng: $ 300.14
# Close 30696.96 Predicted: $ [11466.38]   Actual: $ 30696.96   Delta:$ [19230.583988]   Trade Rng: $ 421.01
# Close 30991.69 Predicted: $ [11304.93]   Actual: $ 30991.69   Delta:$ [19686.755175]   Trade Rng: $ 224.21
# Close 30601.78 Predicted: $ [10712.84]   Actual: $ 30601.78   Delta:$ [19888.934488]   Trade Rng: $ 394.15
# Close 31269.92 Predicted: $ [11144.68]   Actual: $ 31269.92   Delta:$ [20125.244093]   Trade Rng: $ 375.72
# Close 31062.35 Predicted: $ [10548.15]   Actual: $ 31062.35   Delta:$ [20514.199943]   Trade Rng: $ 271.34
# Close 30999.55 Predicted: $ [10747.56]   Actual: $ 30999.55   Delta:$ [20251.991054]   Trade Rng: $ 658.59
# Close 31259.36 Predicted: $ [11032.62]   Actual: $ 31259.36   Delta:$ [20226.736475]   Trade Rng: $ 203.15
# Close 31430.62 Predicted: $ [11306.18]   Actual: $ 31430.62   Delta:$ [20124.434819]   Trade Rng: $ 335.07
# Close 32042.25 Predicted: $ [11629.89]   Actual: $ 32042.25   Delta:$ [20412.363631]   Trade Rng: $ 270.25
# Close 32040.29 Predicted: $ [11458.62]   Actual: $ 32040.29   Delta:$ [20581.667539]   Trade Rng: $ 234.52
# Close 31659.03 Predicted: $ [11665.68]   Actual: $ 31659.03   Delta:$ [19993.350127]   Trade Rng: $ 359.38
# Close 32315.99 Predicted: $ [12232.11]   Actual: $ 32315.99   Delta:$ [20083.875369]   Trade Rng: $ 435.48
# Close 32494.66 Predicted: $ [11855.13]   Actual: $ 32494.66   Delta:$ [20639.528291]   Trade Rng: $ 284.05
# Close 31936.51 Predicted: $ [11556.02]   Actual: $ 31936.51   Delta:$ [20380.492848]   Trade Rng: $ 373.72
# Close 31746.53 Predicted: $ [11293.21]   Actual: $ 31746.53   Delta:$ [20453.322145]   Trade Rng: $ 232.98
# Close 30994.67 Predicted: $ [10546.08]   Actual: $ 30994.67   Delta:$ [20448.585413]   Trade Rng: $ 503.59
# Close 31075.36 Predicted: $ [10263.95]   Actual: $ 31075.36   Delta:$ [20811.407696]   Trade Rng: $ 232.29
# Close 30526.88 Predicted: $ [9490.27]   Actual: $ 30526.88   Delta:$ [21036.608423]   Trade Rng: $ 518.58
# Close 31237.94 Predicted: $ [9576.24]   Actual: $ 31237.94   Delta:$ [21661.702113]   Trade Rng: $ 343.18
# Close 31759.88 Predicted: $ [9472.97]   Actual: $ 31759.88   Delta:$ [22286.911934]   Trade Rng: $ 450.57
# Close 31857.62 Predicted: $ [9843.01]   Actual: $ 31857.62   Delta:$ [22014.609788]   Trade Rng: $ 641.7
# Close 31872.52 Predicted: $ [10294.82]   Actual: $ 31872.52   Delta:$ [21577.696918]   Trade Rng: $ 309.72
# Close 32371.9 Predicted: $ [10772.38]   Actual: $ 32371.9   Delta:$ [21599.515506]   Trade Rng: $ 490.03
# Close 32315.05 Predicted: $ [10744.52]   Actual: $ 32315.05   Delta:$ [21570.528468]   Trade Rng: $ 411.58
# Close 32678.62 Predicted: $ [11215.36]   Actual: $ 32678.62   Delta:$ [21463.255273]   Trade Rng: $ 328.36
# Close 32402.41 Predicted: $ [11137.03]   Actual: $ 32402.41   Delta:$ [21265.384064]   Trade Rng: $ 333.94
# Close 32571.03 Predicted: $ [11741.69]   Actual: $ 32571.03   Delta:$ [20829.340329]   Trade Rng: $ 381.14
# Close 33023.78 Predicted: $ [12149.13]   Actual: $ 33023.78   Delta:$ [20874.647209]   Trade Rng: $ 389.24
# Close 33242.59 Predicted: $ [12522.26]   Actual: $ 33242.59   Delta:$ [20720.331099]   Trade Rng: $ 278.49
# Close 33533.09 Predicted: $ [12853.66]   Actual: $ 33533.09   Delta:$ [20679.432978]   Trade Rng: $ 208.37
# Close 33168.1 Predicted: $ [12620.2]   Actual: $ 33168.1   Delta:$ [20547.898439]   Trade Rng: $ 242.85
# Close 32706.52 Predicted: $ [12491.24]   Actual: $ 32706.52   Delta:$ [20215.282348]   Trade Rng: $ 393.21
# Close 32776.37 Predicted: $ [12710.1]   Actual: $ 32776.37   Delta:$ [20066.267998]   Trade Rng: $ 255.79
# Close 32467.76 Predicted: $ [12348.86]   Actual: $ 32467.76   Delta:$ [20118.902523]   Trade Rng: $ 313.21
# Close 32606.84 Predicted: $ [12870.06]   Actual: $ 32606.84   Delta:$ [19736.778902]   Trade Rng: $ 354.45
# Close 32991.08 Predicted: $ [13335.44]   Actual: $ 32991.08   Delta:$ [19655.634075]   Trade Rng: $ 407.63
# Close 33241.02 Predicted: $ [13769.51]   Actual: $ 33241.02   Delta:$ [19471.51341]   Trade Rng: $ 336.1
# Close 33036.76 Predicted: $ [13618.79]   Actual: $ 33036.76   Delta:$ [19417.968527]   Trade Rng: $ 193.93
# Close 32939.18 Predicted: $ [13596.34]   Actual: $ 32939.18   Delta:$ [19342.84363]   Trade Rng: $ 252.44
# Close 32710.62 Predicted: $ [13341.91]   Actual: $ 32710.62   Delta:$ [19368.71124]   Trade Rng: $ 224.24
# Close 32619.34 Predicted: $ [13139.59]   Actual: $ 32619.34   Delta:$ [19479.747159]   Trade Rng: $ 346.02
# Close 32333.46 Predicted: $ [12739.81]   Actual: $ 32333.46   Delta:$ [19593.655639]   Trade Rng: $ 333.61
# Close 32226.97 Predicted: $ [12536.67]   Actual: $ 32226.97   Delta:$ [19690.30202]   Trade Rng: $ 256.89
# Close 32169.99 Predicted: $ [12249.91]   Actual: $ 32169.99   Delta:$ [19920.083209]   Trade Rng: $ 202.55
# Close 31624.28 Predicted: $ [11880.13]   Actual: $ 31624.28   Delta:$ [19744.147102]   Trade Rng: $ 323.55
# Close 32287.21 Predicted: $ [12243.69]   Actual: $ 32287.21   Delta:$ [20043.516828]   Trade Rng: $ 313.47
# Close 32010.26 Predicted: $ [11359.67]   Actual: $ 32010.26   Delta:$ [20650.593165]   Trade Rng: $ 234.77
# Close 31856.71 Predicted: $ [11092.52]   Actual: $ 31856.71   Delta:$ [20764.192107]   Trade Rng: $ 321.69
# Close 31565.64 Predicted: $ [10482.41]   Actual: $ 31565.64   Delta:$ [21083.227486]   Trade Rng: $ 212.34
# Close 31450.76 Predicted: $ [10404.15]   Actual: $ 31450.76   Delta:$ [21046.60608]   Trade Rng: $ 348.84
# Close 31626.0 Predicted: $ [10540.27]   Actual: $ 31626.0   Delta:$ [21085.728185]   Trade Rng: $ 369.64
# Close 31766.82 Predicted: $ [10676.21]   Actual: $ 31766.82   Delta:$ [21090.609294]   Trade Rng: $ 394.4
# Close 32238.89 Predicted: $ [11016.38]   Actual: $ 32238.89   Delta:$ [21222.513806]   Trade Rng: $ 230.46
# Close 32059.91 Predicted: $ [11017.]   Actual: $ 32059.91   Delta:$ [21042.913651]   Trade Rng: $ 186.41
# Close 32473.65 Predicted: $ [11426.02]   Actual: $ 32473.65   Delta:$ [21047.631954]   Trade Rng: $ 582.45
# Close 32204.33 Predicted: $ [10967.24]   Actual: $ 32204.33   Delta:$ [21237.087745]   Trade Rng: $ 488.89
# Close 32377.29 Predicted: $ [11470.48]   Actual: $ 32377.29   Delta:$ [20906.808377]   Trade Rng: $ 232.21
# Close 32254.56 Predicted: $ [11253.04]   Actual: $ 32254.56   Delta:$ [21001.521154]   Trade Rng: $ 301.29
# Close 32192.75 Predicted: $ [11351.44]   Actual: $ 32192.75   Delta:$ [20841.31165]   Trade Rng: $ 476.64
# Close 32159.28 Predicted: $ [11624.84]   Actual: $ 32159.28   Delta:$ [20534.443714]   Trade Rng: $ 360.35
# Close 32707.69 Predicted: $ [12047.67]   Actual: $ 32707.69   Delta:$ [20660.014644]   Trade Rng: $ 324.81
# Close 33476.58 Predicted: $ [12525.87]   Actual: $ 33476.58   Delta:$ [20950.711053]   Trade Rng: $ 530.29
# Close 33172.22 Predicted: $ [12195.61]   Actual: $ 33172.22   Delta:$ [20976.611437]   Trade Rng: $ 284.89
# Close 32759.23 Predicted: $ [12304.34]   Actual: $ 32759.23   Delta:$ [20454.889267]   Trade Rng: $ 376.15
# Close 32891.16 Predicted: $ [12556.58]   Actual: $ 32891.16   Delta:$ [20334.57866]   Trade Rng: $ 809.42
# Close 32668.34 Predicted: $ [11978.34]   Actual: $ 32668.34   Delta:$ [20689.999531]   Trade Rng: $ 434.9
# Close 32682.51 Predicted: $ [11988.57]   Actual: $ 32682.51   Delta:$ [20693.935041]   Trade Rng: $ 235.73
# Close 32700.94 Predicted: $ [11870.24]   Actual: $ 32700.94   Delta:$ [20830.699102]   Trade Rng: $ 205.62
# Close 32304.25 Predicted: $ [11495.54]   Actual: $ 32304.25   Delta:$ [20808.714068]   Trade Rng: $ 239.31
# Close 32490.52 Predicted: $ [11818.19]   Actual: $ 32490.52   Delta:$ [20672.33138]   Trade Rng: $ 381.49
# Close 32896.03 Predicted: $ [11763.88]   Actual: $ 32896.03   Delta:$ [21132.149671]   Trade Rng: $ 398.16
# Close 32493.89 Predicted: $ [11102.11]   Actual: $ 32493.89   Delta:$ [21391.781444]   Trade Rng: $ 225.0
# Close 32391.26 Predicted: $ [10974.11]   Actual: $ 32391.26   Delta:$ [21417.153517]   Trade Rng: $ 376.29
# Close 32419.33 Predicted: $ [10654.15]   Actual: $ 32419.33   Delta:$ [21765.18401]   Trade Rng: $ 555.26
# Close 31943.93 Predicted: $ [10106.72]   Actual: $ 31943.93   Delta:$ [21837.20735]   Trade Rng: $ 531.42
# Close 32203.57 Predicted: $ [10368.58]   Actual: $ 32203.57   Delta:$ [21834.992636]   Trade Rng: $ 520.32
# Close 32189.73 Predicted: $ [10385.18]   Actual: $ 32189.73   Delta:$ [21804.549842]   Trade Rng: $ 384.28
# Close 32388.42 Predicted: $ [10719.23]   Actual: $ 32388.42   Delta:$ [21669.185526]   Trade Rng: $ 493.35
# Close 32773.02 Predicted: $ [11054.54]   Actual: $ 32773.02   Delta:$ [21718.480359]   Trade Rng: $ 402.35
# Close 33338.7 Predicted: $ [11549.28]   Actual: $ 33338.7   Delta:$ [21789.419195]   Trade Rng: $ 441.73
# Close 33422.52 Predicted: $ [11831.22]   Actual: $ 33422.52   Delta:$ [21591.295069]   Trade Rng: $ 348.08
# Close 33753.33 Predicted: $ [12340.35]   Actual: $ 33753.33   Delta:$ [21412.983047]   Trade Rng: $ 237.67
# Close 33189.04 Predicted: $ [12132.89]   Actual: $ 33189.04   Delta:$ [21056.152282]   Trade Rng: $ 252.26
# Close 33234.14 Predicted: $ [12290.25]   Actual: $ 33234.14   Delta:$ [20943.894019]   Trade Rng: $ 314.12
# Close 33193.99 Predicted: $ [11851.1]   Actual: $ 33193.99   Delta:$ [21342.892949]   Trade Rng: $ 342.78
# Close 32538.33 Predicted: $ [11300.47]   Actual: $ 32538.33   Delta:$ [21237.864143]   Trade Rng: $ 551.12
# Close 32698.81 Predicted: $ [11774.5]   Actual: $ 32698.81   Delta:$ [20924.313883]   Trade Rng: $ 382.11
# Close 32781.54 Predicted: $ [11940.35]   Actual: $ 32781.54   Delta:$ [20841.185295]   Trade Rng: $ 492.01
# Close 33264.88 Predicted: $ [12470.61]   Actual: $ 33264.88   Delta:$ [20794.266961]   Trade Rng: $ 957.91
# Close 33575.14 Predicted: $ [12915.81]   Actual: $ 33575.14   Delta:$ [20659.329817]   Trade Rng: $ 409.27
# Close 33388.91 Predicted: $ [12918.43]   Actual: $ 33388.91   Delta:$ [20470.48059]   Trade Rng: $ 503.19
# Close 33370.42 Predicted: $ [13431.26]   Actual: $ 33370.42   Delta:$ [19939.165197]   Trade Rng: $ 385.72
# Close 33706.08 Predicted: $ [13860.42]   Actual: $ 33706.08   Delta:$ [19845.655988]   Trade Rng: $ 541.33
# Close 33485.49 Predicted: $ [13654.83]   Actual: $ 33485.49   Delta:$ [19830.660052]   Trade Rng: $ 585.83
# Close 33502.42 Predicted: $ [13734.4]   Actual: $ 33502.42   Delta:$ [19768.025799]   Trade Rng: $ 381.12
# Close 33018.65 Predicted: $ [13509.4]   Actual: $ 33018.65   Delta:$ [19509.24763]   Trade Rng: $ 461.57
# Close 32434.0 Predicted: $ [13435.55]   Actual: $ 32434.0   Delta:$ [18998.449509]   Trade Rng: $ 489.15
# Close 32265.17 Predicted: $ [13346.71]   Actual: $ 32265.17   Delta:$ [18918.458504]   Trade Rng: $ 237.14
# Close 31641.27 Predicted: $ [12964.41]   Actual: $ 31641.27   Delta:$ [18676.857779]   Trade Rng: $ 405.29
# Close 31913.74 Predicted: $ [13447.61]   Actual: $ 31913.74   Delta:$ [18466.126588]   Trade Rng: $ 615.5
# Close 32506.78 Predicted: $ [13692.3]   Actual: $ 32506.78   Delta:$ [18814.477623]   Trade Rng: $ 794.79
# Close 32217.43 Predicted: $ [13410.03]   Actual: $ 32217.43   Delta:$ [18807.398378]   Trade Rng: $ 600.6
# Close 31524.22 Predicted: $ [13469.38]   Actual: $ 31524.22   Delta:$ [18054.842076]   Trade Rng: $ 418.71
# Close 31148.01 Predicted: $ [13453.7]   Actual: $ 31148.01   Delta:$ [17694.312591]   Trade Rng: $ 298.53
# Close 30887.88 Predicted: $ [13474.95]   Actual: $ 30887.88   Delta:$ [17412.927357]   Trade Rng: $ 331.61
# Close 31328.16 Predicted: $ [14150.43]   Actual: $ 31328.16   Delta:$ [17177.733154]   Trade Rng: $ 356.8
# Close 31233.54 Predicted: $ [13661.36]   Actual: $ 31233.54   Delta:$ [17572.180157]   Trade Rng: $ 310.64
# Close 30916.31 Predicted: $ [13571.9]   Actual: $ 30916.31   Delta:$ [17344.413527]   Trade Rng: $ 396.43
# Close 30801.13 Predicted: $ [13667.29]   Actual: $ 30801.13   Delta:$ [17133.844007]   Trade Rng: $ 237.11
# Close 30682.68 Predicted: $ [13711.63]   Actual: $ 30682.68   Delta:$ [16971.047024]   Trade Rng: $ 331.84
# Close 30957.77 Predicted: $ [14373.52]   Actual: $ 30957.77   Delta:$ [16584.244783]   Trade Rng: $ 290.09
# Close 31086.82 Predicted: $ [14553.54]   Actual: $ 31086.82   Delta:$ [16533.281275]   Trade Rng: $ 523.8
# Close 30808.35 Predicted: $ [14456.08]   Actual: $ 30808.35   Delta:$ [16352.266616]   Trade Rng: $ 397.55
# Close 30573.93 Predicted: $ [14520.28]   Actual: $ 30573.93   Delta:$ [16053.646938]   Trade Rng: $ 245.41
# Close 30093.59 Predicted: $ [14357.96]   Actual: $ 30093.59   Delta:$ [15735.628653]   Trade Rng: $ 285.23
# Close 29842.99 Predicted: $ [14197.75]   Actual: $ 29842.99   Delta:$ [15645.235904]   Trade Rng: $ 202.88
# Close 29626.34 Predicted: $ [13792.21]   Actual: $ 29626.34   Delta:$ [15834.125394]   Trade Rng: $ 137.49
# Close 29388.3 Predicted: $ [13363.86]   Actual: $ 29388.3   Delta:$ [16024.436655]   Trade Rng: $ 153.5
# Close 29126.72 Predicted: $ [12896.03]   Actual: $ 29126.72   Delta:$ [16230.686052]   Trade Rng: $ 284.54
# Close 29122.18 Predicted: $ [13082.03]   Actual: $ 29122.18   Delta:$ [16040.150142]   Trade Rng: $ 136.88
# Close 29242.82 Predicted: $ [13360.46]   Actual: $ 29242.82   Delta:$ [15882.357566]   Trade Rng: $ 125.05
# Close 28949.88 Predicted: $ [13021.09]   Actual: $ 28949.88   Delta:$ [15928.7917]   Trade Rng: $ 241.73
# Close 29157.95 Predicted: $ [13798.74]   Actual: $ 29157.95   Delta:$ [15359.205459]   Trade Rng: $ 212.31
# Close 29123.18 Predicted: $ [13330.]   Actual: $ 29123.18   Delta:$ [15793.183885]   Trade Rng: $ 195.67
# Close 28856.44 Predicted: $ [12988.76]   Actual: $ 28856.44   Delta:$ [15867.67955]   Trade Rng: $ 129.06
# Close 28457.68 Predicted: $ [12435.78]   Actual: $ 28457.68   Delta:$ [16021.895312]   Trade Rng: $ 379.73
# Close 28416.47 Predicted: $ [12548.65]   Actual: $ 28416.47   Delta:$ [15867.820204]   Trade Rng: $ 218.06
# Close 28620.07 Predicted: $ [13275.42]   Actual: $ 28620.07   Delta:$ [15344.652669]   Trade Rng: $ 231.84
# Close 28593.52 Predicted: $ [12942.19]   Actual: $ 28593.52   Delta:$ [15651.330544]   Trade Rng: $ 196.92
# Close 28564.37 Predicted: $ [13238.23]   Actual: $ 28564.37   Delta:$ [15326.136388]   Trade Rng: $ 113.41
# Close 28657.57 Predicted: $ [13852.55]   Actual: $ 28657.57   Delta:$ [14805.016682]   Trade Rng: $ 250.57
# Close 28606.76 Predicted: $ [13964.8]   Actual: $ 28606.76   Delta:$ [14641.954821]   Trade Rng: $ 251.8
# Close 28658.83 Predicted: $ [14088.76]   Actual: $ 28658.83   Delta:$ [14570.066206]   Trade Rng: $ 145.68
# Close 28514.78 Predicted: $ [13788.68]   Actual: $ 28514.78   Delta:$ [14726.100888]   Trade Rng: $ 177.46
# Close 28493.47 Predicted: $ [13605.28]   Actual: $ 28493.47   Delta:$ [14888.195586]   Trade Rng: $ 184.77
# Close 28156.97 Predicted: $ [13149.08]   Actual: $ 28156.97   Delta:$ [15007.892008]   Trade Rng: $ 232.69
# Close 28082.7 Predicted: $ [12920.38]   Actual: $ 28082.7   Delta:$ [15162.323514]   Trade Rng: $ 211.86
# Close 27923.37 Predicted: $ [12384.17]   Actual: $ 27923.37   Delta:$ [15539.194902]   Trade Rng: $ 137.49
# Close 27633.66 Predicted: $ [11836.82]   Actual: $ 27633.66   Delta:$ [15796.843699]   Trade Rng: $ 213.57
# Close 27518.31 Predicted: $ [11635.25]   Actual: $ 27518.31   Delta:$ [15883.055619]   Trade Rng: $ 140.31
# Close 27472.63 Predicted: $ [11931.5]   Actual: $ 27472.63   Delta:$ [15541.128623]   Trade Rng: $ 134.9
# Close 27813.26 Predicted: $ [12608.66]   Actual: $ 27813.26   Delta:$ [15204.603663]   Trade Rng: $ 182.2
# Close 28287.42 Predicted: $ [13408.85]   Actual: $ 28287.42   Delta:$ [14878.569744]   Trade Rng: $ 344.8
# Close 28188.15 Predicted: $ [13004.07]   Actual: $ 28188.15   Delta:$ [15184.083224]   Trade Rng: $ 148.3
# Close 28041.48 Predicted: $ [12918.08]   Actual: $ 28041.48   Delta:$ [15123.398874]   Trade Rng: $ 138.2
# Close 27782.93 Predicted: $ [12660.2]   Actual: $ 27782.93   Delta:$ [15122.730839]   Trade Rng: $ 138.0
# Close 27883.78 Predicted: $ [12633.9]   Actual: $ 27883.78   Delta:$ [15249.878207]   Trade Rng: $ 245.83
# Close 27518.25 Predicted: $ [11803.62]   Actual: $ 27518.25   Delta:$ [15714.626694]   Trade Rng: $ 392.24
# Close 27476.87 Predicted: $ [11472.95]   Actual: $ 27476.87   Delta:$ [16003.924041]   Trade Rng: $ 170.69
# Close 27385.25 Predicted: $ [11197.9]   Actual: $ 27385.25   Delta:$ [16187.350902]   Trade Rng: $ 183.76
# Close 27419.61 Predicted: $ [11255.5]   Actual: $ 27419.61   Delta:$ [16164.106305]   Trade Rng: $ 139.85
# Close 27466.61 Predicted: $ [10801.13]   Actual: $ 27466.61   Delta:$ [16665.483053]   Trade Rng: $ 286.34
# Close 26945.67 Predicted: $ [10479.31]   Actual: $ 26945.67   Delta:$ [16466.359329]   Trade Rng: $ 253.71
# Close 27333.79 Predicted: $ [10580.66]   Actual: $ 27333.79   Delta:$ [16753.133705]   Trade Rng: $ 421.51
# Close 27010.61 Predicted: $ [10066.16]   Actual: $ 27010.61   Delta:$ [16944.45403]   Trade Rng: $ 284.44
# Close 27229.48 Predicted: $ [10728.68]   Actual: $ 27229.48   Delta:$ [16500.800185]   Trade Rng: $ 424.62
# Close 27222.04 Predicted: $ [11071.88]   Actual: $ 27222.04   Delta:$ [16150.160539]   Trade Rng: $ 318.95
# Close 27832.96 Predicted: $ [11925.27]   Actual: $ 27832.96   Delta:$ [15907.695628]   Trade Rng: $ 351.2
# Close 28143.97 Predicted: $ [12557.21]   Actual: $ 28143.97   Delta:$ [15586.75969]   Trade Rng: $ 275.44
# Close 28623.15 Predicted: $ [13838.53]   Actual: $ 28623.15   Delta:$ [14784.624583]   Trade Rng: $ 305.5
# Close 28444.19 Predicted: $ [13581.56]   Actual: $ 28444.19   Delta:$ [14862.624958]   Trade Rng: $ 175.91
# Close 28309.16 Predicted: $ [13658.9]   Actual: $ 28309.16   Delta:$ [14650.261605]   Trade Rng: $ 236.73
# Close 28237.78 Predicted: $ [13380.37]   Actual: $ 28237.78   Delta:$ [14857.407797]   Trade Rng: $ 195.68
# Close 27927.47 Predicted: $ [12947.35]   Actual: $ 27927.47   Delta:$ [14980.123195]   Trade Rng: $ 134.8
# Close 27498.87 Predicted: $ [12365.14]   Actual: $ 27498.87   Delta:$ [15133.730045]   Trade Rng: $ 305.87
# Close 27516.53 Predicted: $ [12240.99]   Actual: $ 27516.53   Delta:$ [15275.542129]   Trade Rng: $ 209.26
# Close 27445.56 Predicted: $ [11667.58]   Actual: $ 27445.56   Delta:$ [15777.984639]   Trade Rng: $ 225.39
# Close 27423.96 Predicted: $ [11416.22]   Actual: $ 27423.96   Delta:$ [16007.744898]   Trade Rng: $ 184.81
# Close 27453.48 Predicted: $ [11144.76]   Actual: $ 27453.48   Delta:$ [16308.721805]   Trade Rng: $ 163.48
# Close 27104.32 Predicted: $ [10524.7]   Actual: $ 27104.32   Delta:$ [16579.621873]   Trade Rng: $ 337.58
# Close 27473.1 Predicted: $ [11348.14]   Actual: $ 27473.1   Delta:$ [16124.956596]   Trade Rng: $ 254.45
# Close 27531.94 Predicted: $ [11085.81]   Actual: $ 27531.94   Delta:$ [16446.132255]   Trade Rng: $ 179.17
# Close 27513.13 Predicted: $ [11390.6]   Actual: $ 27513.13   Delta:$ [16122.525923]   Trade Rng: $ 105.46
# Close 27696.44 Predicted: $ [11890.93]   Actual: $ 27696.44   Delta:$ [15805.513293]   Trade Rng: $ 141.98
# Close 27501.86 Predicted: $ [11735.45]   Actual: $ 27501.86   Delta:$ [15766.406573]   Trade Rng: $ 130.54
# Close 27602.77 Predicted: $ [12375.76]   Actual: $ 27602.77   Delta:$ [15227.011913]   Trade Rng: $ 276.14
# Close 27427.32 Predicted: $ [12458.9]   Actual: $ 27427.32   Delta:$ [14968.416172]   Trade Rng: $ 168.64
# Close 27670.98 Predicted: $ [13293.83]   Actual: $ 27670.98   Delta:$ [14377.154311]   Trade Rng: $ 303.38
# Close 27584.35 Predicted: $ [12798.82]   Actual: $ 27584.35   Delta:$ [14785.53161]   Trade Rng: $ 204.69
# Close 27606.46 Predicted: $ [13447.82]   Actual: $ 27606.46   Delta:$ [14158.636534]   Trade Rng: $ 210.69
# Close 27685.47 Predicted: $ [14133.75]   Actual: $ 27685.47   Delta:$ [13551.716092]   Trade Rng: $ 260.92
# Close 27693.65 Predicted: $ [13918.19]   Actual: $ 27693.65   Delta:$ [13775.455729]   Trade Rng: $ 152.85
# Close 27509.46 Predicted: $ [13532.24]   Actual: $ 27509.46   Delta:$ [13977.221724]   Trade Rng: $ 164.75
# Close 27402.05 Predicted: $ [13234.79]   Actual: $ 27402.05   Delta:$ [14167.256435]   Trade Rng: $ 166.88
# Close 27346.88 Predicted: $ [12957.9]   Actual: $ 27346.88   Delta:$ [14388.985702]   Trade Rng: $ 134.01
# Close 27327.11 Predicted: $ [13269.13]   Actual: $ 27327.11   Delta:$ [14057.974801]   Trade Rng: $ 224.88
# Close 27433.4 Predicted: $ [13965.28]   Actual: $ 27433.4   Delta:$ [13468.121428]   Trade Rng: $ 191.95
# Close 27382.56 Predicted: $ [13677.25]   Actual: $ 27382.56   Delta:$ [13705.309354]   Trade Rng: $ 149.17
# Close 27362.75 Predicted: $ [13538.84]   Actual: $ 27362.75   Delta:$ [13823.914295]   Trade Rng: $ 125.76
# Close 27395.01 Predicted: $ [13334.99]   Actual: $ 27395.01   Delta:$ [14060.020633]   Trade Rng: $ 218.07
# Close 27299.19 Predicted: $ [12952.23]   Actual: $ 27299.19   Delta:$ [14346.958589]   Trade Rng: $ 298.02
# Close 26906.04 Predicted: $ [12516.93]   Actual: $ 26906.04   Delta:$ [14389.104276]   Trade Rng: $ 230.57
# Close 26553.53 Predicted: $ [12113.3]   Actual: $ 26553.53   Delta:$ [14440.231174]   Trade Rng: $ 149.52
# Close 26405.23 Predicted: $ [12172.43]   Actual: $ 26405.23   Delta:$ [14232.79581]   Trade Rng: $ 232.57
# Close 26791.12 Predicted: $ [12005.51]   Actual: $ 26791.12   Delta:$ [14785.608682]   Trade Rng: $ 223.9
# Close 26138.68 Predicted: $ [10865.92]   Actual: $ 26138.68   Delta:$ [15272.757623]   Trade Rng: $ 604.84
# Close 25822.32 Predicted: $ [11011.65]   Actual: $ 25822.32   Delta:$ [14810.672978]   Trade Rng: $ 303.39
# Close 26119.52 Predicted: $ [11486.85]   Actual: $ 26119.52   Delta:$ [14632.673822]   Trade Rng: $ 189.94
# Close 26449.82 Predicted: $ [11850.07]   Actual: $ 26449.82   Delta:$ [14599.753561]   Trade Rng: $ 318.37
# Close 26446.0 Predicted: $ [11085.01]   Actual: $ 26446.0   Delta:$ [15360.989801]   Trade Rng: $ 165.68
# Close 26175.56 Predicted: $ [10337.89]   Actual: $ 26175.56   Delta:$ [15837.670558]   Trade Rng: $ 147.94
# Close 25973.85 Predicted: $ [9572.29]   Actual: $ 25973.85   Delta:$ [16401.557222]   Trade Rng: $ 183.86
# Close 25820.8 Predicted: $ [8691.41]   Actual: $ 25820.8   Delta:$ [17129.385922]   Trade Rng: $ 314.45
# Close 25716.86 Predicted: $ [8461.09]   Actual: $ 25716.86   Delta:$ [17255.768594]   Trade Rng: $ 196.64
# Close 26094.5 Predicted: $ [8641.67]   Actual: $ 26094.5   Delta:$ [17452.82707]   Trade Rng: $ 178.79
# Close 26093.67 Predicted: $ [8705.63]   Actual: $ 26093.67   Delta:$ [17388.044617]   Trade Rng: $ 253.45
# Close 26340.5 Predicted: $ [9133.1]   Actual: $ 26340.5   Delta:$ [17207.400893]   Trade Rng: $ 172.78
# Close 26447.87 Predicted: $ [9267.97]   Actual: $ 26447.87   Delta:$ [17179.894934]   Trade Rng: $ 154.6
# Close 26405.87 Predicted: $ [8823.6]   Actual: $ 26405.87   Delta:$ [17582.26754]   Trade Rng: $ 172.62
# Close 26235.25 Predicted: $ [8700.92]   Actual: $ 26235.25   Delta:$ [17534.325052]   Trade Rng: $ 143.8
# Close 26507.87 Predicted: $ [8953.38]   Actual: $ 26507.87   Delta:$ [17554.48906]   Trade Rng: $ 185.6
# Close 26387.72 Predicted: $ [8959.61]   Actual: $ 26387.72   Delta:$ [17428.108829]   Trade Rng: $ 185.97
# Close 26568.03 Predicted: $ [9453.19]   Actual: $ 26568.03   Delta:$ [17114.84216]   Trade Rng: $ 346.48
# Close 27237.64 Predicted: $ [9823.37]   Actual: $ 27237.64   Delta:$ [17414.270393]   Trade Rng: $ 922.58
# Close 27527.12 Predicted: $ [10391.88]   Actual: $ 27527.12   Delta:$ [17135.234353]   Trade Rng: $ 183.8
# Close 28051.7 Predicted: $ [11527.46]   Actual: $ 28051.7   Delta:$ [16524.242093]   Trade Rng: $ 224.21
# Close 28156.21 Predicted: $ [11582.95]   Actual: $ 28156.21   Delta:$ [16573.26533]   Trade Rng: $ 175.63
# Close 27954.85 Predicted: $ [11327.77]   Actual: $ 27954.85   Delta:$ [16627.08324]   Trade Rng: $ 201.91
# Close 27842.33 Predicted: $ [11071.7]   Actual: $ 27842.33   Delta:$ [16770.630652]   Trade Rng: $ 209.07
# Close 27901.01 Predicted: $ [10769.74]   Actual: $ 27901.01   Delta:$ [17131.269687]   Trade Rng: $ 131.06
# Close 27574.43 Predicted: $ [9910.89]   Actual: $ 27574.43   Delta:$ [17663.541251]   Trade Rng: $ 318.84
# Close 27686.4 Predicted: $ [10355.31]   Actual: $ 27686.4   Delta:$ [17331.089355]   Trade Rng: $ 227.98
# Close 27885.87 Predicted: $ [10641.3]   Actual: $ 27885.87   Delta:$ [17244.567032]   Trade Rng: $ 139.47
# Close 27820.4 Predicted: $ [10279.32]   Actual: $ 27820.4   Delta:$ [17541.080762]   Trade Rng: $ 235.76
# Close 27777.9 Predicted: $ [10588.58]   Actual: $ 27777.9   Delta:$ [17189.319381]   Trade Rng: $ 153.25
# Close 28226.08 Predicted: $ [11126.3]   Actual: $ 28226.08   Delta:$ [17099.77915]   Trade Rng: $ 321.06
# Close 27968.99 Predicted: $ [10707.51]   Actual: $ 27968.99   Delta:$ [17261.484818]   Trade Rng: $ 197.38
# Close 28027.84 Predicted: $ [11489.83]   Actual: $ 28027.84   Delta:$ [16538.013164]   Trade Rng: $ 170.18
# Close 28162.83 Predicted: $ [12041.62]   Actual: $ 28162.83   Delta:$ [16121.206509]   Trade Rng: $ 155.93
# Close 28283.03 Predicted: $ [12573.1]   Actual: $ 28283.03   Delta:$ [15709.93016]   Trade Rng: $ 192.18
# Close 28383.09 Predicted: $ [12570.89]   Actual: $ 28383.09   Delta:$ [15812.204565]   Trade Rng: $ 136.28
# Close 28115.74 Predicted: $ [12054.65]   Actual: $ 28115.74   Delta:$ [16061.085682]   Trade Rng: $ 138.63
# Close 27944.79 Predicted: $ [11641.34]   Actual: $ 27944.79   Delta:$ [16303.445534]   Trade Rng: $ 165.19
# Close 27899.77 Predicted: $ [11715.31]   Actual: $ 27899.77   Delta:$ [16184.459937]   Trade Rng: $ 160.76
# Close 27930.57 Predicted: $ [12072.42]   Actual: $ 27930.57   Delta:$ [15858.151587]   Trade Rng: $ 167.66
# Close 28028.3 Predicted: $ [12126.71]   Actual: $ 28028.3   Delta:$ [15901.592618]   Trade Rng: $ 119.61
# Close 27990.17 Predicted: $ [11893.29]   Actual: $ 27990.17   Delta:$ [16096.884643]   Trade Rng: $ 326.1
# Close 27963.47 Predicted: $ [12219.54]   Actual: $ 27963.47   Delta:$ [15743.93112]   Trade Rng: $ 135.36
# Close 28263.57 Predicted: $ [12277.96]   Actual: $ 28263.57   Delta:$ [15985.611408]   Trade Rng: $ 341.57
# Close 27446.1 Predicted: $ [11589.61]   Actual: $ 27446.1   Delta:$ [15856.488829]   Trade Rng: $ 492.45
# Close 27716.43 Predicted: $ [12606.3]   Actual: $ 27716.43   Delta:$ [15110.131603]   Trade Rng: $ 114.76
# Close 27872.11 Predicted: $ [12169.14]   Actual: $ 27872.11   Delta:$ [15702.970408]   Trade Rng: $ 237.66
# Close 27527.64 Predicted: $ [11640.15]   Actual: $ 27527.64   Delta:$ [15887.491021]   Trade Rng: $ 238.63
# Close 27199.74 Predicted: $ [11780.28]   Actual: $ 27199.74   Delta:$ [15419.459575]   Trade Rng: $ 220.48
# Close 27663.39 Predicted: $ [12569.54]   Actual: $ 27663.39   Delta:$ [15093.853871]   Trade Rng: $ 357.28
# Close 27678.92 Predicted: $ [12269.39]   Actual: $ 27678.92   Delta:$ [15409.531222]   Trade Rng: $ 145.67
# Close 27587.46 Predicted: $ [11943.82]   Actual: $ 27587.46   Delta:$ [15643.639282]   Trade Rng: $ 156.79
# Close 27105.2 Predicted: $ [11796.]   Actual: $ 27105.2   Delta:$ [15309.195696]   Trade Rng: $ 210.0
# Close 27345.24 Predicted: $ [12642.4]   Actual: $ 27345.24   Delta:$ [14702.839248]   Trade Rng: $ 284.38
# Close 27431.84 Predicted: $ [12625.36]   Actual: $ 27431.84   Delta:$ [14806.484754]   Trade Rng: $ 119.47
# Close 27250.28 Predicted: $ [12207.67]   Actual: $ 27250.28   Delta:$ [15042.605869]   Trade Rng: $ 173.15
# Close 26974.9 Predicted: $ [11800.74]   Actual: $ 26974.9   Delta:$ [15174.163517]   Trade Rng: $ 264.62
# Close 26890.58 Predicted: $ [11588.77]   Actual: $ 26890.58   Delta:$ [15301.810009]   Trade Rng: $ 334.07
# Close 27006.96 Predicted: $ [11879.45]   Actual: $ 27006.96   Delta:$ [15127.50632]   Trade Rng: $ 116.0
# Close 27257.38 Predicted: $ [12187.39]   Actual: $ 27257.38   Delta:$ [15069.990407]   Trade Rng: $ 220.1
# Close 27156.14 Predicted: $ [11755.9]   Actual: $ 27156.14   Delta:$ [15400.238578]   Trade Rng: $ 178.59
# Close 26775.79 Predicted: $ [11443.21]   Actual: $ 26775.79   Delta:$ [15332.578223]   Trade Rng: $ 319.78
# Close 27090.76 Predicted: $ [11406.73]   Actual: $ 27090.76   Delta:$ [15684.031181]   Trade Rng: $ 165.79
# Close 26237.42 Predicted: $ [10243.22]   Actual: $ 26237.42   Delta:$ [15994.200964]   Trade Rng: $ 584.81
# Close 26396.83 Predicted: $ [10976.01]   Actual: $ 26396.83   Delta:$ [15420.81722]   Trade Rng: $ 170.89
# Close 26401.25 Predicted: $ [10939.39]   Actual: $ 26401.25   Delta:$ [15461.855498]   Trade Rng: $ 182.34
# Close 27116.11 Predicted: $ [11640.46]   Actual: $ 27116.11   Delta:$ [15475.645645]   Trade Rng: $ 390.06
# Close 27311.3 Predicted: $ [11216.64]   Actual: $ 27311.3   Delta:$ [16094.66576]   Trade Rng: $ 277.01
# Close 27120.53 Predicted: $ [10919.45]   Actual: $ 27120.53   Delta:$ [16201.077478]   Trade Rng: $ 261.21
# Close 26992.21 Predicted: $ [10539.22]   Actual: $ 26992.21   Delta:$ [16452.987254]   Trade Rng: $ 186.25
# Close 26215.79 Predicted: $ [9655.1]   Actual: $ 26215.79   Delta:$ [16560.690472]   Trade Rng: $ 360.92
# Close 25937.21 Predicted: $ [9459.59]   Actual: $ 25937.21   Delta:$ [16477.619994]   Trade Rng: $ 601.88
# Close 26422.05 Predicted: $ [9181.43]   Actual: $ 26422.05   Delta:$ [17240.61931]   Trade Rng: $ 468.06
# Close 26173.98 Predicted: $ [8563.88]   Actual: $ 26173.98   Delta:$ [17610.101507]   Trade Rng: $ 236.89
# Close 26571.87 Predicted: $ [8800.91]   Actual: $ 26571.87   Delta:$ [17770.955169]   Trade Rng: $ 577.96
# Close 26431.55 Predicted: $ [8638.89]   Actual: $ 26431.55   Delta:$ [17792.656577]   Trade Rng: $ 156.43
# Close 27153.83 Predicted: $ [9074.21]   Actual: $ 27153.83   Delta:$ [18079.61937]   Trade Rng: $ 354.84
# Close 27313.13 Predicted: $ [9232.9]   Actual: $ 27313.13   Delta:$ [18080.229426]   Trade Rng: $ 241.89
# Close 27688.42 Predicted: $ [9877.24]   Actual: $ 27688.42   Delta:$ [17811.181156]   Trade Rng: $ 169.84
# Close 27567.65 Predicted: $ [10029.86]   Actual: $ 27567.65   Delta:$ [17537.793757]   Trade Rng: $ 279.59
# Close 27875.91 Predicted: $ [10754.02]   Actual: $ 27875.91   Delta:$ [17121.891519]   Trade Rng: $ 129.31
# Close 27818.62 Predicted: $ [11037.87]   Actual: $ 27818.62   Delta:$ [16780.751906]   Trade Rng: $ 144.76
# Close 28614.63 Predicted: $ [12022.54]   Actual: $ 28614.63   Delta:$ [16592.090836]   Trade Rng: $ 346.28
# Mean Trading Range: $ 364.47
# Mean Delta (Actual vs Prediction): $ 20379.53

# %% [markdown]
# ## - Rescaled data (0..1) (Adjusted Prediction vs Target)

# %%
def analyze_pred_adj(y_test, y_pred, y_p_adj):
    elements = len(y_p_adj)
    # print(elements)
    tot_deltas = 0
    tot_tradrng = 0
    for i in range(-1, -elements, -1):
        actual = data_set['Adj Close'].iloc[i - 1]
        scalefac = data_set['Adj Close'].iloc[i - 1] / y_test[i - 1]
        # print("Scaling Factor", scalefac)
        predval = y_p_adj[i] * scalefac
        predval = y_pred[i - 1] if np.isinf(predval) else predval
        pred_delta = abs(predval - actual)
        tot_deltas += pred_delta
        trd_rng = abs(data_set['High'].iloc[i] - data_set['Low'].iloc[i])
        tot_tradrng += trd_rng
        print("Close", actual.round(2), "Predicted: $", predval.round(2), "  Actual: $", actual.round(2), "  Delta:$", pred_delta.round(6), "  Trade Rng: $", trd_rng.round(2))

    return pred_delta, tot_deltas, tot_tradrng

pred_delta, tot_deltas, tot_tradrng = analyze_pred_adj(y_test, y_pred, y_p_adj)

print("Mean Trading Range: $", round(tot_tradrng / elements, 2))
print("Mean Delta (Actual vs Prediction): $", round((tot_deltas[0] / elements), 2))
# Out:
# Close 34675.46 Predicted: $ [34216.92]   Actual: $ 34675.46   Delta:$ [458.539773]   Trade Rng: $ 2834.47
# Close 31458.42 Predicted: $ [28196.75]   Actual: $ 31458.42   Delta:$ [3261.672204]   Trade Rng: $ 2834.47
# Close 35909.7 Predicted: $ [40444.23]   Actual: $ 35909.7   Delta:$ [4534.533982]   Trade Rng: $ 4145.06
# Close 38126.33 Predicted: $ [38166.69]   Actual: $ 38126.33   Delta:$ [40.365109]   Trade Rng: $ 1591.37
# Close 39101.82 Predicted: $ [38589.96]   Actual: $ 39101.82   Delta:$ [511.856373]   Trade Rng: $ 1043.68
# Close 38525.95 Predicted: $ [37734.47]   Actual: $ 38525.95   Delta:$ [791.475768]   Trade Rng: $ 1233.99
# Close 38468.63 Predicted: $ [38427.72]   Actual: $ 38468.63   Delta:$ [40.909565]   Trade Rng: $ 454.46
# Close 37667.41 Predicted: $ [37369.79]   Actual: $ 37667.41   Delta:$ [297.622011]   Trade Rng: $ 709.69
# Close 37869.51 Predicted: $ [38626.53]   Actual: $ 37869.51   Delta:$ [757.021521]   Trade Rng: $ 494.77
# Close 39154.85 Predicted: $ [39473.69]   Actual: $ 39154.85   Delta:$ [318.835504]   Trade Rng: $ 732.21
# Close 39594.39 Predicted: $ [38768.7]   Actual: $ 39594.39   Delta:$ [825.689326]   Trade Rng: $ 546.77
# Close 39599.0 Predicted: $ [38951.34]   Actual: $ 39599.0   Delta:$ [647.663484]   Trade Rng: $ 407.98
# Close 40063.79 Predicted: $ [39520.68]   Actual: $ 40063.79   Delta:$ [543.104758]   Trade Rng: $ 453.81
# Close 40126.35 Predicted: $ [39639.91]   Actual: $ 40126.35   Delta:$ [486.440695]   Trade Rng: $ 388.32
# Close 41097.69 Predicted: $ [40844.]   Actual: $ 41097.69   Delta:$ [253.687304]   Trade Rng: $ 483.41
# Close 41275.08 Predicted: $ [40239.01]   Actual: $ 41275.08   Delta:$ [1036.070942]   Trade Rng: $ 411.73
# Close 41190.68 Predicted: $ [40813.74]   Actual: $ 41190.68   Delta:$ [376.938624]   Trade Rng: $ 299.42
# Close 42224.02 Predicted: $ [42286.33]   Actual: $ 42224.02   Delta:$ [62.315168]   Trade Rng: $ 566.47
# Close 41831.99 Predicted: $ [41121.73]   Actual: $ 41831.99   Delta:$ [710.259468]   Trade Rng: $ 324.31
# Close 41580.17 Predicted: $ [41146.37]   Actual: $ 41580.17   Delta:$ [433.80156]   Trade Rng: $ 458.78
# Close 40780.7 Predicted: $ [40527.11]   Actual: $ 40780.7   Delta:$ [253.592497]   Trade Rng: $ 826.91
# Close 40912.37 Predicted: $ [41459.84]   Actual: $ 40912.37   Delta:$ [547.464728]   Trade Rng: $ 331.54
# Close 40913.65 Predicted: $ [41000.65]   Actual: $ 40913.65   Delta:$ [87.003672]   Trade Rng: $ 353.24
# Close 40580.76 Predicted: $ [40492.32]   Actual: $ 40580.76   Delta:$ [88.444748]   Trade Rng: $ 367.08
# Close 40074.69 Predicted: $ [40016.51]   Actual: $ 40074.69   Delta:$ [58.179149]   Trade Rng: $ 521.36
# Close 39631.06 Predicted: $ [39743.37]   Actual: $ 39631.06   Delta:$ [112.310227]   Trade Rng: $ 655.86
# Close 39583.08 Predicted: $ [39733.98]   Actual: $ 39583.08   Delta:$ [150.901664]   Trade Rng: $ 405.59
# Close 39341.54 Predicted: $ [39551.99]   Actual: $ 39341.54   Delta:$ [210.453248]   Trade Rng: $ 297.97
# Close 39667.07 Predicted: $ [40280.25]   Actual: $ 39667.07   Delta:$ [613.181089]   Trade Rng: $ 245.73
# Close 39173.15 Predicted: $ [39223.18]   Actual: $ 39173.15   Delta:$ [50.031208]   Trade Rng: $ 555.07
# Close 38804.65 Predicted: $ [39015.85]   Actual: $ 38804.65   Delta:$ [211.198457]   Trade Rng: $ 457.0
# Close 38596.47 Predicted: $ [38844.42]   Actual: $ 38596.47   Delta:$ [247.955169]   Trade Rng: $ 489.4
# Close 38633.02 Predicted: $ [39006.69]   Actual: $ 38633.02   Delta:$ [373.669431]   Trade Rng: $ 263.55
# Close 38570.76 Predicted: $ [38657.69]   Actual: $ 38570.76   Delta:$ [86.929073]   Trade Rng: $ 374.54
# Close 38482.11 Predicted: $ [38186.24]   Actual: $ 38482.11   Delta:$ [295.866678]   Trade Rng: $ 344.56
# Close 38102.44 Predicted: $ [37918.5]   Actual: $ 38102.44   Delta:$ [183.941281]   Trade Rng: $ 186.13
# Close 38814.56 Predicted: $ [39078.18]   Actual: $ 38814.56   Delta:$ [263.625469]   Trade Rng: $ 492.5
# Close 38720.47 Predicted: $ [38218.92]   Actual: $ 38720.47   Delta:$ [501.546875]   Trade Rng: $ 470.95
# Close 38876.71 Predicted: $ [39010.96]   Actual: $ 38876.71   Delta:$ [134.247741]   Trade Rng: $ 562.65
# Close 39134.79 Predicted: $ [39512.98]   Actual: $ 39134.79   Delta:$ [378.187218]   Trade Rng: $ 136.63
# Close 39038.16 Predicted: $ [38979.42]   Actual: $ 39038.16   Delta:$ [58.743465]   Trade Rng: $ 261.78
# Close 38683.93 Predicted: $ [38572.79]   Actual: $ 38683.93   Delta:$ [111.143277]   Trade Rng: $ 391.76
# Close 38703.51 Predicted: $ [38684.01]   Actual: $ 38703.51   Delta:$ [19.506337]   Trade Rng: $ 186.42
# Close 38490.17 Predicted: $ [38435.32]   Actual: $ 38490.17   Delta:$ [54.851586]   Trade Rng: $ 318.43
# Close 38837.46 Predicted: $ [39298.88]   Actual: $ 38837.46   Delta:$ [461.42402]   Trade Rng: $ 312.43
# Close 38923.03 Predicted: $ [38942.43]   Actual: $ 38923.03   Delta:$ [19.396719]   Trade Rng: $ 303.27
# Close 38487.9 Predicted: $ [37995.46]   Actual: $ 38487.9   Delta:$ [492.440005]   Trade Rng: $ 297.55
# Close 38054.13 Predicted: $ [37750.14]   Actual: $ 38054.13   Delta:$ [303.988116]   Trade Rng: $ 439.32
# Close 38556.87 Predicted: $ [38764.8]   Actual: $ 38556.87   Delta:$ [207.929742]   Trade Rng: $ 521.03
# Close 38855.37 Predicted: $ [38722.58]   Actual: $ 38855.37   Delta:$ [132.795177]   Trade Rng: $ 617.75
# Close 38900.02 Predicted: $ [38483.96]   Actual: $ 38900.02   Delta:$ [416.061481]   Trade Rng: $ 225.84
# Close 38646.11 Predicted: $ [38389.43]   Actual: $ 38646.11   Delta:$ [256.674569]   Trade Rng: $ 232.09
# Close 39103.22 Predicted: $ [39039.79]   Actual: $ 39103.22   Delta:$ [63.431219]   Trade Rng: $ 373.12
# Close 38617.1 Predicted: $ [37997.55]   Actual: $ 38617.1   Delta:$ [619.555151]   Trade Rng: $ 512.04
# Close 38946.93 Predicted: $ [39303.18]   Actual: $ 38946.93   Delta:$ [356.254316]   Trade Rng: $ 262.05
# Close 39069.68 Predicted: $ [39081.94]   Actual: $ 39069.68   Delta:$ [12.258241]   Trade Rng: $ 403.87
# Close 38787.38 Predicted: $ [38927.46]   Actual: $ 38787.38   Delta:$ [140.083433]   Trade Rng: $ 733.46
# Close 38920.26 Predicted: $ [39309.54]   Actual: $ 38920.26   Delta:$ [389.277965]   Trade Rng: $ 302.93
# Close 38385.73 Predicted: $ [38404.07]   Actual: $ 38385.73   Delta:$ [18.340541]   Trade Rng: $ 436.05
# Close 38356.06 Predicted: $ [38681.29]   Actual: $ 38356.06   Delta:$ [325.232812]   Trade Rng: $ 480.99
# Close 38179.46 Predicted: $ [38224.28]   Actual: $ 38179.46   Delta:$ [44.823009]   Trade Rng: $ 392.97
# Close 38229.11 Predicted: $ [38292.68]   Actual: $ 38229.11   Delta:$ [63.571866]   Trade Rng: $ 303.82
# Close 38073.98 Predicted: $ [37859.63]   Actual: $ 38073.98   Delta:$ [214.353135]   Trade Rng: $ 614.97
# Close 38202.37 Predicted: $ [38557.64]   Actual: $ 38202.37   Delta:$ [355.266394]   Trade Rng: $ 357.57
# Close 38835.1 Predicted: $ [39154.34]   Actual: $ 38835.1   Delta:$ [319.234256]   Trade Rng: $ 589.5
# Close 38236.07 Predicted: $ [37858.46]   Actual: $ 38236.07   Delta:$ [377.605801]   Trade Rng: $ 321.17
# Close 38274.05 Predicted: $ [38756.26]   Actual: $ 38274.05   Delta:$ [482.208539]   Trade Rng: $ 397.41
# Close 38405.66 Predicted: $ [38734.32]   Actual: $ 38405.66   Delta:$ [328.661593]   Trade Rng: $ 397.1
# Close 37934.76 Predicted: $ [37923.14]   Actual: $ 37934.76   Delta:$ [11.626058]   Trade Rng: $ 426.06
# Close 37628.48 Predicted: $ [38422.38]   Actual: $ 37628.48   Delta:$ [793.898529]   Trade Rng: $ 546.84
# Close 38460.08 Predicted: $ [39286.78]   Actual: $ 38460.08   Delta:$ [826.702912]   Trade Rng: $ 525.3
# Close 37552.16 Predicted: $ [37303.07]   Actual: $ 37552.16   Delta:$ [249.091959]   Trade Rng: $ 602.61
# Close 37438.61 Predicted: $ [37697.35]   Actual: $ 37438.61   Delta:$ [258.741533]   Trade Rng: $ 420.51
# Close 37068.35 Predicted: $ [37384.67]   Actual: $ 37068.35   Delta:$ [316.31931]   Trade Rng: $ 459.17
# Close 38079.7 Predicted: $ [38537.88]   Actual: $ 38079.7   Delta:$ [458.183311]   Trade Rng: $ 1016.42
# Close 37961.8 Predicted: $ [37437.16]   Actual: $ 37961.8   Delta:$ [524.640048]   Trade Rng: $ 571.84
# Close 38471.2 Predicted: $ [38594.81]   Actual: $ 38471.2   Delta:$ [123.611668]   Trade Rng: $ 625.81
# Close 39232.8 Predicted: $ [39283.25]   Actual: $ 39232.8   Delta:$ [50.453822]   Trade Rng: $ 442.5
# Close 39523.55 Predicted: $ [39270.25]   Actual: $ 39523.55   Delta:$ [253.299476]   Trade Rng: $ 411.85
# Close 39442.63 Predicted: $ [39188.]   Actual: $ 39442.63   Delta:$ [254.627143]   Trade Rng: $ 317.09
# Close 39581.81 Predicted: $ [39807.57]   Actual: $ 39581.81   Delta:$ [225.762238]   Trade Rng: $ 408.17
# Close 39773.13 Predicted: $ [39905.41]   Actual: $ 39773.13   Delta:$ [132.283144]   Trade Rng: $ 198.22
# Close 39347.04 Predicted: $ [39006.18]   Actual: $ 39347.04   Delta:$ [340.856226]   Trade Rng: $ 297.0
# Close 38992.08 Predicted: $ [39260.96]   Actual: $ 38992.08   Delta:$ [268.878967]   Trade Rng: $ 420.36
# Close 39773.14 Predicted: $ [40133.28]   Actual: $ 39773.14   Delta:$ [360.136754]   Trade Rng: $ 500.52
# Close 39451.85 Predicted: $ [38911.59]   Actual: $ 39451.85   Delta:$ [540.262955]   Trade Rng: $ 469.88
# Close 39838.91 Predicted: $ [39709.87]   Actual: $ 39838.91   Delta:$ [129.036379]   Trade Rng: $ 408.86
# Close 39803.09 Predicted: $ [39517.94]   Actual: $ 39803.09   Delta:$ [285.145761]   Trade Rng: $ 443.18
# Close 40369.44 Predicted: $ [40221.36]   Actual: $ 40369.44   Delta:$ [148.080485]   Trade Rng: $ 990.77
# Close 40168.07 Predicted: $ [39766.82]   Actual: $ 40168.07   Delta:$ [401.245641]   Trade Rng: $ 253.6
# Close 40762.73 Predicted: $ [40840.49]   Actual: $ 40762.73   Delta:$ [77.762552]   Trade Rng: $ 427.96
# Close 40398.03 Predicted: $ [39809.32]   Actual: $ 40398.03   Delta:$ [588.707485]   Trade Rng: $ 527.15
# Close 40414.12 Predicted: $ [40602.68]   Actual: $ 40414.12   Delta:$ [188.554659]   Trade Rng: $ 248.68
# Close 40888.43 Predicted: $ [41447.01]   Actual: $ 40888.43   Delta:$ [558.576659]   Trade Rng: $ 423.06
# Close 40815.66 Predicted: $ [40747.6]   Actual: $ 40815.66   Delta:$ [68.059027]   Trade Rng: $ 373.61
# Close 40003.6 Predicted: $ [40045.69]   Actual: $ 40003.6   Delta:$ [42.085634]   Trade Rng: $ 371.13
# Close 39740.44 Predicted: $ [39766.06]   Actual: $ 39740.44   Delta:$ [25.616253]   Trade Rng: $ 596.1
# Close 38707.64 Predicted: $ [38168.87]   Actual: $ 38707.64   Delta:$ [538.766629]   Trade Rng: $ 833.64
# Close 38807.38 Predicted: $ [38867.93]   Actual: $ 38807.38   Delta:$ [60.551758]   Trade Rng: $ 288.74
# Close 38695.97 Predicted: $ [38069.66]   Actual: $ 38695.97   Delta:$ [626.307102]   Trade Rng: $ 440.16
# Close 38797.51 Predicted: $ [38123.91]   Actual: $ 38797.51   Delta:$ [673.601085]   Trade Rng: $ 695.23
# Close 38820.49 Predicted: $ [38330.]   Actual: $ 38820.49   Delta:$ [490.488938]   Trade Rng: $ 570.42
# Close 39688.94 Predicted: $ [39247.27]   Actual: $ 39688.94   Delta:$ [441.666869]   Trade Rng: $ 744.62
# Close 39598.71 Predicted: $ [38734.65]   Actual: $ 39598.71   Delta:$ [864.057555]   Trade Rng: $ 437.73
# Close 40090.78 Predicted: $ [40199.96]   Actual: $ 40090.78   Delta:$ [109.178668]   Trade Rng: $ 953.71
# Close 40097.63 Predicted: $ [39873.2]   Actual: $ 40097.63   Delta:$ [224.430004]   Trade Rng: $ 378.73
# Close 40109.23 Predicted: $ [39976.95]   Actual: $ 40109.23   Delta:$ [132.279755]   Trade Rng: $ 386.65
# Close 39910.82 Predicted: $ [39461.85]   Actual: $ 39910.82   Delta:$ [448.971689]   Trade Rng: $ 313.09
# Close 39166.19 Predicted: $ [38839.11]   Actual: $ 39166.19   Delta:$ [327.079557]   Trade Rng: $ 765.59
# Close 39208.03 Predicted: $ [39582.45]   Actual: $ 39208.03   Delta:$ [374.423536]   Trade Rng: $ 373.31
# Close 39239.52 Predicted: $ [39452.31]   Actual: $ 39239.52   Delta:$ [212.792068]   Trade Rng: $ 208.48
# Close 39233.71 Predicted: $ [39280.42]   Actual: $ 39233.71   Delta:$ [46.708155]   Trade Rng: $ 313.26
# Close 39098.68 Predicted: $ [38637.77]   Actual: $ 39098.68   Delta:$ [460.906107]   Trade Rng: $ 207.05
# Close 38262.16 Predicted: $ [37708.77]   Actual: $ 38262.16   Delta:$ [553.387537]   Trade Rng: $ 648.9
# Close 38363.61 Predicted: $ [38680.63]   Actual: $ 38363.61   Delta:$ [317.021316]   Trade Rng: $ 244.55
# Close 38470.38 Predicted: $ [38668.88]   Actual: $ 38470.38   Delta:$ [198.5038]   Trade Rng: $ 454.29
# Close 38487.24 Predicted: $ [38419.83]   Actual: $ 38487.24   Delta:$ [67.407347]   Trade Rng: $ 274.14
# Close 38157.94 Predicted: $ [37741.16]   Actual: $ 38157.94   Delta:$ [416.781886]   Trade Rng: $ 503.51
# Close 37703.32 Predicted: $ [37768.88]   Actual: $ 37703.32   Delta:$ [65.556258]   Trade Rng: $ 253.38
# Close 37963.97 Predicted: $ [38193.5]   Actual: $ 37963.97   Delta:$ [229.52852]   Trade Rng: $ 231.38
# Close 36897.42 Predicted: $ [36821.6]   Actual: $ 36897.42   Delta:$ [75.824465]   Trade Rng: $ 826.59
# Close 36863.28 Predicted: $ [37184.97]   Actual: $ 36863.28   Delta:$ [321.688614]   Trade Rng: $ 480.23
# Close 36119.92 Predicted: $ [35695.5]   Actual: $ 36119.92   Delta:$ [424.422096]   Trade Rng: $ 750.77
# Close 36160.66 Predicted: $ [36515.11]   Actual: $ 36160.66   Delta:$ [354.447654]   Trade Rng: $ 340.87
# Close 36354.16 Predicted: $ [36543.94]   Actual: $ 36354.16   Delta:$ [189.777899]   Trade Rng: $ 228.5
# Close 36158.02 Predicted: $ [35768.72]   Actual: $ 36158.02   Delta:$ [389.296153]   Trade Rng: $ 239.62
# Close 36011.46 Predicted: $ [35889.78]   Actual: $ 36011.46   Delta:$ [121.680701]   Trade Rng: $ 357.48
# Close 36286.71 Predicted: $ [36514.68]   Actual: $ 36286.71   Delta:$ [227.970857]   Trade Rng: $ 221.76
# Close 36065.86 Predicted: $ [35693.24]   Actual: $ 36065.86   Delta:$ [372.622146]   Trade Rng: $ 587.95
# Close 36026.94 Predicted: $ [35495.09]   Actual: $ 36026.94   Delta:$ [531.851282]   Trade Rng: $ 209.72
# Close 35751.07 Predicted: $ [35136.76]   Actual: $ 35751.07   Delta:$ [614.315072]   Trade Rng: $ 373.1
# Close 36236.47 Predicted: $ [36128.45]   Actual: $ 36236.47   Delta:$ [108.021616]   Trade Rng: $ 372.82
# Close 36226.48 Predicted: $ [35772.79]   Actual: $ 36226.48   Delta:$ [453.692046]   Trade Rng: $ 399.82
# Close 36517.57 Predicted: $ [36607.08]   Actual: $ 36517.57   Delta:$ [89.513526]   Trade Rng: $ 366.5
# Close 36546.95 Predicted: $ [36254.46]   Actual: $ 36546.95   Delta:$ [292.486271]   Trade Rng: $ 548.44
# Close 35963.27 Predicted: $ [35375.91]   Actual: $ 35963.27   Delta:$ [587.360407]   Trade Rng: $ 345.89
# Close 35466.17 Predicted: $ [35048.53]   Actual: $ 35466.17   Delta:$ [417.639515]   Trade Rng: $ 286.16
# Close 35477.75 Predicted: $ [35406.09]   Actual: $ 35477.75   Delta:$ [71.660408]   Trade Rng: $ 356.84
# Close 35619.18 Predicted: $ [35710.84]   Actual: $ 35619.18   Delta:$ [91.657761]   Trade Rng: $ 762.7
# Close 35901.79 Predicted: $ [35970.84]   Actual: $ 35901.79   Delta:$ [69.049919]   Trade Rng: $ 368.15
# Close 35577.11 Predicted: $ [35311.61]   Actual: $ 35577.11   Delta:$ [265.499805]   Trade Rng: $ 463.91
# Close 35049.86 Predicted: $ [35095.22]   Actual: $ 35049.86   Delta:$ [45.363626]   Trade Rng: $ 477.41
# Close 34441.72 Predicted: $ [34680.49]   Actual: $ 34441.72   Delta:$ [238.769588]   Trade Rng: $ 307.99
# Close 33763.18 Predicted: $ [33909.3]   Actual: $ 33763.18   Delta:$ [146.11612]   Trade Rng: $ 653.28
# Close 33377.42 Predicted: $ [33230.67]   Actual: $ 33377.42   Delta:$ [146.748678]   Trade Rng: $ 389.96
# Close 33288.29 Predicted: $ [33165.1]   Actual: $ 33288.29   Delta:$ [123.184116]   Trade Rng: $ 310.61
# Close 33464.17 Predicted: $ [33614.82]   Actual: $ 33464.17   Delta:$ [150.650982]   Trade Rng: $ 606.21
# Close 33539.62 Predicted: $ [33859.46]   Actual: $ 33539.62   Delta:$ [319.835908]   Trade Rng: $ 347.54
# Close 33681.24 Predicted: $ [34007.48]   Actual: $ 33681.24   Delta:$ [326.242241]   Trade Rng: $ 160.49
# Close 33305.85 Predicted: $ [33216.38]   Actual: $ 33305.85   Delta:$ [89.470057]   Trade Rng: $ 234.23
# Close 33254.03 Predicted: $ [33355.01]   Actual: $ 33254.03   Delta:$ [100.974419]   Trade Rng: $ 130.9
# Close 33169.05 Predicted: $ [33014.24]   Actual: $ 33169.05   Delta:$ [154.813896]   Trade Rng: $ 192.94
# Close 33140.47 Predicted: $ [33531.65]   Actual: $ 33140.47   Delta:$ [391.183956]   Trade Rng: $ 223.49
# Close 33675.94 Predicted: $ [34266.23]   Actual: $ 33675.94   Delta:$ [590.29202]   Trade Rng: $ 240.05
# Close 33219.39 Predicted: $ [32848.95]   Actual: $ 33219.39   Delta:$ [370.440689]   Trade Rng: $ 356.74
# Close 32758.98 Predicted: $ [32858.03]   Actual: $ 32758.98   Delta:$ [99.044542]   Trade Rng: $ 564.96
# Close 32970.55 Predicted: $ [33405.37]   Actual: $ 32970.55   Delta:$ [434.821998]   Trade Rng: $ 249.35
# Close 32686.25 Predicted: $ [32665.02]   Actual: $ 32686.25   Delta:$ [21.225102]   Trade Rng: $ 389.67
# Close 32926.35 Predicted: $ [33483.84]   Actual: $ 32926.35   Delta:$ [557.486154]   Trade Rng: $ 605.51
# Close 32843.7 Predicted: $ [32951.08]   Actual: $ 32843.7   Delta:$ [107.383098]   Trade Rng: $ 240.09
# Close 32791.8 Predicted: $ [32510.27]   Actual: $ 32791.8   Delta:$ [281.527758]   Trade Rng: $ 371.89
# Close 32307.86 Predicted: $ [32045.]   Actual: $ 32307.86   Delta:$ [262.863233]   Trade Rng: $ 282.98
# Close 32858.31 Predicted: $ [33522.18]   Actual: $ 32858.31   Delta:$ [663.873812]   Trade Rng: $ 398.97
# Close 33445.9 Predicted: $ [33192.68]   Actual: $ 33445.9   Delta:$ [253.22341]   Trade Rng: $ 381.18
# Close 32775.82 Predicted: $ [31538.23]   Actual: $ 32775.82   Delta:$ [1237.592265]   Trade Rng: $ 538.04
# Close 33231.27 Predicted: $ [33199.82]   Actual: $ 33231.27   Delta:$ [31.450952]   Trade Rng: $ 363.14
# Close 33431.51 Predicted: $ [33353.87]   Actual: $ 33431.51   Delta:$ [77.646222]   Trade Rng: $ 301.34
# Close 33486.89 Predicted: $ [33211.01]   Actual: $ 33486.89   Delta:$ [275.879227]   Trade Rng: $ 154.15
# Close 33321.22 Predicted: $ [32496.02]   Actual: $ 33321.22   Delta:$ [825.201174]   Trade Rng: $ 325.82
# Close 33408.39 Predicted: $ [32989.31]   Actual: $ 33408.39   Delta:$ [419.081339]   Trade Rng: $ 337.16
# Close 33447.67 Predicted: $ [33250.12]   Actual: $ 33447.67   Delta:$ [197.556366]   Trade Rng: $ 247.81
# Close 33625.53 Predicted: $ [33732.33]   Actual: $ 33625.53   Delta:$ [106.795199]   Trade Rng: $ 414.37
# Close 33451.83 Predicted: $ [32991.89]   Actual: $ 33451.83   Delta:$ [459.94254]   Trade Rng: $ 195.29
# Close 33354.14 Predicted: $ [32943.52]   Actual: $ 33354.14   Delta:$ [410.624053]   Trade Rng: $ 410.51
# Close 33388.03 Predicted: $ [33272.17]   Actual: $ 33388.03   Delta:$ [115.863831]   Trade Rng: $ 205.59
# Close 33585.2 Predicted: $ [33673.57]   Actual: $ 33585.2   Delta:$ [88.36736]   Trade Rng: $ 500.77
# Close 33424.41 Predicted: $ [33591.52]   Actual: $ 33424.41   Delta:$ [167.11084]   Trade Rng: $ 335.96
# Close 33519.7 Predicted: $ [33655.87]   Actual: $ 33519.7   Delta:$ [136.170015]   Trade Rng: $ 380.29
# Close 32695.93 Predicted: $ [32515.96]   Actual: $ 32695.93   Delta:$ [179.970563]   Trade Rng: $ 459.59
# Close 32585.11 Predicted: $ [32928.97]   Actual: $ 32585.11   Delta:$ [343.859326]   Trade Rng: $ 168.87
# Close 32568.11 Predicted: $ [32852.56]   Actual: $ 32568.11   Delta:$ [284.4495]   Trade Rng: $ 414.03
# Close 32646.46 Predicted: $ [32518.99]   Actual: $ 32646.46   Delta:$ [127.471792]   Trade Rng: $ 350.69
# Close 32166.48 Predicted: $ [31772.91]   Actual: $ 32166.48   Delta:$ [393.567404]   Trade Rng: $ 530.51
# Close 32271.82 Predicted: $ [32900.61]   Actual: $ 32271.82   Delta:$ [628.787542]   Trade Rng: $ 462.83
# Close 32708.48 Predicted: $ [33181.03]   Actual: $ 32708.48   Delta:$ [472.550809]   Trade Rng: $ 340.18
# Close 31949.89 Predicted: $ [31924.59]   Actual: $ 31949.89   Delta:$ [25.301045]   Trade Rng: $ 371.04
# Close 31601.65 Predicted: $ [31881.67]   Actual: $ 31601.65   Delta:$ [280.017368]   Trade Rng: $ 208.77
# Close 30858.85 Predicted: $ [30718.32]   Actual: $ 30858.85   Delta:$ [140.524902]   Trade Rng: $ 300.14
# Close 30696.96 Predicted: $ [31250.31]   Actual: $ 30696.96   Delta:$ [553.345441]   Trade Rng: $ 421.01
# Close 30991.69 Predicted: $ [31448.12]   Actual: $ 30991.69   Delta:$ [456.426704]   Trade Rng: $ 224.21
# Close 30601.78 Predicted: $ [30620.33]   Actual: $ 30601.78   Delta:$ [18.545827]   Trade Rng: $ 394.15
# Close 31269.92 Predicted: $ [31983.29]   Actual: $ 31269.92   Delta:$ [713.372383]   Trade Rng: $ 375.72
# Close 31062.35 Predicted: $ [30447.15]   Actual: $ 31062.35   Delta:$ [615.203445]   Trade Rng: $ 271.34
# Close 30999.55 Predicted: $ [30601.73]   Actual: $ 30999.55   Delta:$ [397.823286]   Trade Rng: $ 658.59
# Close 31259.36 Predicted: $ [31079.62]   Actual: $ 31259.36   Delta:$ [179.736257]   Trade Rng: $ 203.15
# Close 31430.62 Predicted: $ [31535.12]   Actual: $ 31430.62   Delta:$ [104.504368]   Trade Rng: $ 335.07
# Close 32042.25 Predicted: $ [32322.07]   Actual: $ 32042.25   Delta:$ [279.823476]   Trade Rng: $ 270.25
# Close 32040.29 Predicted: $ [31412.46]   Actual: $ 32040.29   Delta:$ [627.827112]   Trade Rng: $ 234.52
# Close 31659.03 Predicted: $ [31521.88]   Actual: $ 31659.03   Delta:$ [137.146822]   Trade Rng: $ 359.38
# Close 32315.99 Predicted: $ [33437.65]   Actual: $ 32315.99   Delta:$ [1121.655071]   Trade Rng: $ 435.48
# Close 32494.66 Predicted: $ [32931.35]   Actual: $ 32494.66   Delta:$ [436.686898]   Trade Rng: $ 284.05
# Close 31936.51 Predicted: $ [32350.2]   Actual: $ 31936.51   Delta:$ [413.686864]   Trade Rng: $ 373.72
# Close 31746.53 Predicted: $ [32349.79]   Actual: $ 31746.53   Delta:$ [603.260874]   Trade Rng: $ 232.98
# Close 30994.67 Predicted: $ [31384.93]   Actual: $ 30994.67   Delta:$ [390.256468]   Trade Rng: $ 503.59
# Close 31075.36 Predicted: $ [31633.59]   Actual: $ 31075.36   Delta:$ [558.229289]   Trade Rng: $ 232.29
# Close 30526.88 Predicted: $ [30417.2]   Actual: $ 30526.88   Delta:$ [109.677059]   Trade Rng: $ 518.58
# Close 31237.94 Predicted: $ [31743.81]   Actual: $ 31237.94   Delta:$ [505.869943]   Trade Rng: $ 343.18
# Close 31759.88 Predicted: $ [31389.42]   Actual: $ 31759.88   Delta:$ [370.45745]   Trade Rng: $ 450.57
# Close 31857.62 Predicted: $ [31166.79]   Actual: $ 31857.62   Delta:$ [690.82806]   Trade Rng: $ 641.7
# Close 31872.52 Predicted: $ [31576.57]   Actual: $ 31872.52   Delta:$ [295.953189]   Trade Rng: $ 309.72
# Close 32371.9 Predicted: $ [32365.51]   Actual: $ 32371.9   Delta:$ [6.387714]   Trade Rng: $ 490.03
# Close 32315.05 Predicted: $ [31871.82]   Actual: $ 32315.05   Delta:$ [443.226351]   Trade Rng: $ 411.58
# Close 32678.62 Predicted: $ [32341.45]   Actual: $ 32678.62   Delta:$ [337.171949]   Trade Rng: $ 328.36
# Close 32402.41 Predicted: $ [31375.42]   Actual: $ 32402.41   Delta:$ [1026.994452]   Trade Rng: $ 333.94
# Close 32571.03 Predicted: $ [32174.05]   Actual: $ 32571.03   Delta:$ [396.980606]   Trade Rng: $ 381.14
# Close 33023.78 Predicted: $ [32824.75]   Actual: $ 33023.78   Delta:$ [199.028137]   Trade Rng: $ 389.24
# Close 33242.59 Predicted: $ [33311.65]   Actual: $ 33242.59   Delta:$ [69.056398]   Trade Rng: $ 278.49
# Close 33533.09 Predicted: $ [33739.12]   Actual: $ 33533.09   Delta:$ [206.025705]   Trade Rng: $ 208.37
# Close 33168.1 Predicted: $ [32809.3]   Actual: $ 33168.1   Delta:$ [358.797188]   Trade Rng: $ 242.85
# Close 32706.52 Predicted: $ [32371.43]   Actual: $ 32706.52   Delta:$ [335.090011]   Trade Rng: $ 393.21
# Close 32776.37 Predicted: $ [32565.02]   Actual: $ 32776.37   Delta:$ [211.35515]   Trade Rng: $ 255.79
# Close 32467.76 Predicted: $ [31458.44]   Actual: $ 32467.76   Delta:$ [1009.319397]   Trade Rng: $ 313.21
# Close 32606.84 Predicted: $ [32144.57]   Actual: $ 32606.84   Delta:$ [462.271105]   Trade Rng: $ 354.45
# Close 32991.08 Predicted: $ [32960.47]   Actual: $ 32991.08   Delta:$ [30.612501]   Trade Rng: $ 407.63
# Close 33241.02 Predicted: $ [33469.52]   Actual: $ 33241.02   Delta:$ [228.502677]   Trade Rng: $ 336.1
# Close 33036.76 Predicted: $ [33131.27]   Actual: $ 33036.76   Delta:$ [94.505274]   Trade Rng: $ 193.93
# Close 32939.18 Predicted: $ [33254.7]   Actual: $ 32939.18   Delta:$ [315.519259]   Trade Rng: $ 252.44
# Close 32710.62 Predicted: $ [33065.27]   Actual: $ 32710.62   Delta:$ [354.652548]   Trade Rng: $ 224.24
# Close 32619.34 Predicted: $ [33042.48]   Actual: $ 32619.34   Delta:$ [423.141629]   Trade Rng: $ 346.02
# Close 32333.46 Predicted: $ [32575.87]   Actual: $ 32333.46   Delta:$ [242.41134]   Trade Rng: $ 333.61
# Close 32226.97 Predicted: $ [32626.35]   Actual: $ 32226.97   Delta:$ [399.378631]   Trade Rng: $ 256.89
# Close 32169.99 Predicted: $ [32252.05]   Actual: $ 32169.99   Delta:$ [82.060704]   Trade Rng: $ 202.55
# Close 31624.28 Predicted: $ [31968.49]   Actual: $ 31624.28   Delta:$ [344.215231]   Trade Rng: $ 323.55
# Close 32287.21 Predicted: $ [33778.76]   Actual: $ 32287.21   Delta:$ [1491.544422]   Trade Rng: $ 313.47
# Close 32010.26 Predicted: $ [32440.33]   Actual: $ 32010.26   Delta:$ [430.067319]   Trade Rng: $ 234.77
# Close 31856.71 Predicted: $ [32238.02]   Actual: $ 31856.71   Delta:$ [381.30909]   Trade Rng: $ 321.69
# Close 31565.64 Predicted: $ [31282.98]   Actual: $ 31565.64   Delta:$ [282.663609]   Trade Rng: $ 212.34
# Close 31450.76 Predicted: $ [31188.85]   Actual: $ 31450.76   Delta:$ [261.911279]   Trade Rng: $ 348.84
# Close 31626.0 Predicted: $ [31432.59]   Actual: $ 31626.0   Delta:$ [193.405113]   Trade Rng: $ 369.64
# Close 31766.82 Predicted: $ [31677.53]   Actual: $ 31766.82   Delta:$ [89.293311]   Trade Rng: $ 394.4
# Close 32238.89 Predicted: $ [32287.21]   Actual: $ 32238.89   Delta:$ [48.323944]   Trade Rng: $ 230.46
# Close 32059.91 Predicted: $ [31922.95]   Actual: $ 32059.91   Delta:$ [136.958979]   Trade Rng: $ 186.41
# Close 32473.65 Predicted: $ [32763.56]   Actual: $ 32473.65   Delta:$ [289.911178]   Trade Rng: $ 582.45
# Close 32204.33 Predicted: $ [31740.5]   Actual: $ 32204.33   Delta:$ [463.829043]   Trade Rng: $ 488.89
# Close 32377.29 Predicted: $ [32469.18]   Actual: $ 32377.29   Delta:$ [91.88664]   Trade Rng: $ 232.21
# Close 32254.56 Predicted: $ [31797.66]   Actual: $ 32254.56   Delta:$ [456.898227]   Trade Rng: $ 301.29
# Close 32192.75 Predicted: $ [31530.42]   Actual: $ 32192.75   Delta:$ [662.329655]   Trade Rng: $ 476.64
# Close 32159.28 Predicted: $ [31777.26]   Actual: $ 32159.28   Delta:$ [382.023033]   Trade Rng: $ 360.35
# Close 32707.69 Predicted: $ [33076.9]   Actual: $ 32707.69   Delta:$ [369.207054]   Trade Rng: $ 324.81
# Close 33476.58 Predicted: $ [33924.15]   Actual: $ 33476.58   Delta:$ [447.574258]   Trade Rng: $ 530.29
# Close 33172.22 Predicted: $ [32688.98]   Actual: $ 33172.22   Delta:$ [483.235508]   Trade Rng: $ 284.89
# Close 32759.23 Predicted: $ [32736.44]   Actual: $ 32759.23   Delta:$ [22.788592]   Trade Rng: $ 376.15
# Close 32891.16 Predicted: $ [33459.42]   Actual: $ 32891.16   Delta:$ [568.256668]   Trade Rng: $ 809.42
# Close 32668.34 Predicted: $ [32699.15]   Actual: $ 32668.34   Delta:$ [30.81485]   Trade Rng: $ 434.9
# Close 32682.51 Predicted: $ [32977.08]   Actual: $ 32682.51   Delta:$ [294.570847]   Trade Rng: $ 235.73
# Close 32700.94 Predicted: $ [32730.88]   Actual: $ 32700.94   Delta:$ [29.94268]   Trade Rng: $ 205.62
# Close 32304.25 Predicted: $ [32077.54]   Actual: $ 32304.25   Delta:$ [226.705398]   Trade Rng: $ 239.31
# Close 32490.52 Predicted: $ [33343.93]   Actual: $ 32490.52   Delta:$ [853.40922]   Trade Rng: $ 381.49
# Close 32896.03 Predicted: $ [33783.46]   Actual: $ 32896.03   Delta:$ [887.432688]   Trade Rng: $ 398.16
# Close 32493.89 Predicted: $ [32665.9]   Actual: $ 32493.89   Delta:$ [172.009685]   Trade Rng: $ 225.0
# Close 32391.26 Predicted: $ [32959.84]   Actual: $ 32391.26   Delta:$ [568.583153]   Trade Rng: $ 376.29
# Close 32419.33 Predicted: $ [32550.13]   Actual: $ 32419.33   Delta:$ [130.800681]   Trade Rng: $ 555.26
# Close 31943.93 Predicted: $ [31423.72]   Actual: $ 31943.93   Delta:$ [520.206949]   Trade Rng: $ 531.42
# Close 32203.57 Predicted: $ [32055.71]   Actual: $ 32203.57   Delta:$ [147.861855]   Trade Rng: $ 520.32
# Close 32189.73 Predicted: $ [31635.14]   Actual: $ 32189.73   Delta:$ [554.589991]   Trade Rng: $ 384.28
# Close 32388.42 Predicted: $ [31970.8]   Actual: $ 32388.42   Delta:$ [417.622717]   Trade Rng: $ 493.35
# Close 32773.02 Predicted: $ [32487.27]   Actual: $ 32773.02   Delta:$ [285.749057]   Trade Rng: $ 402.35
# Close 33338.7 Predicted: $ [33090.02]   Actual: $ 33338.7   Delta:$ [248.674528]   Trade Rng: $ 441.73
# Close 33422.52 Predicted: $ [33213.04]   Actual: $ 33422.52   Delta:$ [209.482427]   Trade Rng: $ 348.08
# Close 33753.33 Predicted: $ [33882.12]   Actual: $ 33753.33   Delta:$ [128.7921]   Trade Rng: $ 237.67
# Close 33189.04 Predicted: $ [33147.44]   Actual: $ 33189.04   Delta:$ [41.600798]   Trade Rng: $ 252.26
# Close 33234.14 Predicted: $ [33894.69]   Actual: $ 33234.14   Delta:$ [660.553047]   Trade Rng: $ 314.12
# Close 33193.99 Predicted: $ [33020.57]   Actual: $ 33193.99   Delta:$ [173.420234]   Trade Rng: $ 342.78
# Close 32538.33 Predicted: $ [31571.86]   Actual: $ 32538.33   Delta:$ [966.47447]   Trade Rng: $ 551.12
# Close 32698.81 Predicted: $ [32208.44]   Actual: $ 32698.81   Delta:$ [490.371839]   Trade Rng: $ 382.11
# Close 32781.54 Predicted: $ [32231.64]   Actual: $ 32781.54   Delta:$ [549.897176]   Trade Rng: $ 492.01
# Close 33264.88 Predicted: $ [33052.45]   Actual: $ 33264.88   Delta:$ [212.430787]   Trade Rng: $ 957.91
# Close 33575.14 Predicted: $ [33189.06]   Actual: $ 33575.14   Delta:$ [386.075889]   Trade Rng: $ 409.27
# Close 33388.91 Predicted: $ [32542.18]   Actual: $ 33388.91   Delta:$ [846.728115]   Trade Rng: $ 503.19
# Close 33370.42 Predicted: $ [33214.35]   Actual: $ 33370.42   Delta:$ [156.067595]   Trade Rng: $ 385.72
# Close 33706.08 Predicted: $ [33911.79]   Actual: $ 33706.08   Delta:$ [205.708258]   Trade Rng: $ 541.33
# Close 33485.49 Predicted: $ [33394.39]   Actual: $ 33485.49   Delta:$ [91.101827]   Trade Rng: $ 585.83
# Close 33502.42 Predicted: $ [33525.5]   Actual: $ 33502.42   Delta:$ [23.079431]   Trade Rng: $ 381.12
# Close 33018.65 Predicted: $ [32667.37]   Actual: $ 33018.65   Delta:$ [351.274354]   Trade Rng: $ 461.57
# Close 32434.0 Predicted: $ [32288.05]   Actual: $ 32434.0   Delta:$ [145.954673]   Trade Rng: $ 489.15
# Close 32265.17 Predicted: $ [31934.44]   Actual: $ 32265.17   Delta:$ [330.728827]   Trade Rng: $ 237.14
# Close 31641.27 Predicted: $ [30923.66]   Actual: $ 31641.27   Delta:$ [717.605189]   Trade Rng: $ 405.29
# Close 31913.74 Predicted: $ [32173.03]   Actual: $ 31913.74   Delta:$ [259.29292]   Trade Rng: $ 615.5
# Close 32506.78 Predicted: $ [32818.75]   Actual: $ 32506.78   Delta:$ [311.966544]   Trade Rng: $ 794.79
# Close 32217.43 Predicted: $ [31635.2]   Actual: $ 32217.43   Delta:$ [582.229163]   Trade Rng: $ 600.6
# Close 31524.22 Predicted: $ [30883.26]   Actual: $ 31524.22   Delta:$ [640.964722]   Trade Rng: $ 418.71
# Close 31148.01 Predicted: $ [30543.48]   Actual: $ 31148.01   Delta:$ [604.531169]   Trade Rng: $ 298.53
# Close 30887.88 Predicted: $ [30639.01]   Actual: $ 30887.88   Delta:$ [248.871997]   Trade Rng: $ 331.61
# Close 31328.16 Predicted: $ [31974.19]   Actual: $ 31328.16   Delta:$ [646.025382]   Trade Rng: $ 356.8
# Close 31233.54 Predicted: $ [31022.52]   Actual: $ 31233.54   Delta:$ [211.015403]   Trade Rng: $ 310.64
# Close 30916.31 Predicted: $ [30424.11]   Actual: $ 30916.31   Delta:$ [492.200978]   Trade Rng: $ 396.43
# Close 30801.13 Predicted: $ [30172.75]   Actual: $ 30801.13   Delta:$ [628.378938]   Trade Rng: $ 237.11
# Close 30682.68 Predicted: $ [29984.87]   Actual: $ 30682.68   Delta:$ [697.813456]   Trade Rng: $ 331.84
# Close 30957.77 Predicted: $ [30954.87]   Actual: $ 30957.77   Delta:$ [2.901888]   Trade Rng: $ 290.09
# Close 31086.82 Predicted: $ [31024.99]   Actual: $ 31086.82   Delta:$ [61.833577]   Trade Rng: $ 523.8
# Close 30808.35 Predicted: $ [30638.89]   Actual: $ 30808.35   Delta:$ [169.460564]   Trade Rng: $ 397.55
# Close 30573.93 Predicted: $ [30608.11]   Actual: $ 30573.93   Delta:$ [34.180386]   Trade Rng: $ 245.41
# Close 30093.59 Predicted: $ [30311.93]   Actual: $ 30093.59   Delta:$ [218.338635]   Trade Rng: $ 285.23
# Close 29842.99 Predicted: $ [30431.57]   Actual: $ 29842.99   Delta:$ [588.579965]   Trade Rng: $ 202.88
# Close 29626.34 Predicted: $ [30086.28]   Actual: $ 29626.34   Delta:$ [459.938932]   Trade Rng: $ 137.49
# Close 29388.3 Predicted: $ [29420.23]   Actual: $ 29388.3   Delta:$ [31.926648]   Trade Rng: $ 153.5
# Close 29126.72 Predicted: $ [28708.62]   Actual: $ 29126.72   Delta:$ [418.09808]   Trade Rng: $ 284.54
# Close 29122.18 Predicted: $ [28908.33]   Actual: $ 29122.18   Delta:$ [213.846542]   Trade Rng: $ 136.88
# Close 29242.82 Predicted: $ [29116.41]   Actual: $ 29242.82   Delta:$ [126.408869]   Trade Rng: $ 125.05
# Close 28949.88 Predicted: $ [28544.8]   Actual: $ 28949.88   Delta:$ [405.080956]   Trade Rng: $ 241.73
# Close 29157.95 Predicted: $ [30058.83]   Actual: $ 29157.95   Delta:$ [900.882932]   Trade Rng: $ 212.31
# Close 29123.18 Predicted: $ [29636.71]   Actual: $ 29123.18   Delta:$ [513.527229]   Trade Rng: $ 195.67
# Close 28856.44 Predicted: $ [28800.85]   Actual: $ 28856.44   Delta:$ [55.590141]   Trade Rng: $ 129.06
# Close 28457.68 Predicted: $ [27771.07]   Actual: $ 28457.68   Delta:$ [686.612988]   Trade Rng: $ 379.73
# Close 28416.47 Predicted: $ [27896.91]   Actual: $ 28416.47   Delta:$ [519.563862]   Trade Rng: $ 218.06
# Close 28620.07 Predicted: $ [28640.21]   Actual: $ 28620.07   Delta:$ [20.139179]   Trade Rng: $ 231.84
# Close 28593.52 Predicted: $ [27815.72]   Actual: $ 28593.52   Delta:$ [777.80185]   Trade Rng: $ 196.92
# Close 28564.37 Predicted: $ [27879.12]   Actual: $ 28564.37   Delta:$ [685.251113]   Trade Rng: $ 113.41
# Close 28657.57 Predicted: $ [28548.17]   Actual: $ 28657.57   Delta:$ [109.396031]   Trade Rng: $ 250.57
# Close 28606.76 Predicted: $ [28749.59]   Actual: $ 28606.76   Delta:$ [142.825848]   Trade Rng: $ 251.8
# Close 28658.83 Predicted: $ [29127.79]   Actual: $ 28658.83   Delta:$ [468.964662]   Trade Rng: $ 145.68
# Close 28514.78 Predicted: $ [29000.]   Actual: $ 28514.78   Delta:$ [485.217307]   Trade Rng: $ 177.46
# Close 28493.47 Predicted: $ [29072.17]   Actual: $ 28493.47   Delta:$ [578.697127]   Trade Rng: $ 184.77
# Close 28156.97 Predicted: $ [28689.84]   Actual: $ 28156.97   Delta:$ [532.874055]   Trade Rng: $ 232.69
# Close 28082.7 Predicted: $ [28916.67]   Actual: $ 28082.7   Delta:$ [833.969836]   Trade Rng: $ 211.86
# Close 27923.37 Predicted: $ [28268.11]   Actual: $ 27923.37   Delta:$ [344.745776]   Trade Rng: $ 137.49
# Close 27633.66 Predicted: $ [27263.22]   Actual: $ 27633.66   Delta:$ [370.441209]   Trade Rng: $ 213.57
# Close 27518.31 Predicted: $ [26490.93]   Actual: $ 27518.31   Delta:$ [1027.38234]   Trade Rng: $ 140.31
# Close 27472.63 Predicted: $ [26523.48]   Actual: $ 27472.63   Delta:$ [949.153074]   Trade Rng: $ 134.9
# Close 27813.26 Predicted: $ [27692.78]   Actual: $ 27813.26   Delta:$ [120.480223]   Trade Rng: $ 182.2
# Close 28287.42 Predicted: $ [28965.07]   Actual: $ 28287.42   Delta:$ [677.651057]   Trade Rng: $ 344.8
# Close 28188.15 Predicted: $ [28353.79]   Actual: $ 28188.15   Delta:$ [165.641521]   Trade Rng: $ 148.3
# Close 28041.48 Predicted: $ [28335.07]   Actual: $ 28041.48   Delta:$ [293.586393]   Trade Rng: $ 138.2
# Close 27782.93 Predicted: $ [28398.57]   Actual: $ 27782.93   Delta:$ [615.643962]   Trade Rng: $ 138.0
# Close 27883.78 Predicted: $ [28870.04]   Actual: $ 27883.78   Delta:$ [986.264515]   Trade Rng: $ 245.83
# Close 27518.25 Predicted: $ [27799.24]   Actual: $ 27518.25   Delta:$ [280.988484]   Trade Rng: $ 392.24
# Close 27476.87 Predicted: $ [27796.6]   Actual: $ 27476.87   Delta:$ [319.734042]   Trade Rng: $ 170.69
# Close 27385.25 Predicted: $ [27634.44]   Actual: $ 27385.25   Delta:$ [249.190312]   Trade Rng: $ 183.76
# Close 27419.61 Predicted: $ [28165.36]   Actual: $ 27419.61   Delta:$ [745.747647]   Trade Rng: $ 139.85
# Close 27466.61 Predicted: $ [27582.31]   Actual: $ 27466.61   Delta:$ [115.69981]   Trade Rng: $ 286.34
# Close 26945.67 Predicted: $ [26901.9]   Actual: $ 26945.67   Delta:$ [43.773901]   Trade Rng: $ 253.71
# Close 27333.79 Predicted: $ [27350.38]   Actual: $ 27333.79   Delta:$ [16.588475]   Trade Rng: $ 421.51
# Close 27010.61 Predicted: $ [25857.09]   Actual: $ 27010.61   Delta:$ [1153.520067]   Trade Rng: $ 284.44
# Close 27229.48 Predicted: $ [26240.42]   Actual: $ 27229.48   Delta:$ [989.063479]   Trade Rng: $ 424.62
# Close 27222.04 Predicted: $ [25887.52]   Actual: $ 27222.04   Delta:$ [1334.519384]   Trade Rng: $ 318.95
# Close 27832.96 Predicted: $ [26813.39]   Actual: $ 27832.96   Delta:$ [1019.571811]   Trade Rng: $ 351.2
# Close 28143.97 Predicted: $ [27362.68]   Actual: $ 28143.97   Delta:$ [781.287294]   Trade Rng: $ 275.44
# Close 28623.15 Predicted: $ [29018.39]   Actual: $ 28623.15   Delta:$ [395.238816]   Trade Rng: $ 305.5
# Close 28444.19 Predicted: $ [28507.81]   Actual: $ 28444.19   Delta:$ [63.621201]   Trade Rng: $ 175.91
# Close 28309.16 Predicted: $ [28914.11]   Actual: $ 28309.16   Delta:$ [604.9457]   Trade Rng: $ 236.73
# Close 28237.78 Predicted: $ [28913.68]   Actual: $ 28237.78   Delta:$ [675.897637]   Trade Rng: $ 195.68
# Close 27927.47 Predicted: $ [28397.88]   Actual: $ 27927.47   Delta:$ [470.4057]   Trade Rng: $ 134.8
# Close 27498.87 Predicted: $ [27880.5]   Actual: $ 27498.87   Delta:$ [381.627255]   Trade Rng: $ 305.87
# Close 27516.53 Predicted: $ [28323.47]   Actual: $ 27516.53   Delta:$ [806.940615]   Trade Rng: $ 209.26
# Close 27445.56 Predicted: $ [27986.11]   Actual: $ 27445.56   Delta:$ [540.547256]   Trade Rng: $ 225.39
# Close 27423.96 Predicted: $ [27900.99]   Actual: $ 27423.96   Delta:$ [477.028211]   Trade Rng: $ 184.81
# Close 27453.48 Predicted: $ [27441.14]   Actual: $ 27453.48   Delta:$ [12.343885]   Trade Rng: $ 163.48
# Close 27104.32 Predicted: $ [26355.64]   Actual: $ 27104.32   Delta:$ [748.677977]   Trade Rng: $ 337.58
# Close 27473.1 Predicted: $ [27633.42]   Actual: $ 27473.1   Delta:$ [160.32166]   Trade Rng: $ 254.45
# Close 27531.94 Predicted: $ [26934.25]   Actual: $ 27531.94   Delta:$ [597.688663]   Trade Rng: $ 179.17
# Close 27513.13 Predicted: $ [27011.81]   Actual: $ 27513.13   Delta:$ [501.322483]   Trade Rng: $ 105.46
# Close 27696.44 Predicted: $ [27357.64]   Actual: $ 27696.44   Delta:$ [338.796794]   Trade Rng: $ 141.98
# Close 27501.86 Predicted: $ [26537.71]   Actual: $ 27501.86   Delta:$ [964.147156]   Trade Rng: $ 130.54
# Close 27602.77 Predicted: $ [27063.97]   Actual: $ 27602.77   Delta:$ [538.79985]   Trade Rng: $ 276.14
# Close 27427.32 Predicted: $ [26765.49]   Actual: $ 27427.32   Delta:$ [661.828925]   Trade Rng: $ 168.64
# Close 27670.98 Predicted: $ [27571.76]   Actual: $ 27670.98   Delta:$ [99.224182]   Trade Rng: $ 303.38
# Close 27584.35 Predicted: $ [26528.8]   Actual: $ 27584.35   Delta:$ [1055.546597]   Trade Rng: $ 204.69
# Close 27606.46 Predicted: $ [27210.4]   Actual: $ 27606.46   Delta:$ [396.065901]   Trade Rng: $ 210.69
# Close 27685.47 Predicted: $ [28279.5]   Actual: $ 27685.47   Delta:$ [594.027016]   Trade Rng: $ 260.92
# Close 27693.65 Predicted: $ [28272.68]   Actual: $ 27693.65   Delta:$ [579.033458]   Trade Rng: $ 152.85
# Close 27509.46 Predicted: $ [27757.5]   Actual: $ 27509.46   Delta:$ [248.03863]   Trade Rng: $ 164.75
# Close 27402.05 Predicted: $ [27189.46]   Actual: $ 27402.05   Delta:$ [212.588426]   Trade Rng: $ 166.88
# Close 27346.88 Predicted: $ [26625.79]   Actual: $ 27346.88   Delta:$ [721.087773]   Trade Rng: $ 134.01
# Close 27327.11 Predicted: $ [26913.99]   Actual: $ 27327.11   Delta:$ [413.124341]   Trade Rng: $ 224.88
# Close 27433.4 Predicted: $ [27902.5]   Actual: $ 27433.4   Delta:$ [469.100435]   Trade Rng: $ 191.95
# Close 27382.56 Predicted: $ [27738.05]   Actual: $ 27382.56   Delta:$ [355.487355]   Trade Rng: $ 149.17
# Close 27362.75 Predicted: $ [27917.03]   Actual: $ 27362.75   Delta:$ [554.276545]   Trade Rng: $ 125.76
# Close 27395.01 Predicted: $ [28124.34]   Actual: $ 27395.01   Delta:$ [729.326703]   Trade Rng: $ 218.07
# Close 27299.19 Predicted: $ [27723.89]   Actual: $ 27299.19   Delta:$ [424.700272]   Trade Rng: $ 298.02
# Close 26906.04 Predicted: $ [27021.91]   Actual: $ 26906.04   Delta:$ [115.866227]   Trade Rng: $ 230.57
# Close 26553.53 Predicted: $ [26630.79]   Actual: $ 26553.53   Delta:$ [77.262124]   Trade Rng: $ 149.52
# Close 26405.23 Predicted: $ [27398.6]   Actual: $ 26405.23   Delta:$ [993.365568]   Trade Rng: $ 232.57
# Close 26791.12 Predicted: $ [27605.07]   Actual: $ 26791.12   Delta:$ [813.954151]   Trade Rng: $ 223.9
# Close 26138.68 Predicted: $ [25100.38]   Actual: $ 26138.68   Delta:$ [1038.297507]   Trade Rng: $ 604.84
# Close 25822.32 Predicted: $ [25339.56]   Actual: $ 25822.32   Delta:$ [482.761594]   Trade Rng: $ 303.39
# Close 26119.52 Predicted: $ [26843.73]   Actual: $ 26119.52   Delta:$ [724.210162]   Trade Rng: $ 189.94
# Close 26449.82 Predicted: $ [28164.16]   Actual: $ 26449.82   Delta:$ [1714.341414]   Trade Rng: $ 318.37
# Close 26446.0 Predicted: $ [27821.67]   Actual: $ 26446.0   Delta:$ [1375.674818]   Trade Rng: $ 165.68
# Close 26175.56 Predicted: $ [27279.04]   Actual: $ 26175.56   Delta:$ [1103.474527]   Trade Rng: $ 147.94
# Close 25973.85 Predicted: $ [26746.38]   Actual: $ 25973.85   Delta:$ [772.525523]   Trade Rng: $ 183.86
# Close 25820.8 Predicted: $ [25712.73]   Actual: $ 25820.8   Delta:$ [108.072604]   Trade Rng: $ 314.45
# Close 25716.86 Predicted: $ [25521.22]   Actual: $ 25716.86   Delta:$ [195.640411]   Trade Rng: $ 196.64
# Close 26094.5 Predicted: $ [25995.88]   Actual: $ 26094.5   Delta:$ [98.623263]   Trade Rng: $ 178.79
# Close 26093.67 Predicted: $ [25861.22]   Actual: $ 26093.67   Delta:$ [232.450139]   Trade Rng: $ 253.45
# Close 26340.5 Predicted: $ [26781.56]   Actual: $ 26340.5   Delta:$ [441.064114]   Trade Rng: $ 172.78
# Close 26447.87 Predicted: $ [26985.13]   Actual: $ 26447.87   Delta:$ [537.259684]   Trade Rng: $ 154.6
# Close 26405.87 Predicted: $ [26203.83]   Actual: $ 26405.87   Delta:$ [202.035312]   Trade Rng: $ 172.62
# Close 26235.25 Predicted: $ [25871.63]   Actual: $ 26235.25   Delta:$ [363.618174]   Trade Rng: $ 143.8
# Close 26507.87 Predicted: $ [26254.39]   Actual: $ 26507.87   Delta:$ [253.47541]   Trade Rng: $ 185.6
# Close 26387.72 Predicted: $ [25485.46]   Actual: $ 26387.72   Delta:$ [902.264452]   Trade Rng: $ 185.97
# Close 26568.03 Predicted: $ [25981.13]   Actual: $ 26568.03   Delta:$ [586.90386]   Trade Rng: $ 346.48
# Close 27237.64 Predicted: $ [26457.8]   Actual: $ 27237.64   Delta:$ [779.84377]   Trade Rng: $ 922.58
# Close 27527.12 Predicted: $ [26862.74]   Actual: $ 27527.12   Delta:$ [664.374735]   Trade Rng: $ 183.8
# Close 28051.7 Predicted: $ [28606.53]   Actual: $ 28051.7   Delta:$ [554.835128]   Trade Rng: $ 224.21
# Close 28156.21 Predicted: $ [28641.76]   Actual: $ 28156.21   Delta:$ [485.547672]   Trade Rng: $ 175.63
# Close 27954.85 Predicted: $ [28474.22]   Actual: $ 27954.85   Delta:$ [519.369106]   Trade Rng: $ 201.91
# Close 27842.33 Predicted: $ [28552.36]   Actual: $ 27842.33   Delta:$ [710.028863]   Trade Rng: $ 209.07
# Close 27901.01 Predicted: $ [28249.5]   Actual: $ 27901.01   Delta:$ [348.486605]   Trade Rng: $ 131.06
# Close 27574.43 Predicted: $ [26908.53]   Actual: $ 27574.43   Delta:$ [665.89621]   Trade Rng: $ 318.84
# Close 27686.4 Predicted: $ [27717.79]   Actual: $ 27686.4   Delta:$ [31.391455]   Trade Rng: $ 227.98
# Close 27885.87 Predicted: $ [28011.36]   Actual: $ 27885.87   Delta:$ [125.490633]   Trade Rng: $ 139.47
# Close 27820.4 Predicted: $ [27189.79]   Actual: $ 27820.4   Delta:$ [630.607988]   Trade Rng: $ 235.76
# Close 27777.9 Predicted: $ [27493.83]   Actual: $ 27777.9   Delta:$ [284.07211]   Trade Rng: $ 153.25
# Close 28226.08 Predicted: $ [28077.71]   Actual: $ 28226.08   Delta:$ [148.370631]   Trade Rng: $ 321.06
# Close 27968.99 Predicted: $ [26557.35]   Actual: $ 27968.99   Delta:$ [1411.638592]   Trade Rng: $ 197.38
# Close 28027.84 Predicted: $ [27233.59]   Actual: $ 28027.84   Delta:$ [794.24805]   Trade Rng: $ 170.18
# Close 28162.83 Predicted: $ [27895.05]   Actual: $ 28162.83   Delta:$ [267.778453]   Trade Rng: $ 155.93
# Close 28283.03 Predicted: $ [28862.64]   Actual: $ 28283.03   Delta:$ [579.611248]   Trade Rng: $ 192.18
# Close 28383.09 Predicted: $ [29055.58]   Actual: $ 28383.09   Delta:$ [672.491919]   Trade Rng: $ 136.28
# Close 28115.74 Predicted: $ [28139.58]   Actual: $ 28115.74   Delta:$ [23.836074]   Trade Rng: $ 138.63
# Close 27944.79 Predicted: $ [27518.1]   Actual: $ 27944.79   Delta:$ [426.69351]   Trade Rng: $ 165.19
# Close 27899.77 Predicted: $ [27570.59]   Actual: $ 27899.77   Delta:$ [329.184348]   Trade Rng: $ 160.76
# Close 27930.57 Predicted: $ [27987.78]   Actual: $ 27930.57   Delta:$ [57.214319]   Trade Rng: $ 167.66
# Close 28028.3 Predicted: $ [28098.3]   Actual: $ 28028.3   Delta:$ [69.996568]   Trade Rng: $ 119.61
# Close 27990.17 Predicted: $ [27701.17]   Actual: $ 27990.17   Delta:$ [288.996684]   Trade Rng: $ 326.1
# Close 27963.47 Predicted: $ [28237.27]   Actual: $ 27963.47   Delta:$ [273.800259]   Trade Rng: $ 135.36
# Close 28263.57 Predicted: $ [28164.27]   Actual: $ 28263.57   Delta:$ [99.303992]   Trade Rng: $ 341.57
# Close 27446.1 Predicted: $ [26607.28]   Actual: $ 27446.1   Delta:$ [838.822418]   Trade Rng: $ 492.45
# Close 27716.43 Predicted: $ [28649.31]   Actual: $ 27716.43   Delta:$ [932.879531]   Trade Rng: $ 114.76
# Close 27872.11 Predicted: $ [28025.74]   Actual: $ 27872.11   Delta:$ [153.630895]   Trade Rng: $ 237.66
# Close 27527.64 Predicted: $ [26623.44]   Actual: $ 27527.64   Delta:$ [904.201667]   Trade Rng: $ 238.63
# Close 27199.74 Predicted: $ [26794.36]   Actual: $ 27199.74   Delta:$ [405.376105]   Trade Rng: $ 220.48
# Close 27663.39 Predicted: $ [28412.1]   Actual: $ 27663.39   Delta:$ [748.706119]   Trade Rng: $ 357.28
# Close 27678.92 Predicted: $ [27835.63]   Actual: $ 27678.92   Delta:$ [156.707264]   Trade Rng: $ 145.67
# Close 27587.46 Predicted: $ [26896.29]   Actual: $ 27587.46   Delta:$ [691.175317]   Trade Rng: $ 156.79
# Close 27105.2 Predicted: $ [26289.11]   Actual: $ 27105.2   Delta:$ [816.088144]   Trade Rng: $ 210.0
# Close 27345.24 Predicted: $ [27906.3]   Actual: $ 27345.24   Delta:$ [561.054971]   Trade Rng: $ 284.38
# Close 27431.84 Predicted: $ [28133.59]   Actual: $ 27431.84   Delta:$ [701.745654]   Trade Rng: $ 119.47
# Close 27250.28 Predicted: $ [27483.82]   Actual: $ 27250.28   Delta:$ [233.545159]   Trade Rng: $ 173.15
# Close 26974.9 Predicted: $ [26742.79]   Actual: $ 26974.9   Delta:$ [232.114274]   Trade Rng: $ 264.62
# Close 26890.58 Predicted: $ [26535.32]   Actual: $ 26890.58   Delta:$ [355.258501]   Trade Rng: $ 334.07
# Close 27006.96 Predicted: $ [27236.62]   Actual: $ 27006.96   Delta:$ [229.663211]   Trade Rng: $ 116.0
# Close 27257.38 Predicted: $ [28047.67]   Actual: $ 27257.38   Delta:$ [790.291443]   Trade Rng: $ 220.1
# Close 27156.14 Predicted: $ [27498.18]   Actual: $ 27156.14   Delta:$ [342.035754]   Trade Rng: $ 178.59
# Close 26775.79 Predicted: $ [27354.49]   Actual: $ 26775.79   Delta:$ [578.700953]   Trade Rng: $ 319.78
# Close 27090.76 Predicted: $ [27501.85]   Actual: $ 27090.76   Delta:$ [411.085352]   Trade Rng: $ 165.79
# Close 26237.42 Predicted: $ [25027.09]   Actual: $ 26237.42   Delta:$ [1210.333767]   Trade Rng: $ 584.81
# Close 26396.83 Predicted: $ [26200.4]   Actual: $ 26396.83   Delta:$ [196.434723]   Trade Rng: $ 170.89
# Close 26401.25 Predicted: $ [26449.96]   Actual: $ 26401.25   Delta:$ [48.712699]   Trade Rng: $ 182.34
# Close 27116.11 Predicted: $ [28416.03]   Actual: $ 27116.11   Delta:$ [1299.922798]   Trade Rng: $ 390.06
# Close 27311.3 Predicted: $ [28078.49]   Actual: $ 27311.3   Delta:$ [767.186837]   Trade Rng: $ 277.01
# Close 27120.53 Predicted: $ [27943.47]   Actual: $ 27120.53   Delta:$ [822.939137]   Trade Rng: $ 261.21
# Close 26992.21 Predicted: $ [27628.89]   Actual: $ 26992.21   Delta:$ [636.682176]   Trade Rng: $ 186.25
# Close 26215.79 Predicted: $ [26065.82]   Actual: $ 26215.79   Delta:$ [149.966478]   Trade Rng: $ 360.92
# Close 25937.21 Predicted: $ [26677.73]   Actual: $ 25937.21   Delta:$ [740.523494]   Trade Rng: $ 601.88
# Close 26422.05 Predicted: $ [27148.29]   Actual: $ 26422.05   Delta:$ [726.238221]   Trade Rng: $ 468.06
# Close 26173.98 Predicted: $ [26029.09]   Actual: $ 26173.98   Delta:$ [144.887572]   Trade Rng: $ 236.89
# Close 26571.87 Predicted: $ [26609.17]   Actual: $ 26571.87   Delta:$ [37.30451]   Trade Rng: $ 577.96
# Close 26431.55 Predicted: $ [26025.67]   Actual: $ 26431.55   Delta:$ [405.883434]   Trade Rng: $ 156.43
# Close 27153.83 Predicted: $ [27109.98]   Actual: $ 27153.83   Delta:$ [43.848834]   Trade Rng: $ 354.84
# Close 27313.13 Predicted: $ [26684.62]   Actual: $ 27313.13   Delta:$ [628.505863]   Trade Rng: $ 241.89
# Close 27688.42 Predicted: $ [27113.35]   Actual: $ 27688.42   Delta:$ [575.066567]   Trade Rng: $ 169.84
# Close 27567.65 Predicted: $ [26534.11]   Actual: $ 27567.65   Delta:$ [1033.54321]   Trade Rng: $ 279.59
# Close 27875.91 Predicted: $ [27602.58]   Actual: $ 27875.91   Delta:$ [273.329449]   Trade Rng: $ 129.31
# Close 27818.62 Predicted: $ [27450.76]   Actual: $ 27818.62   Delta:$ [367.862977]   Trade Rng: $ 144.76
# Close 28614.63 Predicted: $ [12022.54]   Actual: $ 28614.63   Delta:$ [16592.090836]   Trade Rng: $ 346.28
# Mean Trading Range: $ 364.47
# Mean Delta (Actual vs Prediction): $ 439.66

# %% [markdown]
# ### - Deltas between predicted price and actual price

# %%
# Calculate an array of deltas between predicted price and actual price
print("Std Dev -     Pred: ", pred_delta.std())
y_pa_delta = abs(y_test - y_p_adj)
print("Std Dev - Pred Adj: ", y_pa_delta.std())
print("Better by", (y_p_delta.std() / y_pa_delta.std()), "Standard Deviations")
# Out:
# Std Dev -     Pred:  0.0
# Std Dev - Pred Adj:  0.020635273407375147
# Better by 6.361402744896186 Standard Deviations

# %% [markdown]
# ### - Deltas between predicted price and actual price

# %%
# Calculate an array of deltas between predicted price and actual price
print("Std Dev -     Pred: ", pred_delta.std())
y_pa_delta = abs(y_test - y_p_adj)
print("Std Dev - Pred Adj: ", y_pa_delta.std())
print("Better by", (y_p_delta.std() / y_pa_delta.std()), "Standard Deviations")
# Out:
# Std Dev -     Pred:  0.0
# Std Dev - Pred Adj:  0.020635273407375147
# Better by 6.361402744896186 Standard Deviations

# %% [markdown]
# ## - Trend Prediction Stats using Unscaled (v < 1) Adjusted
# ** The stats are not entirely accurate a the adjusted prediction will change when the new close actually occurs
#    and the adjusting process includes the new close in the calculation

# %%
# How often is the prediction within 1% of the actual price?
pct = 0.05
pct_delta = abs(y_test * pct)
delta = abs(y_test - y_p_adj)
within_range = delta[delta < pct_delta]
# Get average price range for the instrument
avg_price_rng = data_set['High'] - data_set['Low']
# Get pct of average price range
pcnt_avg_price_rng = avg_price_rng.mean() * pct

print("Within",pct * 100,"% of Acutal Adj Close","[ Trading Range:$", round(tot_tradrng / elements, 2), 
      " Within Avg Price:", avg_price_rng.mean().round(2), " Average Difference to Actual: $", pcnt_avg_price_rng.round(2),"]", 
      " Pct within Range:", round((len(within_range) / len(y_test)),2) * 100,"%")

# How often is the predicted trend the same as the actual trend?
test_trend = y_test[1:] - y_test[:-1]
pred_trend = y_p_adj[1:] - y_p_adj[:-1]
delta = [1 if (test_trend < 0) and (pred_trend < 0) or (test_trend > 0) and (pred_trend > 0) else 0 for test_trend, pred_trend in zip(test_trend, pred_trend)]
# Print the number of elements in delta and the percent of delta that are 1.
print("Same Trend:", len(delta), "Wrong:", len(delta) - len(within_range)+1, "Right", np.count_nonzero(within_range+1), "%Right", round((len(within_range)-1) / len(delta) * 100,2))
# Out:
# Within 5.0 % of Acutal Adj Close [ Trading Range:$ 364.47  Within Avg Price: 270.32  Average Difference to Actual: $ 13.52 ]  Pct within Range: 96.0 %
# Same Trend: 466 Wrong: 19 Right 448 %Right 95.92

# %% [markdown]
# # Model Details...

# %%
# Review feature importance
# importance = model.coef_

import shap
import pydot

print(X_train.shape)

print(model.summary())

from keras.utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
from IPython.display import Image

pass
# Out:
# (1865, 15, 17)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_input (InputLayer)         │ (None, 15, 17)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ first_layer (LSTM)              │ (None, 200)            │       174,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_layer (Dense)             │ (None, 1)              │           201 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Activation)             │ (None, 1)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 523,805 (2.00 MB)
#  Trainable params: 174,601 (682.04 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 349,204 (1.33 MB)
# None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 12
#       9 print(model.summary())
#      11 from keras.utils import plot_model
# ---> 12 plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
#      13 from IPython.display import Image
#      15 pass
#
# File ~/anaconda3/envs/lean-trading/lib/python3.11/site-packages/keras/utils/vis_utils.py:466, in plot_model(model, to_file, show_shapes, show_dtype, show_layer_names, rankdir, expand_nested, dpi, layer_range, show_layer_activations, show_trainable)
#     463     else:
#     464         raise ImportError(message)
# --> 466 dot = model_to_dot(
#     467     model,
#     468     show_shapes=show_shapes,
#     469     show_dtype=show_dtype,
#     470     show_layer_names=show_layer_names,
#     471     rankdir=rankdir,
#     472     expand_nested=expand_nested,
#     473     dpi=dpi,
#     474     layer_range=layer_range,
#     475     show_layer_activations=show_layer_activations,
#     476     show_trainable=show_trainable,
#     477 )
#     478 to_file = io_utils.path_to_string(to_file)
#     479 if dot is None:
#
# File ~/anaconda3/envs/lean-trading/lib/python3.11/site-packages/keras/utils/vis_utils.py:185, in model_to_dot(model, show_shapes, show_dtype, show_layer_names, rankdir, expand_nested, dpi, subgraph, layer_range, show_layer_activations, show_trainable)
#     182 sub_w_last_node = {}
#     184 layers = model.layers
# --> 185 if not model._is_graph_network:
#     186     node = pydot.Node(str(id(model)), label=model.name)
#     187     dot.add_node(node)
#
# AttributeError: 'Functional' object has no attribute '_is_graph_network'

# %% [markdown]
# ## - Model Plot
# <img src="model_plot.png" alt="Drawing" style="width: 200px;"/>
