# %% [markdown]
# # Price ML Predicion
#
# ## Price Prediction's Caveats
#
#   When the characteristics of the instrument are far from stable, price prediction can be quite off.
#   - Examples...
#     - SERV
#     - MEDS
#     - XCUR
#
#   Price Prediction should be combined with Prediction of market highs and lows because if you just entered the market based on predicted price, you could get washed out by manipulative Market Wales hitting your stops.
#
#   Predicting High, Low, Market Open and Market Close Should be done using separate models, using the same model parameters.
#
#   Before trading an instrument, one should review the median market price range, verses median prediction accuracy delta, to verify whether the instrument is worth trading. I have a hunch that the smaller the trading range as compared to the prediction delta, the less likely the instrument is worth engaging with.
# <p>
#
# ## Current Enhancements
#
# From a visual review, although the prediction strays from the price
#    the trend of the prediction seems quite accurate.
#    By pulling the prediction closer to the price, by an average of the delta,
#    between the price and the prediction, the new prediction is quite accurate.
# <p>
#
# ## Enhancements (to add)
#
# We should be able to add prediction targets for high and low for the day by
#    adding the target high-difference and low-difference to the data set,
#    similar to the way we added the target close-difference.
#
# We can also apparently pull minute bars from Yahoo. And with that, we can
#    perform more granular predictions, to the hour, 15min, 5min, and
#    1min period.

# %% [markdown]
# # Choose an existing model -or- Create a New Model

# %%
# Create a list of available .keras models from model_dir...
# Restart the kernel
# %reset -f
# %gui asyncio

import ipywidgets as widgets
from ipywidgets import Output, Checkbox, TwoByTwoLayout
import re
import datetime
import os
import asyncio
import yfinance as yf

# os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'

global Ticker, DataStart, DateEnd, ticker, dateStart, dateEnd, CreateNewModel, model_dir, model_files, Selected_Model

Ticker    = 'AMZN'

DateStart = '2015-06-03'
DateEnd   = '2024-07-30'
CreateNewModel = "Create New Model"

# Get list of file from the model directory...
model_dir = 'models/'
model_files = os.listdir(model_dir)
Selected_Model = None

def wait_for_change(widget, value):
    future = asyncio.Future()
    def getvalue(change):
        # make the new value available
        future.set_result(change.new)
        widget.unobserve(getvalue, value)
    widget.observe(getvalue, value)
    return future

def model_choices():
    global Ticker, DataStart, DateEnd, ticker, dateStart, dateEnd, CreateNewModel, model_dir, model_files, Selected_Model
    
    # Filter the list to only include .keras files...
    models_lst = [file for file in model_files if re.search(r'\.keras$', file)]
    models_lst.sort()
    model_files = [CreateNewModel] + models_lst
    # Display the list of files...
    Selected_Model = widgets.Select ( options=model_files,
                                      value=model_files[0],
                                      description='Model File: ',
                                      disabled=False )
    ticker     = widgets.Text(value=Ticker, description='TICKER: ')
    DateStart = "2015-01-01"
    dateStart = widgets.Text(value=DateStart, description='Start Date: ')
    chk_save_model = widgets.Checkbox(value=True, description='Save Model')
    # Set the DateEnd to today's date with the format 'YYYY-MM-DD, determined by the system date.
    if Selected_Model.value == CreateNewModel:
        DateEnd = datetime.datetime.now().strftime('%Y-%m-%d')
    dateEnd   = widgets.Text(value=DateEnd, description='End Date: ')
    out = Output()
    
    async def f0():
        for i in range(10):
            out.append_stdout('did work ' + str(i) + '\n')
            x = await wait_for_change(Selected_Model, 'value')
            if Selected_Model.value != CreateNewModel:
                ticker.value = Selected_Model.value.split('_')[0]
                if '~' in ticker.value:
                    ticker.value = ticker.value.replace('~', '=')
            out.append_stdout('async function continued with value ' + str(x) + '\n')
        asyncio.ensure_future(f0())
    
    async def f1():
        for i in range(10):
            out.append_stdout('did work ' + str(i) + '\n')
            x = await wait_for_change(ticker, 'value')
            tkr = ticker.value
            tkr = re.sub(r'Invalid: ', '', tkr)
            if Selected_Model.value == CreateNewModel:
                # Check yahoo if symbol is valid...
                try:
                    ticker_ = yf.Ticker(tkr).history(period='5d',interval='1d')
                except:
                    ticker_ = []
                if len(ticker_) == 0:
                    ticker.value = 'Invalid: ' + tkr
                else:
                    ticker.value = ticker.upper()
            out.append_stdout('async function continued with value ' + str(x) + '\n')
        asyncio.ensure_future(f1())
    
    asyncio.ensure_future(f0())
    asyncio.ensure_future(f1())
    
    from IPython.display import display, Pretty, Markdown, Latex
    inst0 = """
        +-------------------------------+
        | Choose or Create a New Model  |
        +-------------------------------+
        
    Make you Model Selection and Updates the Start and End Dates.
    Or, Create a New Model by entering by leave the Model File: as
    "Create New Model", and entering the Ticker, Start Date and End Date.
    """
    display(Pretty(inst0))
    
    # print(inst0, inst1)
    display(Selected_Model)
    print()
    display(ticker, dateStart, dateEnd, chk_save_model)
    print()
    # display(out)

    # if selected_model.value == CreateNewModel:
    # - Create a new model using the ticker.value, dateStart.value, DateEnd.vale values.
    return(Selected_Model, ticker, dateStart, dateEnd, chk_save_model, asyncio)

Selected_Model, ticker, dateStart, dateEnd, chk_save_model, asyncio = model_choices()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 26
#      24 # Get list of file from the model directory...
#      25 model_dir = 'models/'
# ---> 26 model_files = os.listdir(model_dir)
#      27 Selected_Model = None
#      29 def wait_for_change(widget, value):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'models/'

# %%
def print_model_choices(Selected_Model, ticker, dateStart, dateEnd, chk_save_model):
    print( "Selected_Model:", Selected_Model.value)
    print("Ticker: ", ticker.value)
    print("DateStart: ", dateStart.value)
    print("DateEnd: ", dateEnd.value)
    print("Save Model: ", chk_save_model.value)
        

print_model_choices(Selected_Model, ticker, dateStart, dateEnd, chk_save_model)
# Out:
# Selected_Model: Create New Model
# Ticker:  CRNT
# DateStart:  2015-01-01
# DateEnd:  2024-08-09
# Save Model:  True

# %% [markdown]
# #  Load the latest data for the selected Ticker...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn
import pandas as pd
import yfinance as yf

global data, feature_cnt, feature_cnt_dl, model_path

def load_data():
    global Ticker, DataStart, DateEnd, ticker, dateStart, dateEnd, CreateNewModel, model_dir, model_files, model_path, Selected_Model
    global data_orig, data, feature_cnt, feature_cnt_dl

    model_dir = 'models/'

    if Selected_Model.value == CreateNewModel:
        modelDateStart = DateStart
        modelDateEnd = DateEnd
        model_file = ticker.value + "_" + dateStart.value + "_" + dateEnd.value + ".keras"
        model_path = model_dir + model_file
    else:
        model_path = model_dir + Selected_Model.value

    # If we are using an existing model, we still have to download the data as we need the
    # actual price data to adjust the prediction.

    # If the predicted value varies/swings-about too much from the price,
    # the days/period training period many be changed to exclude the prior period
    # That does not have present-time characteristics with regard to price movement.
    data_orig = yf.download(tickers = ticker.value, start = dateStart.value, end = dateEnd.value)
    data=data_orig.copy(deep=True)
    offset = pd.Timedelta(days=-30)
    # Resample to 'W'eekly or 'ME'(Month End)
    # logic = {'Open'  : 'first',
    #          'High'  : 'max',
    #          'Low'   : 'min',
    #          'Close' : 'last',
    #          'Adj Close': 'last',
    #          'Volume': 'sum'}
    # data = data.resample('W', offset=offset).apply(logic)
    print("Pulling Data for:", ticker.value, "from", dateStart.value, "to", dateEnd.value)
    print("data.len():", len(data), "data.shape:", data.shape)

    feature_cnt_dl = data.shape[1]
    feature_cnt = feature_cnt_dl + 1  # Actual count vs index count.

load_data()
# data.tail(10)
data.head(5), data.tail(5)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Pulling Data for: CRNT from 2015-01-01 to 2024-08-09
# data.len(): 2416 data.shape: (2416, 6)
# (            Open  High   Low  Close  Adj Close  Volume
#  Date
#  2015-01-02  1.03  1.03  0.98   1.02       1.02  380000
#  2015-01-05  1.03  1.03  1.00   1.02       1.02  229500
#  2015-01-06  1.03  1.03  1.00   1.02       1.02  195100
#  2015-01-07  1.02  1.02  0.98   0.99       0.99  359000
#  2015-01-08  0.99  1.03  0.98   0.98       0.98  289200,
#              Open  High   Low  Close  Adj Close   Volume
#  Date
#  2024-08-02  2.83  2.89  2.65   2.70       2.70   629800
#  2024-08-05  2.56  2.61  2.42   2.47       2.47   587100
#  2024-08-06  2.48  2.55  2.45   2.48       2.48   306700
#  2024-08-07  2.70  2.75  2.51   2.65       2.65   967000
#  2024-08-08  2.71  2.87  2.64   2.86       2.86  1459800)

# %% [markdown]
# ##  - Add indicators to the data

# %%
# Add indicators to the data...

import pandas_ta as ta

def add_indicators(data, feature_cnt_dl):

    feature_cnt = feature_cnt_dl

    data = data_orig.copy(deep=True)

    # print("= Before Adding Indicators ========================================================")
    # print(data.tail(10))

    data['RSI']=ta.rsi(data.Close, length=3); feature_cnt += 1
    # data['EMAF']=ta.ema(data.Close, length=3); feature_cnt += 1
    # data['EMAM']=ta.ema(data.Close, length=6); feature_cnt += 1
    data['EMAS']=ta.ema(data.Close, length=9); feature_cnt += 1
    data['DPO3']=ta.dpo(data.Close, length=3, centered=True); feature_cnt += 1
    data['DPO6']=ta.dpo(data.Close, length=6, centered=True); feature_cnt += 1
    data['DPO9']=ta.dpo(data.Close, length=9, centered=True); feature_cnt += 1

    # print("= After Adding DPO2 ========================================================")
    # print(data.tail(10))
    #
    # On Balance Volume
    if data['Volume'].iloc[-1] > 0:
        data = data.join(ta.aobv(data.Close, data.Volume, fast=True, min_lookback=3, max_lookback=9))
        feature_cnt += 7 # ta.aobv adds 7 columns

    # print("= After Adding APBV ========================================================")
    # print(data.tail(10))

    # Target is the difference between the adjusted close and the open price.
    data['Target'] = data['Adj Close']-data.Open
    # Shift the target up by one day.Target is the difference between the adjusted close and the open price.
    # That is, the target is the difference between the adjusted close and the open price.
    # Our model will predict the target close for the next day. So we shift the target up by one day.
    data['Target'] = data['Target'].shift(-1)
    feature_cnt += 1

    # 1 if the price goes up, 0 if the price goes down.
    # Not a feature: Needed to test prediction accuracy.
    data['TargetClass'] = [1 if data['Target'].iloc[i]>0 else 0 for i in range(len(data))]

    # The TargetNextClose is the adjusted close price for the next day.
    # This is the value we want to predict.
    # Not a feature: Needed to test prediction accuracy.
    data['TargetNextClose'] = data['Adj Close'].shift(-1)

    # Before scaling the data, we need to use the last good value for rows that have NaN values.
    data.ffill(inplace=True)

    # print("= After Adding Targets___ and ForwardFill ========================================================")
    # print(data.tail(10))

    # Reset the index of the dataframe.
    data.reset_index(inplace = True)
    data_date = data['Date'].copy()
    data.drop(['Date'], axis=1, inplace=True);   feature_cnt -= 1
    data.drop(['Close'], axis=1, inplace=True);  feature_cnt -= 1
    # data.drop(['Volume'], axis=1, inplace=True); feature_cnt -= 1

    # Add one more row to the data file, this will be our next day's prediction.
    data = pd.concat([data,data[-1:]])
    # And, reindex the dataframe.
    data.reset_index(inplace=True)

    # print("feature_cnt_d1:", feature_cnt_dl, " feature_cnt:", feature_cnt)
    return data, feature_cnt, data_date

data_aug, feature_cnt, data_date = add_indicators(data, feature_cnt_dl)

data_set = data_aug.copy(deep=True)
print("Len data:", len(data_aug), "Len data_set", len(data_set))
# data_set.tail(10)
# Out:
# Len data: 2417 Len data_set 2417

# %% [markdown]
# ## - Scale the data
#
#   The data is scaled to a range of 0 to 1.
#   This is done to ensure that the data is normalized, so that the model can be trained on it

# %%
# Scale the data for training...

import sklearn
from sklearn.preprocessing import MinMaxScaler


def scale_data(data_set):
    sc = MinMaxScaler(feature_range=(0,1))
    data_set_scaled = sc.fit_transform(data_set)
    return sc, data_set_scaled

sc, data_set_scaled = scale_data(data_set)

print("data_set.shape:", data_set.shape, "data_set_scaled.shape", data_set_scaled.shape)
# print(data_set_scaled)
# Out:
# data_set.shape: (2417, 21) data_set_scaled.shape (2417, 21)

# %%
# Check of nan an/or 0 dataums...
# After scaling the data, we need to check for NaN and 0 values,
# and forward fill the data with the last known value.
# In the case of a series of 0 values, begining at index 0,
# we have to back fill those values with the first non-non/zero value available.
# *** Currently, we are not handling this case. ***
def scaled_data_cleanup(data_set):
    nan_indices = np.argwhere(np.isnan(data_set_scaled))
    zer_indices = np.argwhere(data_set_scaled == 0)

    # print("nan_indices:", nan_indices)
    # print('zer_indices:', zer_indices)

    for i in range(len(nan_indices)):
        j = nan_indices[i][1] - 1
        if j < 0:
            j = nan_indices[i][1] + 1
        data_set_scaled[nan_indices[i][0], nan_indices[i][1]] = data_set_scaled[nan_indices[i][0], j]
    for i in range(len(zer_indices)):
        j = zer_indices[i][1] - 1
        if j < 0:
            j = zer_indices[i][1] + 1
        data_set_scaled[zer_indices[i][0], zer_indices[i][1]] = data_set_scaled[zer_indices[i][0], j]

    nan_indices = np.argwhere(np.isnan(data_set_scaled))
    zer_indices = np.argwhere(data_set_scaled == 0)

    return data_set_scaled, nan_indices, zer_indices

data_set_scaled, nan_indices, zer_indices = scaled_data_cleanup(data_set)
# print("nan_indices:", nan_indices)
# print('zer_indices:', zer_indices)

# %% [markdown]
# ## - Prepare the scaled data for the model
#
#   - The data is prepared for the model by creating a 3D array of the data.
#   - The data is split into training and test data.
#   - The training data is used to train the model.
#   - The test data is used to test the model.
#   - The model is then used to predict the next day's price.

# %%
# LSTM needs a rolling period of data for each feature to make predictions.
# multiple feature from data provided to the model
global X, backcandles, y, yi, data_set
backcandles = 15 # Set the rolling window size.

def prep_model_inputs(data_scaled, backcandles):
    X = []
    # print(data_set_scaled[0].size)
    # data_set_scaled=data_set.values
    # print(data_set_scaled.shape[0])

    # Create a 3D array of the data. X[features][periods][candles]
    # Where candles is the number of candles that rolls by 1 period for each period.
    for j in range(feature_cnt): # data_set_scaled[0].size):# last 2 columns are target not X
        X.append([])
        for i in range(backcandles, data_set_scaled.shape[0]): # backcandles+2
            X[j].append(data_set_scaled[i-backcandles:i, j])

    # print("X.shape:", np.array(X).shape)
    X = np.array(X)
    # Move axis from 0 to position 2
    X=np.moveaxis(X, [0], [2])
    # print("X.shape:", X.shape)

    # Erase first elements of y because of backcandles to match X length
    # del(yi[0:backcandles])
    #X, yi = np.array(X), np.array(yi)
    # Choose -1 for last column, classification else -2...
    X, yi = np.array(X), np.array(data_set_scaled[backcandles:,-1])
    y = np.reshape(yi,(len(yi),1))
    #y=sc.fit_transform(yi)
    #X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
    
    # print("data_set.shape:",data_set.shape,"X.shape:",X.shape)
    # print(X)
    # print("=========================================================")
    # print(y.shape)
    # print(y)

    return X, y, yi

X, y, yi = prep_model_inputs(data_set_scaled, backcandles)

# %%
# split data into train test sets

global splitlimit
splitlimit = int(len(X)*0.8)

def split_data(X, y, splitlimit):
    # print("lenX:",len(X), "splitLimit:",splitlimit)
    X_train, X_test = X[:splitlimit], X[splitlimit:] # Training data, Test Data
    y_train, y_test = y[:splitlimit], y[splitlimit:] # Training data, Test Data

    # print("X_train.shape:", X_train.shape)
    # print("y_train.shape:", y_train.shape)
    # print("X_test.shape:", X_test.shape)
    # print("y_test.shape:", y_test.shape)
    # print("== X_train ===========================================")
    # print(X_train[-20:-10])
    # print("== _train ===========================================")
    # print(y_train[-20:-10])    

    return X_train, X_test, y_train, y_test

X_train, X_test, y_train, y_test = split_data(X, y, splitlimit)

# %% [markdown]
# # Load an Existing Model -or- Model Training
#  - Using LSTM (Long Short Term Memory) Model
#  - Using Keras (Tensorflow) Library
#  - LSTM --> Dense Layer --> Activation Layer

# %%
import tensorflow as tf
import keras
import numpy as np
import os
from keras import optimizers
from keras.callbacks import History
from keras.models import Model
from keras.layers import Dense, Dropout, LSTM, Input, Activation, concatenate
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Dense
from keras.layers import TimeDistributed

def create_fit_model(X_train, y_train, backcandels, model_path):
    # If the Keras model file exists, load it. Otherwise, create a new model.
    if os.path.exists(model_path) and Selected_Model.value != CreateNewModel:
        # Load the model...
        model = keras.models.load_model(model_path)
        model_path = model_path.replace('~', '=')
        print("Model Loaded:", model_path)
    else:
        # Create a new model...

        #tf.random.set_seed(20)
        np.random.seed(10)

        lstm_input = Input(shape=(backcandles, feature_cnt), name='lstm_input')
        inputs = LSTM(200, name='first_layer')(lstm_input)
        inputs = Dense(1, name='dense_layer')(inputs)
        output = Activation('linear', name='output')(inputs)
        model = Model(inputs=lstm_input, outputs=output)
        adam = optimizers.Adam()
        model.compile(optimizer=adam, loss='mse')
        # model.fit(x=X_train, y=y_train, batch_size=15, epochs=30, shuffle=True, validation_split = 0.1)
        model.fit(x=X_train, y=y_train, batch_size=30, epochs=50, shuffle=True, validation_split = 0.1)

        # Save the model...
        if chk_save_model.value:
            model_path = model_path.replace('=', '~')
            model.save(model_path)
    
    return model

model = create_fit_model(X_train, y_train, backcandles, model_path)
# Out:
# 2024-08-09 13:09:41.492798: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-08-09 13:09:41.502630: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-09 13:09:41.514469: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-09 13:09:41.518054: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-09 13:09:41.527416: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-09 13:09:42.098502: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Epoch 1/50
# 2024-08-09 13:09:42.486281: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2024-08-09 13:09:42.486299: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:135] retrieving CUDA diagnostic information for host: motoko-7760
# 2024-08-09 13:09:42.486304: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:142] hostname: motoko-7760
# 2024-08-09 13:09:42.486414: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:166] libcuda reported version is: 555.42.6
# 2024-08-09 13:09:42.486427: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:170] kernel reported version is: NOT_FOUND: could not find kernel module information in driver version file contents: "NVRM version: NVIDIA UNIX Open Kernel Module for x86_64  555.42.06  Release Build  (dvs-builder@U16-I3-A13-3-4)  Tue Jun  4 00:45:31 UTC 2024
# GCC version:  gcc version 12.3.0 (Ubuntu 12.3.0-1ubuntu1~22.04)
# "
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0237 - val_loss: 6.2265e-04
# Epoch 2/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - val_loss: 6.0348e-04
# Epoch 3/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - val_loss: 4.1845e-04
# Epoch 4/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.4408e-04 - val_loss: 4.1160e-04
# Epoch 5/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.8960e-04 - val_loss: 8.4114e-04
# Epoch 6/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.4539e-04 - val_loss: 3.5815e-04
# Epoch 7/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.4770e-04 - val_loss: 3.2688e-04
# Epoch 8/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.7710e-04 - val_loss: 3.4876e-04
# Epoch 9/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.4035e-04 - val_loss: 1.6494e-04
# Epoch 10/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.6793e-04 - val_loss: 1.8307e-04
# Epoch 11/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.1289e-04 - val_loss: 1.3947e-04
# Epoch 12/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.9335e-04 - val_loss: 1.3467e-04
# Epoch 13/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4570e-04 - val_loss: 1.4548e-04
# Epoch 14/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.8311e-04 - val_loss: 8.4278e-05
# Epoch 15/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.9982e-04 - val_loss: 1.2361e-04
# Epoch 16/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4471e-04 - val_loss: 9.6111e-05
# Epoch 17/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0172e-04 - val_loss: 1.7185e-04
# Epoch 18/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5455e-04 - val_loss: 9.2786e-05
# Epoch 19/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3293e-04 - val_loss: 3.3100e-04
# Epoch 20/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2743e-04 - val_loss: 8.5554e-05
# Epoch 21/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6308e-04 - val_loss: 5.3358e-04
# Epoch 22/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.3776e-04 - val_loss: 8.1427e-05
# Epoch 23/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7698e-04 - val_loss: 1.0242e-04
# Epoch 24/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8803e-04 - val_loss: 7.8371e-05
# Epoch 25/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0088e-04 - val_loss: 5.8437e-05
# Epoch 26/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5675e-04 - val_loss: 1.5532e-04
# Epoch 27/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.9604e-04 - val_loss: 5.3198e-04
# Epoch 28/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1613e-04 - val_loss: 9.0020e-05
# Epoch 29/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9204e-04 - val_loss: 6.6126e-05
# Epoch 30/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7866e-04 - val_loss: 1.2248e-04
# Epoch 31/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0871e-04 - val_loss: 1.4235e-04
# Epoch 32/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9896e-04 - val_loss: 7.0726e-05
# Epoch 33/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9537e-04 - val_loss: 9.6392e-05
# Epoch 34/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7883e-04 - val_loss: 6.8897e-05
# Epoch 35/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3669e-04 - val_loss: 5.7024e-05
# Epoch 36/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0118e-04 - val_loss: 9.7322e-05
# Epoch 37/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5794e-04 - val_loss: 8.5698e-05
# Epoch 38/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6847e-04 - val_loss: 2.5658e-04
# Epoch 39/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4747e-04 - val_loss: 1.7930e-04
# Epoch 40/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5228e-04 - val_loss: 9.2699e-05
# Epoch 41/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9161e-04 - val_loss: 5.5324e-05
# Epoch 42/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1140e-04 - val_loss: 1.0227e-04
# Epoch 43/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9390e-04 - val_loss: 6.2526e-05
# Epoch 44/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5645e-04 - val_loss: 1.3588e-04
# Epoch 45/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9607e-04 - val_loss: 1.6813e-04
# Epoch 46/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2930e-04 - val_loss: 1.7816e-04
# Epoch 47/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6596e-04 - val_loss: 7.8616e-05
# Epoch 48/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8728e-04 - val_loss: 8.9358e-05
# Epoch 49/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8235e-04 - val_loss: 2.3895e-04
# Epoch 50/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5318e-04 - val_loss: 6.9322e-05

# %% [markdown]
# # Model Testing

# %%
# Sow some y_pred values. If prediction is no good, we might see NaN values.
y_pred = model.predict(X_test)
# for i in range(10):
#     print(y_pred[i], y_test[i], )
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %% [markdown]
# ## - Adjust the prediction
#   The ideal for the prediction is for it to be as close to the actual price as possible.
#   What was observed is that the prediction is often off by a delta.
#   The delta is the difference between the actual price and the predicted price.
#   After applying an average of the delta to the prediction, the prediction is closer to the actual price.
#   Usually within 1% of the actual price, which is an incredible improvement.
#
#   The resulting numpy array y_p_adj is the adjusted prediction, which we will use as the prediction for the next day.
#
#   TO OD: Add code to find extreme deltas and adjust the prediction to be similar to the largest price move in the recent past.

# %%
# Calculate the delta between actual price and prediction
# Bring the prediction closer to the price based on the delta
def mov_avg(x, w):
    return abs(np.convolve(x, np.ones(w), 'valid') / w)

def apply_deltas(a,p,d, w):
    al = list(a) # Actual
    pl = list(p) # Predicted
    dl = list(d) # Delta
    rl = [] # Return List
    if len(dl) < len(pl):
        for i in range(len(pl) - len(dl)):
            # Duplidate the first value in the list to make the list the same size as pl.
            dl.insert(0, dl[0])
    # We don't apply the average to our first predictions
    # fot the size of the moving average window.
    # For this area, we just return the predicted value.
    i = w - 1
    for j in range(0, i):
        rl.append(pl[j]) 
    # print("al.len", len(al), "pl.len", len(pl), "dl.len", len(dl))
    # Beyond the window, we apply the average delta to the prediction.
    delta_factor = 1
    for delta in dl[:-1]:
        if i >= len(dl):
            break
        # print("i:", i, "dl:", len(dl), "al:", len(al), "pl:", len(pl))
        if al[i] > pl[i]:
            # If the actual price is greater than the predicted price, add the delta.
            val = pl[i] + (delta * delta_factor)
        else:
            # If the actual price is less than or equal to the predicted price, subtract the delta.
            val = pl[i] - (delta * delta_factor)
        rl.append(val)
        i += 1
    return rl

def adjust_prediction(y_test, y_pred, avg_win=5):
    """
    Calculate the delta between actual price and prediction
    Bring the prediction closer to the price based on the delta
    """

    y_p_delta = y_pred - y_test
    # Shift delta to the left by 1 day so that the adjusted prediction
    # only uses know data, and duplidate the delta for the last day (which we don't know).
    y_p_delta = np.append(y_p_delta[1:], y_p_delta[-1])
    # Calculate the average delta for the prediction.
    y_p_davg = mov_avg(y_p_delta, avg_win)

    # print(y_test.shape, y_pred.shape, y_p_adj.shape, y_p_delta.shape)
    y_p_adj = apply_deltas(y_test, y_pred, y_p_davg, avg_win)
    # We don't know the actual price for today, so we don't know the delta and average,
    # so for today, we will use the last known average delta (yesterday's) to adjust todays prediction.
    if y_test[-2] > y_pred[-1]:
        y_p_adj[-1] = y_pred[-1] + y_p_davg[-2]
    else:
        y_p_adj[-1] = y_pred[-1] - y_p_davg[-2]
    # Convert y_p_adj to a numpy array for plotting.
    y_p_adj = np.array(y_p_adj)

    return y_p_adj, y_p_delta

y_p_adj, y_p_delta = adjust_prediction(y_test, y_pred, avg_win=3)
# print("y_pred:", y_pred.shape[0])

# %% [markdown]
# # - Plot the Test Results

# %% [markdown]
# ### - Unscaled Data (0..1) (Prediction vs Target)

# %%
# Use an interactive plot to see the results
# %matplotlib notebook

def plot_pred_results(y_test, y_pred, y_p_adj):
    # Plot the scaled test and predicted data.
    y_test_plot = y_test[:-2]
    plt.figure(figsize=(16,8))
    # Acj Close
    plt.plot(y_test_plot, color = 'black', label = 'Test',     marker='.')
    # Original Prediction
    plt.plot(y_pred[1:],      color = 'red',   label = 'Pred',     marker='1')
    # Adjusted Prediction
    plt.plot(y_p_adj[1:],     color = 'orange', label = 'Adj Pred', marker='1')
    plt.legend()
    plt.grid()
    plt.show()
    return plt

plt = plot_pred_results(y_test, y_pred, y_p_adj)
# pd.DataFrame(y_test_plot).tail(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 19
#      16     plt.show()
#      17     return plt
# ---> 19 plt = plot_pred_results(y_test, y_pred, y_p_adj)
#
# NameError: name 'y_test' is not defined

# %% [markdown]
# ### - Rescaled Data ($USD) (Prediction vs Target)

# %%
# Plot using candlesticks using matplotlib...

# Use an interactive plot to see the results
# %matplotlib notebook

def plot_candlesticks(plt, prices, title, width=1, width2=.25, clr_up='green', clr_dn='red', clr_wick='black'):
    """
    Plot Candlesticks...
    :param plt:    maplotlib.pyplot handle
    :param prices: The series of OHLC prices to plot
    :param title:  A title for the plot
    :param width:
    :param width2:
    :param clr_up:
    :param clr_dn:
    :param clr_wick:
    :return:
    """
    #define up and down prices
    up = prices[prices.Close>=prices.Open]
    down = prices[prices.Close<prices.Open]

    #plot up prices
    plt.bar(up.index,up.Close-up.Open,width,bottom=up.Open,color=clr_up, alpha=.30)
    # plt.bar(up.index,up.High-up.Close,width2,bottom=up.Close,color=clr_up, alpha=.25)
    # plt.bar(up.index,up.Low-up.Open,width2,bottom=up.Open,color=clr_up, alpha=.25)
    plt.bar(up.index,up.High-up.Low,width2,bottom=up.Low,color=clr_wick, alpha=.30)

    #plot down prices
    plt.bar(down.index,down.Open-down.Close,width,bottom=down.Close,color=clr_dn, alpha=.25)
    # plt.bar(down.index,down.High-down.Open,width2,bottom=down.Open,color=clr_dn, alpha=.25)
    # plt.bar(down.index,down.Low-down.Close,width2,bottom=down.Close,color=clr_dn, alpha=.25)
    plt.bar(down.index,down.High-down.Low,width2,bottom=down.Low,color=clr_wick, alpha=.25)

    #rotate x-axis tick labels
    plt.xticks(rotation=45, ha='right')

import math
import mplfinance as mfp


def plot_pred_results(y_test, y_pred, y_p_adj, data_set, data_set_scaled, data_date):
    # Plot the original Adj Cost data that is in dollars...
    # Remove the last Adj Price, because it just aopy of the last adj
    plt_test_usd = np.array(data_set[backcandles + splitlimit:]['Adj Close'])
    plt_test_plot =np.array(plt_test_usd[:-1].reshape(-1,1))

    # Using Inverse_Transform to Rescale the predicted data to dollars...
    # To rescale the data, we need to use .inverse_transform with a similar tructure
    # to the original data_set_scaled returned by the .fit_transform function that did
    # the original scaling.
    # So we feed om the "test" portion of the data_set_scaled and replace the "TargetNextClose"
    # Column, which is the last column, with the predicted values (which we wan to rescale).
    # This is then fed to the .inverse_transform function to get the rescaled values, and we
    # will get accurate rescaled predicted values.
    data_set_scaled_y = data_set_scaled[backcandles + splitlimit:, :].copy()
    
    # Replace the last column in data_set_scaled_y with the predicted values...
    data_set_scaled_y[:, -1] = y_p_adj.reshape(-1)
    # Get the rescaled values for the adjusted prediction...
    y_pred_adj_rs = sc.inverse_transform(data_set_scaled_y)[:, -1]
    
    # Replace the last column in data_set_scaled_y with the predicted values...
    data_set_scaled_y[:, -1] = y_pred.reshape(-1)
    # Get the rescaled values for the adjusted prediction...
    y_pred_rs = sc.inverse_transform(data_set_scaled_y)[:, -1]

    # Calculate the mean of the delta between the prediction and the actual price...
    # Used to create price range circles around the prediction...
    plt_delta = np.array(pd.DataFrame([abs(plt_test_usd[i] - y_pred_adj_rs[i]) for i in range(len(y_p_adj)) ]).rolling(window=6).mean())

    # Dates...
    data_date_str = [str(date) for date in data_date]
    plt_test_dates = np.array((data_date_str[backcandles + splitlimit - 1:-1]), ).reshape(-1,1)
    plt_pred_dates = np.array((data_date_str[backcandles + splitlimit - 1:]),   ).reshape(-1,1)

    # empty_arr = np.zeros(((len(plt_test_plot)+1, 18)))
    # plt_pred_adj = sc.inverse_transform(np.append(y_p_adj, empty_arr, axis=1))[0:, 1]

    # Plot the data...
    plt.figure(figsize=(16,8))
    plt.autoscale(tight=True)

    plt_test_plot = plt_test_plot.reshape(-1,1)

    # Plot the actual price data ($USD)...
    plt.plot(plt_test_plot, color = 'black', label = 'Test', marker='+')
    # Plot the rescaled price data ($USD)...
    # plt.plot(plt_test_rescaled, color = 'purple', label = 'Test', marker='+')
    # Plot the adj predicted price data ($USD)...
    # plt.plot(plt_pred_adj, color = 'green', label = 'Test', marker='.')
    # Plot the adj predicted price data ($USD)...
    plt.plot(y_pred_rs, color = 'green', label = 'Test', marker='.')
    # Plot the adj predicted price data ($USD)...
    plt.plot(y_pred_adj_rs, color = 'orange', label = 'Test', marker='.')

    # Plot the candlesticks...
    ds_tmp = data_set[backcandles + splitlimit:-1]
    cs_data = ds_tmp.loc[backcandles + splitlimit:, ['Open','High','Low','Adj Close']].copy().reset_index()
    cs_data.rename(columns={'Adj Close':'Close'}, inplace=True)
    plot_candlesticks (plt, cs_data, 'Candlesticks')

    # Plot the text of the predicted price...
    plt.text(len(y_pred_adj_rs) -1, y_pred_adj_rs[-1], y_pred_adj_rs[-1].round(2), fontsize=8, color='black', ha='left', va='center')

    # plt.xlabel(range(0,len(plt_pred_dates)), plt_pred_dates.tolist(), rotation=45)
    #  .set_major_formatter(matplotlib.dates.DateFormatter('%Y')))

    # Plot a Price Range Circle Arounds the current Prediction...
    Plot_Pred_Circle = True
    if Plot_Pred_Circle:
        import matplotlib.patches as ptch
        lst_pred = len(y_pred_adj_rs) -1
        # ax.set_xlim = ([0, len(plt_pred_adj)])
        # ax.set_ylim = ([plt_pred_adj.min(), plt_pred_adj.max()])
        cpos = np.array([lst_pred, y_pred_adj_rs[-1]])
        circ_pred0 = ptch.Circle(cpos, radius=plt_delta[-1][0]/1,   color='grey',   fill=True, alpha=0.20)
        circ_pred1 = ptch.Circle(cpos, radius=plt_delta[-1][0]/1.5, color='blue',   fill=True, alpha=0.20)
        circ_pred2 = ptch.Circle(cpos, radius=plt_delta[-1][0]/2,   color='yellow', fill=True, alpha=0.20)
        circ_pred3 = ptch.Circle(cpos, radius=plt_delta[-1][0]/3,   color='red',    fill=True, alpha=0.20)
        ax = plt.gca()
        # ax.set_aspect("equal")
        ax.add_patch(circ_pred0)
        ax.add_patch(circ_pred1)
        ax.add_patch(circ_pred2)
        ax.add_patch(circ_pred3)

    plt.grid(visible=True, which='both')
    plt.legend()
    plt.show()
    return plt, y_pred_rs, y_pred_adj_rs

plt, y_pred_rs, y_pred_adj_rs = plot_pred_results(y_test, y_pred, y_p_adj, data_set, data_set_scaled, data_date)
# Out:
# <div id='2ba4f81e-733d-4f5d-8313-6f77656920a2'></div>

# %% [markdown]
# ### - Plot the Prediction Results (Using mplfinance)

# %%
# Plot using mlpfinance...
import mplfinance as mpf
print('Ticker:', ticker.value)
def plot_pred_results(Ticker, y_test, y_pred, y_p_adj, y_pred_adj_rs, data_set, data_set_scaled, data_date):
    # Createe a dataframe of the data for plt_test_usd, with a datetime index...
    df_plt_test_usd = pd.DataFrame()
    df_plt_test_usd.insert(0, 'Date', data_date[backcandles + splitlimit + 4:])
    df_plt_test_usd.reset_index()
    ohlcv = data_orig.iloc[backcandles + splitlimit + 4:, [0,1,2,3,4,5]].copy()
    ohlcv.reset_index()
    df_plt_test_usd = pd.concat([df_plt_test_usd, ohlcv.set_axis(df_plt_test_usd.index)], axis=1)
    
    # Add a place holder for the prediction...
    next_date = df_plt_test_usd.iloc[-1, 0] + pd.DateOffset(days=1)
    next_open      = df_plt_test_usd.iloc[-1, 4]
    next_high      = df_plt_test_usd.iloc[-1, 4]
    next_low       = df_plt_test_usd.iloc[-1, 4]
    next_close     = df_plt_test_usd.iloc[-1, 4]
    next_adj_close = df_plt_test_usd.iloc[-1, 4]
    next_volume    = 0
    
    # Prepare the prediction data for the plot...
    c_pred_rs     = pd.DataFrame(y_pred_rs[4:]).rename({0:'pred_rs'}, axis=1)
    c_pred_adj_rs = pd.DataFrame(y_pred_adj_rs[4:]).rename({0:'pred_adj_rs'}, axis=1)
    
    # Append a new row to the dataframe so it extends out to the prediction...
    new_row = { 'Date': next_date, "Open": next_open, "High": next_high, "Low": next_low, "Close": next_close,
                                   "Adj Close": next_adj_close, "Volume": next_volume,
                                   "pred_rs": c_pred_rs.iloc[-1], "pred_adj_rs": c_pred_adj_rs.iloc[-1] }
    new_row = pd.DataFrame(new_row, index=[6])
    df_plt_test_usd = pd.concat([df_plt_test_usd, new_row], axis=0, ignore_index=True)
    
    # Add the prediction data to the OHLCV plot data...
    df_plt_test_usd = pd.concat([df_plt_test_usd, c_pred_rs.set_axis(df_plt_test_usd.index)],     axis=1)
    df_plt_test_usd = pd.concat([df_plt_test_usd, c_pred_adj_rs.set_axis(df_plt_test_usd.index)], axis=1)
    
    df_plt_test_usd.ffill(inplace=True)
    df_plt_test_usd.set_index('Date', inplace=True, drop=True)
    df_plt_test_usd.ffill(inplace=True)
    df_plt_test_usd.rename(index={6:'pred_rs', 7:'pred_adj_rs'}, inplace=True)
    # Add a day row to df_plt_test_usd as a place holder for the prediction...
    print("df_plt_test_usd:", df_plt_test_usd.shape)
    
    kwargs = dict(type='candle', volume=True, figratio=(11,6), figscale=1.25, warn_too_much_data=10000, title='Ticker: '+ticker.value)
    preds = [ mpf.make_addplot(df_plt_test_usd['pred_rs'],     type='line', panel=0, color='g', secondary_y=False),
              mpf.make_addplot(df_plt_test_usd['pred_adj_rs'], type='line', panel=0, color='r', secondary_y=False)  ]
    mpf.plot(df_plt_test_usd,**kwargs,style='binance', addplot=preds)
    return mpf

mpf = plot_pred_results(Ticker, y_test, y_pred, y_p_adj, y_pred_adj_rs, data_set, data_set_scaled, data_date)
# Out:
# Ticker: CRNT
# df_plt_test_usd: (477, 10)
# <div id='3151f2d8-5bfe-4e30-ab34-536d01898152'></div>

# %% [markdown]
# # Analysis of the Prediction
#  - Rescaled data (0..1) (Prediction vs Target)

# %%
# We convert our data back to dollars...
# predval = y_pred[i] * scalefac

def analyze_pred(y_test, y_pred, y_p_adj, data_set, data_set_scaled, data_date):
    # Convert back to dollar $values
    elements = len(y_pred)
    print(elements)
    tot_deltas = 0
    tot_tradrng = 0
    for i in range(-1, -elements, -1):
        actual = data_set['Adj Close'].iloc[i - 1]
        scalefac = data_set['Adj Close'].iloc[i - 1] / y_test[i - 1]
        # print("Scaling Factor", scalefac)
        predval = y_pred[i] * scalefac
        predval = y_pred[i - 1] if np.isinf(predval) else predval
        pred_delta = abs(predval - actual)
        tot_deltas += pred_delta
        trd_rng = abs(data_set['High'].iloc[i] - data_set['Low'].iloc[i])
        tot_tradrng += trd_rng
        print("Close", actual.round(2), "Predicted: $", predval.round(2), "  Actual: $", actual.round(2), "  Delta:$", pred_delta.round(6), "  Trade Rng: $", trd_rng.round(2))

    print("Mean Trading Range: $", round(tot_tradrng / elements, 2))
    print("Mean Delta (Actual vs Prediction): $", round((tot_deltas[0] / elements), 2))
    return tot_deltas, tot_tradrng, elements

tot_deltas, tot_tradrng, elements = analyze_pred(y_test, y_pred, y_p_adj, data_set, data_set_scaled, data_date)
# Out:
# 481
# Close 2.86 Predicted: $ [2.28]   Actual: $ 2.86   Delta:$ [0.579581]   Trade Rng: $ 0.23
# Close 2.65 Predicted: $ [2.07]   Actual: $ 2.65   Delta:$ [0.578512]   Trade Rng: $ 0.23
# Close 2.48 Predicted: $ [2.29]   Actual: $ 2.48   Delta:$ [0.192782]   Trade Rng: $ 0.24
# Close 2.47 Predicted: $ [2.63]   Actual: $ 2.47   Delta:$ [0.15862]   Trade Rng: $ 0.1
# Close 2.7 Predicted: $ [2.84]   Actual: $ 2.7   Delta:$ [0.140655]   Trade Rng: $ 0.19
# Close 2.85 Predicted: $ [2.59]   Actual: $ 2.85   Delta:$ [0.264599]   Trade Rng: $ 0.24
# Close 2.77 Predicted: $ [2.56]   Actual: $ 2.77   Delta:$ [0.213494]   Trade Rng: $ 0.11
# Close 2.74 Predicted: $ [2.77]   Actual: $ 2.74   Delta:$ [0.033455]   Trade Rng: $ 0.09
# Close 2.71 Predicted: $ [2.81]   Actual: $ 2.71   Delta:$ [0.096881]   Trade Rng: $ 0.06
# Close 2.73 Predicted: $ [2.83]   Actual: $ 2.73   Delta:$ [0.103325]   Trade Rng: $ 0.07
# Close 2.73 Predicted: $ [2.76]   Actual: $ 2.73   Delta:$ [0.031619]   Trade Rng: $ 0.07
# Close 2.7 Predicted: $ [2.7]   Actual: $ 2.7   Delta:$ [0.000111]   Trade Rng: $ 0.11
# Close 2.73 Predicted: $ [2.72]   Actual: $ 2.73   Delta:$ [0.009867]   Trade Rng: $ 0.1
# Close 2.68 Predicted: $ [2.68]   Actual: $ 2.68   Delta:$ [0.004501]   Trade Rng: $ 0.1
# Close 2.58 Predicted: $ [2.68]   Actual: $ 2.58   Delta:$ [0.098894]   Trade Rng: $ 0.15
# Close 2.63 Predicted: $ [2.78]   Actual: $ 2.63   Delta:$ [0.150674]   Trade Rng: $ 0.07
# Close 2.67 Predicted: $ [2.7]   Actual: $ 2.67   Delta:$ [0.027866]   Trade Rng: $ 0.1
# Close 2.7 Predicted: $ [2.67]   Actual: $ 2.7   Delta:$ [0.030371]   Trade Rng: $ 0.16
# Close 2.62 Predicted: $ [2.61]   Actual: $ 2.62   Delta:$ [0.010993]   Trade Rng: $ 0.13
# Close 2.63 Predicted: $ [2.69]   Actual: $ 2.63   Delta:$ [0.061333]   Trade Rng: $ 0.06
# Close 2.62 Predicted: $ [2.64]   Actual: $ 2.62   Delta:$ [0.022913]   Trade Rng: $ 0.08
# Close 2.57 Predicted: $ [2.6]   Actual: $ 2.57   Delta:$ [0.026746]   Trade Rng: $ 0.04
# Close 2.54 Predicted: $ [2.6]   Actual: $ 2.54   Delta:$ [0.064846]   Trade Rng: $ 0.06
# Close 2.44 Predicted: $ [2.58]   Actual: $ 2.44   Delta:$ [0.135462]   Trade Rng: $ 0.04
# Close 2.45 Predicted: $ [2.63]   Actual: $ 2.45   Delta:$ [0.182278]   Trade Rng: $ 0.08
# Close 2.51 Predicted: $ [2.54]   Actual: $ 2.51   Delta:$ [0.030087]   Trade Rng: $ 0.12
# Close 2.51 Predicted: $ [2.43]   Actual: $ 2.51   Delta:$ [0.083319]   Trade Rng: $ 0.04
# Close 2.49 Predicted: $ [2.46]   Actual: $ 2.49   Delta:$ [0.030341]   Trade Rng: $ 0.08
# Close 2.5 Predicted: $ [2.5]   Actual: $ 2.5   Delta:$ [0.003744]   Trade Rng: $ 0.1
# Close 2.42 Predicted: $ [2.43]   Actual: $ 2.42   Delta:$ [0.007281]   Trade Rng: $ 0.11
# Close 2.39 Predicted: $ [2.49]   Actual: $ 2.39   Delta:$ [0.103158]   Trade Rng: $ 0.04
# Close 2.43 Predicted: $ [2.49]   Actual: $ 2.43   Delta:$ [0.05895]   Trade Rng: $ 0.07
# Close 2.43 Predicted: $ [2.39]   Actual: $ 2.43   Delta:$ [0.037338]   Trade Rng: $ 0.05
# Close 2.48 Predicted: $ [2.44]   Actual: $ 2.48   Delta:$ [0.043202]   Trade Rng: $ 0.14
# Close 2.41 Predicted: $ [2.35]   Actual: $ 2.41   Delta:$ [0.063016]   Trade Rng: $ 0.13
# Close 2.52 Predicted: $ [2.51]   Actual: $ 2.52   Delta:$ [0.014409]   Trade Rng: $ 0.17
# Close 2.46 Predicted: $ [2.39]   Actual: $ 2.46   Delta:$ [0.070707]   Trade Rng: $ 0.1
# Close 2.46 Predicted: $ [2.51]   Actual: $ 2.46   Delta:$ [0.049257]   Trade Rng: $ 0.04
# Close 2.53 Predicted: $ [2.57]   Actual: $ 2.53   Delta:$ [0.04446]   Trade Rng: $ 0.09
# Close 2.53 Predicted: $ [2.5]   Actual: $ 2.53   Delta:$ [0.026278]   Trade Rng: $ 0.07
# Close 2.52 Predicted: $ [2.51]   Actual: $ 2.52   Delta:$ [0.012385]   Trade Rng: $ 0.11
# Close 2.53 Predicted: $ [2.53]   Actual: $ 2.53   Delta:$ [0.004254]   Trade Rng: $ 0.06
# Close 2.62 Predicted: $ [2.57]   Actual: $ 2.62   Delta:$ [0.052528]   Trade Rng: $ 0.04
# Close 2.59 Predicted: $ [2.48]   Actual: $ 2.59   Delta:$ [0.110568]   Trade Rng: $ 0.07
# Close 2.57 Predicted: $ [2.57]   Actual: $ 2.57   Delta:$ [0.002678]   Trade Rng: $ 0.05
# Close 2.6 Predicted: $ [2.61]   Actual: $ 2.6   Delta:$ [0.007766]   Trade Rng: $ 0.08
# Close 2.61 Predicted: $ [2.57]   Actual: $ 2.61   Delta:$ [0.035057]   Trade Rng: $ 0.06
# Close 2.63 Predicted: $ [2.6]   Actual: $ 2.63   Delta:$ [0.029082]   Trade Rng: $ 0.07
# Close 2.61 Predicted: $ [2.59]   Actual: $ 2.61   Delta:$ [0.024644]   Trade Rng: $ 0.08
# Close 2.56 Predicted: $ [2.62]   Actual: $ 2.56   Delta:$ [0.057214]   Trade Rng: $ 0.14
# Close 2.64 Predicted: $ [2.75]   Actual: $ 2.64   Delta:$ [0.105372]   Trade Rng: $ 0.1
# Close 2.7 Predicted: $ [2.66]   Actual: $ 2.7   Delta:$ [0.044226]   Trade Rng: $ 0.14
# Close 2.66 Predicted: $ [2.62]   Actual: $ 2.66   Delta:$ [0.039623]   Trade Rng: $ 0.17
# Close 2.74 Predicted: $ [2.76]   Actual: $ 2.74   Delta:$ [0.02018]   Trade Rng: $ 0.1
# Close 2.8 Predicted: $ [2.7]   Actual: $ 2.8   Delta:$ [0.101676]   Trade Rng: $ 0.08
# Close 2.75 Predicted: $ [2.66]   Actual: $ 2.75   Delta:$ [0.089818]   Trade Rng: $ 0.08
# Close 2.73 Predicted: $ [2.75]   Actual: $ 2.73   Delta:$ [0.01515]   Trade Rng: $ 0.1
# Close 2.69 Predicted: $ [2.77]   Actual: $ 2.69   Delta:$ [0.075698]   Trade Rng: $ 0.07
# Close 2.69 Predicted: $ [2.79]   Actual: $ 2.69   Delta:$ [0.099783]   Trade Rng: $ 0.07
# Close 2.67 Predicted: $ [2.73]   Actual: $ 2.67   Delta:$ [0.059439]   Trade Rng: $ 0.04
# Close 2.67 Predicted: $ [2.71]   Actual: $ 2.67   Delta:$ [0.040776]   Trade Rng: $ 0.09
# Close 2.83 Predicted: $ [2.85]   Actual: $ 2.83   Delta:$ [0.023655]   Trade Rng: $ 0.21
# Close 2.86 Predicted: $ [2.73]   Actual: $ 2.86   Delta:$ [0.132617]   Trade Rng: $ 0.09
# Close 2.84 Predicted: $ [2.75]   Actual: $ 2.84   Delta:$ [0.089697]   Trade Rng: $ 0.08
# Close 2.77 Predicted: $ [2.7]   Actual: $ 2.77   Delta:$ [0.07336]   Trade Rng: $ 0.13
# Close 3.15 Predicted: $ [3.12]   Actual: $ 3.15   Delta:$ [0.030469]   Trade Rng: $ 0.28
# Close 3.04 Predicted: $ [2.72]   Actual: $ 3.04   Delta:$ [0.315875]   Trade Rng: $ 0.15
# Close 2.86 Predicted: $ [2.85]   Actual: $ 2.86   Delta:$ [0.01248]   Trade Rng: $ 0.2
# Close 2.77 Predicted: $ [2.94]   Actual: $ 2.77   Delta:$ [0.166767]   Trade Rng: $ 0.15
# Close 2.77 Predicted: $ [2.93]   Actual: $ 2.77   Delta:$ [0.157429]   Trade Rng: $ 0.09
# Close 2.82 Predicted: $ [2.82]   Actual: $ 2.82   Delta:$ [0.004682]   Trade Rng: $ 0.07
# Close 2.76 Predicted: $ [2.72]   Actual: $ 2.76   Delta:$ [0.038242]   Trade Rng: $ 0.15
# Close 2.74 Predicted: $ [2.78]   Actual: $ 2.74   Delta:$ [0.035423]   Trade Rng: $ 0.12
# Close 2.71 Predicted: $ [2.78]   Actual: $ 2.71   Delta:$ [0.074927]   Trade Rng: $ 0.09
# Close 2.79 Predicted: $ [2.82]   Actual: $ 2.79   Delta:$ [0.033442]   Trade Rng: $ 0.1
# Close 2.76 Predicted: $ [2.7]   Actual: $ 2.76   Delta:$ [0.056797]   Trade Rng: $ 0.11
# Close 2.73 Predicted: $ [2.73]   Actual: $ 2.73   Delta:$ [0.003855]   Trade Rng: $ 0.12
# Close 2.7 Predicted: $ [2.75]   Actual: $ 2.7   Delta:$ [0.046557]   Trade Rng: $ 0.1
# Close 2.79 Predicted: $ [2.85]   Actual: $ 2.79   Delta:$ [0.057487]   Trade Rng: $ 0.09
# Close 2.76 Predicted: $ [2.73]   Actual: $ 2.76   Delta:$ [0.02511]   Trade Rng: $ 0.12
# Close 2.77 Predicted: $ [2.78]   Actual: $ 2.77   Delta:$ [0.014409]   Trade Rng: $ 0.08
# Close 2.91 Predicted: $ [2.87]   Actual: $ 2.91   Delta:$ [0.042021]   Trade Rng: $ 0.16
# Close 3.09 Predicted: $ [2.93]   Actual: $ 3.09   Delta:$ [0.161033]   Trade Rng: $ 0.24
# Close 3.01 Predicted: $ [2.81]   Actual: $ 3.01   Delta:$ [0.198142]   Trade Rng: $ 0.1
# Close 3.16 Predicted: $ [3.1]   Actual: $ 3.16   Delta:$ [0.061238]   Trade Rng: $ 0.15
# Close 3.18 Predicted: $ [3.01]   Actual: $ 3.18   Delta:$ [0.171694]   Trade Rng: $ 0.09
# Close 3.19 Predicted: $ [3.08]   Actual: $ 3.19   Delta:$ [0.105625]   Trade Rng: $ 0.11
# Close 3.11 Predicted: $ [3.09]   Actual: $ 3.11   Delta:$ [0.024615]   Trade Rng: $ 0.1
# Close 3.08 Predicted: $ [3.17]   Actual: $ 3.08   Delta:$ [0.087441]   Trade Rng: $ 0.11
# Close 3.09 Predicted: $ [3.16]   Actual: $ 3.09   Delta:$ [0.074997]   Trade Rng: $ 0.09
# Close 3.07 Predicted: $ [3.12]   Actual: $ 3.07   Delta:$ [0.046845]   Trade Rng: $ 0.11
# Close 3.2 Predicted: $ [3.21]   Actual: $ 3.2   Delta:$ [0.010371]   Trade Rng: $ 0.15
# Close 3.22 Predicted: $ [3.12]   Actual: $ 3.22   Delta:$ [0.104318]   Trade Rng: $ 0.1
# Close 3.19 Predicted: $ [3.14]   Actual: $ 3.19   Delta:$ [0.04988]   Trade Rng: $ 0.06
# Close 3.29 Predicted: $ [3.24]   Actual: $ 3.29   Delta:$ [0.048556]   Trade Rng: $ 0.14
# Close 3.14 Predicted: $ [3.02]   Actual: $ 3.14   Delta:$ [0.123577]   Trade Rng: $ 0.21
# Close 3.17 Predicted: $ [3.2]   Actual: $ 3.17   Delta:$ [0.030009]   Trade Rng: $ 0.12
# Close 3.02 Predicted: $ [3.02]   Actual: $ 3.02   Delta:$ [0.004278]   Trade Rng: $ 0.14
# Close 2.98 Predicted: $ [3.16]   Actual: $ 2.98   Delta:$ [0.175576]   Trade Rng: $ 0.07
# Close 3.05 Predicted: $ [3.16]   Actual: $ 3.05   Delta:$ [0.112136]   Trade Rng: $ 0.13
# Close 3.07 Predicted: $ [3.05]   Actual: $ 3.07   Delta:$ [0.020969]   Trade Rng: $ 0.1
# Close 3.07 Predicted: $ [3.05]   Actual: $ 3.07   Delta:$ [0.024041]   Trade Rng: $ 0.08
# Close 3.12 Predicted: $ [3.03]   Actual: $ 3.12   Delta:$ [0.088035]   Trade Rng: $ 0.13
# Close 3.07 Predicted: $ [2.96]   Actual: $ 3.07   Delta:$ [0.11006]   Trade Rng: $ 0.15
# Close 2.99 Predicted: $ [3.]   Actual: $ 2.99   Delta:$ [0.00755]   Trade Rng: $ 0.13
# Close 2.96 Predicted: $ [3.04]   Actual: $ 2.96   Delta:$ [0.078787]   Trade Rng: $ 0.1
# Close 2.96 Predicted: $ [3.05]   Actual: $ 2.96   Delta:$ [0.092823]   Trade Rng: $ 0.09
# Close 2.98 Predicted: $ [3.03]   Actual: $ 2.98   Delta:$ [0.047546]   Trade Rng: $ 0.07
# Close 2.94 Predicted: $ [2.95]   Actual: $ 2.94   Delta:$ [0.011875]   Trade Rng: $ 0.08
# Close 3.01 Predicted: $ [3.03]   Actual: $ 3.01   Delta:$ [0.021557]   Trade Rng: $ 0.13
# Close 3.03 Predicted: $ [2.98]   Actual: $ 3.03   Delta:$ [0.051692]   Trade Rng: $ 0.19
# Close 3.05 Predicted: $ [3.02]   Actual: $ 3.05   Delta:$ [0.02658]   Trade Rng: $ 0.12
# Close 2.94 Predicted: $ [2.94]   Actual: $ 2.94   Delta:$ [0.000879]   Trade Rng: $ 0.13
# Close 2.99 Predicted: $ [3.11]   Actual: $ 2.99   Delta:$ [0.119371]   Trade Rng: $ 0.06
# Close 3.05 Predicted: $ [3.07]   Actual: $ 3.05   Delta:$ [0.015608]   Trade Rng: $ 0.18
# Close 2.85 Predicted: $ [2.82]   Actual: $ 2.85   Delta:$ [0.030272]   Trade Rng: $ 0.18
# Close 2.88 Predicted: $ [3.01]   Actual: $ 2.88   Delta:$ [0.133068]   Trade Rng: $ 0.08
# Close 2.92 Predicted: $ [2.86]   Actual: $ 2.92   Delta:$ [0.058172]   Trade Rng: $ 0.17
# Close 2.77 Predicted: $ [2.68]   Actual: $ 2.77   Delta:$ [0.08961]   Trade Rng: $ 0.29
# Close 2.79 Predicted: $ [2.9]   Actual: $ 2.79   Delta:$ [0.110152]   Trade Rng: $ 0.22
# Close 2.68 Predicted: $ [2.74]   Actual: $ 2.68   Delta:$ [0.061628]   Trade Rng: $ 0.22
# Close 2.6 Predicted: $ [2.75]   Actual: $ 2.6   Delta:$ [0.154319]   Trade Rng: $ 0.08
# Close 2.51 Predicted: $ [2.72]   Actual: $ 2.51   Delta:$ [0.207267]   Trade Rng: $ 0.12
# Close 2.6 Predicted: $ [2.74]   Actual: $ 2.6   Delta:$ [0.138311]   Trade Rng: $ 0.13
# Close 2.6 Predicted: $ [2.56]   Actual: $ 2.6   Delta:$ [0.041014]   Trade Rng: $ 0.1
# Close 2.61 Predicted: $ [2.59]   Actual: $ 2.61   Delta:$ [0.024416]   Trade Rng: $ 0.06
# Close 2.62 Predicted: $ [2.58]   Actual: $ 2.62   Delta:$ [0.041868]   Trade Rng: $ 0.06
# Close 2.52 Predicted: $ [2.48]   Actual: $ 2.52   Delta:$ [0.036765]   Trade Rng: $ 0.13
# Close 2.45 Predicted: $ [2.54]   Actual: $ 2.45   Delta:$ [0.08607]   Trade Rng: $ 0.09
# Close 2.43 Predicted: $ [2.54]   Actual: $ 2.43   Delta:$ [0.112647]   Trade Rng: $ 0.11
# Close 2.42 Predicted: $ [2.51]   Actual: $ 2.42   Delta:$ [0.087405]   Trade Rng: $ 0.06
# Close 2.46 Predicted: $ [2.54]   Actual: $ 2.46   Delta:$ [0.079848]   Trade Rng: $ 0.07
# Close 2.44 Predicted: $ [2.48]   Actual: $ 2.44   Delta:$ [0.036397]   Trade Rng: $ 0.06
# Close 2.55 Predicted: $ [2.58]   Actual: $ 2.55   Delta:$ [0.03379]   Trade Rng: $ 0.15
# Close 2.53 Predicted: $ [2.47]   Actual: $ 2.53   Delta:$ [0.056038]   Trade Rng: $ 0.05
# Close 2.59 Predicted: $ [2.53]   Actual: $ 2.59   Delta:$ [0.056936]   Trade Rng: $ 0.11
# Close 2.58 Predicted: $ [2.5]   Actual: $ 2.58   Delta:$ [0.078365]   Trade Rng: $ 0.09
# Close 2.52 Predicted: $ [2.53]   Actual: $ 2.52   Delta:$ [0.012262]   Trade Rng: $ 0.11
# Close 2.51 Predicted: $ [2.64]   Actual: $ 2.51   Delta:$ [0.133339]   Trade Rng: $ 0.09
# Close 2.53 Predicted: $ [2.63]   Actual: $ 2.53   Delta:$ [0.102849]   Trade Rng: $ 0.06
# Close 2.52 Predicted: $ [2.56]   Actual: $ 2.52   Delta:$ [0.040067]   Trade Rng: $ 0.13
# Close 2.7 Predicted: $ [2.74]   Actual: $ 2.7   Delta:$ [0.042243]   Trade Rng: $ 0.24
# Close 2.59 Predicted: $ [2.49]   Actual: $ 2.59   Delta:$ [0.100958]   Trade Rng: $ 0.2
# Close 2.62 Predicted: $ [2.73]   Actual: $ 2.62   Delta:$ [0.11142]   Trade Rng: $ 0.14
# Close 2.62 Predicted: $ [2.73]   Actual: $ 2.62   Delta:$ [0.107675]   Trade Rng: $ 0.33
# Close 2.34 Predicted: $ [2.43]   Actual: $ 2.34   Delta:$ [0.085598]   Trade Rng: $ 0.16
# Close 2.32 Predicted: $ [2.65]   Actual: $ 2.32   Delta:$ [0.329285]   Trade Rng: $ 0.08
# Close 2.28 Predicted: $ [2.44]   Actual: $ 2.28   Delta:$ [0.159918]   Trade Rng: $ 0.09
# Close 2.27 Predicted: $ [2.37]   Actual: $ 2.27   Delta:$ [0.097617]   Trade Rng: $ 0.05
# Close 2.24 Predicted: $ [2.32]   Actual: $ 2.24   Delta:$ [0.083548]   Trade Rng: $ 0.07
# Close 2.1 Predicted: $ [2.24]   Actual: $ 2.1   Delta:$ [0.143095]   Trade Rng: $ 0.16
# Close 2.11 Predicted: $ [2.4]   Actual: $ 2.11   Delta:$ [0.294667]   Trade Rng: $ 0.1
# Close 2.16 Predicted: $ [2.28]   Actual: $ 2.16   Delta:$ [0.119369]   Trade Rng: $ 0.07
# Close 2.14 Predicted: $ [2.18]   Actual: $ 2.14   Delta:$ [0.036967]   Trade Rng: $ 0.04
# Close 2.13 Predicted: $ [2.23]   Actual: $ 2.13   Delta:$ [0.096722]   Trade Rng: $ 0.07
# Close 2.07 Predicted: $ [2.18]   Actual: $ 2.07   Delta:$ [0.113969]   Trade Rng: $ 0.09
# Close 2.11 Predicted: $ [2.26]   Actual: $ 2.11   Delta:$ [0.14605]   Trade Rng: $ 0.04
# Close 2.1 Predicted: $ [2.16]   Actual: $ 2.1   Delta:$ [0.059942]   Trade Rng: $ 0.04
# Close 2.05 Predicted: $ [2.13]   Actual: $ 2.05   Delta:$ [0.081046]   Trade Rng: $ 0.08
# Close 2.02 Predicted: $ [2.16]   Actual: $ 2.02   Delta:$ [0.137685]   Trade Rng: $ 0.15
# Close 1.99 Predicted: $ [2.1]   Actual: $ 1.99   Delta:$ [0.114997]   Trade Rng: $ 0.08
# Close 2.01 Predicted: $ [2.11]   Actual: $ 2.01   Delta:$ [0.096896]   Trade Rng: $ 0.07
# Close 2.02 Predicted: $ [2.04]   Actual: $ 2.02   Delta:$ [0.019447]   Trade Rng: $ 0.06
# Close 1.92 Predicted: $ [1.95]   Actual: $ 1.92   Delta:$ [0.027967]   Trade Rng: $ 0.08
# Close 1.87 Predicted: $ [2.05]   Actual: $ 1.87   Delta:$ [0.181928]   Trade Rng: $ 0.1
# Close 1.87 Predicted: $ [2.04]   Actual: $ 1.87   Delta:$ [0.173287]   Trade Rng: $ 0.05
# Close 1.89 Predicted: $ [1.97]   Actual: $ 1.89   Delta:$ [0.083326]   Trade Rng: $ 0.05
# Close 1.89 Predicted: $ [1.91]   Actual: $ 1.89   Delta:$ [0.019121]   Trade Rng: $ 0.04
# Close 1.87 Predicted: $ [1.9]   Actual: $ 1.87   Delta:$ [0.030308]   Trade Rng: $ 0.05
# Close 1.84 Predicted: $ [1.95]   Actual: $ 1.84   Delta:$ [0.114269]   Trade Rng: $ 0.08
# Close 1.87 Predicted: $ [1.99]   Actual: $ 1.87   Delta:$ [0.118373]   Trade Rng: $ 0.12
# Close 1.9 Predicted: $ [1.95]   Actual: $ 1.9   Delta:$ [0.046133]   Trade Rng: $ 0.06
# Close 1.89 Predicted: $ [1.89]   Actual: $ 1.89   Delta:$ [0.000105]   Trade Rng: $ 0.07
# Close 1.89 Predicted: $ [1.95]   Actual: $ 1.89   Delta:$ [0.059464]   Trade Rng: $ 0.1
# Close 1.92 Predicted: $ [1.94]   Actual: $ 1.92   Delta:$ [0.022553]   Trade Rng: $ 0.07
# Close 1.87 Predicted: $ [1.89]   Actual: $ 1.87   Delta:$ [0.018027]   Trade Rng: $ 0.08
# Close 1.81 Predicted: $ [1.92]   Actual: $ 1.81   Delta:$ [0.106824]   Trade Rng: $ 0.09
# Close 1.78 Predicted: $ [1.96]   Actual: $ 1.78   Delta:$ [0.184721]   Trade Rng: $ 0.08
# Close 1.83 Predicted: $ [1.98]   Actual: $ 1.83   Delta:$ [0.150516]   Trade Rng: $ 0.06
# Close 1.84 Predicted: $ [1.87]   Actual: $ 1.84   Delta:$ [0.030854]   Trade Rng: $ 0.05
# Close 1.78 Predicted: $ [1.82]   Actual: $ 1.78   Delta:$ [0.043523]   Trade Rng: $ 0.11
# Close 1.75 Predicted: $ [1.94]   Actual: $ 1.75   Delta:$ [0.192063]   Trade Rng: $ 0.06
# Close 1.8 Predicted: $ [1.95]   Actual: $ 1.8   Delta:$ [0.149383]   Trade Rng: $ 0.08
# Close 1.76 Predicted: $ [1.82]   Actual: $ 1.76   Delta:$ [0.060942]   Trade Rng: $ 0.09
# Close 1.72 Predicted: $ [1.85]   Actual: $ 1.72   Delta:$ [0.134886]   Trade Rng: $ 0.07
# Close 1.75 Predicted: $ [1.89]   Actual: $ 1.75   Delta:$ [0.143837]   Trade Rng: $ 0.06
# Close 1.73 Predicted: $ [1.82]   Actual: $ 1.73   Delta:$ [0.089581]   Trade Rng: $ 0.06
# Close 1.67 Predicted: $ [1.79]   Actual: $ 1.67   Delta:$ [0.122446]   Trade Rng: $ 0.11
# Close 1.68 Predicted: $ [1.87]   Actual: $ 1.68   Delta:$ [0.185774]   Trade Rng: $ 0.05
# Close 1.72 Predicted: $ [1.79]   Actual: $ 1.72   Delta:$ [0.07145]   Trade Rng: $ 0.13
# Close 1.83 Predicted: $ [1.81]   Actual: $ 1.83   Delta:$ [0.016852]   Trade Rng: $ 0.18
# Close 1.71 Predicted: $ [1.64]   Actual: $ 1.71   Delta:$ [0.072839]   Trade Rng: $ 0.11
# Close 1.67 Predicted: $ [1.92]   Actual: $ 1.67   Delta:$ [0.245393]   Trade Rng: $ 0.08
# Close 1.7 Predicted: $ [1.9]   Actual: $ 1.7   Delta:$ [0.203942]   Trade Rng: $ 0.12
# Close 1.67 Predicted: $ [1.76]   Actual: $ 1.67   Delta:$ [0.086716]   Trade Rng: $ 0.06
# Close 1.68 Predicted: $ [1.76]   Actual: $ 1.68   Delta:$ [0.080981]   Trade Rng: $ 0.08
# Close 1.68 Predicted: $ [1.73]   Actual: $ 1.68   Delta:$ [0.04515]   Trade Rng: $ 0.07
# Close 1.7 Predicted: $ [1.68]   Actual: $ 1.7   Delta:$ [0.015978]   Trade Rng: $ 0.07
# Close 1.64 Predicted: $ [1.59]   Actual: $ 1.64   Delta:$ [0.054957]   Trade Rng: $ 0.13
# Close 1.56 Predicted: $ [1.67]   Actual: $ 1.56   Delta:$ [0.108194]   Trade Rng: $ 0.06
# Close 1.62 Predicted: $ [1.83]   Actual: $ 1.62   Delta:$ [0.212134]   Trade Rng: $ 0.04
# Close 1.64 Predicted: $ [1.73]   Actual: $ 1.64   Delta:$ [0.085204]   Trade Rng: $ 0.11
# Close 1.64 Predicted: $ [1.73]   Actual: $ 1.64   Delta:$ [0.086119]   Trade Rng: $ 0.07
# Close 1.63 Predicted: $ [1.75]   Actual: $ 1.63   Delta:$ [0.116163]   Trade Rng: $ 0.07
# Close 1.65 Predicted: $ [1.79]   Actual: $ 1.65   Delta:$ [0.139481]   Trade Rng: $ 0.04
# Close 1.65 Predicted: $ [1.71]   Actual: $ 1.65   Delta:$ [0.062803]   Trade Rng: $ 0.05
# Close 1.77 Predicted: $ [1.81]   Actual: $ 1.77   Delta:$ [0.043996]   Trade Rng: $ 0.12
# Close 1.84 Predicted: $ [1.72]   Actual: $ 1.84   Delta:$ [0.124717]   Trade Rng: $ 0.08
# Close 1.85 Predicted: $ [1.73]   Actual: $ 1.85   Delta:$ [0.121089]   Trade Rng: $ 0.05
# Close 1.86 Predicted: $ [1.81]   Actual: $ 1.86   Delta:$ [0.048079]   Trade Rng: $ 0.04
# Close 1.95 Predicted: $ [1.94]   Actual: $ 1.95   Delta:$ [0.010156]   Trade Rng: $ 0.09
# Close 1.95 Predicted: $ [1.91]   Actual: $ 1.95   Delta:$ [0.040205]   Trade Rng: $ 0.06
# Close 1.95 Predicted: $ [2.03]   Actual: $ 1.95   Delta:$ [0.077759]   Trade Rng: $ 0.04
# Close 1.95 Predicted: $ [2.08]   Actual: $ 1.95   Delta:$ [0.131885]   Trade Rng: $ 0.08
# Close 2.02 Predicted: $ [2.14]   Actual: $ 2.02   Delta:$ [0.119807]   Trade Rng: $ 0.1
# Close 2.05 Predicted: $ [2.03]   Actual: $ 2.05   Delta:$ [0.016863]   Trade Rng: $ 0.1
# Close 2.02 Predicted: $ [2.05]   Actual: $ 2.02   Delta:$ [0.02556]   Trade Rng: $ 0.08
# Close 1.95 Predicted: $ [2.07]   Actual: $ 1.95   Delta:$ [0.117338]   Trade Rng: $ 0.08
# Close 1.95 Predicted: $ [2.18]   Actual: $ 1.95   Delta:$ [0.22549]   Trade Rng: $ 0.04
# Close 1.96 Predicted: $ [2.07]   Actual: $ 1.96   Delta:$ [0.111197]   Trade Rng: $ 0.04
# Close 1.95 Predicted: $ [2.]   Actual: $ 1.95   Delta:$ [0.046829]   Trade Rng: $ 0.05
# Close 1.94 Predicted: $ [1.97]   Actual: $ 1.94   Delta:$ [0.025012]   Trade Rng: $ 0.04
# Close 1.91 Predicted: $ [1.92]   Actual: $ 1.91   Delta:$ [0.009775]   Trade Rng: $ 0.08
# Close 1.9 Predicted: $ [1.95]   Actual: $ 1.9   Delta:$ [0.050264]   Trade Rng: $ 0.05
# Close 1.91 Predicted: $ [1.94]   Actual: $ 1.91   Delta:$ [0.033931]   Trade Rng: $ 0.14
# Close 1.91 Predicted: $ [1.95]   Actual: $ 1.91   Delta:$ [0.039953]   Trade Rng: $ 0.07
# Close 1.91 Predicted: $ [1.95]   Actual: $ 1.91   Delta:$ [0.043663]   Trade Rng: $ 0.05
# Close 1.84 Predicted: $ [1.92]   Actual: $ 1.84   Delta:$ [0.076987]   Trade Rng: $ 0.09
# Close 1.83 Predicted: $ [1.95]   Actual: $ 1.83   Delta:$ [0.12342]   Trade Rng: $ 0.04
# Close 1.85 Predicted: $ [1.93]   Actual: $ 1.85   Delta:$ [0.075182]   Trade Rng: $ 0.04
# Close 1.85 Predicted: $ [1.87]   Actual: $ 1.85   Delta:$ [0.01851]   Trade Rng: $ 0.04
# Close 1.78 Predicted: $ [1.84]   Actual: $ 1.78   Delta:$ [0.060657]   Trade Rng: $ 0.08
# Close 1.85 Predicted: $ [2.03]   Actual: $ 1.85   Delta:$ [0.183134]   Trade Rng: $ 0.08
# Close 1.87 Predicted: $ [1.94]   Actual: $ 1.87   Delta:$ [0.069284]   Trade Rng: $ 0.03
# Close 1.9 Predicted: $ [1.97]   Actual: $ 1.9   Delta:$ [0.07118]   Trade Rng: $ 0.07
# Close 1.95 Predicted: $ [1.96]   Actual: $ 1.95   Delta:$ [0.009217]   Trade Rng: $ 0.06
# Close 1.97 Predicted: $ [1.94]   Actual: $ 1.97   Delta:$ [0.033134]   Trade Rng: $ 0.05
# Close 1.95 Predicted: $ [1.95]   Actual: $ 1.95   Delta:$ [0.002643]   Trade Rng: $ 0.06
# Close 1.94 Predicted: $ [1.99]   Actual: $ 1.94   Delta:$ [0.052345]   Trade Rng: $ 0.06
# Close 1.93 Predicted: $ [1.98]   Actual: $ 1.93   Delta:$ [0.054837]   Trade Rng: $ 0.07
# Close 1.93 Predicted: $ [1.97]   Actual: $ 1.93   Delta:$ [0.043149]   Trade Rng: $ 0.05
# Close 1.9 Predicted: $ [1.94]   Actual: $ 1.9   Delta:$ [0.042821]   Trade Rng: $ 0.09
# Close 1.88 Predicted: $ [1.95]   Actual: $ 1.88   Delta:$ [0.066418]   Trade Rng: $ 0.07
# Close 1.88 Predicted: $ [1.95]   Actual: $ 1.88   Delta:$ [0.073802]   Trade Rng: $ 0.05
# Close 1.92 Predicted: $ [1.93]   Actual: $ 1.92   Delta:$ [0.006371]   Trade Rng: $ 0.14
# Close 1.87 Predicted: $ [1.9]   Actual: $ 1.87   Delta:$ [0.025216]   Trade Rng: $ 0.11
# Close 1.88 Predicted: $ [1.98]   Actual: $ 1.88   Delta:$ [0.10345]   Trade Rng: $ 0.1
# Close 1.98 Predicted: $ [2.04]   Actual: $ 1.98   Delta:$ [0.061135]   Trade Rng: $ 0.11
# Close 2.02 Predicted: $ [1.96]   Actual: $ 2.02   Delta:$ [0.059069]   Trade Rng: $ 0.05
# Close 2.06 Predicted: $ [2.03]   Actual: $ 2.06   Delta:$ [0.030921]   Trade Rng: $ 0.07
# Close 2.09 Predicted: $ [2.05]   Actual: $ 2.09   Delta:$ [0.040945]   Trade Rng: $ 0.08
# Close 2.07 Predicted: $ [2.05]   Actual: $ 2.07   Delta:$ [0.017987]   Trade Rng: $ 0.12
# Close 2.13 Predicted: $ [2.12]   Actual: $ 2.13   Delta:$ [0.007676]   Trade Rng: $ 0.07
# Close 2.08 Predicted: $ [2.09]   Actual: $ 2.08   Delta:$ [0.011284]   Trade Rng: $ 0.09
# Close 2.12 Predicted: $ [2.18]   Actual: $ 2.12   Delta:$ [0.057604]   Trade Rng: $ 0.1
# Close 2.1 Predicted: $ [2.13]   Actual: $ 2.1   Delta:$ [0.034241]   Trade Rng: $ 0.09
# Close 2.12 Predicted: $ [2.2]   Actual: $ 2.12   Delta:$ [0.08355]   Trade Rng: $ 0.07
# Close 2.18 Predicted: $ [2.17]   Actual: $ 2.18   Delta:$ [0.011365]   Trade Rng: $ 0.12
# Close 2.02 Predicted: $ [2.]   Actual: $ 2.02   Delta:$ [0.024613]   Trade Rng: $ 0.2
# Close 2.02 Predicted: $ [2.22]   Actual: $ 2.02   Delta:$ [0.204898]   Trade Rng: $ 0.08
# Close 2.02 Predicted: $ [2.15]   Actual: $ 2.02   Delta:$ [0.131221]   Trade Rng: $ 0.1
# Close 2.07 Predicted: $ [2.16]   Actual: $ 2.07   Delta:$ [0.094029]   Trade Rng: $ 0.1
# Close 2.06 Predicted: $ [2.07]   Actual: $ 2.06   Delta:$ [0.013964]   Trade Rng: $ 0.08
# Close 2.03 Predicted: $ [2.05]   Actual: $ 2.03   Delta:$ [0.017216]   Trade Rng: $ 0.1
# Close 2.11 Predicted: $ [2.14]   Actual: $ 2.11   Delta:$ [0.030373]   Trade Rng: $ 0.1
# Close 2.11 Predicted: $ [2.03]   Actual: $ 2.11   Delta:$ [0.077679]   Trade Rng: $ 0.07
# Close 2.18 Predicted: $ [2.14]   Actual: $ 2.18   Delta:$ [0.041482]   Trade Rng: $ 0.13
# Close 2.2 Predicted: $ [2.13]   Actual: $ 2.2   Delta:$ [0.071109]   Trade Rng: $ 0.11
# Close 2.2 Predicted: $ [2.18]   Actual: $ 2.2   Delta:$ [0.018099]   Trade Rng: $ 0.12
# Close 2.23 Predicted: $ [2.22]   Actual: $ 2.23   Delta:$ [0.008818]   Trade Rng: $ 0.11
# Close 2.32 Predicted: $ [2.24]   Actual: $ 2.32   Delta:$ [0.078026]   Trade Rng: $ 0.18
# Close 2.35 Predicted: $ [2.23]   Actual: $ 2.35   Delta:$ [0.11826]   Trade Rng: $ 0.08
# Close 2.31 Predicted: $ [2.27]   Actual: $ 2.31   Delta:$ [0.040589]   Trade Rng: $ 0.1
# Close 2.23 Predicted: $ [2.33]   Actual: $ 2.23   Delta:$ [0.09771]   Trade Rng: $ 0.16
# Close 2.15 Predicted: $ [2.35]   Actual: $ 2.15   Delta:$ [0.202424]   Trade Rng: $ 0.09
# Close 2.16 Predicted: $ [2.36]   Actual: $ 2.16   Delta:$ [0.203755]   Trade Rng: $ 0.08
# Close 2.15 Predicted: $ [2.23]   Actual: $ 2.15   Delta:$ [0.084576]   Trade Rng: $ 0.11
# Close 2.2 Predicted: $ [2.23]   Actual: $ 2.2   Delta:$ [0.026848]   Trade Rng: $ 0.08
# Close 2.1 Predicted: $ [2.08]   Actual: $ 2.1   Delta:$ [0.019165]   Trade Rng: $ 0.2
# Close 1.92 Predicted: $ [2.04]   Actual: $ 1.92   Delta:$ [0.122298]   Trade Rng: $ 0.23
# Close 1.94 Predicted: $ [2.22]   Actual: $ 1.94   Delta:$ [0.283702]   Trade Rng: $ 0.07
# Close 1.9 Predicted: $ [2.01]   Actual: $ 1.9   Delta:$ [0.111064]   Trade Rng: $ 0.09
# Close 1.89 Predicted: $ [1.99]   Actual: $ 1.89   Delta:$ [0.103571]   Trade Rng: $ 0.05
# Close 1.97 Predicted: $ [2.04]   Actual: $ 1.97   Delta:$ [0.067465]   Trade Rng: $ 0.09
# Close 1.96 Predicted: $ [1.91]   Actual: $ 1.96   Delta:$ [0.046603]   Trade Rng: $ 0.07
# Close 1.99 Predicted: $ [2.]   Actual: $ 1.99   Delta:$ [0.007772]   Trade Rng: $ 0.04
# Close 2.06 Predicted: $ [2.05]   Actual: $ 2.06   Delta:$ [0.011228]   Trade Rng: $ 0.07
# Close 2.02 Predicted: $ [2.03]   Actual: $ 2.02   Delta:$ [0.014815]   Trade Rng: $ 0.07
# Close 2.03 Predicted: $ [2.15]   Actual: $ 2.03   Delta:$ [0.124066]   Trade Rng: $ 0.16
# Close 2.04 Predicted: $ [2.12]   Actual: $ 2.04   Delta:$ [0.081491]   Trade Rng: $ 0.11
# Close 2.14 Predicted: $ [2.15]   Actual: $ 2.14   Delta:$ [0.011326]   Trade Rng: $ 0.11
# Close 2.1 Predicted: $ [2.04]   Actual: $ 2.1   Delta:$ [0.061342]   Trade Rng: $ 0.04
# Close 2.11 Predicted: $ [2.19]   Actual: $ 2.11   Delta:$ [0.076983]   Trade Rng: $ 0.07
# Close 2.14 Predicted: $ [2.2]   Actual: $ 2.14   Delta:$ [0.062477]   Trade Rng: $ 0.09
# Close 2.05 Predicted: $ [2.1]   Actual: $ 2.05   Delta:$ [0.054944]   Trade Rng: $ 0.1
# Close 1.94 Predicted: $ [2.1]   Actual: $ 1.94   Delta:$ [0.163156]   Trade Rng: $ 0.15
# Close 1.9 Predicted: $ [2.12]   Actual: $ 1.9   Delta:$ [0.221424]   Trade Rng: $ 0.07
# Close 1.87 Predicted: $ [2.01]   Actual: $ 1.87   Delta:$ [0.140274]   Trade Rng: $ 0.07
# Close 1.84 Predicted: $ [1.91]   Actual: $ 1.84   Delta:$ [0.074722]   Trade Rng: $ 0.06
# Close 1.79 Predicted: $ [1.87]   Actual: $ 1.79   Delta:$ [0.082431]   Trade Rng: $ 0.06
# Close 1.78 Predicted: $ [1.94]   Actual: $ 1.78   Delta:$ [0.15805]   Trade Rng: $ 0.08
# Close 1.8 Predicted: $ [1.9]   Actual: $ 1.8   Delta:$ [0.100342]   Trade Rng: $ 0.06
# Close 1.8 Predicted: $ [1.87]   Actual: $ 1.8   Delta:$ [0.0743]   Trade Rng: $ 0.06
# Close 1.8 Predicted: $ [1.91]   Actual: $ 1.8   Delta:$ [0.106018]   Trade Rng: $ 0.06
# Close 1.82 Predicted: $ [1.93]   Actual: $ 1.82   Delta:$ [0.105265]   Trade Rng: $ 0.08
# Close 1.83 Predicted: $ [1.87]   Actual: $ 1.83   Delta:$ [0.042092]   Trade Rng: $ 0.05
# Close 1.78 Predicted: $ [1.8]   Actual: $ 1.78   Delta:$ [0.019576]   Trade Rng: $ 0.05
# Close 1.79 Predicted: $ [1.86]   Actual: $ 1.79   Delta:$ [0.070749]   Trade Rng: $ 0.03
# Close 1.78 Predicted: $ [1.78]   Actual: $ 1.78   Delta:$ [0.002529]   Trade Rng: $ 0.06
# Close 1.73 Predicted: $ [1.79]   Actual: $ 1.73   Delta:$ [0.063021]   Trade Rng: $ 0.1
# Close 1.74 Predicted: $ [1.85]   Actual: $ 1.74   Delta:$ [0.11167]   Trade Rng: $ 0.04
# Close 1.73 Predicted: $ [1.83]   Actual: $ 1.73   Delta:$ [0.103743]   Trade Rng: $ 0.05
# Close 1.74 Predicted: $ [1.82]   Actual: $ 1.74   Delta:$ [0.082066]   Trade Rng: $ 0.04
# Close 1.71 Predicted: $ [1.77]   Actual: $ 1.71   Delta:$ [0.061424]   Trade Rng: $ 0.08
# Close 1.75 Predicted: $ [1.84]   Actual: $ 1.75   Delta:$ [0.088655]   Trade Rng: $ 0.06
# Close 1.8 Predicted: $ [1.82]   Actual: $ 1.8   Delta:$ [0.020949]   Trade Rng: $ 0.11
# Close 1.77 Predicted: $ [1.78]   Actual: $ 1.77   Delta:$ [0.014183]   Trade Rng: $ 0.08
# Close 1.77 Predicted: $ [1.91]   Actual: $ 1.77   Delta:$ [0.138059]   Trade Rng: $ 0.06
# Close 1.8 Predicted: $ [1.95]   Actual: $ 1.8   Delta:$ [0.154096]   Trade Rng: $ 0.07
# Close 1.79 Predicted: $ [1.88]   Actual: $ 1.79   Delta:$ [0.090232]   Trade Rng: $ 0.07
# Close 1.87 Predicted: $ [1.91]   Actual: $ 1.87   Delta:$ [0.038793]   Trade Rng: $ 0.08
# Close 1.95 Predicted: $ [1.86]   Actual: $ 1.95   Delta:$ [0.091338]   Trade Rng: $ 0.22
# Close 1.82 Predicted: $ [1.76]   Actual: $ 1.82   Delta:$ [0.057176]   Trade Rng: $ 0.15
# Close 1.77 Predicted: $ [1.97]   Actual: $ 1.77   Delta:$ [0.199718]   Trade Rng: $ 0.07
# Close 1.77 Predicted: $ [2.]   Actual: $ 1.77   Delta:$ [0.234233]   Trade Rng: $ 0.05
# Close 1.81 Predicted: $ [1.96]   Actual: $ 1.81   Delta:$ [0.149231]   Trade Rng: $ 0.06
# Close 1.82 Predicted: $ [1.87]   Actual: $ 1.82   Delta:$ [0.047728]   Trade Rng: $ 0.08
# Close 1.84 Predicted: $ [1.89]   Actual: $ 1.84   Delta:$ [0.047599]   Trade Rng: $ 0.04
# Close 1.88 Predicted: $ [1.88]   Actual: $ 1.88   Delta:$ [0.002156]   Trade Rng: $ 0.13
# Close 1.82 Predicted: $ [1.84]   Actual: $ 1.82   Delta:$ [0.01634]   Trade Rng: $ 0.1
# Close 1.69 Predicted: $ [1.85]   Actual: $ 1.69   Delta:$ [0.163434]   Trade Rng: $ 0.17
# Close 1.68 Predicted: $ [1.99]   Actual: $ 1.68   Delta:$ [0.310908]   Trade Rng: $ 0.05
# Close 1.69 Predicted: $ [1.84]   Actual: $ 1.69   Delta:$ [0.146556]   Trade Rng: $ 0.04
# Close 1.68 Predicted: $ [1.72]   Actual: $ 1.68   Delta:$ [0.039086]   Trade Rng: $ 0.07
# Close 1.66 Predicted: $ [1.73]   Actual: $ 1.66   Delta:$ [0.069546]   Trade Rng: $ 0.04
# Close 1.68 Predicted: $ [1.78]   Actual: $ 1.68   Delta:$ [0.1018]   Trade Rng: $ 0.04
# Close 1.66 Predicted: $ [1.79]   Actual: $ 1.66   Delta:$ [0.129213]   Trade Rng: $ 0.07
# Close 1.7 Predicted: $ [1.84]   Actual: $ 1.7   Delta:$ [0.144818]   Trade Rng: $ 0.07
# Close 1.65 Predicted: $ [1.74]   Actual: $ 1.65   Delta:$ [0.093081]   Trade Rng: $ 0.07
# Close 1.69 Predicted: $ [1.86]   Actual: $ 1.69   Delta:$ [0.168107]   Trade Rng: $ 0.07
# Close 1.67 Predicted: $ [1.76]   Actual: $ 1.67   Delta:$ [0.092836]   Trade Rng: $ 0.07
# Close 1.66 Predicted: $ [1.75]   Actual: $ 1.66   Delta:$ [0.094807]   Trade Rng: $ 0.04
# Close 1.68 Predicted: $ [1.76]   Actual: $ 1.68   Delta:$ [0.081638]   Trade Rng: $ 0.03
# Close 1.69 Predicted: $ [1.71]   Actual: $ 1.69   Delta:$ [0.017964]   Trade Rng: $ 0.05
# Close 1.61 Predicted: $ [1.66]   Actual: $ 1.61   Delta:$ [0.053839]   Trade Rng: $ 0.11
# Close 1.63 Predicted: $ [1.81]   Actual: $ 1.63   Delta:$ [0.180165]   Trade Rng: $ 0.03
# Close 1.63 Predicted: $ [1.73]   Actual: $ 1.63   Delta:$ [0.103074]   Trade Rng: $ 0.04
# Close 1.63 Predicted: $ [1.71]   Actual: $ 1.63   Delta:$ [0.079425]   Trade Rng: $ 0.06
# Close 1.67 Predicted: $ [1.73]   Actual: $ 1.67   Delta:$ [0.058345]   Trade Rng: $ 0.04
# Close 1.63 Predicted: $ [1.61]   Actual: $ 1.63   Delta:$ [0.018629]   Trade Rng: $ 0.06
# Close 1.56 Predicted: $ [1.64]   Actual: $ 1.56   Delta:$ [0.076897]   Trade Rng: $ 0.05
# Close 1.68 Predicted: $ [1.81]   Actual: $ 1.68   Delta:$ [0.128563]   Trade Rng: $ 0.13
# Close 1.68 Predicted: $ [1.59]   Actual: $ 1.68   Delta:$ [0.09394]   Trade Rng: $ 0.06
# Close 1.7 Predicted: $ [1.68]   Actual: $ 1.7   Delta:$ [0.02473]   Trade Rng: $ 0.07
# Close 1.68 Predicted: $ [1.72]   Actual: $ 1.68   Delta:$ [0.041105]   Trade Rng: $ 0.04
# Close 1.71 Predicted: $ [1.82]   Actual: $ 1.71   Delta:$ [0.105578]   Trade Rng: $ 0.05
# Close 1.75 Predicted: $ [1.8]   Actual: $ 1.75   Delta:$ [0.051631]   Trade Rng: $ 0.05
# Close 1.75 Predicted: $ [1.75]   Actual: $ 1.75   Delta:$ [0.00178]   Trade Rng: $ 0.05
# Close 1.74 Predicted: $ [1.77]   Actual: $ 1.74   Delta:$ [0.028426]   Trade Rng: $ 0.04
# Close 1.76 Predicted: $ [1.82]   Actual: $ 1.76   Delta:$ [0.055451]   Trade Rng: $ 0.04
# Close 1.8 Predicted: $ [1.82]   Actual: $ 1.8   Delta:$ [0.018438]   Trade Rng: $ 0.05
# Close 1.78 Predicted: $ [1.81]   Actual: $ 1.78   Delta:$ [0.028328]   Trade Rng: $ 0.02
# Close 1.8 Predicted: $ [1.9]   Actual: $ 1.8   Delta:$ [0.099093]   Trade Rng: $ 0.04
# Close 1.85 Predicted: $ [1.87]   Actual: $ 1.85   Delta:$ [0.019071]   Trade Rng: $ 0.06
# Close 1.82 Predicted: $ [1.83]   Actual: $ 1.82   Delta:$ [0.006538]   Trade Rng: $ 0.06
# Close 1.84 Predicted: $ [1.92]   Actual: $ 1.84   Delta:$ [0.075472]   Trade Rng: $ 0.05
# Close 1.86 Predicted: $ [1.9]   Actual: $ 1.86   Delta:$ [0.037625]   Trade Rng: $ 0.06
# Close 1.88 Predicted: $ [1.89]   Actual: $ 1.88   Delta:$ [0.005854]   Trade Rng: $ 0.05
# Close 1.9 Predicted: $ [1.87]   Actual: $ 1.9   Delta:$ [0.034608]   Trade Rng: $ 0.03
# Close 1.94 Predicted: $ [1.86]   Actual: $ 1.94   Delta:$ [0.07697]   Trade Rng: $ 0.07
# Close 1.9 Predicted: $ [1.86]   Actual: $ 1.9   Delta:$ [0.044929]   Trade Rng: $ 0.05
# Close 1.92 Predicted: $ [1.95]   Actual: $ 1.92   Delta:$ [0.031436]   Trade Rng: $ 0.04
# Close 1.91 Predicted: $ [1.95]   Actual: $ 1.91   Delta:$ [0.043012]   Trade Rng: $ 0.05
# Close 1.92 Predicted: $ [2.02]   Actual: $ 1.92   Delta:$ [0.104472]   Trade Rng: $ 0.05
# Close 1.92 Predicted: $ [2.07]   Actual: $ 1.92   Delta:$ [0.150983]   Trade Rng: $ 0.06
# Close 1.95 Predicted: $ [2.11]   Actual: $ 1.95   Delta:$ [0.155288]   Trade Rng: $ 0.07
# Close 1.92 Predicted: $ [2.]   Actual: $ 1.92   Delta:$ [0.082505]   Trade Rng: $ 0.05
# Close 2.18 Predicted: $ [2.21]   Actual: $ 2.18   Delta:$ [0.028213]   Trade Rng: $ 0.27
# Close 2.2 Predicted: $ [1.93]   Actual: $ 2.2   Delta:$ [0.270551]   Trade Rng: $ 0.07
# Close 2.17 Predicted: $ [2.04]   Actual: $ 2.17   Delta:$ [0.12719]   Trade Rng: $ 0.04
# Close 2.15 Predicted: $ [2.14]   Actual: $ 2.15   Delta:$ [0.009867]   Trade Rng: $ 0.07
# Close 2.1 Predicted: $ [2.13]   Actual: $ 2.1   Delta:$ [0.029894]   Trade Rng: $ 0.1
# Close 2.08 Predicted: $ [2.17]   Actual: $ 2.08   Delta:$ [0.094734]   Trade Rng: $ 0.03
# Close 2.09 Predicted: $ [2.17]   Actual: $ 2.09   Delta:$ [0.080626]   Trade Rng: $ 0.13
# Close 2.1 Predicted: $ [2.12]   Actual: $ 2.1   Delta:$ [0.021994]   Trade Rng: $ 0.12
# Close 2.15 Predicted: $ [2.16]   Actual: $ 2.15   Delta:$ [0.005659]   Trade Rng: $ 0.09
# Close 2.06 Predicted: $ [2.09]   Actual: $ 2.06   Delta:$ [0.031622]   Trade Rng: $ 0.11
# Close 2.08 Predicted: $ [2.22]   Actual: $ 2.08   Delta:$ [0.135465]   Trade Rng: $ 0.02
# Close 2.07 Predicted: $ [2.12]   Actual: $ 2.07   Delta:$ [0.048222]   Trade Rng: $ 0.08
# Close 2.09 Predicted: $ [2.16]   Actual: $ 2.09   Delta:$ [0.066454]   Trade Rng: $ 0.09
# Close 2.07 Predicted: $ [2.16]   Actual: $ 2.07   Delta:$ [0.089874]   Trade Rng: $ 0.06
# Close 2.13 Predicted: $ [2.28]   Actual: $ 2.13   Delta:$ [0.1479]   Trade Rng: $ 0.07
# Close 2.11 Predicted: $ [2.19]   Actual: $ 2.11   Delta:$ [0.081153]   Trade Rng: $ 0.09
# Close 2.13 Predicted: $ [2.27]   Actual: $ 2.13   Delta:$ [0.137972]   Trade Rng: $ 0.09
# Close 2.17 Predicted: $ [2.21]   Actual: $ 2.17   Delta:$ [0.036329]   Trade Rng: $ 0.05
# Close 2.14 Predicted: $ [2.13]   Actual: $ 2.14   Delta:$ [0.008001]   Trade Rng: $ 0.07
# Close 2.14 Predicted: $ [2.18]   Actual: $ 2.14   Delta:$ [0.036745]   Trade Rng: $ 0.05
# Close 2.13 Predicted: $ [2.17]   Actual: $ 2.13   Delta:$ [0.036089]   Trade Rng: $ 0.05
# Close 2.05 Predicted: $ [2.08]   Actual: $ 2.05   Delta:$ [0.033345]   Trade Rng: $ 0.12
# Close 2.0 Predicted: $ [2.12]   Actual: $ 2.0   Delta:$ [0.119132]   Trade Rng: $ 0.07
# Close 2.02 Predicted: $ [2.12]   Actual: $ 2.02   Delta:$ [0.099334]   Trade Rng: $ 0.05
# Close 1.98 Predicted: $ [1.96]   Actual: $ 1.98   Delta:$ [0.022365]   Trade Rng: $ 0.06
# Close 1.91 Predicted: $ [1.96]   Actual: $ 1.91   Delta:$ [0.050135]   Trade Rng: $ 0.08
# Close 1.92 Predicted: $ [2.]   Actual: $ 1.92   Delta:$ [0.080886]   Trade Rng: $ 0.04
# Close 1.86 Predicted: $ [1.92]   Actual: $ 1.86   Delta:$ [0.06303]   Trade Rng: $ 0.1
# Close 1.87 Predicted: $ [2.]   Actual: $ 1.87   Delta:$ [0.129604]   Trade Rng: $ 0.06
# Close 1.9 Predicted: $ [1.97]   Actual: $ 1.9   Delta:$ [0.074597]   Trade Rng: $ 0.05
# Close 1.93 Predicted: $ [1.94]   Actual: $ 1.93   Delta:$ [0.005084]   Trade Rng: $ 0.07
# Close 1.97 Predicted: $ [1.94]   Actual: $ 1.97   Delta:$ [0.02568]   Trade Rng: $ 0.09
# Close 1.95 Predicted: $ [1.93]   Actual: $ 1.95   Delta:$ [0.021372]   Trade Rng: $ 0.07
# Close 1.95 Predicted: $ [1.99]   Actual: $ 1.95   Delta:$ [0.040149]   Trade Rng: $ 0.06
# Close 1.89 Predicted: $ [1.98]   Actual: $ 1.89   Delta:$ [0.088307]   Trade Rng: $ 0.09
# Close 1.92 Predicted: $ [2.1]   Actual: $ 1.92   Delta:$ [0.182721]   Trade Rng: $ 0.07
# Close 1.96 Predicted: $ [2.06]   Actual: $ 1.96   Delta:$ [0.098998]   Trade Rng: $ 0.09
# Close 2.02 Predicted: $ [2.02]   Actual: $ 2.02   Delta:$ [0.000408]   Trade Rng: $ 0.1
# Close 1.9 Predicted: $ [1.89]   Actual: $ 1.9   Delta:$ [0.007279]   Trade Rng: $ 0.09
# Close 2.03 Predicted: $ [2.18]   Actual: $ 2.03   Delta:$ [0.148785]   Trade Rng: $ 0.18
# Close 2.03 Predicted: $ [1.99]   Actual: $ 2.03   Delta:$ [0.036064]   Trade Rng: $ 0.05
# Close 1.97 Predicted: $ [2.04]   Actual: $ 1.97   Delta:$ [0.074719]   Trade Rng: $ 0.12
# Close 1.95 Predicted: $ [2.17]   Actual: $ 1.95   Delta:$ [0.223537]   Trade Rng: $ 0.04
# Close 2.02 Predicted: $ [2.13]   Actual: $ 2.02   Delta:$ [0.111004]   Trade Rng: $ 0.07
# Close 1.99 Predicted: $ [1.98]   Actual: $ 1.99   Delta:$ [0.008169]   Trade Rng: $ 0.1
# Close 1.99 Predicted: $ [2.04]   Actual: $ 1.99   Delta:$ [0.049581]   Trade Rng: $ 0.08
# Close 1.96 Predicted: $ [2.]   Actual: $ 1.96   Delta:$ [0.043925]   Trade Rng: $ 0.05
# Close 1.95 Predicted: $ [2.02]   Actual: $ 1.95   Delta:$ [0.069402]   Trade Rng: $ 0.04
# Close 1.93 Predicted: $ [1.99]   Actual: $ 1.93   Delta:$ [0.055633]   Trade Rng: $ 0.05
# Close 1.89 Predicted: $ [1.97]   Actual: $ 1.89   Delta:$ [0.07674]   Trade Rng: $ 0.06
# Close 1.87 Predicted: $ [1.99]   Actual: $ 1.87   Delta:$ [0.122335]   Trade Rng: $ 0.04
# Close 1.86 Predicted: $ [1.98]   Actual: $ 1.86   Delta:$ [0.122614]   Trade Rng: $ 0.05
# Close 1.85 Predicted: $ [1.97]   Actual: $ 1.85   Delta:$ [0.120441]   Trade Rng: $ 0.07
# Close 1.81 Predicted: $ [1.93]   Actual: $ 1.81   Delta:$ [0.11956]   Trade Rng: $ 0.06
# Close 1.87 Predicted: $ [2.]   Actual: $ 1.87   Delta:$ [0.131696]   Trade Rng: $ 0.09
# Close 1.9 Predicted: $ [1.93]   Actual: $ 1.9   Delta:$ [0.025105]   Trade Rng: $ 0.04
# Close 1.92 Predicted: $ [1.92]   Actual: $ 1.92   Delta:$ [0.002192]   Trade Rng: $ 0.06
# Close 1.86 Predicted: $ [1.89]   Actual: $ 1.86   Delta:$ [0.031854]   Trade Rng: $ 0.09
# Close 1.86 Predicted: $ [2.04]   Actual: $ 1.86   Delta:$ [0.183665]   Trade Rng: $ 0.07
# Close 1.87 Predicted: $ [2.01]   Actual: $ 1.87   Delta:$ [0.143388]   Trade Rng: $ 0.07
# Close 1.8 Predicted: $ [1.88]   Actual: $ 1.8   Delta:$ [0.080809]   Trade Rng: $ 0.06
# Close 1.83 Predicted: $ [1.96]   Actual: $ 1.83   Delta:$ [0.132977]   Trade Rng: $ 0.07
# Close 1.89 Predicted: $ [1.88]   Actual: $ 1.89   Delta:$ [0.00684]   Trade Rng: $ 0.09
# Close 1.75 Predicted: $ [1.71]   Actual: $ 1.75   Delta:$ [0.044274]   Trade Rng: $ 0.08
# Close 1.71 Predicted: $ [1.95]   Actual: $ 1.71   Delta:$ [0.238515]   Trade Rng: $ 0.05
# Close 1.75 Predicted: $ [2.01]   Actual: $ 1.75   Delta:$ [0.255253]   Trade Rng: $ 0.06
# Close 1.79 Predicted: $ [1.94]   Actual: $ 1.79   Delta:$ [0.150099]   Trade Rng: $ 0.07
# Close 1.8 Predicted: $ [1.89]   Actual: $ 1.8   Delta:$ [0.091007]   Trade Rng: $ 0.06
# Close 1.92 Predicted: $ [2.01]   Actual: $ 1.92   Delta:$ [0.085686]   Trade Rng: $ 0.1
# Close 1.89 Predicted: $ [1.89]   Actual: $ 1.89   Delta:$ [0.003948]   Trade Rng: $ 0.05
# Close 1.91 Predicted: $ [1.98]   Actual: $ 1.91   Delta:$ [0.067944]   Trade Rng: $ 0.07
# Close 1.88 Predicted: $ [1.92]   Actual: $ 1.88   Delta:$ [0.042731]   Trade Rng: $ 0.06
# Close 1.89 Predicted: $ [1.98]   Actual: $ 1.89   Delta:$ [0.094237]   Trade Rng: $ 0.06
# Close 1.88 Predicted: $ [1.93]   Actual: $ 1.88   Delta:$ [0.054356]   Trade Rng: $ 0.04
# Close 1.86 Predicted: $ [1.93]   Actual: $ 1.86   Delta:$ [0.065841]   Trade Rng: $ 0.07
# Close 1.82 Predicted: $ [1.9]   Actual: $ 1.82   Delta:$ [0.080513]   Trade Rng: $ 0.08
# Close 1.79 Predicted: $ [1.9]   Actual: $ 1.79   Delta:$ [0.105248]   Trade Rng: $ 0.1
# Close 1.76 Predicted: $ [1.86]   Actual: $ 1.76   Delta:$ [0.098366]   Trade Rng: $ 0.03
# Close 1.76 Predicted: $ [1.86]   Actual: $ 1.76   Delta:$ [0.099024]   Trade Rng: $ 0.05
# Close 1.77 Predicted: $ [1.84]   Actual: $ 1.77   Delta:$ [0.066895]   Trade Rng: $ 0.03
# Close 1.79 Predicted: $ [1.79]   Actual: $ 1.79   Delta:$ [0.002258]   Trade Rng: $ 0.08
# Close 1.76 Predicted: $ [1.73]   Actual: $ 1.76   Delta:$ [0.030601]   Trade Rng: $ 0.05
# Close 1.71 Predicted: $ [1.78]   Actual: $ 1.71   Delta:$ [0.072378]   Trade Rng: $ 0.06
# Close 1.76 Predicted: $ [1.87]   Actual: $ 1.76   Delta:$ [0.11023]   Trade Rng: $ 0.06
# Close 1.81 Predicted: $ [1.78]   Actual: $ 1.81   Delta:$ [0.025659]   Trade Rng: $ 0.08
# Close 1.85 Predicted: $ [1.78]   Actual: $ 1.85   Delta:$ [0.071934]   Trade Rng: $ 0.07
# Close 1.87 Predicted: $ [1.8]   Actual: $ 1.87   Delta:$ [0.070283]   Trade Rng: $ 0.06
# Close 1.82 Predicted: $ [1.84]   Actual: $ 1.82   Delta:$ [0.018714]   Trade Rng: $ 0.06
# Close 1.83 Predicted: $ [1.97]   Actual: $ 1.83   Delta:$ [0.136954]   Trade Rng: $ 0.06
# Close 1.84 Predicted: $ [1.95]   Actual: $ 1.84   Delta:$ [0.110354]   Trade Rng: $ 0.08
# Close 1.92 Predicted: $ [1.96]   Actual: $ 1.92   Delta:$ [0.037113]   Trade Rng: $ 0.14
# Close 1.89 Predicted: $ [1.87]   Actual: $ 1.89   Delta:$ [0.01942]   Trade Rng: $ 0.09
# Close 1.88 Predicted: $ [1.94]   Actual: $ 1.88   Delta:$ [0.060794]   Trade Rng: $ 0.08
# Close 1.91 Predicted: $ [1.99]   Actual: $ 1.91   Delta:$ [0.078283]   Trade Rng: $ 0.08
# Close 1.98 Predicted: $ [2.]   Actual: $ 1.98   Delta:$ [0.020786]   Trade Rng: $ 0.06
# Close 2.07 Predicted: $ [2.]   Actual: $ 2.07   Delta:$ [0.071527]   Trade Rng: $ 0.07
# Close 2.09 Predicted: $ [1.94]   Actual: $ 2.09   Delta:$ [0.151538]   Trade Rng: $ 0.08
# Close 2.05 Predicted: $ [1.99]   Actual: $ 2.05   Delta:$ [0.063074]   Trade Rng: $ 0.09
# Close 2.08 Predicted: $ [2.12]   Actual: $ 2.08   Delta:$ [0.036784]   Trade Rng: $ 0.08
# Close 2.09 Predicted: $ [2.1]   Actual: $ 2.09   Delta:$ [0.006488]   Trade Rng: $ 0.07
# Close 2.12 Predicted: $ [2.11]   Actual: $ 2.12   Delta:$ [0.007989]   Trade Rng: $ 0.05
# Close 2.12 Predicted: $ [2.09]   Actual: $ 2.12   Delta:$ [0.028172]   Trade Rng: $ 0.05
# Close 2.13 Predicted: $ [2.14]   Actual: $ 2.13   Delta:$ [0.011572]   Trade Rng: $ 0.05
# Mean Trading Range: $ 0.09
# Mean Delta (Actual vs Prediction): $ 0.08

# %% [markdown]
# ## - Rescaled data (0..1) (Adjusted Prediction vs Target)

# %%
def analyze_pred_adj(y_test, y_pred, y_p_adj):
    elements = len(y_p_adj)
    # print(elements)
    tot_deltas = 0
    tot_tradrng = 0
    for i in range(-1, -elements, -1):
        actual = data_set['Adj Close'].iloc[i - 1]
        scalefac = data_set['Adj Close'].iloc[i - 1] / y_test[i - 1]
        # print("Scaling Factor", scalefac)
        predval = y_p_adj[i] * scalefac
        predval = y_pred[i - 1] if np.isinf(predval) else predval
        pred_delta = abs(predval - actual)
        tot_deltas += pred_delta
        trd_rng = abs(data_set['High'].iloc[i] - data_set['Low'].iloc[i])
        tot_tradrng += trd_rng
        print("Close", actual.round(2), "Predicted: $", predval.round(2), "  Actual: $", actual.round(2), "  Delta:$", pred_delta.round(6), "  Trade Rng: $", trd_rng.round(2))

    return pred_delta, tot_deltas, tot_tradrng

pred_delta, tot_deltas, tot_tradrng = analyze_pred_adj(y_test, y_pred, y_p_adj)

print("Mean Trading Range: $", round(tot_tradrng / elements, 2))
print("Mean Delta (Actual vs Prediction): $", round((tot_deltas[0] / elements), 2))
# Out:
# Close 2.86 Predicted: $ [2.85]   Actual: $ 2.86   Delta:$ [0.01091]   Trade Rng: $ 0.23
# Close 2.65 Predicted: $ [2.22]   Actual: $ 2.65   Delta:$ [0.425932]   Trade Rng: $ 0.23
# Close 2.48 Predicted: $ [2.32]   Actual: $ 2.48   Delta:$ [0.161673]   Trade Rng: $ 0.24
# Close 2.47 Predicted: $ [2.7]   Actual: $ 2.47   Delta:$ [0.226557]   Trade Rng: $ 0.1
# Close 2.7 Predicted: $ [2.84]   Actual: $ 2.7   Delta:$ [0.13937]   Trade Rng: $ 0.19
# Close 2.85 Predicted: $ [2.57]   Actual: $ 2.85   Delta:$ [0.276221]   Trade Rng: $ 0.24
# Close 2.77 Predicted: $ [2.57]   Actual: $ 2.77   Delta:$ [0.204668]   Trade Rng: $ 0.11
# Close 2.74 Predicted: $ [2.83]   Actual: $ 2.74   Delta:$ [0.090083]   Trade Rng: $ 0.09
# Close 2.71 Predicted: $ [2.77]   Actual: $ 2.71   Delta:$ [0.057656]   Trade Rng: $ 0.06
# Close 2.73 Predicted: $ [2.83]   Actual: $ 2.73   Delta:$ [0.100876]   Trade Rng: $ 0.07
# Close 2.73 Predicted: $ [2.76]   Actual: $ 2.73   Delta:$ [0.026893]   Trade Rng: $ 0.07
# Close 2.7 Predicted: $ [2.7]   Actual: $ 2.7   Delta:$ [0.004419]   Trade Rng: $ 0.11
# Close 2.73 Predicted: $ [2.74]   Actual: $ 2.73   Delta:$ [0.011774]   Trade Rng: $ 0.1
# Close 2.68 Predicted: $ [2.63]   Actual: $ 2.68   Delta:$ [0.045379]   Trade Rng: $ 0.1
# Close 2.58 Predicted: $ [2.64]   Actual: $ 2.58   Delta:$ [0.058032]   Trade Rng: $ 0.15
# Close 2.63 Predicted: $ [2.84]   Actual: $ 2.63   Delta:$ [0.207654]   Trade Rng: $ 0.07
# Close 2.67 Predicted: $ [2.7]   Actual: $ 2.67   Delta:$ [0.026439]   Trade Rng: $ 0.1
# Close 2.7 Predicted: $ [2.67]   Actual: $ 2.7   Delta:$ [0.034517]   Trade Rng: $ 0.16
# Close 2.62 Predicted: $ [2.61]   Actual: $ 2.62   Delta:$ [0.013877]   Trade Rng: $ 0.13
# Close 2.63 Predicted: $ [2.7]   Actual: $ 2.63   Delta:$ [0.074714]   Trade Rng: $ 0.06
# Close 2.62 Predicted: $ [2.61]   Actual: $ 2.62   Delta:$ [0.008733]   Trade Rng: $ 0.08
# Close 2.57 Predicted: $ [2.56]   Actual: $ 2.57   Delta:$ [0.008391]   Trade Rng: $ 0.04
# Close 2.54 Predicted: $ [2.66]   Actual: $ 2.54   Delta:$ [0.118473]   Trade Rng: $ 0.06
# Close 2.44 Predicted: $ [2.55]   Actual: $ 2.44   Delta:$ [0.110585]   Trade Rng: $ 0.04
# Close 2.45 Predicted: $ [2.62]   Actual: $ 2.45   Delta:$ [0.174504]   Trade Rng: $ 0.08
# Close 2.51 Predicted: $ [2.52]   Actual: $ 2.51   Delta:$ [0.0107]   Trade Rng: $ 0.12
# Close 2.51 Predicted: $ [2.41]   Actual: $ 2.51   Delta:$ [0.097383]   Trade Rng: $ 0.04
# Close 2.49 Predicted: $ [2.47]   Actual: $ 2.49   Delta:$ [0.019614]   Trade Rng: $ 0.08
# Close 2.5 Predicted: $ [2.5]   Actual: $ 2.5   Delta:$ [0.000384]   Trade Rng: $ 0.1
# Close 2.42 Predicted: $ [2.42]   Actual: $ 2.42   Delta:$ [0.002657]   Trade Rng: $ 0.11
# Close 2.39 Predicted: $ [2.5]   Actual: $ 2.39   Delta:$ [0.105324]   Trade Rng: $ 0.04
# Close 2.43 Predicted: $ [2.49]   Actual: $ 2.43   Delta:$ [0.057527]   Trade Rng: $ 0.07
# Close 2.43 Predicted: $ [2.34]   Actual: $ 2.43   Delta:$ [0.088334]   Trade Rng: $ 0.05
# Close 2.48 Predicted: $ [2.44]   Actual: $ 2.48   Delta:$ [0.039083]   Trade Rng: $ 0.14
# Close 2.41 Predicted: $ [2.32]   Actual: $ 2.41   Delta:$ [0.085233]   Trade Rng: $ 0.13
# Close 2.52 Predicted: $ [2.54]   Actual: $ 2.52   Delta:$ [0.019775]   Trade Rng: $ 0.17
# Close 2.46 Predicted: $ [2.36]   Actual: $ 2.46   Delta:$ [0.096839]   Trade Rng: $ 0.1
# Close 2.46 Predicted: $ [2.55]   Actual: $ 2.46   Delta:$ [0.086893]   Trade Rng: $ 0.04
# Close 2.53 Predicted: $ [2.56]   Actual: $ 2.53   Delta:$ [0.027383]   Trade Rng: $ 0.09
# Close 2.53 Predicted: $ [2.48]   Actual: $ 2.53   Delta:$ [0.04874]   Trade Rng: $ 0.07
# Close 2.52 Predicted: $ [2.52]   Actual: $ 2.52   Delta:$ [0.002142]   Trade Rng: $ 0.11
# Close 2.53 Predicted: $ [2.55]   Actual: $ 2.53   Delta:$ [0.015874]   Trade Rng: $ 0.06
# Close 2.62 Predicted: $ [2.58]   Actual: $ 2.62   Delta:$ [0.036112]   Trade Rng: $ 0.04
# Close 2.59 Predicted: $ [2.46]   Actual: $ 2.59   Delta:$ [0.130333]   Trade Rng: $ 0.07
# Close 2.57 Predicted: $ [2.58]   Actual: $ 2.57   Delta:$ [0.005931]   Trade Rng: $ 0.05
# Close 2.6 Predicted: $ [2.61]   Actual: $ 2.6   Delta:$ [0.008404]   Trade Rng: $ 0.08
# Close 2.61 Predicted: $ [2.57]   Actual: $ 2.61   Delta:$ [0.041637]   Trade Rng: $ 0.06
# Close 2.63 Predicted: $ [2.62]   Actual: $ 2.63   Delta:$ [0.00922]   Trade Rng: $ 0.07
# Close 2.61 Predicted: $ [2.54]   Actual: $ 2.61   Delta:$ [0.06784]   Trade Rng: $ 0.08
# Close 2.56 Predicted: $ [2.57]   Actual: $ 2.56   Delta:$ [0.007338]   Trade Rng: $ 0.14
# Close 2.64 Predicted: $ [2.72]   Actual: $ 2.64   Delta:$ [0.075425]   Trade Rng: $ 0.1
# Close 2.7 Predicted: $ [2.65]   Actual: $ 2.7   Delta:$ [0.053665]   Trade Rng: $ 0.14
# Close 2.66 Predicted: $ [2.61]   Actual: $ 2.66   Delta:$ [0.047974]   Trade Rng: $ 0.17
# Close 2.74 Predicted: $ [2.78]   Actual: $ 2.74   Delta:$ [0.035509]   Trade Rng: $ 0.1
# Close 2.8 Predicted: $ [2.69]   Actual: $ 2.8   Delta:$ [0.10683]   Trade Rng: $ 0.08
# Close 2.75 Predicted: $ [2.67]   Actual: $ 2.75   Delta:$ [0.080471]   Trade Rng: $ 0.08
# Close 2.73 Predicted: $ [2.79]   Actual: $ 2.73   Delta:$ [0.063567]   Trade Rng: $ 0.1
# Close 2.69 Predicted: $ [2.73]   Actual: $ 2.69   Delta:$ [0.039458]   Trade Rng: $ 0.07
# Close 2.69 Predicted: $ [2.76]   Actual: $ 2.69   Delta:$ [0.068775]   Trade Rng: $ 0.07
# Close 2.67 Predicted: $ [2.68]   Actual: $ 2.67   Delta:$ [0.014261]   Trade Rng: $ 0.04
# Close 2.67 Predicted: $ [2.68]   Actual: $ 2.67   Delta:$ [0.014919]   Trade Rng: $ 0.09
# Close 2.83 Predicted: $ [2.84]   Actual: $ 2.83   Delta:$ [0.005281]   Trade Rng: $ 0.21
# Close 2.86 Predicted: $ [2.63]   Actual: $ 2.86   Delta:$ [0.226838]   Trade Rng: $ 0.09
# Close 2.84 Predicted: $ [2.76]   Actual: $ 2.84   Delta:$ [0.082021]   Trade Rng: $ 0.08
# Close 2.77 Predicted: $ [2.73]   Actual: $ 2.77   Delta:$ [0.043412]   Trade Rng: $ 0.13
# Close 3.15 Predicted: $ [3.14]   Actual: $ 3.15   Delta:$ [0.01042]   Trade Rng: $ 0.28
# Close 3.04 Predicted: $ [2.65]   Actual: $ 3.04   Delta:$ [0.388551]   Trade Rng: $ 0.15
# Close 2.86 Predicted: $ [2.87]   Actual: $ 2.86   Delta:$ [0.005281]   Trade Rng: $ 0.2
# Close 2.77 Predicted: $ [2.96]   Actual: $ 2.77   Delta:$ [0.187133]   Trade Rng: $ 0.15
# Close 2.77 Predicted: $ [2.92]   Actual: $ 2.77   Delta:$ [0.152818]   Trade Rng: $ 0.09
# Close 2.82 Predicted: $ [2.82]   Actual: $ 2.82   Delta:$ [0.004693]   Trade Rng: $ 0.07
# Close 2.76 Predicted: $ [2.72]   Actual: $ 2.76   Delta:$ [0.044091]   Trade Rng: $ 0.15
# Close 2.74 Predicted: $ [2.81]   Actual: $ 2.74   Delta:$ [0.066542]   Trade Rng: $ 0.12
# Close 2.71 Predicted: $ [2.78]   Actual: $ 2.71   Delta:$ [0.07236]   Trade Rng: $ 0.09
# Close 2.79 Predicted: $ [2.83]   Actual: $ 2.79   Delta:$ [0.041192]   Trade Rng: $ 0.1
# Close 2.76 Predicted: $ [2.69]   Actual: $ 2.76   Delta:$ [0.065441]   Trade Rng: $ 0.11
# Close 2.73 Predicted: $ [2.77]   Actual: $ 2.73   Delta:$ [0.043558]   Trade Rng: $ 0.12
# Close 2.7 Predicted: $ [2.72]   Actual: $ 2.7   Delta:$ [0.017414]   Trade Rng: $ 0.1
# Close 2.79 Predicted: $ [2.83]   Actual: $ 2.79   Delta:$ [0.039546]   Trade Rng: $ 0.09
# Close 2.76 Predicted: $ [2.73]   Actual: $ 2.76   Delta:$ [0.026701]   Trade Rng: $ 0.12
# Close 2.77 Predicted: $ [2.81]   Actual: $ 2.77   Delta:$ [0.039671]   Trade Rng: $ 0.08
# Close 2.91 Predicted: $ [2.89]   Actual: $ 2.91   Delta:$ [0.015052]   Trade Rng: $ 0.16
# Close 3.09 Predicted: $ [2.9]   Actual: $ 3.09   Delta:$ [0.191404]   Trade Rng: $ 0.24
# Close 3.01 Predicted: $ [2.74]   Actual: $ 3.01   Delta:$ [0.266485]   Trade Rng: $ 0.1
# Close 3.16 Predicted: $ [3.12]   Actual: $ 3.16   Delta:$ [0.042673]   Trade Rng: $ 0.15
# Close 3.18 Predicted: $ [2.97]   Actual: $ 3.18   Delta:$ [0.209412]   Trade Rng: $ 0.09
# Close 3.19 Predicted: $ [3.09]   Actual: $ 3.19   Delta:$ [0.104896]   Trade Rng: $ 0.11
# Close 3.11 Predicted: $ [3.11]   Actual: $ 3.11   Delta:$ [0.001984]   Trade Rng: $ 0.1
# Close 3.08 Predicted: $ [3.19]   Actual: $ 3.08   Delta:$ [0.112402]   Trade Rng: $ 0.11
# Close 3.09 Predicted: $ [3.12]   Actual: $ 3.09   Delta:$ [0.034893]   Trade Rng: $ 0.09
# Close 3.07 Predicted: $ [3.11]   Actual: $ 3.07   Delta:$ [0.035108]   Trade Rng: $ 0.11
# Close 3.2 Predicted: $ [3.22]   Actual: $ 3.2   Delta:$ [0.022957]   Trade Rng: $ 0.15
# Close 3.22 Predicted: $ [3.08]   Actual: $ 3.22   Delta:$ [0.139261]   Trade Rng: $ 0.1
# Close 3.19 Predicted: $ [3.23]   Actual: $ 3.19   Delta:$ [0.035343]   Trade Rng: $ 0.06
# Close 3.29 Predicted: $ [3.28]   Actual: $ 3.29   Delta:$ [0.00573]   Trade Rng: $ 0.14
# Close 3.14 Predicted: $ [2.96]   Actual: $ 3.14   Delta:$ [0.175379]   Trade Rng: $ 0.21
# Close 3.17 Predicted: $ [3.22]   Actual: $ 3.17   Delta:$ [0.051768]   Trade Rng: $ 0.12
# Close 3.02 Predicted: $ [2.99]   Actual: $ 3.02   Delta:$ [0.025821]   Trade Rng: $ 0.14
# Close 2.98 Predicted: $ [3.2]   Actual: $ 2.98   Delta:$ [0.219782]   Trade Rng: $ 0.07
# Close 3.05 Predicted: $ [3.16]   Actual: $ 3.05   Delta:$ [0.110313]   Trade Rng: $ 0.13
# Close 3.07 Predicted: $ [3.01]   Actual: $ 3.07   Delta:$ [0.063057]   Trade Rng: $ 0.1
# Close 3.07 Predicted: $ [2.98]   Actual: $ 3.07   Delta:$ [0.087856]   Trade Rng: $ 0.08
# Close 3.12 Predicted: $ [3.08]   Actual: $ 3.12   Delta:$ [0.041205]   Trade Rng: $ 0.13
# Close 3.07 Predicted: $ [2.98]   Actual: $ 3.07   Delta:$ [0.094947]   Trade Rng: $ 0.15
# Close 2.99 Predicted: $ [3.02]   Actual: $ 2.99   Delta:$ [0.027836]   Trade Rng: $ 0.13
# Close 2.96 Predicted: $ [3.08]   Actual: $ 2.96   Delta:$ [0.124097]   Trade Rng: $ 0.1
# Close 2.96 Predicted: $ [3.04]   Actual: $ 2.96   Delta:$ [0.075546]   Trade Rng: $ 0.09
# Close 2.98 Predicted: $ [3.01]   Actual: $ 2.98   Delta:$ [0.029924]   Trade Rng: $ 0.07
# Close 2.94 Predicted: $ [2.95]   Actual: $ 2.94   Delta:$ [0.007359]   Trade Rng: $ 0.08
# Close 3.01 Predicted: $ [3.06]   Actual: $ 3.01   Delta:$ [0.048625]   Trade Rng: $ 0.13
# Close 3.03 Predicted: $ [2.98]   Actual: $ 3.03   Delta:$ [0.054464]   Trade Rng: $ 0.19
# Close 3.05 Predicted: $ [3.]   Actual: $ 3.05   Delta:$ [0.051968]   Trade Rng: $ 0.12
# Close 2.94 Predicted: $ [2.91]   Actual: $ 2.94   Delta:$ [0.03073]   Trade Rng: $ 0.13
# Close 2.99 Predicted: $ [3.11]   Actual: $ 2.99   Delta:$ [0.124804]   Trade Rng: $ 0.06
# Close 3.05 Predicted: $ [3.03]   Actual: $ 3.05   Delta:$ [0.02384]   Trade Rng: $ 0.18
# Close 2.85 Predicted: $ [2.76]   Actual: $ 2.85   Delta:$ [0.093671]   Trade Rng: $ 0.18
# Close 2.88 Predicted: $ [3.07]   Actual: $ 2.88   Delta:$ [0.187266]   Trade Rng: $ 0.08
# Close 2.92 Predicted: $ [2.88]   Actual: $ 2.92   Delta:$ [0.039944]   Trade Rng: $ 0.17
# Close 2.77 Predicted: $ [2.69]   Actual: $ 2.77   Delta:$ [0.082991]   Trade Rng: $ 0.29
# Close 2.79 Predicted: $ [2.96]   Actual: $ 2.79   Delta:$ [0.170572]   Trade Rng: $ 0.22
# Close 2.68 Predicted: $ [2.72]   Actual: $ 2.68   Delta:$ [0.035633]   Trade Rng: $ 0.22
# Close 2.6 Predicted: $ [2.81]   Actual: $ 2.6   Delta:$ [0.212872]   Trade Rng: $ 0.08
# Close 2.51 Predicted: $ [2.7]   Actual: $ 2.51   Delta:$ [0.186113]   Trade Rng: $ 0.12
# Close 2.6 Predicted: $ [2.75]   Actual: $ 2.6   Delta:$ [0.1538]   Trade Rng: $ 0.13
# Close 2.6 Predicted: $ [2.53]   Actual: $ 2.6   Delta:$ [0.065765]   Trade Rng: $ 0.1
# Close 2.61 Predicted: $ [2.62]   Actual: $ 2.61   Delta:$ [0.013731]   Trade Rng: $ 0.06
# Close 2.62 Predicted: $ [2.61]   Actual: $ 2.62   Delta:$ [0.014108]   Trade Rng: $ 0.06
# Close 2.52 Predicted: $ [2.48]   Actual: $ 2.52   Delta:$ [0.035016]   Trade Rng: $ 0.13
# Close 2.45 Predicted: $ [2.58]   Actual: $ 2.45   Delta:$ [0.125285]   Trade Rng: $ 0.09
# Close 2.43 Predicted: $ [2.47]   Actual: $ 2.43   Delta:$ [0.040657]   Trade Rng: $ 0.11
# Close 2.42 Predicted: $ [2.45]   Actual: $ 2.42   Delta:$ [0.033162]   Trade Rng: $ 0.06
# Close 2.46 Predicted: $ [2.47]   Actual: $ 2.46   Delta:$ [0.006767]   Trade Rng: $ 0.07
# Close 2.44 Predicted: $ [2.47]   Actual: $ 2.44   Delta:$ [0.027434]   Trade Rng: $ 0.06
# Close 2.55 Predicted: $ [2.57]   Actual: $ 2.55   Delta:$ [0.020278]   Trade Rng: $ 0.15
# Close 2.53 Predicted: $ [2.45]   Actual: $ 2.53   Delta:$ [0.081257]   Trade Rng: $ 0.05
# Close 2.59 Predicted: $ [2.55]   Actual: $ 2.59   Delta:$ [0.039431]   Trade Rng: $ 0.11
# Close 2.58 Predicted: $ [2.46]   Actual: $ 2.58   Delta:$ [0.119432]   Trade Rng: $ 0.09
# Close 2.52 Predicted: $ [2.6]   Actual: $ 2.52   Delta:$ [0.076309]   Trade Rng: $ 0.11
# Close 2.51 Predicted: $ [2.58]   Actual: $ 2.51   Delta:$ [0.073061]   Trade Rng: $ 0.09
# Close 2.53 Predicted: $ [2.54]   Actual: $ 2.53   Delta:$ [0.014402]   Trade Rng: $ 0.06
# Close 2.52 Predicted: $ [2.52]   Actual: $ 2.52   Delta:$ [0.004445]   Trade Rng: $ 0.13
# Close 2.7 Predicted: $ [2.65]   Actual: $ 2.7   Delta:$ [0.052854]   Trade Rng: $ 0.24
# Close 2.59 Predicted: $ [2.43]   Actual: $ 2.59   Delta:$ [0.161619]   Trade Rng: $ 0.2
# Close 2.62 Predicted: $ [2.78]   Actual: $ 2.62   Delta:$ [0.158602]   Trade Rng: $ 0.14
# Close 2.62 Predicted: $ [2.69]   Actual: $ 2.62   Delta:$ [0.071601]   Trade Rng: $ 0.33
# Close 2.34 Predicted: $ [2.41]   Actual: $ 2.34   Delta:$ [0.072855]   Trade Rng: $ 0.16
# Close 2.32 Predicted: $ [2.73]   Actual: $ 2.32   Delta:$ [0.405056]   Trade Rng: $ 0.08
# Close 2.28 Predicted: $ [2.37]   Actual: $ 2.28   Delta:$ [0.094093]   Trade Rng: $ 0.09
# Close 2.27 Predicted: $ [2.29]   Actual: $ 2.27   Delta:$ [0.024711]   Trade Rng: $ 0.05
# Close 2.24 Predicted: $ [2.23]   Actual: $ 2.24   Delta:$ [0.008319]   Trade Rng: $ 0.07
# Close 2.1 Predicted: $ [2.15]   Actual: $ 2.1   Delta:$ [0.050211]   Trade Rng: $ 0.16
# Close 2.11 Predicted: $ [2.3]   Actual: $ 2.11   Delta:$ [0.186687]   Trade Rng: $ 0.1
# Close 2.16 Predicted: $ [2.18]   Actual: $ 2.16   Delta:$ [0.02094]   Trade Rng: $ 0.07
# Close 2.14 Predicted: $ [2.11]   Actual: $ 2.14   Delta:$ [0.02902]   Trade Rng: $ 0.04
# Close 2.13 Predicted: $ [2.14]   Actual: $ 2.13   Delta:$ [0.008648]   Trade Rng: $ 0.07
# Close 2.07 Predicted: $ [2.11]   Actual: $ 2.07   Delta:$ [0.039057]   Trade Rng: $ 0.09
# Close 2.11 Predicted: $ [2.17]   Actual: $ 2.11   Delta:$ [0.061479]   Trade Rng: $ 0.04
# Close 2.1 Predicted: $ [2.1]   Actual: $ 2.1   Delta:$ [0.000836]   Trade Rng: $ 0.04
# Close 2.05 Predicted: $ [2.08]   Actual: $ 2.05   Delta:$ [0.03112]   Trade Rng: $ 0.08
# Close 2.02 Predicted: $ [2.11]   Actual: $ 2.02   Delta:$ [0.085736]   Trade Rng: $ 0.15
# Close 1.99 Predicted: $ [2.06]   Actual: $ 1.99   Delta:$ [0.067869]   Trade Rng: $ 0.08
# Close 2.01 Predicted: $ [2.07]   Actual: $ 2.01   Delta:$ [0.061486]   Trade Rng: $ 0.07
# Close 2.02 Predicted: $ [2.]   Actual: $ 2.02   Delta:$ [0.021981]   Trade Rng: $ 0.06
# Close 1.92 Predicted: $ [1.9]   Actual: $ 1.92   Delta:$ [0.020632]   Trade Rng: $ 0.08
# Close 1.87 Predicted: $ [1.98]   Actual: $ 1.87   Delta:$ [0.112639]   Trade Rng: $ 0.1
# Close 1.87 Predicted: $ [1.99]   Actual: $ 1.87   Delta:$ [0.116473]   Trade Rng: $ 0.05
# Close 1.89 Predicted: $ [1.92]   Actual: $ 1.89   Delta:$ [0.027282]   Trade Rng: $ 0.05
# Close 1.89 Predicted: $ [1.85]   Actual: $ 1.89   Delta:$ [0.036157]   Trade Rng: $ 0.04
# Close 1.87 Predicted: $ [1.82]   Actual: $ 1.87   Delta:$ [0.047632]   Trade Rng: $ 0.05
# Close 1.84 Predicted: $ [1.88]   Actual: $ 1.84   Delta:$ [0.043178]   Trade Rng: $ 0.08
# Close 1.87 Predicted: $ [1.92]   Actual: $ 1.87   Delta:$ [0.049704]   Trade Rng: $ 0.12
# Close 1.9 Predicted: $ [1.91]   Actual: $ 1.9   Delta:$ [0.005457]   Trade Rng: $ 0.06
# Close 1.89 Predicted: $ [1.84]   Actual: $ 1.89   Delta:$ [0.045605]   Trade Rng: $ 0.07
# Close 1.89 Predicted: $ [1.91]   Actual: $ 1.89   Delta:$ [0.021839]   Trade Rng: $ 0.1
# Close 1.92 Predicted: $ [1.89]   Actual: $ 1.92   Delta:$ [0.031287]   Trade Rng: $ 0.07
# Close 1.87 Predicted: $ [1.83]   Actual: $ 1.87   Delta:$ [0.035295]   Trade Rng: $ 0.08
# Close 1.81 Predicted: $ [1.83]   Actual: $ 1.81   Delta:$ [0.017563]   Trade Rng: $ 0.09
# Close 1.78 Predicted: $ [1.87]   Actual: $ 1.78   Delta:$ [0.093215]   Trade Rng: $ 0.08
# Close 1.83 Predicted: $ [1.89]   Actual: $ 1.83   Delta:$ [0.056861]   Trade Rng: $ 0.06
# Close 1.84 Predicted: $ [1.8]   Actual: $ 1.84   Delta:$ [0.043036]   Trade Rng: $ 0.05
# Close 1.78 Predicted: $ [1.72]   Actual: $ 1.78   Delta:$ [0.057117]   Trade Rng: $ 0.11
# Close 1.75 Predicted: $ [1.84]   Actual: $ 1.75   Delta:$ [0.092852]   Trade Rng: $ 0.06
# Close 1.8 Predicted: $ [1.85]   Actual: $ 1.8   Delta:$ [0.052894]   Trade Rng: $ 0.08
# Close 1.76 Predicted: $ [1.74]   Actual: $ 1.76   Delta:$ [0.023935]   Trade Rng: $ 0.09
# Close 1.72 Predicted: $ [1.76]   Actual: $ 1.72   Delta:$ [0.039496]   Trade Rng: $ 0.07
# Close 1.75 Predicted: $ [1.79]   Actual: $ 1.75   Delta:$ [0.04333]   Trade Rng: $ 0.06
# Close 1.73 Predicted: $ [1.74]   Actual: $ 1.73   Delta:$ [0.014738]   Trade Rng: $ 0.06
# Close 1.67 Predicted: $ [1.73]   Actual: $ 1.67   Delta:$ [0.055086]   Trade Rng: $ 0.11
# Close 1.68 Predicted: $ [1.76]   Actual: $ 1.68   Delta:$ [0.082967]   Trade Rng: $ 0.05
# Close 1.72 Predicted: $ [1.72]   Actual: $ 1.72   Delta:$ [0.002911]   Trade Rng: $ 0.13
# Close 1.83 Predicted: $ [1.72]   Actual: $ 1.83   Delta:$ [0.108547]   Trade Rng: $ 0.18
# Close 1.71 Predicted: $ [1.56]   Actual: $ 1.71   Delta:$ [0.150427]   Trade Rng: $ 0.11
# Close 1.67 Predicted: $ [1.82]   Actual: $ 1.67   Delta:$ [0.15456]   Trade Rng: $ 0.08
# Close 1.7 Predicted: $ [1.82]   Actual: $ 1.7   Delta:$ [0.12349]   Trade Rng: $ 0.12
# Close 1.67 Predicted: $ [1.73]   Actual: $ 1.67   Delta:$ [0.064951]   Trade Rng: $ 0.06
# Close 1.68 Predicted: $ [1.75]   Actual: $ 1.68   Delta:$ [0.069283]   Trade Rng: $ 0.08
# Close 1.68 Predicted: $ [1.71]   Actual: $ 1.68   Delta:$ [0.029549]   Trade Rng: $ 0.07
# Close 1.7 Predicted: $ [1.69]   Actual: $ 1.7   Delta:$ [0.011923]   Trade Rng: $ 0.07
# Close 1.64 Predicted: $ [1.65]   Actual: $ 1.64   Delta:$ [0.011842]   Trade Rng: $ 0.13
# Close 1.56 Predicted: $ [1.78]   Actual: $ 1.56   Delta:$ [0.22273]   Trade Rng: $ 0.06
# Close 1.62 Predicted: $ [1.66]   Actual: $ 1.62   Delta:$ [0.043371]   Trade Rng: $ 0.04
# Close 1.64 Predicted: $ [1.6]   Actual: $ 1.64   Delta:$ [0.038514]   Trade Rng: $ 0.11
# Close 1.64 Predicted: $ [1.61]   Actual: $ 1.64   Delta:$ [0.026718]   Trade Rng: $ 0.07
# Close 1.63 Predicted: $ [1.66]   Actual: $ 1.63   Delta:$ [0.029053]   Trade Rng: $ 0.07
# Close 1.65 Predicted: $ [1.7]   Actual: $ 1.65   Delta:$ [0.045524]   Trade Rng: $ 0.04
# Close 1.65 Predicted: $ [1.65]   Actual: $ 1.65   Delta:$ [0.00139]   Trade Rng: $ 0.05
# Close 1.77 Predicted: $ [1.77]   Actual: $ 1.77   Delta:$ [0.004331]   Trade Rng: $ 0.12
# Close 1.84 Predicted: $ [1.71]   Actual: $ 1.84   Delta:$ [0.126793]   Trade Rng: $ 0.08
# Close 1.85 Predicted: $ [1.69]   Actual: $ 1.85   Delta:$ [0.158193]   Trade Rng: $ 0.05
# Close 1.86 Predicted: $ [1.89]   Actual: $ 1.86   Delta:$ [0.025747]   Trade Rng: $ 0.04
# Close 1.95 Predicted: $ [1.82]   Actual: $ 1.95   Delta:$ [0.131516]   Trade Rng: $ 0.09
# Close 1.95 Predicted: $ [1.8]   Actual: $ 1.95   Delta:$ [0.148638]   Trade Rng: $ 0.06
# Close 1.95 Predicted: $ [1.91]   Actual: $ 1.95   Delta:$ [0.041581]   Trade Rng: $ 0.04
# Close 1.95 Predicted: $ [1.98]   Actual: $ 1.95   Delta:$ [0.029289]   Trade Rng: $ 0.08
# Close 2.02 Predicted: $ [2.05]   Actual: $ 2.02   Delta:$ [0.029175]   Trade Rng: $ 0.1
# Close 2.05 Predicted: $ [1.95]   Actual: $ 2.05   Delta:$ [0.099062]   Trade Rng: $ 0.1
# Close 2.02 Predicted: $ [1.96]   Actual: $ 2.02   Delta:$ [0.06251]   Trade Rng: $ 0.08
# Close 1.95 Predicted: $ [1.98]   Actual: $ 1.95   Delta:$ [0.031601]   Trade Rng: $ 0.08
# Close 1.95 Predicted: $ [2.11]   Actual: $ 1.95   Delta:$ [0.164478]   Trade Rng: $ 0.04
# Close 1.96 Predicted: $ [2.05]   Actual: $ 1.96   Delta:$ [0.089731]   Trade Rng: $ 0.04
# Close 1.95 Predicted: $ [1.99]   Actual: $ 1.95   Delta:$ [0.044703]   Trade Rng: $ 0.05
# Close 1.94 Predicted: $ [1.96]   Actual: $ 1.94   Delta:$ [0.024532]   Trade Rng: $ 0.04
# Close 1.91 Predicted: $ [1.94]   Actual: $ 1.91   Delta:$ [0.031946]   Trade Rng: $ 0.08
# Close 1.9 Predicted: $ [1.99]   Actual: $ 1.9   Delta:$ [0.089132]   Trade Rng: $ 0.05
# Close 1.91 Predicted: $ [1.88]   Actual: $ 1.91   Delta:$ [0.027356]   Trade Rng: $ 0.14
# Close 1.91 Predicted: $ [1.91]   Actual: $ 1.91   Delta:$ [0.002008]   Trade Rng: $ 0.07
# Close 1.91 Predicted: $ [1.91]   Actual: $ 1.91   Delta:$ [0.00259]   Trade Rng: $ 0.05
# Close 1.84 Predicted: $ [1.89]   Actual: $ 1.84   Delta:$ [0.045393]   Trade Rng: $ 0.09
# Close 1.83 Predicted: $ [2.01]   Actual: $ 1.83   Delta:$ [0.181476]   Trade Rng: $ 0.04
# Close 1.85 Predicted: $ [1.87]   Actual: $ 1.85   Delta:$ [0.02205]   Trade Rng: $ 0.04
# Close 1.85 Predicted: $ [1.77]   Actual: $ 1.85   Delta:$ [0.081991]   Trade Rng: $ 0.04
# Close 1.78 Predicted: $ [1.73]   Actual: $ 1.78   Delta:$ [0.050743]   Trade Rng: $ 0.08
# Close 1.85 Predicted: $ [1.9]   Actual: $ 1.85   Delta:$ [0.047571]   Trade Rng: $ 0.08
# Close 1.87 Predicted: $ [1.86]   Actual: $ 1.87   Delta:$ [0.010344]   Trade Rng: $ 0.03
# Close 1.9 Predicted: $ [1.91]   Actual: $ 1.9   Delta:$ [0.014691]   Trade Rng: $ 0.07
# Close 1.95 Predicted: $ [1.92]   Actual: $ 1.95   Delta:$ [0.030517]   Trade Rng: $ 0.06
# Close 1.97 Predicted: $ [1.91]   Actual: $ 1.97   Delta:$ [0.064105]   Trade Rng: $ 0.05
# Close 1.95 Predicted: $ [1.93]   Actual: $ 1.95   Delta:$ [0.022679]   Trade Rng: $ 0.06
# Close 1.94 Predicted: $ [1.96]   Actual: $ 1.94   Delta:$ [0.017742]   Trade Rng: $ 0.06
# Close 1.93 Predicted: $ [1.96]   Actual: $ 1.93   Delta:$ [0.028634]   Trade Rng: $ 0.07
# Close 1.93 Predicted: $ [1.94]   Actual: $ 1.93   Delta:$ [0.013154]   Trade Rng: $ 0.05
# Close 1.9 Predicted: $ [1.93]   Actual: $ 1.9   Delta:$ [0.025564]   Trade Rng: $ 0.09
# Close 1.88 Predicted: $ [1.9]   Actual: $ 1.88   Delta:$ [0.019358]   Trade Rng: $ 0.07
# Close 1.88 Predicted: $ [1.92]   Actual: $ 1.88   Delta:$ [0.035063]   Trade Rng: $ 0.05
# Close 1.92 Predicted: $ [1.86]   Actual: $ 1.92   Delta:$ [0.057229]   Trade Rng: $ 0.14
# Close 1.87 Predicted: $ [1.83]   Actual: $ 1.87   Delta:$ [0.042624]   Trade Rng: $ 0.11
# Close 1.88 Predicted: $ [1.9]   Actual: $ 1.88   Delta:$ [0.020148]   Trade Rng: $ 0.1
# Close 1.98 Predicted: $ [1.97]   Actual: $ 1.98   Delta:$ [0.009884]   Trade Rng: $ 0.11
# Close 2.02 Predicted: $ [1.92]   Actual: $ 2.02   Delta:$ [0.095342]   Trade Rng: $ 0.05
# Close 2.06 Predicted: $ [2.02]   Actual: $ 2.06   Delta:$ [0.038198]   Trade Rng: $ 0.07
# Close 2.09 Predicted: $ [2.01]   Actual: $ 2.09   Delta:$ [0.077537]   Trade Rng: $ 0.08
# Close 2.07 Predicted: $ [2.04]   Actual: $ 2.07   Delta:$ [0.0323]   Trade Rng: $ 0.12
# Close 2.13 Predicted: $ [2.19]   Actual: $ 2.13   Delta:$ [0.05772]   Trade Rng: $ 0.07
# Close 2.08 Predicted: $ [2.05]   Actual: $ 2.08   Delta:$ [0.028044]   Trade Rng: $ 0.09
# Close 2.12 Predicted: $ [2.24]   Actual: $ 2.12   Delta:$ [0.117574]   Trade Rng: $ 0.1
# Close 2.1 Predicted: $ [2.09]   Actual: $ 2.1   Delta:$ [0.014181]   Trade Rng: $ 0.09
# Close 2.12 Predicted: $ [2.2]   Actual: $ 2.12   Delta:$ [0.075828]   Trade Rng: $ 0.07
# Close 2.18 Predicted: $ [2.13]   Actual: $ 2.18   Delta:$ [0.054643]   Trade Rng: $ 0.12
# Close 2.02 Predicted: $ [1.95]   Actual: $ 2.02   Delta:$ [0.066813]   Trade Rng: $ 0.2
# Close 2.02 Predicted: $ [2.33]   Actual: $ 2.02   Delta:$ [0.313521]   Trade Rng: $ 0.08
# Close 2.02 Predicted: $ [2.09]   Actual: $ 2.02   Delta:$ [0.066334]   Trade Rng: $ 0.1
# Close 2.07 Predicted: $ [2.14]   Actual: $ 2.07   Delta:$ [0.067018]   Trade Rng: $ 0.1
# Close 2.06 Predicted: $ [2.06]   Actual: $ 2.06   Delta:$ [0.001685]   Trade Rng: $ 0.08
# Close 2.03 Predicted: $ [2.05]   Actual: $ 2.03   Delta:$ [0.015992]   Trade Rng: $ 0.1
# Close 2.11 Predicted: $ [2.16]   Actual: $ 2.11   Delta:$ [0.054405]   Trade Rng: $ 0.1
# Close 2.11 Predicted: $ [2.02]   Actual: $ 2.11   Delta:$ [0.085523]   Trade Rng: $ 0.07
# Close 2.18 Predicted: $ [2.16]   Actual: $ 2.18   Delta:$ [0.022635]   Trade Rng: $ 0.13
# Close 2.2 Predicted: $ [2.12]   Actual: $ 2.2   Delta:$ [0.077586]   Trade Rng: $ 0.11
# Close 2.2 Predicted: $ [2.18]   Actual: $ 2.2   Delta:$ [0.019815]   Trade Rng: $ 0.12
# Close 2.23 Predicted: $ [2.22]   Actual: $ 2.23   Delta:$ [0.005269]   Trade Rng: $ 0.11
# Close 2.32 Predicted: $ [2.27]   Actual: $ 2.32   Delta:$ [0.052613]   Trade Rng: $ 0.18
# Close 2.35 Predicted: $ [2.19]   Actual: $ 2.35   Delta:$ [0.158477]   Trade Rng: $ 0.08
# Close 2.31 Predicted: $ [2.21]   Actual: $ 2.31   Delta:$ [0.097978]   Trade Rng: $ 0.1
# Close 2.23 Predicted: $ [2.25]   Actual: $ 2.23   Delta:$ [0.021165]   Trade Rng: $ 0.16
# Close 2.15 Predicted: $ [2.3]   Actual: $ 2.15   Delta:$ [0.146337]   Trade Rng: $ 0.09
# Close 2.16 Predicted: $ [2.3]   Actual: $ 2.16   Delta:$ [0.144905]   Trade Rng: $ 0.08
# Close 2.15 Predicted: $ [2.22]   Actual: $ 2.15   Delta:$ [0.072728]   Trade Rng: $ 0.11
# Close 2.2 Predicted: $ [2.22]   Actual: $ 2.2   Delta:$ [0.019775]   Trade Rng: $ 0.08
# Close 2.1 Predicted: $ [2.06]   Actual: $ 2.1   Delta:$ [0.036007]   Trade Rng: $ 0.2
# Close 1.92 Predicted: $ [2.08]   Actual: $ 1.92   Delta:$ [0.158991]   Trade Rng: $ 0.23
# Close 1.94 Predicted: $ [2.3]   Actual: $ 1.94   Delta:$ [0.359838]   Trade Rng: $ 0.07
# Close 1.9 Predicted: $ [1.95]   Actual: $ 1.9   Delta:$ [0.054562]   Trade Rng: $ 0.09
# Close 1.89 Predicted: $ [1.95]   Actual: $ 1.89   Delta:$ [0.058551]   Trade Rng: $ 0.05
# Close 1.97 Predicted: $ [1.99]   Actual: $ 1.97   Delta:$ [0.02049]   Trade Rng: $ 0.09
# Close 1.96 Predicted: $ [1.86]   Actual: $ 1.96   Delta:$ [0.104637]   Trade Rng: $ 0.07
# Close 1.99 Predicted: $ [2.08]   Actual: $ 1.99   Delta:$ [0.089016]   Trade Rng: $ 0.04
# Close 2.06 Predicted: $ [1.95]   Actual: $ 2.06   Delta:$ [0.112845]   Trade Rng: $ 0.07
# Close 2.02 Predicted: $ [1.98]   Actual: $ 2.02   Delta:$ [0.043246]   Trade Rng: $ 0.07
# Close 2.03 Predicted: $ [2.07]   Actual: $ 2.03   Delta:$ [0.043772]   Trade Rng: $ 0.16
# Close 2.04 Predicted: $ [2.07]   Actual: $ 2.04   Delta:$ [0.031913]   Trade Rng: $ 0.11
# Close 2.14 Predicted: $ [2.08]   Actual: $ 2.14   Delta:$ [0.058541]   Trade Rng: $ 0.11
# Close 2.1 Predicted: $ [1.98]   Actual: $ 2.1   Delta:$ [0.124782]   Trade Rng: $ 0.04
# Close 2.11 Predicted: $ [2.12]   Actual: $ 2.11   Delta:$ [0.008911]   Trade Rng: $ 0.07
# Close 2.14 Predicted: $ [2.15]   Actual: $ 2.14   Delta:$ [0.012775]   Trade Rng: $ 0.09
# Close 2.05 Predicted: $ [2.07]   Actual: $ 2.05   Delta:$ [0.023249]   Trade Rng: $ 0.1
# Close 1.94 Predicted: $ [2.07]   Actual: $ 1.94   Delta:$ [0.129857]   Trade Rng: $ 0.15
# Close 1.9 Predicted: $ [2.09]   Actual: $ 1.9   Delta:$ [0.185022]   Trade Rng: $ 0.07
# Close 1.87 Predicted: $ [1.98]   Actual: $ 1.87   Delta:$ [0.106532]   Trade Rng: $ 0.07
# Close 1.84 Predicted: $ [1.86]   Actual: $ 1.84   Delta:$ [0.02195]   Trade Rng: $ 0.06
# Close 1.79 Predicted: $ [1.79]   Actual: $ 1.79   Delta:$ [0.002286]   Trade Rng: $ 0.06
# Close 1.78 Predicted: $ [1.84]   Actual: $ 1.78   Delta:$ [0.058727]   Trade Rng: $ 0.08
# Close 1.8 Predicted: $ [1.79]   Actual: $ 1.8   Delta:$ [0.009907]   Trade Rng: $ 0.06
# Close 1.8 Predicted: $ [1.78]   Actual: $ 1.8   Delta:$ [0.022886]   Trade Rng: $ 0.06
# Close 1.8 Predicted: $ [1.83]   Actual: $ 1.8   Delta:$ [0.030835]   Trade Rng: $ 0.06
# Close 1.82 Predicted: $ [1.89]   Actual: $ 1.82   Delta:$ [0.07385]   Trade Rng: $ 0.08
# Close 1.83 Predicted: $ [1.86]   Actual: $ 1.83   Delta:$ [0.032534]   Trade Rng: $ 0.05
# Close 1.78 Predicted: $ [1.79]   Actual: $ 1.78   Delta:$ [0.008918]   Trade Rng: $ 0.05
# Close 1.79 Predicted: $ [1.88]   Actual: $ 1.79   Delta:$ [0.094645]   Trade Rng: $ 0.03
# Close 1.78 Predicted: $ [1.72]   Actual: $ 1.78   Delta:$ [0.060498]   Trade Rng: $ 0.06
# Close 1.73 Predicted: $ [1.73]   Actual: $ 1.73   Delta:$ [0.001373]   Trade Rng: $ 0.1
# Close 1.74 Predicted: $ [1.76]   Actual: $ 1.74   Delta:$ [0.021222]   Trade Rng: $ 0.04
# Close 1.73 Predicted: $ [1.78]   Actual: $ 1.73   Delta:$ [0.048069]   Trade Rng: $ 0.05
# Close 1.74 Predicted: $ [1.75]   Actual: $ 1.74   Delta:$ [0.011739]   Trade Rng: $ 0.04
# Close 1.71 Predicted: $ [1.69]   Actual: $ 1.71   Delta:$ [0.01781]   Trade Rng: $ 0.08
# Close 1.75 Predicted: $ [1.74]   Actual: $ 1.75   Delta:$ [0.0146]   Trade Rng: $ 0.06
# Close 1.8 Predicted: $ [1.7]   Actual: $ 1.8   Delta:$ [0.09835]   Trade Rng: $ 0.11
# Close 1.77 Predicted: $ [1.66]   Actual: $ 1.77   Delta:$ [0.10894]   Trade Rng: $ 0.08
# Close 1.77 Predicted: $ [1.8]   Actual: $ 1.77   Delta:$ [0.031033]   Trade Rng: $ 0.06
# Close 1.8 Predicted: $ [1.87]   Actual: $ 1.8   Delta:$ [0.07395]   Trade Rng: $ 0.07
# Close 1.79 Predicted: $ [1.82]   Actual: $ 1.79   Delta:$ [0.032581]   Trade Rng: $ 0.07
# Close 1.87 Predicted: $ [1.87]   Actual: $ 1.87   Delta:$ [0.00038]   Trade Rng: $ 0.08
# Close 1.95 Predicted: $ [1.8]   Actual: $ 1.95   Delta:$ [0.150578]   Trade Rng: $ 0.22
# Close 1.82 Predicted: $ [1.7]   Actual: $ 1.82   Delta:$ [0.123638]   Trade Rng: $ 0.15
# Close 1.77 Predicted: $ [2.1]   Actual: $ 1.77   Delta:$ [0.32873]   Trade Rng: $ 0.07
# Close 1.77 Predicted: $ [1.89]   Actual: $ 1.77   Delta:$ [0.120154]   Trade Rng: $ 0.05
# Close 1.81 Predicted: $ [1.88]   Actual: $ 1.81   Delta:$ [0.068014]   Trade Rng: $ 0.06
# Close 1.82 Predicted: $ [1.8]   Actual: $ 1.82   Delta:$ [0.020373]   Trade Rng: $ 0.08
# Close 1.84 Predicted: $ [1.82]   Actual: $ 1.84   Delta:$ [0.01829]   Trade Rng: $ 0.04
# Close 1.88 Predicted: $ [1.82]   Actual: $ 1.88   Delta:$ [0.062982]   Trade Rng: $ 0.13
# Close 1.82 Predicted: $ [1.77]   Actual: $ 1.82   Delta:$ [0.050503]   Trade Rng: $ 0.1
# Close 1.69 Predicted: $ [1.79]   Actual: $ 1.69   Delta:$ [0.098637]   Trade Rng: $ 0.17
# Close 1.68 Predicted: $ [1.91]   Actual: $ 1.68   Delta:$ [0.233658]   Trade Rng: $ 0.05
# Close 1.69 Predicted: $ [1.78]   Actual: $ 1.69   Delta:$ [0.090486]   Trade Rng: $ 0.04
# Close 1.68 Predicted: $ [1.63]   Actual: $ 1.68   Delta:$ [0.0529]   Trade Rng: $ 0.07
# Close 1.66 Predicted: $ [1.62]   Actual: $ 1.66   Delta:$ [0.038342]   Trade Rng: $ 0.04
# Close 1.68 Predicted: $ [1.63]   Actual: $ 1.68   Delta:$ [0.052541]   Trade Rng: $ 0.04
# Close 1.66 Predicted: $ [1.68]   Actual: $ 1.66   Delta:$ [0.019032]   Trade Rng: $ 0.07
# Close 1.7 Predicted: $ [1.7]   Actual: $ 1.7   Delta:$ [0.001059]   Trade Rng: $ 0.07
# Close 1.65 Predicted: $ [1.65]   Actual: $ 1.65   Delta:$ [0.001365]   Trade Rng: $ 0.07
# Close 1.69 Predicted: $ [1.76]   Actual: $ 1.69   Delta:$ [0.067109]   Trade Rng: $ 0.07
# Close 1.67 Predicted: $ [1.71]   Actual: $ 1.67   Delta:$ [0.036808]   Trade Rng: $ 0.07
# Close 1.66 Predicted: $ [1.69]   Actual: $ 1.66   Delta:$ [0.029322]   Trade Rng: $ 0.04
# Close 1.68 Predicted: $ [1.71]   Actual: $ 1.68   Delta:$ [0.034054]   Trade Rng: $ 0.03
# Close 1.69 Predicted: $ [1.63]   Actual: $ 1.69   Delta:$ [0.056115]   Trade Rng: $ 0.05
# Close 1.61 Predicted: $ [1.59]   Actual: $ 1.61   Delta:$ [0.015503]   Trade Rng: $ 0.11
# Close 1.63 Predicted: $ [1.71]   Actual: $ 1.63   Delta:$ [0.083277]   Trade Rng: $ 0.03
# Close 1.63 Predicted: $ [1.67]   Actual: $ 1.63   Delta:$ [0.035179]   Trade Rng: $ 0.04
# Close 1.63 Predicted: $ [1.67]   Actual: $ 1.63   Delta:$ [0.040201]   Trade Rng: $ 0.06
# Close 1.67 Predicted: $ [1.72]   Actual: $ 1.67   Delta:$ [0.050939]   Trade Rng: $ 0.04
# Close 1.63 Predicted: $ [1.57]   Actual: $ 1.63   Delta:$ [0.055957]   Trade Rng: $ 0.06
# Close 1.56 Predicted: $ [1.67]   Actual: $ 1.56   Delta:$ [0.10856]   Trade Rng: $ 0.05
# Close 1.68 Predicted: $ [1.89]   Actual: $ 1.68   Delta:$ [0.213956]   Trade Rng: $ 0.13
# Close 1.68 Predicted: $ [1.55]   Actual: $ 1.68   Delta:$ [0.134412]   Trade Rng: $ 0.06
# Close 1.7 Predicted: $ [1.76]   Actual: $ 1.7   Delta:$ [0.063064]   Trade Rng: $ 0.07
# Close 1.68 Predicted: $ [1.64]   Actual: $ 1.68   Delta:$ [0.044101]   Trade Rng: $ 0.04
# Close 1.71 Predicted: $ [1.74]   Actual: $ 1.71   Delta:$ [0.027498]   Trade Rng: $ 0.05
# Close 1.75 Predicted: $ [1.75]   Actual: $ 1.75   Delta:$ [0.000892]   Trade Rng: $ 0.05
# Close 1.75 Predicted: $ [1.71]   Actual: $ 1.75   Delta:$ [0.038666]   Trade Rng: $ 0.05
# Close 1.74 Predicted: $ [1.7]   Actual: $ 1.74   Delta:$ [0.038741]   Trade Rng: $ 0.04
# Close 1.76 Predicted: $ [1.74]   Actual: $ 1.76   Delta:$ [0.021772]   Trade Rng: $ 0.04
# Close 1.8 Predicted: $ [1.74]   Actual: $ 1.8   Delta:$ [0.059066]   Trade Rng: $ 0.05
# Close 1.78 Predicted: $ [1.74]   Actual: $ 1.78   Delta:$ [0.044236]   Trade Rng: $ 0.02
# Close 1.8 Predicted: $ [1.84]   Actual: $ 1.8   Delta:$ [0.038077]   Trade Rng: $ 0.04
# Close 1.85 Predicted: $ [1.8]   Actual: $ 1.85   Delta:$ [0.048937]   Trade Rng: $ 0.06
# Close 1.82 Predicted: $ [1.78]   Actual: $ 1.82   Delta:$ [0.037885]   Trade Rng: $ 0.06
# Close 1.84 Predicted: $ [1.87]   Actual: $ 1.84   Delta:$ [0.033546]   Trade Rng: $ 0.05
# Close 1.86 Predicted: $ [1.89]   Actual: $ 1.86   Delta:$ [0.034804]   Trade Rng: $ 0.06
# Close 1.88 Predicted: $ [1.88]   Actual: $ 1.88   Delta:$ [0.003457]   Trade Rng: $ 0.05
# Close 1.9 Predicted: $ [1.85]   Actual: $ 1.9   Delta:$ [0.05287]   Trade Rng: $ 0.03
# Close 1.94 Predicted: $ [1.89]   Actual: $ 1.94   Delta:$ [0.054745]   Trade Rng: $ 0.07
# Close 1.9 Predicted: $ [1.82]   Actual: $ 1.9   Delta:$ [0.084462]   Trade Rng: $ 0.05
# Close 1.92 Predicted: $ [2.07]   Actual: $ 1.92   Delta:$ [0.14516]   Trade Rng: $ 0.04
# Close 1.91 Predicted: $ [1.82]   Actual: $ 1.91   Delta:$ [0.092064]   Trade Rng: $ 0.05
# Close 1.92 Predicted: $ [1.87]   Actual: $ 1.92   Delta:$ [0.051229]   Trade Rng: $ 0.05
# Close 1.92 Predicted: $ [1.98]   Actual: $ 1.92   Delta:$ [0.063438]   Trade Rng: $ 0.06
# Close 1.95 Predicted: $ [2.01]   Actual: $ 1.95   Delta:$ [0.055558]   Trade Rng: $ 0.07
# Close 1.92 Predicted: $ [1.99]   Actual: $ 1.92   Delta:$ [0.066822]   Trade Rng: $ 0.05
# Close 2.18 Predicted: $ [2.21]   Actual: $ 2.18   Delta:$ [0.032992]   Trade Rng: $ 0.27
# Close 2.2 Predicted: $ [1.88]   Actual: $ 2.2   Delta:$ [0.32426]   Trade Rng: $ 0.07
# Close 2.17 Predicted: $ [2.06]   Actual: $ 2.17   Delta:$ [0.109503]   Trade Rng: $ 0.04
# Close 2.15 Predicted: $ [2.16]   Actual: $ 2.15   Delta:$ [0.006764]   Trade Rng: $ 0.07
# Close 2.1 Predicted: $ [2.16]   Actual: $ 2.1   Delta:$ [0.05995]   Trade Rng: $ 0.1
# Close 2.08 Predicted: $ [2.14]   Actual: $ 2.08   Delta:$ [0.059399]   Trade Rng: $ 0.03
# Close 2.09 Predicted: $ [2.11]   Actual: $ 2.09   Delta:$ [0.019448]   Trade Rng: $ 0.13
# Close 2.1 Predicted: $ [2.08]   Actual: $ 2.1   Delta:$ [0.018245]   Trade Rng: $ 0.12
# Close 2.15 Predicted: $ [2.09]   Actual: $ 2.15   Delta:$ [0.05561]   Trade Rng: $ 0.09
# Close 2.06 Predicted: $ [2.06]   Actual: $ 2.06   Delta:$ [0.002248]   Trade Rng: $ 0.11
# Close 2.08 Predicted: $ [2.3]   Actual: $ 2.08   Delta:$ [0.222617]   Trade Rng: $ 0.02
# Close 2.07 Predicted: $ [2.02]   Actual: $ 2.07   Delta:$ [0.045504]   Trade Rng: $ 0.08
# Close 2.09 Predicted: $ [2.01]   Actual: $ 2.09   Delta:$ [0.075948]   Trade Rng: $ 0.09
# Close 2.07 Predicted: $ [2.03]   Actual: $ 2.07   Delta:$ [0.0415]   Trade Rng: $ 0.06
# Close 2.13 Predicted: $ [2.15]   Actual: $ 2.13   Delta:$ [0.023395]   Trade Rng: $ 0.07
# Close 2.11 Predicted: $ [2.11]   Actual: $ 2.11   Delta:$ [0.004755]   Trade Rng: $ 0.09
# Close 2.13 Predicted: $ [2.23]   Actual: $ 2.13   Delta:$ [0.098871]   Trade Rng: $ 0.09
# Close 2.17 Predicted: $ [2.18]   Actual: $ 2.17   Delta:$ [0.00846]   Trade Rng: $ 0.05
# Close 2.14 Predicted: $ [2.12]   Actual: $ 2.14   Delta:$ [0.020894]   Trade Rng: $ 0.07
# Close 2.14 Predicted: $ [2.19]   Actual: $ 2.14   Delta:$ [0.048845]   Trade Rng: $ 0.05
# Close 2.13 Predicted: $ [2.16]   Actual: $ 2.13   Delta:$ [0.033215]   Trade Rng: $ 0.05
# Close 2.05 Predicted: $ [2.08]   Actual: $ 2.05   Delta:$ [0.032311]   Trade Rng: $ 0.12
# Close 2.0 Predicted: $ [2.12]   Actual: $ 2.0   Delta:$ [0.119743]   Trade Rng: $ 0.07
# Close 2.02 Predicted: $ [2.1]   Actual: $ 2.02   Delta:$ [0.08093]   Trade Rng: $ 0.05
# Close 1.98 Predicted: $ [1.95]   Actual: $ 1.98   Delta:$ [0.026712]   Trade Rng: $ 0.06
# Close 1.91 Predicted: $ [1.98]   Actual: $ 1.91   Delta:$ [0.065505]   Trade Rng: $ 0.08
# Close 1.92 Predicted: $ [2.06]   Actual: $ 1.92   Delta:$ [0.144284]   Trade Rng: $ 0.04
# Close 1.86 Predicted: $ [1.87]   Actual: $ 1.86   Delta:$ [0.009688]   Trade Rng: $ 0.1
# Close 1.87 Predicted: $ [1.94]   Actual: $ 1.87   Delta:$ [0.067354]   Trade Rng: $ 0.06
# Close 1.9 Predicted: $ [1.93]   Actual: $ 1.9   Delta:$ [0.025304]   Trade Rng: $ 0.05
# Close 1.93 Predicted: $ [1.91]   Actual: $ 1.93   Delta:$ [0.024179]   Trade Rng: $ 0.07
# Close 1.97 Predicted: $ [1.89]   Actual: $ 1.97   Delta:$ [0.07576]   Trade Rng: $ 0.09
# Close 1.95 Predicted: $ [1.88]   Actual: $ 1.95   Delta:$ [0.073935]   Trade Rng: $ 0.07
# Close 1.95 Predicted: $ [1.89]   Actual: $ 1.95   Delta:$ [0.062298]   Trade Rng: $ 0.06
# Close 1.89 Predicted: $ [1.89]   Actual: $ 1.89   Delta:$ [0.004974]   Trade Rng: $ 0.09
# Close 1.92 Predicted: $ [1.99]   Actual: $ 1.92   Delta:$ [0.069964]   Trade Rng: $ 0.07
# Close 1.96 Predicted: $ [2.03]   Actual: $ 1.96   Delta:$ [0.067479]   Trade Rng: $ 0.09
# Close 2.02 Predicted: $ [1.94]   Actual: $ 2.02   Delta:$ [0.075198]   Trade Rng: $ 0.1
# Close 1.9 Predicted: $ [1.83]   Actual: $ 1.9   Delta:$ [0.067249]   Trade Rng: $ 0.09
# Close 2.03 Predicted: $ [2.32]   Actual: $ 2.03   Delta:$ [0.293498]   Trade Rng: $ 0.18
# Close 2.03 Predicted: $ [1.91]   Actual: $ 2.03   Delta:$ [0.122776]   Trade Rng: $ 0.05
# Close 1.97 Predicted: $ [1.95]   Actual: $ 1.97   Delta:$ [0.021823]   Trade Rng: $ 0.12
# Close 1.95 Predicted: $ [2.11]   Actual: $ 1.95   Delta:$ [0.162845]   Trade Rng: $ 0.04
# Close 2.02 Predicted: $ [2.08]   Actual: $ 2.02   Delta:$ [0.05572]   Trade Rng: $ 0.07
# Close 1.99 Predicted: $ [1.96]   Actual: $ 1.99   Delta:$ [0.026189]   Trade Rng: $ 0.1
# Close 1.99 Predicted: $ [2.07]   Actual: $ 1.99   Delta:$ [0.081946]   Trade Rng: $ 0.08
# Close 1.96 Predicted: $ [1.97]   Actual: $ 1.96   Delta:$ [0.013368]   Trade Rng: $ 0.05
# Close 1.95 Predicted: $ [1.98]   Actual: $ 1.95   Delta:$ [0.027543]   Trade Rng: $ 0.04
# Close 1.93 Predicted: $ [1.93]   Actual: $ 1.93   Delta:$ [0.000865]   Trade Rng: $ 0.05
# Close 1.89 Predicted: $ [1.89]   Actual: $ 1.89   Delta:$ [0.001657]   Trade Rng: $ 0.06
# Close 1.87 Predicted: $ [1.9]   Actual: $ 1.87   Delta:$ [0.027824]   Trade Rng: $ 0.04
# Close 1.86 Predicted: $ [1.9]   Actual: $ 1.86   Delta:$ [0.039088]   Trade Rng: $ 0.05
# Close 1.85 Predicted: $ [1.87]   Actual: $ 1.85   Delta:$ [0.024386]   Trade Rng: $ 0.07
# Close 1.81 Predicted: $ [1.85]   Actual: $ 1.81   Delta:$ [0.038862]   Trade Rng: $ 0.06
# Close 1.87 Predicted: $ [1.91]   Actual: $ 1.87   Delta:$ [0.036483]   Trade Rng: $ 0.09
# Close 1.9 Predicted: $ [1.86]   Actual: $ 1.9   Delta:$ [0.042543]   Trade Rng: $ 0.04
# Close 1.92 Predicted: $ [1.83]   Actual: $ 1.92   Delta:$ [0.091753]   Trade Rng: $ 0.06
# Close 1.86 Predicted: $ [1.79]   Actual: $ 1.86   Delta:$ [0.067321]   Trade Rng: $ 0.09
# Close 1.86 Predicted: $ [1.96]   Actual: $ 1.86   Delta:$ [0.103671]   Trade Rng: $ 0.07
# Close 1.87 Predicted: $ [1.96]   Actual: $ 1.87   Delta:$ [0.093865]   Trade Rng: $ 0.07
# Close 1.8 Predicted: $ [1.85]   Actual: $ 1.8   Delta:$ [0.045741]   Trade Rng: $ 0.06
# Close 1.83 Predicted: $ [1.99]   Actual: $ 1.83   Delta:$ [0.161063]   Trade Rng: $ 0.07
# Close 1.89 Predicted: $ [1.82]   Actual: $ 1.89   Delta:$ [0.071074]   Trade Rng: $ 0.09
# Close 1.75 Predicted: $ [1.6]   Actual: $ 1.75   Delta:$ [0.145558]   Trade Rng: $ 0.08
# Close 1.71 Predicted: $ [2.13]   Actual: $ 1.71   Delta:$ [0.42198]   Trade Rng: $ 0.05
# Close 1.75 Predicted: $ [1.83]   Actual: $ 1.75   Delta:$ [0.079536]   Trade Rng: $ 0.06
# Close 1.79 Predicted: $ [1.77]   Actual: $ 1.79   Delta:$ [0.024714]   Trade Rng: $ 0.07
# Close 1.8 Predicted: $ [1.78]   Actual: $ 1.8   Delta:$ [0.024255]   Trade Rng: $ 0.06
# Close 1.92 Predicted: $ [1.89]   Actual: $ 1.92   Delta:$ [0.030604]   Trade Rng: $ 0.1
# Close 1.89 Predicted: $ [1.84]   Actual: $ 1.89   Delta:$ [0.045868]   Trade Rng: $ 0.05
# Close 1.91 Predicted: $ [1.91]   Actual: $ 1.91   Delta:$ [0.003348]   Trade Rng: $ 0.07
# Close 1.88 Predicted: $ [1.87]   Actual: $ 1.88   Delta:$ [0.008656]   Trade Rng: $ 0.06
# Close 1.89 Predicted: $ [1.93]   Actual: $ 1.89   Delta:$ [0.038826]   Trade Rng: $ 0.06
# Close 1.88 Predicted: $ [1.89]   Actual: $ 1.88   Delta:$ [0.014633]   Trade Rng: $ 0.04
# Close 1.86 Predicted: $ [1.89]   Actual: $ 1.86   Delta:$ [0.028962]   Trade Rng: $ 0.07
# Close 1.82 Predicted: $ [1.87]   Actual: $ 1.82   Delta:$ [0.046068]   Trade Rng: $ 0.08
# Close 1.79 Predicted: $ [1.85]   Actual: $ 1.79   Delta:$ [0.058511]   Trade Rng: $ 0.1
# Close 1.76 Predicted: $ [1.82]   Actual: $ 1.76   Delta:$ [0.057175]   Trade Rng: $ 0.03
# Close 1.76 Predicted: $ [1.83]   Actual: $ 1.76   Delta:$ [0.066652]   Trade Rng: $ 0.05
# Close 1.77 Predicted: $ [1.82]   Actual: $ 1.77   Delta:$ [0.051778]   Trade Rng: $ 0.03
# Close 1.79 Predicted: $ [1.78]   Actual: $ 1.79   Delta:$ [0.006732]   Trade Rng: $ 0.08
# Close 1.76 Predicted: $ [1.7]   Actual: $ 1.76   Delta:$ [0.060744]   Trade Rng: $ 0.05
# Close 1.71 Predicted: $ [1.75]   Actual: $ 1.71   Delta:$ [0.037824]   Trade Rng: $ 0.06
# Close 1.76 Predicted: $ [1.83]   Actual: $ 1.76   Delta:$ [0.071421]   Trade Rng: $ 0.06
# Close 1.81 Predicted: $ [1.75]   Actual: $ 1.81   Delta:$ [0.058267]   Trade Rng: $ 0.08
# Close 1.85 Predicted: $ [1.74]   Actual: $ 1.85   Delta:$ [0.107787]   Trade Rng: $ 0.07
# Close 1.87 Predicted: $ [1.72]   Actual: $ 1.87   Delta:$ [0.145792]   Trade Rng: $ 0.06
# Close 1.82 Predicted: $ [1.77]   Actual: $ 1.82   Delta:$ [0.052297]   Trade Rng: $ 0.06
# Close 1.83 Predicted: $ [1.86]   Actual: $ 1.83   Delta:$ [0.029979]   Trade Rng: $ 0.06
# Close 1.84 Predicted: $ [1.89]   Actual: $ 1.84   Delta:$ [0.045449]   Trade Rng: $ 0.08
# Close 1.92 Predicted: $ [1.89]   Actual: $ 1.92   Delta:$ [0.031527]   Trade Rng: $ 0.14
# Close 1.89 Predicted: $ [1.83]   Actual: $ 1.89   Delta:$ [0.064525]   Trade Rng: $ 0.09
# Close 1.88 Predicted: $ [1.88]   Actual: $ 1.88   Delta:$ [0.003603]   Trade Rng: $ 0.08
# Close 1.91 Predicted: $ [1.94]   Actual: $ 1.91   Delta:$ [0.029564]   Trade Rng: $ 0.08
# Close 1.98 Predicted: $ [1.99]   Actual: $ 1.98   Delta:$ [0.008945]   Trade Rng: $ 0.06
# Close 2.07 Predicted: $ [1.98]   Actual: $ 2.07   Delta:$ [0.092114]   Trade Rng: $ 0.07
# Close 2.09 Predicted: $ [1.94]   Actual: $ 2.09   Delta:$ [0.153185]   Trade Rng: $ 0.08
# Close 2.05 Predicted: $ [2.]   Actual: $ 2.05   Delta:$ [0.05186]   Trade Rng: $ 0.09
# Close 2.08 Predicted: $ [2.15]   Actual: $ 2.08   Delta:$ [0.068007]   Trade Rng: $ 0.08
# Close 2.09 Predicted: $ [2.08]   Actual: $ 2.09   Delta:$ [0.008431]   Trade Rng: $ 0.07
# Close 2.12 Predicted: $ [2.1]   Actual: $ 2.12   Delta:$ [0.022998]   Trade Rng: $ 0.05
# Close 2.12 Predicted: $ [2.08]   Actual: $ 2.12   Delta:$ [0.042818]   Trade Rng: $ 0.05
# Close 2.13 Predicted: $ [2.14]   Actual: $ 2.13   Delta:$ [0.011572]   Trade Rng: $ 0.05
# Mean Trading Range: $ 0.09
# Mean Delta (Actual vs Prediction): $ 0.07

# %% [markdown]
# ### - Deltas between predicted price and actual price

# %%
# Calculate an array of deltas between predicted price and actual price
print("Std Dev -     Pred: ", pred_delta.std())
y_pa_delta = abs(y_test - y_p_adj)
print("Std Dev - Pred Adj: ", y_pa_delta.std())
print("Better by", (y_p_delta.std() / y_pa_delta.std()), "Standard Deviations")
# Out:
# Std Dev -     Pred:  0.0
# Std Dev - Pred Adj:  0.004827828428919889
# Better by 1.9686092513631546 Standard Deviations

# %% [markdown]
# ### - Deltas between predicted price and actual price

# %%
# Calculate an array of deltas between predicted price and actual price
print("Std Dev -     Pred: ", pred_delta.std())
y_pa_delta = abs(y_test - y_p_adj)
print("Std Dev - Pred Adj: ", y_pa_delta.std())
print("Better by", (y_p_delta.std() / y_pa_delta.std()), "Standard Deviations")
# Out:
# Std Dev -     Pred:  0.0
# Std Dev - Pred Adj:  0.004827828428919889
# Better by 1.9686092513631546 Standard Deviations

# %% [markdown]
# ## - Trend Prediction Stats using Unscaled (v < 1) Adjusted
# ** The stats are not entirely accurate a the adjusted prediction will change when the new close actually occurs
#    and the adjusting process includes the new close in the calculation

# %%
# How often is the prediction within 1% of the actual price?
pct = 0.05
pct_delta = abs(y_test * pct)
delta = abs(y_test - y_p_adj)
within_range = delta[delta < pct_delta]
# Get average price range for the instrument
avg_price_rng = data_set['High'] - data_set['Low']
# Get pct of average price range
pcnt_avg_price_rng = avg_price_rng.mean() * pct

print("Within",pct * 100,"% of Acutal Adj Close","[ Trading Range:$", round(tot_tradrng / elements, 2), 
      " Within Avg Price:", avg_price_rng.mean().round(2), " Average Difference to Actual: $", pcnt_avg_price_rng.round(2),"]", 
      " Pct within Range:", round((len(within_range) / len(y_test)),2) * 100,"%")

# How often is the predicted trend the same as the actual trend?
test_trend = y_test[1:] - y_test[:-1]
pred_trend = y_p_adj[1:] - y_p_adj[:-1]
delta = [1 if (test_trend < 0) and (pred_trend < 0) or (test_trend > 0) and (pred_trend > 0) else 0 for test_trend, pred_trend in zip(test_trend, pred_trend)]
# Print the number of elements in delta and the percent of delta that are 1.
print("Same Trend:", len(delta), "Wrong:", len(delta) - len(within_range)+1, "Right", np.count_nonzero(within_range+1), "%Right", round((len(within_range)-1) / len(delta) * 100,2))
# Out:
# Within 5.0 % of Acutal Adj Close [ Trading Range:$ 0.09  Within Avg Price: 0.12  Average Difference to Actual: $ 0.01 ]  Pct within Range: 95.0 %
# Same Trend: 480 Wrong: 24 Right 457 %Right 95.0

# %% [markdown]
# # Model Details...

# %%
# Review feature importance
# importance = model.coef_

import shap
import pydot

print(X_train.shape)

print(model.summary())

from keras.utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
from IPython.display import Image

pass
# Out:
# (1921, 15, 17)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_input (InputLayer)         │ (None, 15, 17)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ first_layer (LSTM)              │ (None, 200)            │       174,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_layer (Dense)             │ (None, 1)              │           201 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Activation)             │ (None, 1)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 523,805 (2.00 MB)
#  Trainable params: 174,601 (682.04 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 349,204 (1.33 MB)
# None

# %% [markdown]
# ## - Model Plot
# <img src="model_plot.png" alt="Drawing" style="width: 200px;"/>
